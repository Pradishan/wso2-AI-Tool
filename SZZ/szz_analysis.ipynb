# %% [markdown]
# # SZZ analysis

# %% [markdown]
# ## Data preprocessing

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

import pandas as pd
from tqdm import tqdm
from loguru import logger
import concurrent.futures
from pymongo import MongoClient

# GitHub Personal Access Token (optional, but recommended for higher rate limits)
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")
if not GITHUB_TOKEN:
    logger.warning("GitHub token not found. Rate limits may apply.")

# Logger config
logger.add("logs/szz_analysis.log")

# --- Configuration ---
REPO = "ballerina-platform/ballerina-lang"

# %% [markdown]
# Mongo db connection

# %%
# Mongo connection
client = MongoClient("mongodb://localhost:27017/")
db = client.github_data
pull_request_collection = db.pull_requests
logger.info("🔌 MongoDB connected.")
# Out:
# 2025-06-19 11:25:39.694 | INFO     | __main__:<module>:5 - 🔌 MongoDB connected.

# %%
df = pd.read_csv("../data/keyword-linking/pullrequestToIssue/final.csv");
df.head()
# Out:
#    pr_number                                            pr_link  \
# 0      12762  https://github.com/ballerina-platform/ballerin...
# 1      29650  https://github.com/ballerina-platform/ballerin...
# 2      29650  https://github.com/ballerina-platform/ballerin...
# 3      31849  https://github.com/ballerina-platform/ballerin...
# 4      29642  https://github.com/ballerina-platform/ballerin...
#
#                                             pr_title  \
# 0  Add examples for anonymous records and anonymo...
# 1  [LS] Fix invalid type cast being applied for n...
# 2  [LS] Fix invalid type cast being applied for n...
# 3                Fix xml equals check in TypeChecker
# 4                 Fix type check for `ordered` types
#
#                                              pr_body  issue_number  \
# 0                        ## Purpose\r\n> Fix #10825        10825.0
# 1  ## Purpose\r\n$subject\r\n\r\nFixes #29573\r\n...       29428.0
# 2  ## Purpose\r\n$subject\r\n\r\nFixes #29573\r\n...       29573.0
# 3  ## Purpose\r\n$subject\r\nFixes #25709 \r\n\r\...       25709.0
# 4  ## Purpose\r\n$title\r\n\r\nFixes #29643\r\n\r...       29643.0
#
#                                           issue_link
# 0  https://github.com/ballerina-platform/ballerin...
# 1  https://github.com/ballerina-platform/ballerin...
# 2  https://github.com/ballerina-platform/ballerin...
# 3  https://github.com/ballerina-platform/ballerin...
# 4  https://github.com/ballerina-platform/ballerin...

# %% [markdown]
# ### adding the mergecommit

# %%
def find_merge_commit(pr_number, collection):
    """
    Queries MongoDB for a given PR number and returns its merge_commit_sha.

    Args:
        pr_number (int): The pull request number to look up.
        collection: The pymongo collection object to query.

    Returns:
        The merge commit hash as a string, or None if not found or not merged.
    """
    try:
        # Find the PR document in the collection. The 'number' field should store the PR number.
        pr_data = collection.find_one({"pull_request.number": pr_number})

        if not pr_data:
            logger.warning(f"PR #{pr_number}: Not found in the database.")
            return None

        # The 'merged_at' field is a reliable indicator of a merged PR. It's null if not merged.
        if not pr_data["pull_request"].get("merged_at"):
            logger.info(f"PR #{pr_number}: Found in DB, but is not merged. Skipping.")
            return None

        merge_commit_sha = pr_data["pull_request"].get("merge_commit_sha")
        if not merge_commit_sha:
            logger.warning(f"PR #{pr_number}: Is merged, but 'merge_commit_sha' field is missing.")
            return None

        return merge_commit_sha

    except Exception as e:
        logger.error(f"An error occurred while processing PR #{pr_number}: {e}")
        return None

# %%
find_merge_commit(44121, pull_request_collection)
# Out:
# 'b72f76eaa3db59ee54ecfad1d68efde3e4e5d768'

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

logger.info("--- Starting PR Data Enrichment Process ---")

# df = df.head(100)  # Limit to first 1000 rows for testing; remove this line for full dataset

pr_numbers = df['pr_number'].unique().tolist()  # Use unique PR numbers to avoid duplicates
results = {}

# Use ThreadPoolExecutor for concurrent I/O-bound tasks (querying DB)
with ThreadPoolExecutor(max_workers=6) as executor:
    # Create a dictionary to map future to pr_number
    future_to_pr = {executor.submit(find_merge_commit, int(pr), pull_request_collection): pr for pr in pr_numbers}
    
    # Process futures as they complete, with a tqdm progress bar
    for future in tqdm(as_completed(future_to_pr), total=len(pr_numbers), desc="Querying PRs from DB"):
        pr_num = future_to_pr[future]
        try:
            merge_hash = future.result()
            if merge_hash:
                results[pr_num] = merge_hash
            else:
                logger.debug(f"No merge hash found for PR #{pr_num}")
        except Exception as e:
            logger.error(f"A future raised an exception for PR #{pr_num}: {e}")

logger.info(f"Successfully processed all PRs. Found merge hashes for {len(results)} of them.")

# Map the results back to the DataFrame
df['merge_commit_hash'] = df['pr_number'].map(lambda x: results.get(x))

# Filter out rows where the merge commit couldn't be found
original_count = len(df)
df.dropna(subset=['merge_commit_hash'], inplace=True)
final_count = len(df)
logger.success(f"Enrichment complete. Filtered down to {final_count} merged PRs (from {original_count} total).")

# Save the result
output_path = "../data/final/data_with_merge_commit.csv"
df.to_csv(output_path, index=False)
logger.success(f"Data with merge commits saved to {output_path}")
# Out:
# 2025-06-19 11:25:41.101 | INFO     | __main__:<module>:3 - --- Starting PR Data Enrichment Process ---
# 2025-06-19 11:25:41.991 | INFO     | __main__:find_merge_commit:22 - PR #16627: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   0%|          | 0/10635 [00:00<?, ?it/s]2025-06-19 11:25:42.087 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #16627
# Querying PRs from DB:   0%|          | 17/10635 [00:00<01:04, 164.49it/s]2025-06-19 11:25:42.185 | INFO     | __main__:find_merge_commit:22 - PR #12762: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:42.195 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #12762
# 2025-06-19 11:25:42.199 | INFO     | __main__:find_merge_commit:22 - PR #12760: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:42.211 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #12760
# Querying PRs from DB:   1%|          | 57/10635 [00:00<01:46, 98.93it/s] 2025-06-19 11:25:42.588 | INFO     | __main__:find_merge_commit:22 - PR #17887: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:42.593 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #17887
# 2025-06-19 11:25:42.681 | INFO     | __main__:find_merge_commit:22 - PR #37818: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   1%|          | 69/10635 [00:00<01:42, 103.14it/s]2025-06-19 11:25:42.695 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #37818
# Querying PRs from DB:   1%|          | 99/10635 [00:00<01:28, 119.42it/s]2025-06-19 11:25:43.091 | INFO     | __main__:find_merge_commit:22 - PR #5258: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:43.099 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #5258
# 2025-06-19 11:25:43.104 | INFO     | __main__:find_merge_commit:22 - PR #4563: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:43.131 | INFO     | __main__:find_merge_commit:22 - PR #5250: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:43.148 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #4563
# 2025-06-19 11:25:43.156 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #5250
# 2025-06-19 11:25:43.193 | INFO     | __main__:find_merge_commit:22 - PR #5035: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:43.199 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #5035
# Querying PRs from DB:   1%|          | 122/10635 [00:01<02:45, 63.43it/s]2025-06-19 11:25:43.525 | INFO     | __main__:find_merge_commit:22 - PR #22232: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:43.534 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #22232
# Querying PRs from DB:   1%|          | 131/10635 [00:01<02:35, 67.68it/s]2025-06-19 11:25:43.578 | INFO     | __main__:find_merge_commit:22 - PR #22228: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:43.592 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #22228
# Querying PRs from DB:   2%|▏         | 186/10635 [00:02<01:49, 95.30it/s]2025-06-19 11:25:44.184 | INFO     | __main__:find_merge_commit:22 - PR #32697: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:44.201 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32697
# Querying PRs from DB:   2%|▏         | 197/10635 [00:02<01:53, 91.81it/s]2025-06-19 11:25:44.297 | INFO     | __main__:find_merge_commit:22 - PR #12783: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:44.335 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #12783
# Querying PRs from DB:   2%|▏         | 228/10635 [00:02<01:59, 87.12it/s]2025-06-19 11:25:44.703 | INFO     | __main__:find_merge_commit:22 - PR #40335: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:44.711 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40335
# 2025-06-19 11:25:44.744 | INFO     | __main__:find_merge_commit:22 - PR #40339: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:44.752 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40339
# Querying PRs from DB:   2%|▏         | 253/10635 [00:02<01:46, 97.57it/s]2025-06-19 11:25:44.905 | INFO     | __main__:find_merge_commit:22 - PR #40716: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:44.911 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40716
# 2025-06-19 11:25:44.973 | INFO     | __main__:find_merge_commit:22 - PR #41242: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.018 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #41242
# Querying PRs from DB:   2%|▏         | 263/10635 [00:03<01:58, 87.65it/s]2025-06-19 11:25:45.070 | INFO     | __main__:find_merge_commit:22 - PR #5025: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.078 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #5025
# 2025-06-19 11:25:45.091 | INFO     | __main__:find_merge_commit:22 - PR #42577: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.102 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42577
# 2025-06-19 11:25:45.129 | INFO     | __main__:find_merge_commit:22 - PR #35647: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.133 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #35647
# Querying PRs from DB:   3%|▎         | 272/10635 [00:03<02:08, 80.38it/s]2025-06-19 11:25:45.288 | INFO     | __main__:find_merge_commit:22 - PR #29692: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   3%|▎         | 281/10635 [00:03<02:10, 79.39it/s]2025-06-19 11:25:45.311 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29692
# 2025-06-19 11:25:45.368 | INFO     | __main__:find_merge_commit:22 - PR #19287: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.382 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #19287
# Querying PRs from DB:   3%|▎         | 290/10635 [00:03<02:09, 80.14it/s]2025-06-19 11:25:45.467 | INFO     | __main__:find_merge_commit:22 - PR #29697: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.485 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29697
# Querying PRs from DB:   3%|▎         | 302/10635 [00:03<01:54, 89.93it/s]2025-06-19 11:25:45.554 | INFO     | __main__:find_merge_commit:22 - PR #29704: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.575 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29704
# 2025-06-19 11:25:45.616 | INFO     | __main__:find_merge_commit:22 - PR #20155: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.620 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20155
# 2025-06-19 11:25:45.621 | INFO     | __main__:find_merge_commit:22 - PR #29706: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.635 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29706
# Querying PRs from DB:   3%|▎         | 312/10635 [00:03<02:00, 85.35it/s]2025-06-19 11:25:45.678 | INFO     | __main__:find_merge_commit:22 - PR #20157: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.695 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20157
# 2025-06-19 11:25:45.770 | INFO     | __main__:find_merge_commit:22 - PR #14683: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   3%|▎         | 321/10635 [00:03<02:10, 78.99it/s]2025-06-19 11:25:45.784 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14683
# Querying PRs from DB:   3%|▎         | 333/10635 [00:03<01:56, 88.41it/s]2025-06-19 11:25:45.915 | INFO     | __main__:find_merge_commit:22 - PR #24669: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.927 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #24669
# 2025-06-19 11:25:45.955 | INFO     | __main__:find_merge_commit:22 - PR #20836: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:45.969 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20836
# Querying PRs from DB:   3%|▎         | 351/10635 [00:04<02:22, 72.19it/s]2025-06-19 11:25:46.270 | INFO     | __main__:find_merge_commit:22 - PR #32718: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:46.281 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32718
# Querying PRs from DB:   3%|▎         | 361/10635 [00:04<02:11, 78.24it/s]2025-06-19 11:25:46.340 | INFO     | __main__:find_merge_commit:22 - PR #35611: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:46.348 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #35611
# 2025-06-19 11:25:46.384 | INFO     | __main__:find_merge_commit:22 - PR #37803: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:46.388 | INFO     | __main__:find_merge_commit:22 - PR #40362: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   4%|▎         | 374/10635 [00:04<01:52, 91.27it/s]2025-06-19 11:25:46.400 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #37803
# 2025-06-19 11:25:46.412 | INFO     | __main__:find_merge_commit:22 - PR #37802: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:46.416 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40362
# 2025-06-19 11:25:46.436 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #37802
# Querying PRs from DB:   4%|▎         | 393/10635 [00:04<01:27, 117.21it/s]2025-06-19 11:25:46.526 | INFO     | __main__:find_merge_commit:22 - PR #42971: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:46.533 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42971
# 2025-06-19 11:25:46.553 | INFO     | __main__:find_merge_commit:22 - PR #14824: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:46.560 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14824
# Querying PRs from DB:   4%|▍         | 407/10635 [00:04<01:23, 122.50it/s]2025-06-19 11:25:46.697 | INFO     | __main__:find_merge_commit:22 - PR #42956: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:46.702 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42956
# Querying PRs from DB:   4%|▍         | 433/10635 [00:04<01:42, 99.97it/s] 2025-06-19 11:25:46.985 | INFO     | __main__:find_merge_commit:22 - PR #16064: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:47.004 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #16064
# 2025-06-19 11:25:47.035 | INFO     | __main__:find_merge_commit:22 - PR #19278: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:47.046 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #19278
# Querying PRs from DB:   4%|▍         | 455/10635 [00:05<01:52, 90.71it/s]2025-06-19 11:25:47.281 | INFO     | __main__:find_merge_commit:22 - PR #29725: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   4%|▍         | 466/10635 [00:05<01:49, 92.89it/s]2025-06-19 11:25:47.292 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29725
# 2025-06-19 11:25:47.382 | INFO     | __main__:find_merge_commit:22 - PR #22203: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:47.392 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #22203
# Querying PRs from DB:   4%|▍         | 476/10635 [00:05<01:52, 90.52it/s]2025-06-19 11:25:47.502 | INFO     | __main__:find_merge_commit:22 - PR #32762: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   5%|▍         | 491/10635 [00:05<01:36, 105.56it/s]2025-06-19 11:25:47.516 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32762
# Querying PRs from DB:   5%|▍         | 515/10635 [00:05<01:32, 109.69it/s]2025-06-19 11:25:47.816 | INFO     | __main__:find_merge_commit:22 - PR #17995: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:47.820 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #17995
# Querying PRs from DB:   5%|▍         | 527/10635 [00:05<01:32, 109.58it/s]2025-06-19 11:25:47.829 | INFO     | __main__:find_merge_commit:22 - PR #42949: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:47.836 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42949
# 2025-06-19 11:25:47.851 | INFO     | __main__:find_merge_commit:22 - PR #17996: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:47.859 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #17996
# Querying PRs from DB:   5%|▌         | 539/10635 [00:05<01:31, 110.87it/s]2025-06-19 11:25:48.029 | INFO     | __main__:find_merge_commit:22 - PR #12849: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.038 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #12849
# 2025-06-19 11:25:48.087 | INFO     | __main__:find_merge_commit:22 - PR #40393: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   5%|▌         | 551/10635 [00:06<01:46, 94.75it/s] 2025-06-19 11:25:48.109 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40393
# 2025-06-19 11:25:48.113 | INFO     | __main__:find_merge_commit:22 - PR #43020: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.131 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43020
# Querying PRs from DB:   5%|▌         | 571/10635 [00:06<01:26, 115.93it/s]2025-06-19 11:25:48.296 | INFO     | __main__:find_merge_commit:22 - PR #14684: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.311 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14684
# Querying PRs from DB:   5%|▌         | 584/10635 [00:06<01:26, 116.77it/s]2025-06-19 11:25:48.514 | INFO     | __main__:find_merge_commit:22 - PR #14999: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.519 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14999
# Querying PRs from DB:   6%|▌         | 597/10635 [00:06<01:44, 96.35it/s] 2025-06-19 11:25:48.531 | INFO     | __main__:find_merge_commit:22 - PR #19256: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.558 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #19256
# Querying PRs from DB:   6%|▌         | 609/10635 [00:06<01:40, 99.96it/s]2025-06-19 11:25:48.674 | INFO     | __main__:find_merge_commit:22 - PR #24714: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.680 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #24714
# 2025-06-19 11:25:48.708 | INFO     | __main__:find_merge_commit:22 - PR #43032: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.732 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43032
# Querying PRs from DB:   6%|▌         | 627/10635 [00:06<01:24, 117.77it/s]2025-06-19 11:25:48.754 | INFO     | __main__:find_merge_commit:22 - PR #32779: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.760 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32779
# 2025-06-19 11:25:48.807 | INFO     | __main__:find_merge_commit:22 - PR #11221: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.822 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #11221
# 2025-06-19 11:25:48.840 | INFO     | __main__:find_merge_commit:22 - PR #11222: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.844 | INFO     | __main__:find_merge_commit:22 - PR #11218: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.847 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #11222
# 2025-06-19 11:25:48.855 | INFO     | __main__:find_merge_commit:22 - PR #32794: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   6%|▌         | 641/10635 [00:06<01:25, 116.44it/s]2025-06-19 11:25:48.870 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #11218
# 2025-06-19 11:25:48.875 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32794
# 2025-06-19 11:25:48.892 | INFO     | __main__:find_merge_commit:22 - PR #32797: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:48.903 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32797
# Querying PRs from DB:   6%|▌         | 654/10635 [00:06<01:26, 115.49it/s]2025-06-19 11:25:49.004 | INFO     | __main__:find_merge_commit:22 - PR #31763: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:49.013 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #31763
# Querying PRs from DB:   7%|▋         | 698/10635 [00:07<01:27, 113.33it/s]2025-06-19 11:25:49.390 | INFO     | __main__:find_merge_commit:22 - PR #18022: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:49.396 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #18022
# 2025-06-19 11:25:49.448 | INFO     | __main__:find_merge_commit:22 - PR #16596: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:49.457 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #16596
# Querying PRs from DB:   7%|▋         | 723/10635 [00:07<01:29, 110.91it/s]2025-06-19 11:25:49.632 | INFO     | __main__:find_merge_commit:22 - PR #18033: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:49.644 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #18033
# 2025-06-19 11:25:49.647 | INFO     | __main__:find_merge_commit:22 - PR #20228: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:49.665 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20228
# Querying PRs from DB:   7%|▋         | 746/10635 [00:07<01:41, 97.35it/s] 2025-06-19 11:25:49.901 | INFO     | __main__:find_merge_commit:22 - PR #19243: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:49.915 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #19243
# Querying PRs from DB:   7%|▋         | 756/10635 [00:07<01:44, 94.83it/s]2025-06-19 11:25:50.034 | INFO     | __main__:find_merge_commit:22 - PR #43049: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.041 | INFO     | __main__:find_merge_commit:22 - PR #40620: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.041 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43049
# 2025-06-19 11:25:50.048 | INFO     | __main__:find_merge_commit:22 - PR #42936: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.052 | INFO     | __main__:find_merge_commit:22 - PR #43052: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.053 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40620
# 2025-06-19 11:25:50.068 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42936
# 2025-06-19 11:25:50.076 | INFO     | __main__:find_merge_commit:22 - PR #43054: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.078 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43052
# 2025-06-19 11:25:50.081 | INFO     | __main__:find_merge_commit:22 - PR #43053: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   7%|▋         | 766/10635 [00:08<01:56, 84.62it/s]2025-06-19 11:25:50.092 | INFO     | __main__:find_merge_commit:22 - PR #14998: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.128 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43054
# 2025-06-19 11:25:50.151 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43053
# 2025-06-19 11:25:50.174 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14998
# Querying PRs from DB:   7%|▋         | 785/10635 [00:08<01:30, 109.37it/s]2025-06-19 11:25:50.263 | INFO     | __main__:find_merge_commit:22 - PR #6647: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.266 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #6647
# Querying PRs from DB:   7%|▋         | 797/10635 [00:08<01:29, 110.15it/s]2025-06-19 11:25:50.364 | INFO     | __main__:find_merge_commit:22 - PR #18043: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.374 | INFO     | __main__:find_merge_commit:22 - PR #32838: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.375 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #18043
# 2025-06-19 11:25:50.392 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32838
# Querying PRs from DB:   8%|▊         | 809/10635 [00:08<01:30, 108.41it/s]2025-06-19 11:25:50.463 | INFO     | __main__:find_merge_commit:22 - PR #32865: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.471 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32865
# 2025-06-19 11:25:50.550 | INFO     | __main__:find_merge_commit:22 - PR #14741: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.564 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14741
# Querying PRs from DB:   8%|▊         | 821/10635 [00:08<01:36, 101.76it/s]2025-06-19 11:25:50.636 | INFO     | __main__:find_merge_commit:22 - PR #29010: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.645 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29010
# 2025-06-19 11:25:50.652 | INFO     | __main__:find_merge_commit:22 - PR #29821: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.662 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29821
# Querying PRs from DB:   8%|▊         | 843/10635 [00:08<01:36, 101.03it/s]2025-06-19 11:25:50.837 | INFO     | __main__:find_merge_commit:22 - PR #42917: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.843 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42917
# Querying PRs from DB:   8%|▊         | 861/10635 [00:08<01:21, 120.35it/s]2025-06-19 11:25:50.963 | INFO     | __main__:find_merge_commit:22 - PR #24777: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:50.967 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #24777
# Querying PRs from DB:   8%|▊         | 899/10635 [00:09<01:31, 105.96it/s]2025-06-19 11:25:51.390 | INFO     | __main__:find_merge_commit:22 - PR #32910: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:51.395 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32910
# Querying PRs from DB:   9%|▊         | 914/10635 [00:09<01:24, 115.71it/s]2025-06-19 11:25:51.531 | INFO     | __main__:find_merge_commit:22 - PR #28971: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:51.537 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #28971
# Querying PRs from DB:   9%|▊         | 927/10635 [00:09<01:25, 114.08it/s]2025-06-19 11:25:51.555 | INFO     | __main__:find_merge_commit:22 - PR #18062: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:51.562 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #18062
# Querying PRs from DB:   9%|▉         | 940/10635 [00:09<01:22, 116.92it/s]2025-06-19 11:25:51.754 | INFO     | __main__:find_merge_commit:22 - PR #5376: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:   9%|▉         | 954/10635 [00:09<01:20, 119.59it/s]2025-06-19 11:25:51.764 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #5376
# 2025-06-19 11:25:51.780 | INFO     | __main__:find_merge_commit:22 - PR #40624: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:51.786 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40624
# 2025-06-19 11:25:51.794 | INFO     | __main__:find_merge_commit:22 - PR #4971: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:51.797 | INFO     | __main__:find_merge_commit:22 - PR #43103: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:51.804 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #4971
# 2025-06-19 11:25:51.814 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43103
# Querying PRs from DB:   9%|▉         | 980/10635 [00:09<01:23, 115.30it/s]2025-06-19 11:25:52.035 | INFO     | __main__:find_merge_commit:22 - PR #24817: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:52.039 | INFO     | __main__:find_merge_commit:22 - PR #24815: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:52.042 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #24817
# 2025-06-19 11:25:52.051 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #24815
# Querying PRs from DB:   9%|▉         | 993/10635 [00:10<01:21, 117.74it/s]2025-06-19 11:25:52.176 | INFO     | __main__:find_merge_commit:22 - PR #32925: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:52.183 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32925
# Querying PRs from DB:  10%|▉         | 1026/10635 [00:10<01:10, 136.74it/s]2025-06-19 11:25:52.320 | INFO     | __main__:find_merge_commit:22 - PR #31712: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:52.326 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #31712
# 2025-06-19 11:25:52.379 | INFO     | __main__:find_merge_commit:22 - PR #18082: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:52.382 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #18082
# Querying PRs from DB:  10%|▉         | 1040/10635 [00:10<01:10, 136.15it/s]2025-06-19 11:25:52.434 | INFO     | __main__:find_merge_commit:22 - PR #43112: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:52.445 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43112
# Querying PRs from DB:  10%|▉         | 1054/10635 [00:10<01:15, 127.29it/s]2025-06-19 11:25:52.600 | INFO     | __main__:find_merge_commit:22 - PR #43140: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:52.608 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43140
# 2025-06-19 11:25:52.633 | INFO     | __main__:find_merge_commit:22 - PR #40627: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:52.642 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40627
# Querying PRs from DB:  10%|█         | 1105/10635 [00:10<01:06, 142.45it/s]2025-06-19 11:25:52.900 | INFO     | __main__:find_merge_commit:22 - PR #31709: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:52.905 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #31709
# 2025-06-19 11:25:52.955 | INFO     | __main__:find_merge_commit:22 - PR #32966: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:52.967 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32966
# Querying PRs from DB:  11%|█         | 1139/10635 [00:11<01:01, 154.98it/s]2025-06-19 11:25:53.082 | INFO     | __main__:find_merge_commit:22 - PR #18120: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.086 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #18120
# 2025-06-19 11:25:53.127 | INFO     | __main__:find_merge_commit:22 - PR #41273: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.132 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #41273
# 2025-06-19 11:25:53.136 | INFO     | __main__:find_merge_commit:22 - PR #29920: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.147 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29920
# Querying PRs from DB:  11%|█         | 1162/10635 [00:11<00:53, 176.47it/s]2025-06-19 11:25:53.197 | INFO     | __main__:find_merge_commit:22 - PR #28942: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.203 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #28942
# 2025-06-19 11:25:53.261 | INFO     | __main__:find_merge_commit:22 - PR #14686: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.270 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14686
# Querying PRs from DB:  11%|█         | 1180/10635 [00:11<00:55, 170.37it/s]2025-06-19 11:25:53.387 | INFO     | __main__:find_merge_commit:22 - PR #43190: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:  11%|█▏        | 1201/10635 [00:11<00:52, 181.18it/s]2025-06-19 11:25:53.403 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43190
# 2025-06-19 11:25:53.444 | INFO     | __main__:find_merge_commit:22 - PR #25124: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.451 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #25124
# 2025-06-19 11:25:53.463 | INFO     | __main__:find_merge_commit:22 - PR #43203: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.468 | INFO     | __main__:find_merge_commit:22 - PR #26833: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.479 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43203
# 2025-06-19 11:25:53.485 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #26833
# Querying PRs from DB:  11%|█▏        | 1220/10635 [00:11<00:51, 181.40it/s]2025-06-19 11:25:53.581 | INFO     | __main__:find_merge_commit:22 - PR #28935: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.587 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #28935
# 2025-06-19 11:25:53.588 | INFO     | __main__:find_merge_commit:22 - PR #14849: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.597 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14849
# Querying PRs from DB:  12%|█▏        | 1240/10635 [00:11<00:50, 185.03it/s]2025-06-19 11:25:53.629 | INFO     | __main__:find_merge_commit:22 - PR #14850: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.635 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14850
# 2025-06-19 11:25:53.658 | INFO     | __main__:find_merge_commit:22 - PR #16558: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.663 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #16558
# 2025-06-19 11:25:53.674 | INFO     | __main__:find_merge_commit:22 - PR #18139: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.681 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #18139
# 2025-06-19 11:25:53.697 | INFO     | __main__:find_merge_commit:22 - PR #14737: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.701 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14737
# Querying PRs from DB:  12%|█▏        | 1259/10635 [00:11<00:51, 182.73it/s]2025-06-19 11:25:53.744 | INFO     | __main__:find_merge_commit:22 - PR #14851: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.747 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14851
# 2025-06-19 11:25:53.818 | INFO     | __main__:find_merge_commit:22 - PR #20424: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.826 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20424
# 2025-06-19 11:25:53.841 | INFO     | __main__:find_merge_commit:22 - PR #19183: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.855 | INFO     | __main__:find_merge_commit:22 - PR #20438: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.864 | INFO     | __main__:find_merge_commit:22 - PR #20441: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.871 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #19183
# 2025-06-19 11:25:53.880 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20438
# 2025-06-19 11:25:53.884 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20441
# Querying PRs from DB:  12%|█▏        | 1278/10635 [00:11<01:02, 150.44it/s]2025-06-19 11:25:53.906 | INFO     | __main__:find_merge_commit:22 - PR #20443: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.910 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20443
# 2025-06-19 11:25:53.934 | INFO     | __main__:find_merge_commit:22 - PR #9124: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:53.944 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #9124
# 2025-06-19 11:25:54.003 | INFO     | __main__:find_merge_commit:22 - PR #43210: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.011 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43210
# 2025-06-19 11:25:54.051 | INFO     | __main__:find_merge_commit:22 - PR #18143: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.060 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #18143
# Querying PRs from DB:  12%|█▏        | 1295/10635 [00:12<01:13, 127.04it/s]2025-06-19 11:25:54.134 | INFO     | __main__:find_merge_commit:22 - PR #43217: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.138 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43217
# 2025-06-19 11:25:54.150 | INFO     | __main__:find_merge_commit:22 - PR #14852: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.158 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14852
# Querying PRs from DB:  12%|█▏        | 1316/10635 [00:12<01:04, 145.30it/s]2025-06-19 11:25:54.187 | INFO     | __main__:find_merge_commit:22 - PR #43225: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.189 | INFO     | __main__:find_merge_commit:22 - PR #33080: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.194 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43225
# 2025-06-19 11:25:54.211 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #33080
# 2025-06-19 11:25:54.217 | INFO     | __main__:find_merge_commit:22 - PR #43215: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.222 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43215
# 2025-06-19 11:25:54.253 | INFO     | __main__:find_merge_commit:22 - PR #14853: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.259 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14853
# 2025-06-19 11:25:54.266 | INFO     | __main__:find_merge_commit:22 - PR #33114: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.275 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #33114
# Querying PRs from DB:  13%|█▎        | 1337/10635 [00:12<00:58, 158.71it/s]2025-06-19 11:25:54.348 | INFO     | __main__:find_merge_commit:22 - PR #4931: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.357 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #4931
# 2025-06-19 11:25:54.365 | INFO     | __main__:find_merge_commit:22 - PR #28908: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.368 | INFO     | __main__:find_merge_commit:22 - PR #30023: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.376 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #28908
# 2025-06-19 11:25:54.397 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #30023
# Querying PRs from DB:  13%|█▎        | 1355/10635 [00:12<01:01, 151.77it/s]2025-06-19 11:25:54.425 | INFO     | __main__:find_merge_commit:22 - PR #30039: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.430 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #30039
# 2025-06-19 11:25:54.491 | INFO     | __main__:find_merge_commit:22 - PR #40637: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.495 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40637
# 2025-06-19 11:25:54.499 | INFO     | __main__:find_merge_commit:22 - PR #14990: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.509 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14990
# 2025-06-19 11:25:54.533 | INFO     | __main__:find_merge_commit:22 - PR #14687: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.540 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14687
# Querying PRs from DB:  13%|█▎        | 1372/10635 [00:12<01:03, 145.01it/s]2025-06-19 11:25:54.581 | INFO     | __main__:find_merge_commit:22 - PR #43240: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.581 | INFO     | __main__:find_merge_commit:22 - PR #19165: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.587 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43240
# 2025-06-19 11:25:54.595 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #19165
# 2025-06-19 11:25:54.601 | INFO     | __main__:find_merge_commit:22 - PR #42870: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.607 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42870
# 2025-06-19 11:25:54.634 | INFO     | __main__:find_merge_commit:22 - PR #43251: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.640 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43251
# Querying PRs from DB:  13%|█▎        | 1390/10635 [00:12<01:00, 152.92it/s]2025-06-19 11:25:54.683 | INFO     | __main__:find_merge_commit:22 - PR #33144: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.689 | INFO     | __main__:find_merge_commit:22 - PR #33128: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.691 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #33144
# 2025-06-19 11:25:54.710 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #33128
# Querying PRs from DB:  13%|█▎        | 1407/10635 [00:12<01:03, 145.54it/s]2025-06-19 11:25:54.793 | INFO     | __main__:find_merge_commit:22 - PR #33142: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.801 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #33142
# Querying PRs from DB:  13%|█▎        | 1423/10635 [00:12<01:06, 138.43it/s]2025-06-19 11:25:54.913 | INFO     | __main__:find_merge_commit:22 - PR #14854: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.919 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14854
# 2025-06-19 11:25:54.987 | INFO     | __main__:find_merge_commit:22 - PR #18192: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:54.992 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #18192
# 2025-06-19 11:25:54.995 | INFO     | __main__:find_merge_commit:22 - PR #4925: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.002 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #4925
# 2025-06-19 11:25:55.053 | INFO     | __main__:find_merge_commit:22 - PR #14855: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.061 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14855
# 2025-06-19 11:25:55.085 | INFO     | __main__:find_merge_commit:22 - PR #14856: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.091 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14856
# 2025-06-19 11:25:55.150 | INFO     | __main__:find_merge_commit:22 - PR #43259: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.154 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43259
# Querying PRs from DB:  14%|█▎        | 1438/10635 [00:13<01:30, 101.94it/s]2025-06-19 11:25:55.177 | INFO     | __main__:find_merge_commit:22 - PR #43260: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.186 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43260
# Querying PRs from DB:  14%|█▍        | 1466/10635 [00:13<01:06, 137.01it/s]2025-06-19 11:25:55.279 | INFO     | __main__:find_merge_commit:22 - PR #22103: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.281 | INFO     | __main__:find_merge_commit:22 - PR #30094: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.288 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #22103
# 2025-06-19 11:25:55.302 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #30094
# 2025-06-19 11:25:55.345 | INFO     | __main__:find_merge_commit:22 - PR #20495: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.359 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20495
# 2025-06-19 11:25:55.392 | INFO     | __main__:find_merge_commit:22 - PR #20501: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.395 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20501
# Querying PRs from DB:  14%|█▍        | 1518/10635 [00:13<01:04, 141.72it/s]2025-06-19 11:25:55.702 | INFO     | __main__:find_merge_commit:22 - PR #14857: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.707 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14857
# 2025-06-19 11:25:55.732 | INFO     | __main__:find_merge_commit:22 - PR #16536: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.736 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #16536
# Querying PRs from DB:  14%|█▍        | 1534/10635 [00:13<01:05, 138.02it/s]2025-06-19 11:25:55.813 | INFO     | __main__:find_merge_commit:22 - PR #8768: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.821 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #8768
# Querying PRs from DB:  15%|█▍        | 1550/10635 [00:13<01:04, 141.70it/s]2025-06-19 11:25:55.928 | INFO     | __main__:find_merge_commit:22 - PR #42847: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.935 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42847
# 2025-06-19 11:25:55.965 | INFO     | __main__:find_merge_commit:22 - PR #40642: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:55.969 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40642
# Querying PRs from DB:  15%|█▍        | 1569/10635 [00:13<00:59, 153.61it/s]2025-06-19 11:25:55.994 | INFO     | __main__:find_merge_commit:22 - PR #40644: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.003 | INFO     | __main__:find_merge_commit:22 - PR #43297: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.005 | INFO     | __main__:find_merge_commit:22 - PR #43298: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.008 | INFO     | __main__:find_merge_commit:22 - PR #42841: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.028 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40644
# 2025-06-19 11:25:56.057 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43297
# 2025-06-19 11:25:56.063 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43298
# 2025-06-19 11:25:56.066 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42841
# 2025-06-19 11:25:56.095 | INFO     | __main__:find_merge_commit:22 - PR #2439: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.099 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #2439
# Querying PRs from DB:  15%|█▍        | 1585/10635 [00:14<01:03, 142.92it/s]2025-06-19 11:25:56.150 | INFO     | __main__:find_merge_commit:22 - PR #33241: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.166 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #33241
# Querying PRs from DB:  15%|█▌        | 1606/10635 [00:14<00:56, 159.30it/s]2025-06-19 11:25:56.283 | INFO     | __main__:find_merge_commit:22 - PR #18247: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.286 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #18247
# Querying PRs from DB:  15%|█▌        | 1623/10635 [00:14<00:58, 154.69it/s]2025-06-19 11:25:56.404 | INFO     | __main__:find_merge_commit:22 - PR #30153: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.409 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #30153
# Querying PRs from DB:  16%|█▌        | 1660/10635 [00:14<00:55, 162.77it/s]2025-06-19 11:25:56.565 | INFO     | __main__:find_merge_commit:22 - PR #28057: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.583 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #28057
# Querying PRs from DB:  16%|█▌        | 1679/10635 [00:14<00:53, 167.38it/s]2025-06-19 11:25:56.656 | INFO     | __main__:find_merge_commit:22 - PR #2402: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.661 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #2402
# 2025-06-19 11:25:56.711 | INFO     | __main__:find_merge_commit:22 - PR #2464: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.716 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #2464
# 2025-06-19 11:25:56.743 | INFO     | __main__:find_merge_commit:22 - PR #29365: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.746 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29365
# 2025-06-19 11:25:56.750 | INFO     | __main__:find_merge_commit:22 - PR #2492: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.760 | INFO     | __main__:find_merge_commit:22 - PR #2395: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.766 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #2492
# 2025-06-19 11:25:56.771 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #2395
# Querying PRs from DB:  16%|█▌        | 1696/10635 [00:14<01:02, 142.50it/s]2025-06-19 11:25:56.847 | INFO     | __main__:find_merge_commit:22 - PR #9233: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.852 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #9233
# Querying PRs from DB:  16%|█▌        | 1714/10635 [00:14<00:58, 151.40it/s]2025-06-19 11:25:56.962 | INFO     | __main__:find_merge_commit:22 - PR #41268: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:56.974 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #41268
# 2025-06-19 11:25:56.991 | INFO     | __main__:find_merge_commit:22 - PR #43370: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.001 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43370
# Querying PRs from DB:  16%|█▋        | 1731/10635 [00:15<00:57, 154.30it/s]2025-06-19 11:25:57.048 | INFO     | __main__:find_merge_commit:22 - PR #28859: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.068 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #28859
# Querying PRs from DB:  17%|█▋        | 1784/10635 [00:15<00:54, 162.54it/s]2025-06-19 11:25:57.396 | INFO     | __main__:find_merge_commit:22 - PR #33330: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.401 | INFO     | __main__:find_merge_commit:22 - PR #42796: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.409 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #33330
# 2025-06-19 11:25:57.425 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42796
# 2025-06-19 11:25:57.433 | INFO     | __main__:find_merge_commit:22 - PR #42794: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.440 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42794
# 2025-06-19 11:25:57.445 | INFO     | __main__:find_merge_commit:22 - PR #33343: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.459 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #33343
# 2025-06-19 11:25:57.464 | INFO     | __main__:find_merge_commit:22 - PR #42793: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:  17%|█▋        | 1803/10635 [00:15<00:52, 167.10it/s]2025-06-19 11:25:57.480 | INFO     | __main__:find_merge_commit:22 - PR #43393: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.480 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #42793
# 2025-06-19 11:25:57.483 | INFO     | __main__:find_merge_commit:22 - PR #33348: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.499 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #43393
# 2025-06-19 11:25:57.511 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #33348
# 2025-06-19 11:25:57.587 | INFO     | __main__:find_merge_commit:22 - PR #9248: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.597 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #9248
# Querying PRs from DB:  17%|█▋        | 1820/10635 [00:15<01:15, 117.08it/s]2025-06-19 11:25:57.752 | INFO     | __main__:find_merge_commit:22 - PR #9260: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.759 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #9260
# Querying PRs from DB:  17%|█▋        | 1837/10635 [00:15<01:09, 127.14it/s]2025-06-19 11:25:57.936 | INFO     | __main__:find_merge_commit:22 - PR #7305: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:25:57.948 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #7305
# Querying PRs from DB:  18%|█▊        | 1869/10635 [00:16<01:07, 128.98it/s]2025-06-19 11:25:58.120 | INFO     | __main__:find_merge_commit:22 - PR #43410: Found in DB, but is not merged. Skipping.
# ...
# 2025-06-19 11:27:16.651 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14666
# Querying PRs from DB:  95%|█████████▌| 10136/10635 [01:34<00:04, 101.99it/s]2025-06-19 11:27:16.770 | INFO     | __main__:find_merge_commit:22 - PR #14790: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:16.783 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14790
# Querying PRs from DB:  95%|█████████▌| 10147/10635 [01:34<00:05, 82.41it/s] 2025-06-19 11:27:16.958 | INFO     | __main__:find_merge_commit:22 - PR #4490: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:16.976 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #4490
# Querying PRs from DB:  96%|█████████▌| 10183/10635 [01:35<00:06, 71.62it/s]2025-06-19 11:27:17.565 | INFO     | __main__:find_merge_commit:22 - PR #32540: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:17.569 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32540
# Querying PRs from DB:  96%|█████████▌| 10191/10635 [01:35<00:06, 69.19it/s]2025-06-19 11:27:17.604 | INFO     | __main__:find_merge_commit:22 - PR #20008: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:17.617 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20008
# Querying PRs from DB:  96%|█████████▌| 10199/10635 [01:35<00:06, 69.76it/s]2025-06-19 11:27:17.706 | INFO     | __main__:find_merge_commit:22 - PR #20010: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:17.718 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20010
# 2025-06-19 11:27:17.771 | INFO     | __main__:find_merge_commit:22 - PR #12714: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:17.778 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #12714
# Querying PRs from DB:  96%|█████████▌| 10220/10635 [01:35<00:04, 84.61it/s]2025-06-19 11:27:17.929 | INFO     | __main__:find_merge_commit:22 - PR #32566: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:17.937 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32566
# 2025-06-19 11:27:17.951 | INFO     | __main__:find_merge_commit:22 - PR #12725: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:17.955 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #12725
# Querying PRs from DB:  96%|█████████▌| 10230/10635 [01:36<00:04, 85.38it/s]2025-06-19 11:27:18.075 | INFO     | __main__:find_merge_commit:22 - PR #15786: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:18.132 | INFO     | __main__:find_merge_commit:22 - PR #26609: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:18.136 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #15786
# 2025-06-19 11:27:18.220 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #26609
# Querying PRs from DB:  96%|█████████▋| 10239/10635 [01:36<00:05, 67.00it/s]2025-06-19 11:27:18.231 | INFO     | __main__:find_merge_commit:22 - PR #40224: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:18.250 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40224
# Querying PRs from DB:  96%|█████████▋| 10257/10635 [01:36<00:04, 89.31it/s]2025-06-19 11:27:18.397 | INFO     | __main__:find_merge_commit:22 - PR #40239: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:18.405 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40239
# 2025-06-19 11:27:18.454 | INFO     | __main__:find_merge_commit:22 - PR #38603: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:  97%|█████████▋| 10269/10635 [01:36<00:03, 92.36it/s]2025-06-19 11:27:18.484 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #38603
# 2025-06-19 11:27:18.533 | INFO     | __main__:find_merge_commit:22 - PR #15042: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:18.538 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #15042
# Querying PRs from DB:  97%|█████████▋| 10279/10635 [01:36<00:03, 91.46it/s]2025-06-19 11:27:18.615 | INFO     | __main__:find_merge_commit:22 - PR #25225: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:18.655 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #25225
# Querying PRs from DB:  97%|█████████▋| 10290/10635 [01:36<00:03, 91.16it/s]2025-06-19 11:27:18.703 | INFO     | __main__:find_merge_commit:22 - PR #4508: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:18.712 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #4508
# Querying PRs from DB:  97%|█████████▋| 10300/10635 [01:36<00:04, 79.12it/s]2025-06-19 11:27:18.905 | INFO     | __main__:find_merge_commit:22 - PR #29610: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:18.946 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29610
# 2025-06-19 11:27:18.948 | INFO     | __main__:find_merge_commit:22 - PR #4531: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:19.006 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #4531
# Querying PRs from DB:  97%|█████████▋| 10317/10635 [01:37<00:04, 67.56it/s]2025-06-19 11:27:19.200 | INFO     | __main__:find_merge_commit:22 - PR #20029: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:19.214 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20029
# Querying PRs from DB:  97%|█████████▋| 10326/10635 [01:37<00:04, 69.85it/s]2025-06-19 11:27:19.306 | INFO     | __main__:find_merge_commit:22 - PR #24538: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:19.319 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #24538
# 2025-06-19 11:27:19.333 | INFO     | __main__:find_merge_commit:22 - PR #20035: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:19.354 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20035
# 2025-06-19 11:27:19.394 | INFO     | __main__:find_merge_commit:22 - PR #22255: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:19.413 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #22255
# Querying PRs from DB:  97%|█████████▋| 10334/10635 [01:37<00:05, 58.59it/s]2025-06-19 11:27:19.582 | INFO     | __main__:find_merge_commit:22 - PR #24556: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:  97%|█████████▋| 10344/10635 [01:37<00:04, 67.28it/s]2025-06-19 11:27:19.587 | INFO     | __main__:find_merge_commit:22 - PR #32573: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:19.594 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #24556
# 2025-06-19 11:27:19.622 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32573
# 2025-06-19 11:27:19.641 | INFO     | __main__:find_merge_commit:22 - PR #32583: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:19.643 | INFO     | __main__:find_merge_commit:22 - PR #19316: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:19.668 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32583
# 2025-06-19 11:27:19.677 | INFO     | __main__:find_merge_commit:22 - PR #6970: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:  97%|█████████▋| 10353/10635 [01:37<00:04, 65.10it/s]2025-06-19 11:27:19.748 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #19316
# 2025-06-19 11:27:19.767 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #6970
# Querying PRs from DB:  97%|█████████▋| 10366/10635 [01:37<00:03, 78.20it/s]2025-06-19 11:27:19.851 | INFO     | __main__:find_merge_commit:22 - PR #37828: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:19.899 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #37828
# 2025-06-19 11:27:19.940 | INFO     | __main__:find_merge_commit:22 - PR #32602: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:  98%|█████████▊| 10375/10635 [01:37<00:03, 75.54it/s]2025-06-19 11:27:19.986 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #32602
# 2025-06-19 11:27:20.015 | INFO     | __main__:find_merge_commit:22 - PR #38604: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:20.034 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #38604
# Querying PRs from DB:  98%|█████████▊| 10389/10635 [01:38<00:02, 90.59it/s]2025-06-19 11:27:20.156 | INFO     | __main__:find_merge_commit:22 - PR #40257: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:20.159 | INFO     | __main__:find_merge_commit:22 - PR #12735: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:20.172 | INFO     | __main__:find_merge_commit:22 - PR #29629: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:20.177 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #40257
# 2025-06-19 11:27:20.198 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #12735
# 2025-06-19 11:27:20.203 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #29629
# Querying PRs from DB:  98%|█████████▊| 10399/10635 [01:38<00:02, 85.28it/s]2025-06-19 11:27:20.304 | INFO     | __main__:find_merge_commit:22 - PR #25208: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:20.313 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #25208
# Querying PRs from DB:  98%|█████████▊| 10415/10635 [01:38<00:02, 103.50it/s]2025-06-19 11:27:20.370 | INFO     | __main__:find_merge_commit:22 - PR #12742: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:20.384 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #12742
# Querying PRs from DB:  98%|█████████▊| 10439/10635 [01:38<00:02, 83.39it/s] 2025-06-19 11:27:20.654 | INFO     | __main__:find_merge_commit:22 - PR #15039: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:20.670 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #15039
# 2025-06-19 11:27:20.854 | INFO     | __main__:find_merge_commit:22 - PR #15038: Found in DB, but is not merged. Skipping.
# Querying PRs from DB:  98%|█████████▊| 10449/10635 [01:38<00:02, 68.32it/s]2025-06-19 11:27:20.864 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #15038
# 2025-06-19 11:27:20.866 | INFO     | __main__:find_merge_commit:22 - PR #15037: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:20.872 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #15037
# 2025-06-19 11:27:20.920 | INFO     | __main__:find_merge_commit:22 - PR #3670: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:20.927 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #3670
# 2025-06-19 11:27:20.933 | INFO     | __main__:find_merge_commit:22 - PR #14813: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:20.937 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #14813
# Querying PRs from DB:  98%|█████████▊| 10459/10635 [01:38<00:02, 69.23it/s]2025-06-19 11:27:21.005 | INFO     | __main__:find_merge_commit:22 - PR #16630: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:21.011 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #16630
# Querying PRs from DB:  98%|█████████▊| 10469/10635 [01:39<00:02, 74.89it/s]2025-06-19 11:27:21.113 | INFO     | __main__:find_merge_commit:22 - PR #22251: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:21.120 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #22251
# Querying PRs from DB:  99%|█████████▊| 10479/10635 [01:39<00:02, 77.57it/s]2025-06-19 11:27:21.272 | INFO     | __main__:find_merge_commit:22 - PR #16031: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:21.282 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #16031
# Querying PRs from DB:  99%|█████████▊| 10490/10635 [01:39<00:01, 85.27it/s]2025-06-19 11:27:21.455 | INFO     | __main__:find_merge_commit:22 - PR #20080: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:21.469 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #20080
# Querying PRs from DB:  99%|█████████▉| 10509/10635 [01:39<00:02, 57.67it/s]2025-06-19 11:27:21.854 | INFO     | __main__:find_merge_commit:22 - PR #1885: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:21.862 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #1885
# Querying PRs from DB:  99%|█████████▉| 10517/10635 [01:39<00:01, 60.50it/s]2025-06-19 11:27:21.953 | INFO     | __main__:find_merge_commit:22 - PR #820: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:21.960 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #820
# Querying PRs from DB:  99%|█████████▉| 10525/10635 [01:39<00:01, 61.65it/s]2025-06-19 11:27:22.107 | INFO     | __main__:find_merge_commit:22 - PR #27764: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:22.113 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #27764
# Querying PRs from DB:  99%|█████████▉| 10532/10635 [01:40<00:01, 55.73it/s]2025-06-19 11:27:22.258 | INFO     | __main__:find_merge_commit:22 - PR #1993: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:22.263 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #1993
# Querying PRs from DB:  99%|█████████▉| 10539/10635 [01:40<00:01, 50.27it/s]2025-06-19 11:27:22.464 | INFO     | __main__:find_merge_commit:22 - PR #3708: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:22.469 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #3708
# Querying PRs from DB:  99%|█████████▉| 10545/10635 [01:40<00:01, 46.81it/s]2025-06-19 11:27:22.633 | INFO     | __main__:find_merge_commit:22 - PR #3860: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:22.637 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #3860
# Querying PRs from DB:  99%|█████████▉| 10561/10635 [01:40<00:01, 41.59it/s]2025-06-19 11:27:22.948 | INFO     | __main__:find_merge_commit:22 - PR #2086: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:22.954 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #2086
# Querying PRs from DB: 100%|█████████▉| 10599/10635 [01:41<00:00, 47.44it/s]2025-06-19 11:27:23.879 | INFO     | __main__:find_merge_commit:22 - PR #1265: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:23.887 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #1265
# Querying PRs from DB: 100%|█████████▉| 10604/10635 [01:41<00:00, 46.61it/s]2025-06-19 11:27:24.056 | INFO     | __main__:find_merge_commit:22 - PR #12889: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:24.068 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #12889
# Querying PRs from DB: 100%|█████████▉| 10614/10635 [01:42<00:00, 41.80it/s]2025-06-19 11:27:24.318 | INFO     | __main__:find_merge_commit:22 - PR #1013: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:24.323 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #1013
# 2025-06-19 11:27:24.379 | INFO     | __main__:find_merge_commit:22 - PR #1016: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:24.386 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #1016
# Querying PRs from DB: 100%|█████████▉| 10619/10635 [01:42<00:00, 35.73it/s]2025-06-19 11:27:24.445 | INFO     | __main__:find_merge_commit:22 - PR #12828: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:24.490 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #12828
# Querying PRs from DB: 100%|█████████▉| 10632/10635 [01:42<00:00, 44.14it/s]2025-06-19 11:27:24.732 | INFO     | __main__:find_merge_commit:22 - PR #1074: Found in DB, but is not merged. Skipping.
# 2025-06-19 11:27:24.734 | DEBUG    | __main__:<module>:23 - No merge hash found for PR #1074
# Querying PRs from DB: 100%|██████████| 10635/10635 [01:42<00:00, 103.54it/s]
# 2025-06-19 11:27:24.744 | INFO     | __main__:<module>:27 - Successfully processed all PRs. Found merge hashes for 9332 of them.
# 2025-06-19 11:27:24.787 | SUCCESS  | __main__:<module>:36 - Enrichment complete. Filtered down to 12831 merged PRs (from 15355 total).
# 2025-06-19 11:27:27.885 | SUCCESS  | __main__:<module>:41 - Data with merge commits saved to ../data/final/data_with_merge_commit.csv

# %% [markdown]
# ## SZZ phase 2
# ### Identifying the bugitrodusing prs

# %%
import pandas as pd
import git
import os
import re
from loguru import logger
from tqdm.notebook import tqdm

# --- Logging Setup ---
# Logger config
logger.add("logs/szz_analysis.log")

logger.info("Libraries imported and logger configured.")
# Out:
# 2025-06-20 11:09:04.665 | INFO     | __main__:<module>:12 - Libraries imported and logger configured.

# %%
# --- UPDATE THESE VALUES ---

# 1. The local file path to the Git repository you want to analyze.
#    Make sure this repository is up-to-date.
REPO_PATH = "../../ballerina-lang/"

# 2. The enriched CSV file created in the previous step.
INPUT_CSV = "../data/final/data_with_merge_commit.csv"

# 3. The name of the final output file that will contain the SZZ results.
OUTPUT_CSV = "../data/final/szz_bug_introducing_commits.csv"

# 4. (Optional) List of file extensions to analyze.
#    This helps focus on source code and ignore other files.
SOURCE_CODE_EXTENSIONS = [
    # Primary programming languages
    '.java', '.bal', '.js', '.py', 
    
    # Configuration files
    '.yml', '.yaml', '.xml', '.json', '.toml', '.properties',
    
    # Documentation and markup
    '.md', '.html', '.css',
    
    # Build and script files
    '.gradle', '.sh', '.bat'
]

IGNORE_PATTERNS = [
    # Compiled files
    '*.class',
    
    # Log files
    '*.log', '*.log.*',
    
    # Ballerina specific
    'Ballerina.lock',
    
    # Java package files
    '*.jar', '*.war', '*.ear',
    
    # IDE files
    '.idea/', '*.iml', '*.ipr', '*.iws',
    '.classpath', '.project', '.settings/',
    
    # Generated directories
    'target/', 'results/', '.ballerina/', '/gen/',
    
    # Gradle related
    '.gradle/', 'build/',
    
    # Other common ignores
    '.DS_Store',
    '.mtj.tmp/',
    'velocity.log',
    'extractedDistribution/',
    'node_modules/'
]

# --- End of Configuration ---

# Validate the repository path
if not os.path.exists(REPO_PATH):
    logger.error(f"Repository path not found: {REPO_PATH}")
else:
    logger.success(f"Repository found at: {REPO_PATH}")

if not os.path.exists(INPUT_CSV):
    logger.error(f"Input CSV not found: {INPUT_CSV}")
else:
    logger.success(f"Input CSV found at: {INPUT_CSV}")
# Out:
# 2025-06-20 12:06:54.520 | SUCCESS  | __main__:<module>:66 - Repository found at: ../../ballerina-lang/
# 2025-06-20 12:06:54.525 | SUCCESS  | __main__:<module>:71 - Input CSV found at: ../data/final/data_with_merge_commit.csv

# %%
def parse_diff_to_get_deleted_lines(diff_text: str) -> list[int]:
    """
    Parses the text of a diff to find the line numbers that were deleted from the 'A' file.
    """
    deleted_line_nums = []
    lines = diff_text.split('\n')
    current_line_num_a = 0

    for line in lines:
        if line.startswith('@@'):
            match = re.search(r'@@ -(\d+),?\d* \+', line)
            if match:
                current_line_num_a = int(match.group(1))
        elif line.startswith('-') and not line.startswith('---'):
            deleted_line_nums.append(current_line_num_a)
            current_line_num_a += 1
        elif not line.startswith('+') and not line.startswith('@@'):
            current_line_num_a += 1
            
    return deleted_line_nums


# --- THIS IS THE CORRECTED FUNCTION ---
def run_szz_for_commit(repo: git.Repo, fix_commit_hash: str, extensions: list) -> list[dict]:
    """
    Performs the SZZ analysis for a single bug-fixing (merge) commit.
    
    Args:
        repo: The GitPython Repo object.
        fix_commit_hash: The hash of the bug-fixing merge commit.
        extensions: A list of file extensions to analyze.

    Returns:
        A list of dictionaries, each representing a potential bug-introducing commit.
    """
    bug_introducing_candidates = []
    try:
        fix_commit = repo.commit(fix_commit_hash)
    except Exception as e:
        logger.warning(f"Could not access commit {fix_commit_hash}. Skipping. Error: {e}")
        return []

    if len(fix_commit.parents) < 1:
        logger.info(f"Skipping commit {fix_commit_hash}: not a merge commit or has no parents.")
        return []
    
    parent_commit = fix_commit.parents[0]
    diffs = parent_commit.diff(fix_commit, create_patch=True)

    for diff in diffs:
        if diff.a_path is None or not any(diff.a_path.endswith(ext) for ext in extensions):
            continue

        deleted_lines_in_parent = parse_diff_to_get_deleted_lines(diff.diff.decode('utf-8', 'ignore'))
        
        if not deleted_lines_in_parent:
            continue
            
        try:
            blame_output = repo.blame(parent_commit, diff.a_path)
        except git.exc.GitCommandError as e:
            logger.warning(f"Blame failed for file {diff.a_path} in commit {parent_commit.hexsha}. Skipping file. Error: {e}")
            continue

        # **FIX STARTS HERE**
        # We need to manually track the line number, as the blame output doesn't contain it directly.
        current_line_number = 1
        for commit, lines_content in blame_output:
            for _ in lines_content: # We iterate for each line of content
                # Check if the current line number is one of the lines that was fixed
                if current_line_number in deleted_lines_in_parent:
                    candidate = {
                        'bug_introducing_commit': commit.hexsha,
                        'commit_message': commit.message.strip().split('\n')[0],
                        'author': commit.author.name,
                        'date': commit.authored_datetime.isoformat(),
                        'file_path': diff.a_path,
                    }
                    if candidate not in bug_introducing_candidates:
                        bug_introducing_candidates.append(candidate)
                
                # Increment the line counter for the next line
                current_line_number += 1
        # **FIX ENDS HERE**

    return bug_introducing_candidates

logger.info("SZZ helper functions defined (Corrected Version).")
# Out:
# 2025-06-20 12:22:01.745 | INFO     | __main__:<module>:88 - SZZ helper functions defined (Corrected Version).

# %%
logger.info("--- Starting SZZ Analysis ---")

# Load the enriched data from the previous step
try:
    df = pd.read_csv(INPUT_CSV)
    df = df.head(10)
    logger.info(f"Loaded {len(df)} merged PRs from '{INPUT_CSV}'.")
except FileNotFoundError:
    logger.error(f"Could not execute: Input file '{INPUT_CSV}' not found.")
    # Stop execution if file not found
    raise

# Initialize the Git Repo object
try:
    repo = git.Repo(REPO_PATH)
    logger.success("Git repository initialized successfully.")
except Exception as e:
    logger.error(f"Failed to initialize Git repo at '{REPO_PATH}'. Error: {e}")
    # Stop execution if repo is invalid
    raise


all_bics = [] # This list will store all found bug-introducing commits (BICs)

# Use tqdm to create a progress bar for the loop
# We iterate over a list of dictionaries for easier access to row data
pr_fix_list = df.to_dict('records')

for row in tqdm(pr_fix_list, desc="Analyzing Commits"):
    merge_hash = row.get('merge_commit_hash')
    if not merge_hash or pd.isna(merge_hash):
        continue

    # Run the core SZZ analysis for the current merge commit
    bics = run_szz_for_commit(repo, merge_hash, SOURCE_CODE_EXTENSIONS)
    
    # Add original PR and Issue info back to the results
    for bic in bics:
        bic['blamed_by_pr_number'] = row.get('pr_number')
        bic['blamed_by_merge_commit'] = merge_hash
        bic['original_issue_number'] = row.get('issue_number', 'N/A')
        all_bics.append(bic)

logger.success(f"\n--- Analysis Complete ---")
logger.info(f"Found {len(all_bics)} potential bug-introducing change instances.")

# Convert the list of results into a pandas DataFrame for easy viewing and saving
if all_bics:
    results_df = pd.DataFrame(all_bics)
    
    # Save the final results to a CSV file
    results_df.to_csv(OUTPUT_CSV, index=False)
    logger.success(f"Results saved to '{OUTPUT_CSV}'.")
    
    # Display the first few rows of the result right here in the notebook
    print("\n--- SZZ Analysis Results (Sample) ---")
    display(results_df.head())
else:
    logger.info("No bug-introducing commits were found with the current criteria.")
# Out:
# 2025-06-20 12:29:51.771 | INFO     | __main__:<module>:1 - --- Starting SZZ Analysis ---
# 2025-06-20 12:29:52.788 | INFO     | __main__:<module>:7 - Loaded 10 merged PRs from '../data/final/data_with_merge_commit.csv'.
# 2025-06-20 12:29:52.796 | SUCCESS  | __main__:<module>:16 - Git repository initialized successfully.
# Analyzing Commits: 100%|██████████| 10/10 [01:19<00:00,  7.99s/it]
# 2025-06-20 12:31:12.770 | SUCCESS  | __main__:<module>:44 -
# --- Analysis Complete ---
# 2025-06-20 12:31:12.773 | INFO     | __main__:<module>:45 - Found 372 potential bug-introducing change instances.
# 2025-06-20 12:31:12.812 | SUCCESS  | __main__:<module>:53 - Results saved to '../data/final/szz_bug_introducing_commits.csv'.
# --- SZZ Analysis Results (Sample) ---
#                      bug_introducing_commit  \
# 0  bc0d77d31770ecc0b86ae8deafafd58038dbc9a5
# 1  fcdc84257666653f4bb9f16f30a5bf0c8dcdc7ba
# 2  bb98d5334c0f38ad49ebaeb478e7f37fd33761fd
# 3  974ec063c5743f31e89ff0a712d103ae5a7cc452
# 4  bc0d77d31770ecc0b86ae8deafafd58038dbc9a5
#
#                                       commit_message             author  \
# 0               Move code-actions into new structure             Rasika
# 1  Move code-actions' type-infer logic into diagn...      Rasika Perera
# 2  Update type cast code action to use diagnostic...  Imesha Sudasingha
# 3                      Restructure code-action tests             Rasika
# 4               Move code-actions into new structure             Rasika
#
#                         date  \
# 0  2020-10-28T15:58:53+05:30
# 1  2021-02-24T11:15:29+05:30
# 2  2021-03-04T23:38:04+05:30
# 3  2020-11-20T19:48:56+05:30
# 4  2020-10-28T15:58:53+05:30
#
#                                            file_path  blamed_by_pr_number  \
# 0  language-server/modules/langserver-core/src/ma...                29650
# 1  language-server/modules/langserver-core/src/ma...                29650
# 2  language-server/modules/langserver-core/src/ma...                29650
# 3  language-server/modules/langserver-core/src/te...                29650
# 4  language-server/modules/langserver-core/src/ma...                29650
#
#                      blamed_by_merge_commit  original_issue_number
# 0  00bca10f96884fb7ed2e1eb3a6d46e1173e74276                29428.0
# 1  00bca10f96884fb7ed2e1eb3a6d46e1173e74276                29428.0
# 2  00bca10f96884fb7ed2e1eb3a6d46e1173e74276                29428.0
# 3  00bca10f96884fb7ed2e1eb3a6d46e1173e74276                29428.0
# 4  00bca10f96884fb7ed2e1eb3a6d46e1173e74276                29573.0
