# %% [markdown]
# # Feature extraction

# %%
import pandas as pd
import git
import os
from loguru import logger
from tqdm import tqdm
import math
from collections import defaultdict
from concurrent.futures import ThreadPoolExecutor, as_completed # New import

# Logger config
logger.add("logs/szz_analysis.log")

logger.info("Libraries imported and logger configured for Feature Extraction.")
# Out:
# 2025-06-27 11:34:09.254 | INFO     | __main__:<module>:13 - Libraries imported and logger configured for Feature Extraction.

# %% [markdown]
# ## configurations

# %%
os.makedirs('./data', exist_ok=True)

# 1. The local file path to the Git repository you want to analyze.
REPO_PATH = "../../ballerina-lang/"

# 2. The branch you want to analyze (e.g., 'main', 'master', 'develop').
TARGET_BRANCH = 'master' 

# 3. The name of the output file for the extracted features.
OUTPUT_CSV = "/data/feature_extraction_results.csv"

# --- New Configuration for Caching ---
PRECOMPUTED_DATA_FILE = "author_history_cache.pkl"

# 4. (Optional) List of file extensions to analyze.
SOURCE_CODE_EXTENSIONS = [
    # Primary programming languages
    '.java', '.bal', '.js', '.py', 
    
    # Configuration files
    '.yml', '.yaml', '.xml', '.json', '.toml', '.properties',
    
    # Documentation and markup
    '.md', '.html', '.css',
    
    # Build and script files
    '.gradle', '.sh', '.bat'
]

IGNORE_PATTERNS = [
    # Compiled files
    '*.class',
    
    # Log files
    '*.log', '*.log.*',
    
    # Ballerina specific
    'Ballerina.lock',
    
    # Java package files
    '*.jar', '*.war', '*.ear',
    
    # IDE files
    '.idea/', '*.iml', '*.ipr', '*.iws',
    '.classpath', '.project', '.settings/',
    
    # Generated directories
    'target/', 'results/', '.ballerina/', '/gen/',
    
    # Gradle related
    '.gradle/', 'build/',
    
    # Other common ignores
    '.DS_Store',
    '.mtj.tmp/',
    'velocity.log',
    'extractedDistribution/',
    'node_modules/'
]

# --- New Configuration for Performance and Fault Tolerance ---

# 5. Number of parallel processes to use. A good starting point is os.cpu_count() - 1.
MAX_WORKERS = os.cpu_count() - 2 if os.cpu_count() else 1

# 6. How many results to collect before saving a batch to the CSV.
BATCH_SIZE = 500

# --- End of Configuration ---

logger.info(f"Configuration set. Using up to {MAX_WORKERS} worker processes.")
# Out:
# 2025-06-27 11:34:11.271 | INFO     | __main__:<module>:71 - Configuration set. Using up to 6 worker processes.

# %% [markdown]
# ## precomputing to get user experiance matrix

# %%
import pickle
from collections import defaultdict
import bisect

precomputed_data = {}

# --- Step 1: Check for a cached version first ---
if os.path.exists(PRECOMPUTED_DATA_FILE):
    logger.info(f"Found cached history file at '{PRECOMPUTED_DATA_FILE}'. Loading...")
    with open(PRECOMPUTED_DATA_FILE, 'rb') as f:
        precomputed_data = pickle.load(f)
    logger.success("Successfully loaded pre-computed history from cache.")
else:
    logger.info(f"No cached history file found. Starting full pre-computation...")
    
    # --- Step 2: Run the one-time computation if no cache exists ---
    repo = git.Repo(REPO_PATH)
    commits_in_order = list(repo.iter_commits(TARGET_BRANCH, reverse=True))

    author_history = defaultdict(list)
    file_history = defaultdict(set)

    for commit in tqdm(commits_in_order, desc="Building Author & File History"):
        author_email = commit.author.email
        commit_time = commit.authored_datetime
        
        # Calculate metrics based on history *before* this commit
        past_commits_timestamps = author_history[author_email]
        time_since_last = (commit_time - past_commits_timestamps[-1]).total_seconds() if past_commits_timestamps else 0
        
        sixty_days_ago = commit_time - pd.Timedelta(days=60)
        start_index = bisect.bisect_left(past_commits_timestamps, sixty_days_ago)
        recent_commits_count = len(past_commits_timestamps) - start_index

        previous_committers = set()
        if commit.parents:
            for diff in commit.diff(commit.parents[0]):
                file_path = diff.a_path or diff.b_path
                if file_path:
                    previous_committers.update(file_history[file_path])
        
        precomputed_data[commit.hexsha] = {
            'author_total_commits': len(past_commits_timestamps),
            'time_since_last_commit_seconds': time_since_last,
            'recent_commits_60d': recent_commits_count,
            'unique_prior_committers_on_files': len(previous_committers),
        }
        
        # Update the history databases *after* processing
        author_history[author_email].append(commit_time)
        if commit.parents:
            for diff in commit.diff(commit.parents[0]):
                file_path = diff.a_path or diff.b_path
                if file_path:
                    file_history[file_path].add(author_email)

    # --- Step 3: Save the results to the cache file for next time ---
    with open(PRECOMPUTED_DATA_FILE, 'wb') as f:
        pickle.dump(precomputed_data, f)
    logger.success(f"History pre-computation complete and saved to '{PRECOMPUTED_DATA_FILE}'.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5 precomputed_data = {}
#       7 # --- Step 1: Check for a cached version first ---
# ----> 8 if os.path.exists(PRECOMPUTED_DATA_FILE):
#       9     logger.info(f"Found cached history file at '{PRECOMPUTED_DATA_FILE}'. Loading...")
#      10     with open(PRECOMPUTED_DATA_FILE, 'rb') as f:
#
# NameError: name 'os' is not defined

# %% [markdown]
# ## worker function

# %%
def extract_features_for_commit_worker(commit, history_data):
    """
    Worker function that takes a live Commit object and the pre-computed history data.
    """
    try:
        # --- Basic Features (as before) ---
        stats = commit.stats.total
        lines_added = stats['insertions']
        lines_deleted = stats['deletions']
        files_changed = stats['files']
        subsystems = {path.split('/')[0] for path in commit.stats.files.keys()}
        modified_dirs = {os.path.dirname(f) for f in commit.stats.files.keys()}
        
        total_lines_changed = lines_added + lines_deleted
        entropy = 0.0
        if total_lines_changed > 0:
            for file_path, file_stats in commit.stats.files.items():
                file_lines_changed = file_stats['insertions'] + file_stats['deletions']
                if file_lines_changed > 0:
                    change_proportion = file_lines_changed / total_lines_changed
                    entropy -= change_proportion * math.log2(change_proportion)
        
        previous_total_size = 0
        if commit.parents:
            parent = commit.parents[0]
            for diff in commit.diff(parent):
                if diff.a_blob:
                    previous_total_size += diff.a_blob.size

        # --- NEW: Look up pre-computed experience features ---
        experience_metrics = history_data.get(commit.hexsha, {})

        feature_dict = {
            'commit_hash': commit.hexsha,
            'author_email': commit.author.email,
            'commit_date': commit.authored_datetime,
            'lines_added': lines_added,
            'lines_deleted': lines_deleted,
            'files_changed': files_changed,
            'num_modified_subsystems': len(subsystems),          # Ft5
            'num_modified_dirs': len(modified_dirs),             # Ft6
            'entropy': entropy,                                  # Ft7
            'previous_total_size': previous_total_size,        # Ft4
            # Add the experience features from our pre-computed dictionary
            'author_total_commits': experience_metrics.get('author_total_commits', 0), # Ft11 & Ft12
            'time_since_last_commit': experience_metrics.get('time_since_last_commit_seconds', 0), # Ft10
            'recent_commits': experience_metrics.get('recent_commits_60d', 0), # Ft13
            'prior_committers': experience_metrics.get('unique_prior_committers_on_files', 0), # Ft9
        }
        return feature_dict

    except Exception as e:
        logger.warning(f"Could not process commit {commit.hexsha}. Error: {e}")
        return None

logger.info("Final worker function defined, ready to use pre-computed history.")
# Out:
# 2025-06-27 11:34:58.127 | INFO     | __main__:<module>:56 - Final worker function (v3) defined, ready to use pre-computed history.

# %%
import pandas as pd
import git
import os
from tqdm import tqdm

logger.info("--- Starting Final Feature Extraction using Pre-computed History ---")

# --- Step 1: Checkpointing - Load Already Processed Commits ---
# This ensures we can resume if the script is interrupted.
processed_hashes = set()
if os.path.exists(OUTPUT_CSV):
    try:
        logger.info(f"Output file '{OUTPUT_CSV}' found. Loading processed commits to resume.")
        processed_df = pd.read_csv(OUTPUT_CSV)
        processed_hashes = set(processed_df['commit_hash'])
        logger.success(f"Found {len(processed_hashes)} commits already processed. They will be skipped.")
    except Exception as e:
        logger.error(f"Could not read existing CSV file. Starting from scratch. Error: {e}")
        processed_hashes = set()

# --- Step 2: Get the List of Commits to Process ---
# We assume the 'repo' object is already initialized from the pre-computation step.
# If not, uncomment the following line:
repo = git.Repo(REPO_PATH) 

logger.info(f"Fetching commits from branch '{TARGET_BRANCH}'...")
all_commits = list(repo.iter_commits(TARGET_BRANCH))

# Filter out commits that have already been processed
# This uses the 'commit' objects directly, which is efficient.
commits_to_process = [c for c in all_commits if c.hexsha not in processed_hashes]
logger.info(f"Total commits in repo: {len(all_commits)}. New commits to process: {len(commits_to_process)}.")
# Out:
# 2025-06-27 11:35:20.000 | INFO     | __main__:<module>:8 - --- Starting Final Feature Extraction using Pre-computed History ---
# 2025-06-27 11:35:20.007 | INFO     | __main__:<module>:28 - Fetching commits from branch 'master'...
# 2025-06-27 11:35:23.384 | INFO     | __main__:<module>:34 - Total commits in repo: 126808. New commits to process: 126808.

# %%
# --- TEMPORARY DEBUGGING CELL ---
# This runs the code sequentially to find the exact point of failure.

logger.info("--- Starting Feature Extraction in DEBUG MODE (Sequential) ---")

# --- We assume 'precomputed_data' and other variables are already loaded from previous cells ---

all_features = []
error_count = 0
problematic_commits = []

# Use the 'commits_to_process' list you already created in the previous cell
for commit in tqdm(commits_to_process, desc="Extracting Features (Debug Mode)"):
    try:
        # Call the worker function directly
        result = extract_features_for_commit_worker(commit, precomputed_data)
        if result:
            all_features.append(result)
        else:
            # This handles cases where the worker function returns None intentionally
            error_count += 1
            problematic_commits.append(commit.hexsha)

    except Exception as e:
        # This will catch the crash and tell us exactly which commit failed
        logger.error(f"FATAL ERROR on commit: {commit.hexsha}")
        logger.error(f"Error details: {e}")
        # We re-raise the exception to see the full traceback
        raise e

logger.success("--- Sequential Processing Finished ---")
if problematic_commits:
    logger.warning(f"Found {len(problematic_commits)} commits that returned None. Hashes: {problematic_commits}")

if all_features:
    results_df = pd.DataFrame(all_features)
    display(results_df.head())
# Out:
# 2025-06-27 11:35:30.017 | INFO     | __main__:<module>:4 - --- Starting Feature Extraction in DEBUG MODE (Sequential) ---
# Extracting Features (Debug Mode):  16%|█▌        | 19857/126808 [7:01:41<36:42:44,  1.24s/it]    2025-06-27 18:37:14.607 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit be5fc8de6bb8d176540ab0910b26dff770b8df19. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19904/126808 [7:02:32<36:48:44,  1.24s/it]2025-06-27 18:38:06.340 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 12cee979f059fe19e74d44b8ee7cf42135414e8d. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19907/126808 [7:02:38<46:55:31,  1.58s/it]2025-06-27 18:38:14.423 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit e02f91b8158161ad1b114a2a7a3056d69d5bf92b. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19908/126808 [7:02:44<84:13:32,  2.84s/it]2025-06-27 18:38:17.307 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 2e9d1e18659670869b2b34f8ab147ca3caca771b. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19922/126808 [7:02:59<25:31:14,  1.16it/s]2025-06-27 18:38:33.438 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 82a57f76608f37d5a2265831c3c64a87eee9232e. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19925/126808 [7:03:05<42:16:55,  1.42s/it]2025-06-27 18:38:36.592 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 05686eaabe10ec7a1bcb7597c2cedcc764508ecf. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19927/126808 [7:03:07<34:39:55,  1.17s/it]2025-06-27 18:38:43.002 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 4ed0fc4babe3535143bb68293496e765ecd6e5d3. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19932/126808 [7:03:16<38:58:56,  1.31s/it]2025-06-27 18:38:47.931 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 9bf3e57dd113b9e217a4cf891ba66a92e2e2aec0. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19933/126808 [7:03:17<37:24:37,  1.26s/it]2025-06-27 18:38:50.892 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 4f4c4e387f805151df856fa61f9ecc89b7813be1. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19937/126808 [7:03:24<41:05:15,  1.38s/it]2025-06-27 18:38:57.745 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 052f719910f719645d4c6016046a2ad7fd388add. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19938/126808 [7:03:27<57:30:04,  1.94s/it]2025-06-27 18:38:58.728 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 05a3c368795052ed0f0e81659d2faae5f6399401. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19944/126808 [7:03:34<36:43:34,  1.24s/it]2025-06-27 18:39:05.507 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit a65a24209114966a538aad6031849bc942f948a8. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19956/126808 [7:03:46<31:51:48,  1.07s/it]2025-06-27 18:39:17.326 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 0bed7ee45b3135aefc71889ce15b0dfc36e95e34. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19957/126808 [7:03:47<30:57:12,  1.04s/it]2025-06-27 18:39:18.246 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 9ede73dfa8f0aabb01e67c5c073eb0699f052a46. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 19959/126808 [7:03:48<27:39:50,  1.07it/s]2025-06-27 18:39:20.054 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit fcf6306b88675ceadc99620413b71c1284aecb4f. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  16%|█▌        | 20031/126808 [7:05:39<31:50:44,  1.07s/it] 2025-06-27 18:41:10.352 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 1285bf966aeadb78472777b86cd065e93900de32. Error: SHA b'0f180bf01e751929bad5edb0279c1f74f49e094f' could not be resolved, git returned: b'0f180bf01e751929bad5edb0279c1f74f49e094f missing'
# Extracting Features (Debug Mode):  23%|██▎       | 29169/126808 [10:32:34<46:48:27,  1.73s/it]  2025-06-27 22:08:49.409 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 309d747c72ca1a2f260174f02f42f227a84e9172. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  24%|██▍       | 31056/126808 [13:16:16<24:38:39,  1.08it/s]     2025-06-28 00:51:54.549 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 395d5c1c5aa5461248d0cf627a49d8c3f828a3d5. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▍       | 31305/126808 [13:21:18<40:06:11,  1.51s/it]2025-06-28 00:56:56.309 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 9a4e18fab155deb39be69063850fa5f2a8fcff9c. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▍       | 31575/126808 [13:26:51<32:40:06,  1.23s/it]2025-06-28 01:02:29.153 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit d9a118602c10fce6b632a92f1562a1f42db2eaee. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▍       | 31621/126808 [13:27:53<23:51:20,  1.11it/s]2025-06-28 01:03:29.645 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 48e99abecb2fe501c557cb26da91025ab18a068e. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 31823/126808 [13:31:44<25:09:30,  1.05it/s]2025-06-28 01:07:20.063 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit b6c2118ee8ce21bf721ac67e57a6d6f76b2b979f. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 31890/126808 [13:33:11<21:52:32,  1.21it/s]2025-06-28 01:08:47.053 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 132c6fe052b37401df5a2ad063c6383971fc6f37. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 31959/126808 [13:34:39<31:36:31,  1.20s/it]2025-06-28 01:10:13.083 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 8aff3ccf3116c262a3c77f90b8af27cb57003392. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32010/126808 [13:35:39<34:08:22,  1.30s/it]2025-06-28 01:11:14.183 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 499ccdf94b3897049040b9cea98b5a5b366a86ed. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32090/126808 [13:37:10<27:30:23,  1.05s/it]2025-06-28 01:12:43.839 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit cf896643e53c74463302a9790151f1f2a0cec1fc. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32096/126808 [13:37:19<32:57:20,  1.25s/it]2025-06-28 01:12:52.802 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 9abc7f1f1bd24b2f96c3226b87419ce73abf102e. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32123/126808 [13:37:56<23:59:29,  1.10it/s]2025-06-28 01:13:32.163 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 1724bf6282c61d7ac223317db2201e07fb6fea80. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32132/126808 [13:38:16<79:17:19,  3.01s/it]2025-06-28 01:13:50.774 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 2a28e4b5f6c5e399de12636fd4db0e927045694c. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32133/126808 [13:38:20<92:44:15,  3.53s/it]2025-06-28 01:13:54.638 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 64efd1ffd64a4bbe90dfe42b7a921798514dd563. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32143/126808 [13:38:34<32:31:17,  1.24s/it]2025-06-28 01:14:07.522 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit c608589b9e09949c7b0a87b0c1265320d4242fe2. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32174/126808 [13:39:16<31:26:40,  1.20s/it]2025-06-28 01:14:48.957 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 983501c704a0447b3e5b0f66d17b335c38ac22f6. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32175/126808 [13:39:18<44:06:55,  1.68s/it]2025-06-28 01:14:52.338 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 2a36acbd60f6d9d6c927ecc8bf02848b65532db1. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32177/126808 [13:39:23<48:02:49,  1.83s/it]2025-06-28 01:14:58.271 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit fb07b4523067d6fb1930a422c3b634cfce882709. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32216/126808 [13:40:23<29:57:46,  1.14s/it]2025-06-28 01:15:54.726 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 5b2241384b32d2996be3ecb4c800f012dc498e96. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32225/126808 [13:40:40<34:23:32,  1.31s/it]2025-06-28 01:16:12.693 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 32e0cbb1933c5d6ce9020c66598df477c5806b85. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32237/126808 [13:40:52<26:11:48,  1.00it/s]2025-06-28 01:16:25.477 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 45e76c317c39771eda6ba79fc4307c04129dbc81. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32242/126808 [13:40:59<29:47:28,  1.13s/it]2025-06-28 01:16:33.389 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit cc648209fdb43a698f991feeda8cef8e5f629268. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32243/126808 [13:41:03<52:12:43,  1.99s/it]2025-06-28 01:16:34.660 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 6f7b52f111b26a346bc748736d1f5715a3c11f5b. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32248/126808 [13:41:07<27:58:00,  1.06s/it]2025-06-28 01:16:42.310 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 01429e924204d2b0acdbba74837cef1413f8bf8c. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  25%|██▌       | 32276/126808 [13:41:38<24:10:26,  1.09it/s]2025-06-28 01:17:10.446 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 356fb5bfb836345e8e660d8040dae933ed870cec. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32364/126808 [13:43:52<28:44:36,  1.10s/it] 2025-06-28 01:19:23.787 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 0013610f76b928c4574f7af91f18a84803ed9434. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32389/126808 [13:44:34<46:51:45,  1.79s/it] 2025-06-28 01:20:09.548 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 410c2ea80d4eb2c5d1ec34c9147a981293667d32. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32457/126808 [13:45:53<28:00:49,  1.07s/it]2025-06-28 01:21:27.863 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit b747452f77b0892794cfdd7b96585cf5a0945518. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32462/126808 [13:46:03<38:48:45,  1.48s/it]2025-06-28 01:21:37.544 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 5b05b30d0a665a8831d245ab2a7d2b31914b2351. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32464/126808 [13:46:09<57:30:48,  2.19s/it]2025-06-28 01:21:44.138 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit d2865ce9881529919b4357e3c26bf230423b92b1. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32484/126808 [13:46:44<31:19:57,  1.20s/it] 2025-06-28 01:22:19.146 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 8c65aada19cedeb66e4d1dd4beaa7d7136f9d819. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32528/126808 [13:47:36<29:07:56,  1.11s/it]2025-06-28 01:23:12.092 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 2a548d8369a1aed3f7584bb59ab1186e229d92c9. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32561/126808 [13:48:15<25:20:28,  1.03it/s]2025-06-28 01:23:55.101 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit b3697b859674451ba4d69ab17332e19d6a9cd043. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32572/126808 [13:48:36<28:49:48,  1.10s/it]2025-06-28 01:24:10.832 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 36c28040ab9dd5b9d0fa0e86e8be6293bae8928d. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32608/126808 [13:49:16<28:01:32,  1.07s/it]2025-06-28 01:24:50.916 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit b7afa9e1a92d4a5a9fef46c58d5af2f0e0eaa0fa. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32610/126808 [13:49:21<42:17:06,  1.62s/it]2025-06-28 01:24:55.430 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 0cd1a64b17b84d80191dedff46546309c91af0e8. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32618/126808 [13:49:32<28:36:11,  1.09s/it]2025-06-28 01:25:07.596 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 2397f85416480b4cc368fdfa5d04a2bb97889a83. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32673/126808 [13:50:32<28:12:46,  1.08s/it]2025-06-28 01:26:04.780 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit e4f2eded42ac3b291bb1ff90923b71df5e303aa3. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32677/126808 [13:50:37<29:00:27,  1.11s/it]2025-06-28 01:26:10.779 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit ed17e1dc573311bec9438ed6f95de353477a6c9b. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32688/126808 [13:50:50<27:27:39,  1.05s/it]2025-06-28 01:26:23.984 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit bb53147eedaf5e034c06f5630cbe2d639d04ebd8. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32700/126808 [13:51:04<25:22:39,  1.03it/s]2025-06-28 01:26:38.247 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 2d2252e068cfea6d03f0f844f712da12734bde2b. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32706/126808 [13:51:13<32:08:25,  1.23s/it]2025-06-28 01:26:46.980 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 3344e2a9c8a1a4616d4711b4b867cb052e1a0636. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32713/126808 [13:51:23<31:10:09,  1.19s/it]2025-06-28 01:26:56.764 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 1443bc59884d84e119036175256938eecaeb9483. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32717/126808 [13:51:29<31:09:48,  1.19s/it]2025-06-28 01:27:00.659 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 2a6ef83b752e3b6b542719b3ea05e79a8b55291e. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32724/126808 [13:51:36<25:31:26,  1.02it/s]2025-06-28 01:27:07.535 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 86685813c535f55f4f57f7e38fcc2cb71d89039a. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32795/126808 [13:52:58<27:29:07,  1.05s/it]2025-06-28 01:28:34.153 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 36609cb4237ffedcc908a7822823ea0f36176b27. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32809/126808 [13:53:16<25:58:40,  1.01it/s]2025-06-28 01:29:00.516 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 30b02740b1b21aea4b26288d7f8c8a7f817254de. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32874/126808 [13:54:40<30:48:50,  1.18s/it] 2025-06-28 01:30:11.751 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit f43bbd83f760de3c2b6ea4f752048b675df6a531. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32961/126808 [13:56:20<27:31:00,  1.06s/it]2025-06-28 01:31:57.484 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 1ea12819c82e9ea75598858ba28cc4ffd165b239. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 32965/126808 [13:56:30<40:36:03,  1.56s/it]2025-06-28 01:32:24.851 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 0e1fbe635f671de75ca1ee07a569a775a28cc5a1. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33085/126808 [13:59:05<33:31:00,  1.29s/it] 2025-06-28 01:34:40.206 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 362faec196a8f7328d9d4303580c85e9da636465. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33089/126808 [13:59:13<39:02:04,  1.50s/it]2025-06-28 01:34:46.775 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 0ae32a92374417c6b7b0d68b151dab0c2612de2a. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33093/126808 [13:59:23<49:35:28,  1.91s/it]2025-06-28 01:35:01.991 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 917ca30949fbb5b4d8c933c89811644c24aa732f. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33094/126808 [13:59:31<101:07:30,  3.88s/it]2025-06-28 01:35:10.700 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 73e78a56f93ef308ca08f2cf1b29174da8844bf6. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33100/126808 [13:59:46<45:52:47,  1.76s/it] 2025-06-28 01:35:20.741 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit b942f7d21155767a8e07a8d961d8dfc4698bffa3. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33180/126808 [14:01:35<23:03:45,  1.13it/s]2025-06-28 01:37:06.773 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit b20752fcc238ab3a437b2054a080b32519c0ccaf. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33198/126808 [14:01:59<31:53:50,  1.23s/it]2025-06-28 01:37:31.421 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 1ab020ae67c26a8d398cce39b9b994f656778c04. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33203/126808 [14:02:08<37:32:22,  1.44s/it]2025-06-28 01:37:41.340 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 999a342a59cb4436db28c58ad4df1f33d9079c30. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33220/126808 [14:02:27<26:33:16,  1.02s/it]2025-06-28 01:37:59.908 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit bddf8b7a909ad83b19aabe60d69d9af255b0f8b8. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33227/126808 [14:02:36<29:44:34,  1.14s/it]2025-06-28 01:38:21.067 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit fa11d793e15252af2066aba9764d4e44541d6ac2. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33232/126808 [14:02:56<56:49:42,  2.19s/it] 2025-06-28 01:38:27.007 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit c29e3a6cfb7b7357b11ffbf4348a102ac241401d. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33239/126808 [14:03:02<27:48:11,  1.07s/it]2025-06-28 01:38:34.058 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 8fb76870e45ed2a683ea3d936a04d0944cb1038b. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33253/126808 [14:03:17<28:41:17,  1.10s/it]2025-06-28 01:38:48.141 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 1251adf2961f1c1914838177139b16eeddc70f6d. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▌       | 33266/126808 [14:03:29<24:35:29,  1.06it/s]2025-06-28 01:39:00.560 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit dfa1fba9adbefdf4767cd754df521c4500a8c113. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  26%|██▋       | 33316/126808 [14:04:26<23:42:52,  1.10it/s]2025-06-28 01:39:57.217 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit ec9a48fc1735ff3b2687763969c6703ac4efcff4. Error: SHA b'c54bb069829f4ace3c1d438b7acee2558eba0ec2' could not be resolved, git returned: b'c54bb069829f4ace3c1d438b7acee2558eba0ec2 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 33620/126808 [14:10:35<42:46:32,  1.65s/it] 2025-06-28 01:46:18.726 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 972ed74817a8a99c7e40ee302bacd8a3363c2dfe. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34024/126808 [14:20:23<38:09:59,  1.48s/it] 2025-06-28 01:56:14.840 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 362d82fe4d770f60b21e88a9c491fc49cf4d5890. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34380/126808 [14:27:50<28:41:44,  1.12s/it] 2025-06-28 02:03:36.232 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 6c499006b48a12792ffc5183ec0e95a70d1acb2c. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34477/126808 [14:30:00<32:40:46,  1.27s/it] 2025-06-28 02:05:55.498 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit b2bc0ff638d219d7dcbd2e01986a101e3735b2e5. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34743/126808 [14:35:45<30:11:00,  1.18s/it] 2025-06-28 02:11:24.105 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit a9b02bd15439ebdc618f084353c2d7cd343b338e. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34760/126808 [14:36:10<30:02:46,  1.18s/it]2025-06-28 02:11:47.807 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 51176b3f32262e8b374e92bbee8c5392c6192c4b. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34764/126808 [14:36:20<40:07:42,  1.57s/it]2025-06-28 02:11:57.486 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 9067976896c0ac033ff9026b40db5b6d5e8d9f3f. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34771/126808 [14:36:32<32:09:43,  1.26s/it]2025-06-28 02:12:09.906 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 85afb5539c10827590acf0dd547a75ad1af25a24. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34820/126808 [14:37:33<27:16:29,  1.07s/it]2025-06-28 02:13:10.856 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit cab20d7a5b97187e6737011478fcd3ee178b0b37. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34823/126808 [14:37:42<47:04:09,  1.84s/it]2025-06-28 02:13:20.158 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit f5fc4169d53610f1e7b08ee23f6e756cfe688cb2. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34833/126808 [14:38:01<36:06:16,  1.41s/it]2025-06-28 02:13:37.827 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit c307a27918a6ef0fdb13db7e9f3b839c6184e41d. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  27%|██▋       | 34834/126808 [14:38:07<76:31:27,  3.00s/it]2025-06-28 02:13:44.226 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 6ad9917d7923596bf75f4d1186d2a149b4103314. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 34886/126808 [14:39:19<26:49:17,  1.05s/it] 2025-06-28 02:14:56.239 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 5482fa808526ffdf34a96da2763ec44278c5d050. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 34903/126808 [14:39:41<26:48:14,  1.05s/it]2025-06-28 02:15:17.699 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 035d8a2348642d0932a18010ea185794e8889946. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 34913/126808 [14:39:56<31:02:48,  1.22s/it]2025-06-28 02:15:33.959 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit e380dee4b10cea60407391d13b11e1bf81f9ddae. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 34939/126808 [14:40:32<24:48:40,  1.03it/s]2025-06-28 02:16:07.342 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 0120c78800f601f9a2545d6f98fc209d590c43e2. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 34958/126808 [14:41:00<28:11:57,  1.11s/it]2025-06-28 02:16:34.945 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 3b3a889d1adbe14c3050992557bf44e84d456066. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35022/126808 [14:42:20<27:57:34,  1.10s/it]2025-06-28 02:17:55.283 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit d828b7d8b48ddd642bc9520b0b241411a98b6422. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35067/126808 [14:43:16<24:37:45,  1.03it/s]2025-06-28 02:18:51.190 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit b046c8c7ed7d9173cf1b263a1512a1f0c55a434f. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35074/126808 [14:43:26<26:09:07,  1.03s/it]2025-06-28 02:19:00.728 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 167ea47d6c01142b2aa09568ce0757663692dbef. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35102/126808 [14:44:00<34:55:31,  1.37s/it]2025-06-28 02:19:42.479 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit f4410f764fe15da17d0962acd6a694e0413e64a0. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35107/126808 [14:44:17<50:47:12,  1.99s/it] 2025-06-28 02:19:49.663 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 84a2a4f5d76be46e7d1c10165390ce0bbefe95ee. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35144/126808 [14:44:56<28:10:14,  1.11s/it]2025-06-28 02:20:31.113 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 97be7fac3a8c32a95e5153c7788f2d2220f952f2. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35153/126808 [14:45:08<30:25:06,  1.19s/it]2025-06-28 02:20:41.546 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 4103f004f4632ab45e67c1d30912eb6ea93bb8e2. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35155/126808 [14:45:12<35:50:32,  1.41s/it]2025-06-28 02:20:44.697 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 467fdc420dcc2825ba024593113b5a66f325e50a. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35161/126808 [14:45:21<39:55:53,  1.57s/it]2025-06-28 02:20:52.498 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 513af8e7079013526b2b78b1e66c0f04778ab4cd. Error: SHA b'b8db7bd07c04d13c030f3a9bee2eca957e620040' could not be resolved, git returned: b'b8db7bd07c04d13c030f3a9bee2eca957e620040 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35164/126808 [14:45:24<27:31:03,  1.08s/it]2025-06-28 02:20:56.731 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit c548527d63838178c9655572904909bde1f03d67. Error: SHA b'3651b01d215a8065100d45f33c5b213a7541e8b2' could not be resolved, git returned: b'3651b01d215a8065100d45f33c5b213a7541e8b2 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35202/126808 [14:46:11<31:46:42,  1.25s/it]2025-06-28 02:21:43.682 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 27c447e12afe0cd93aab20c1fb9e30cf0241c451. Error: SHA b'3651b01d215a8065100d45f33c5b213a7541e8b2' could not be resolved, git returned: b'3651b01d215a8065100d45f33c5b213a7541e8b2 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35207/126808 [14:46:18<30:27:04,  1.20s/it]2025-06-28 02:21:57.347 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit d527a6166714d0202e28f1b9b456e8d67f9f98ed. Error: SHA b'3651b01d215a8065100d45f33c5b213a7541e8b2' could not be resolved, git returned: b'3651b01d215a8065100d45f33c5b213a7541e8b2 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35223/126808 [14:46:41<24:09:11,  1.05it/s]2025-06-28 02:22:13.069 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 5286ad633f61c79fc97aa63cee53e3779d606ff2. Error: SHA b'3651b01d215a8065100d45f33c5b213a7541e8b2' could not be resolved, git returned: b'3651b01d215a8065100d45f33c5b213a7541e8b2 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35323/126808 [14:49:08<101:37:43,  4.00s/it]2025-06-28 02:24:39.531 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 70c3df69ac4402993c5a339255d0463a5004f1b1. Error: SHA b'3651b01d215a8065100d45f33c5b213a7541e8b2' could not be resolved, git returned: b'3651b01d215a8065100d45f33c5b213a7541e8b2 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 35363/126808 [14:49:51<27:52:29,  1.10s/it] 2025-06-28 02:25:49.249 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 36935f453f231afbb156ff6fb6a5a2924fd6ecba. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 36025/126808 [15:04:24<25:09:13,  1.00it/s] 2025-06-28 02:40:06.933 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 52966bd7bc53baeec37dfce4a947d5a6cad3eb2b. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 36034/126808 [15:04:45<32:45:00,  1.30s/it] 2025-06-28 02:40:27.701 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit aa99952a1b1a774f02019b1c7ce88f6073f91591. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 36053/126808 [15:05:20<35:24:24,  1.40s/it] 2025-06-28 02:41:02.298 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit bd700fdfeaf99eb803ef03c59175df16c1bda8cc. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 36078/126808 [15:06:01<33:13:27,  1.32s/it] 2025-06-28 02:41:44.883 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 0c84ae21baf4a1f0747e68060b6352c9dfd22b1e. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# Extracting Features (Debug Mode):  28%|██▊       | 36117/126808 [15:06:56<26:08:01,  1.04s/it] 2025-06-28 02:42:37.068 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit e69bb3d6524249456a62fdfbecf048da0cacb434. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# Extracting Features (Debug Mode):  29%|██▊       | 36184/126808 [15:08:22<28:14:46,  1.12s/it]2025-06-28 02:44:03.248 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 6b1017574c8e1f3e10805b50682066e3a480227e. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# Extracting Features (Debug Mode):  29%|██▊       | 36186/126808 [15:08:33<77:09:49,  3.07s/it] 2025-06-28 02:44:14.519 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 1aa4988e40c95c84754ac07974cdee543798314c. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# Extracting Features (Debug Mode):  29%|██▊       | 36193/126808 [15:08:50<39:39:25,  1.58s/it] 2025-06-28 02:44:31.982 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 9929630bb7048e5557ac564ff34f35f3ebba1d81. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# Extracting Features (Debug Mode):  29%|██▊       | 36214/126808 [15:09:26<25:12:36,  1.00s/it] 2025-06-28 02:45:06.532 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit d7661a60b0496af2fa2d86d267f844af888af8ff. Error: SHA b'0338b380eb60dd2b59db05edd110a620fe8f9243' could not be resolved, git returned: b'0338b380eb60dd2b59db05edd110a620fe8f9243 missing'
# ...
# Extracting Features (Debug Mode):  72%|███████▏  | 90673/126808 [35:28:45<11:49:41,  1.18s/it]2025-06-28 23:04:17.050 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 98825d254d6fd3c777b726f6e2f8badc829ce1f2. Error: SHA b'363cbcb3505624cb375f5f9c716159931584133f' could not be resolved, git returned: b'363cbcb3505624cb375f5f9c716159931584133f missing'
# Extracting Features (Debug Mode):  72%|███████▏  | 90707/126808 [35:29:25<14:45:44,  1.47s/it]2025-06-28 23:04:57.055 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit db5a33c27084be15bd666642cf32dc294cdf038b. Error: SHA b'363cbcb3505624cb375f5f9c716159931584133f' could not be resolved, git returned: b'363cbcb3505624cb375f5f9c716159931584133f missing'
# Extracting Features (Debug Mode):  75%|███████▍  | 94884/126808 [36:58:50<10:36:36,  1.20s/it]2025-06-29 00:34:40.054 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit d9eaf6e67ec5ed8f5e8e747930b1b4539dc65535. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  76%|███████▌  | 96591/126808 [37:35:39<9:50:08,  1.17s/it] 2025-06-29 01:11:15.899 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 79452df9b77aaf69818604a6a996421322bc7355. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  76%|███████▌  | 96634/126808 [37:36:36<12:27:34,  1.49s/it]2025-06-29 01:12:13.801 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 26b7500f6800b4af33338755cd31e9c38f31a4f9. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97358/126808 [37:51:19<8:41:40,  1.06s/it] 2025-06-29 01:26:54.847 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit c0cde66465a94d7a5bb3c934a1deadbed6b6910e. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97452/126808 [37:53:13<9:37:22,  1.18s/it] 2025-06-29 01:28:47.099 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 9c76500e9be1167cbbfa6ab48c198ab28666d110. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97605/126808 [37:56:21<9:36:02,  1.18s/it] 2025-06-29 01:31:54.714 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 7229d0cd3387bc8321fd89d51aa16045e72de8ae. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97640/126808 [37:57:03<11:00:38,  1.36s/it]2025-06-29 01:32:37.843 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 90492146c30b56d171227c193de50d6242847bac. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97643/126808 [37:57:10<14:09:01,  1.75s/it]2025-06-29 01:32:43.517 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 5ffa09c70fa1ef7fb57d2cd6f87652534e706178. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97786/126808 [38:00:08<12:52:07,  1.60s/it]2025-06-29 01:35:41.720 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit f968834ab30d841ffa39f2523ffe44d9d8a75320. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97819/126808 [38:00:52<8:42:58,  1.08s/it] 2025-06-29 01:36:26.780 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 4d0cc6deb66ba66251f90dbe21eb3bbd078e0fec. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97865/126808 [38:01:51<9:11:14,  1.14s/it] 2025-06-29 01:37:24.654 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 34025ee80bf2ec4c638a6ebb92e0393b0fe3a50d. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97892/126808 [38:02:22<8:33:52,  1.07s/it] 2025-06-29 01:37:56.524 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 7c7ea203a07f6d59142998203065370f2148b4f4. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97901/126808 [38:02:34<9:02:43,  1.13s/it] 2025-06-29 01:38:08.526 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit f9aa5bb1833278562dade97b128c85550f0d6ba7. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97909/126808 [38:02:46<10:04:47,  1.26s/it]2025-06-29 01:38:20.075 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 5c28b6ebccbbe9ba35d64cc07d12c6f9566feda2. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97936/126808 [38:03:20<9:00:07,  1.12s/it] 2025-06-29 01:38:54.069 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 7703e1a0c80d842b9752c07de4e342c9a5dacca1. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97938/126808 [38:03:24<12:16:11,  1.53s/it]2025-06-29 01:38:57.323 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 578e6082dcaf763dc0d676d150ff3a07c9cee926. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97942/126808 [38:03:30<11:08:21,  1.39s/it]2025-06-29 01:39:04.224 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit f5bf7466aeb45e2e29bfd6d7d8ee2223b1e6a59f. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97947/126808 [38:03:37<9:28:23,  1.18s/it] 2025-06-29 01:39:11.276 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit ee15736642d224064e1897ad4867de7738904330. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97948/126808 [38:03:41<14:51:07,  1.85s/it]2025-06-29 01:39:14.372 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 372503d162439857c1ab3b6ac5eba5607369e6d8. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97979/126808 [38:04:18<9:37:09,  1.20s/it] 2025-06-29 01:39:50.342 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 5a900cadb2e5474f530e1ca7ed7c136ce5855960. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  77%|███████▋  | 97980/126808 [38:04:20<12:15:30,  1.53s/it]2025-06-29 01:39:53.461 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit eeca1df938a02f4ae88aec9337f8ae5cd6543fb8. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  94%|█████████▍| 119082/126808 [44:30:22<2:06:01,  1.02it/s] 2025-06-29 08:05:54.494 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 1adcdf2ab39a0c5e249348506777ce60023bd956. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode):  95%|█████████▌| 120652/126808 [44:59:12<1:37:00,  1.06it/s]2025-06-29 08:34:43.936 | WARNING  | __main__:extract_features_for_commit_worker:53 - Could not process commit 4b76b61f0c616645d36af1cebc537585ba17ec7c. Error: SHA b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62' could not be resolved, git returned: b'2f5bfb8df4caf76adb719a7d422ce1d4f79bfb62 missing'
# Extracting Features (Debug Mode): 100%|██████████| 126808/126808 [46:48:46<00:00,  1.33s/it]
# 2025-06-29 10:24:16.152 | SUCCESS  | __main__:<module>:31 - --- Sequential Processing Finished ---
# 2025-06-29 10:24:16.152 | WARNING  | __main__:<module>:33 - Found 983 commits that returned None. Hashes: ['be5fc8de6bb8d176540ab0910b26dff770b8df19', '12cee979f059fe19e74d44b8ee7cf42135414e8d', 'e02f91b8158161ad1b114a2a7a3056d69d5bf92b', '2e9d1e18659670869b2b34f8ab147ca3caca771b', '82a57f76608f37d5a2265831c3c64a87eee9232e', '05686eaabe10ec7a1bcb7597c2cedcc764508ecf', '4ed0fc4babe3535143bb68293496e765ecd6e5d3', '9bf3e57dd113b9e217a4cf891ba66a92e2e2aec0', '4f4c4e387f805151df856fa61f9ecc89b7813be1', '052f719910f719645d4c6016046a2ad7fd388add', '05a3c368795052ed0f0e81659d2faae5f6399401', 'a65a24209114966a538aad6031849bc942f948a8', '0bed7ee45b3135aefc71889ce15b0dfc36e95e34', '9ede73dfa8f0aabb01e67c5c073eb0699f052a46', 'fcf6306b88675ceadc99620413b71c1284aecb4f', '1285bf966aeadb78472777b86cd065e93900de32', '309d747c72ca1a2f260174f02f42f227a84e9172', '395d5c1c5aa5461248d0cf627a49d8c3f828a3d5', '9a4e18fab155deb39be69063850fa5f2a8fcff9c', 'd9a118602c10fce6b632a92f1562a1f42db2eaee', '48e99abecb2fe501c557cb26da91025ab18a068e', 'b6c2118ee8ce21bf721ac67e57a6d6f76b2b979f', '132c6fe052b37401df5a2ad063c6383971fc6f37', '8aff3ccf3116c262a3c77f90b8af27cb57003392', '499ccdf94b3897049040b9cea98b5a5b366a86ed', 'cf896643e53c74463302a9790151f1f2a0cec1fc', '9abc7f1f1bd24b2f96c3226b87419ce73abf102e', '1724bf6282c61d7ac223317db2201e07fb6fea80', '2a28e4b5f6c5e399de12636fd4db0e927045694c', '64efd1ffd64a4bbe90dfe42b7a921798514dd563', 'c608589b9e09949c7b0a87b0c1265320d4242fe2', '983501c704a0447b3e5b0f66d17b335c38ac22f6', '2a36acbd60f6d9d6c927ecc8bf02848b65532db1', 'fb07b4523067d6fb1930a422c3b634cfce882709', '5b2241384b32d2996be3ecb4c800f012dc498e96', '32e0cbb1933c5d6ce9020c66598df477c5806b85', '45e76c317c39771eda6ba79fc4307c04129dbc81', 'cc648209fdb43a698f991feeda8cef8e5f629268', '6f7b52f111b26a346bc748736d1f5715a3c11f5b', '01429e924204d2b0acdbba74837cef1413f8bf8c', '356fb5bfb836345e8e660d8040dae933ed870cec', '0013610f76b928c4574f7af91f18a84803ed9434', '410c2ea80d4eb2c5d1ec34c9147a981293667d32', 'b747452f77b0892794cfdd7b96585cf5a0945518', '5b05b30d0a665a8831d245ab2a7d2b31914b2351', 'd2865ce9881529919b4357e3c26bf230423b92b1', '8c65aada19cedeb66e4d1dd4beaa7d7136f9d819', '2a548d8369a1aed3f7584bb59ab1186e229d92c9', 'b3697b859674451ba4d69ab17332e19d6a9cd043', '36c28040ab9dd5b9d0fa0e86e8be6293bae8928d', 'b7afa9e1a92d4a5a9fef46c58d5af2f0e0eaa0fa', '0cd1a64b17b84d80191dedff46546309c91af0e8', '2397f85416480b4cc368fdfa5d04a2bb97889a83', 'e4f2eded42ac3b291bb1ff90923b71df5e303aa3', 'ed17e1dc573311bec9438ed6f95de353477a6c9b', 'bb53147eedaf5e034c06f5630cbe2d639d04ebd8', '2d2252e068cfea6d03f0f844f712da12734bde2b', '3344e2a9c8a1a4616d4711b4b867cb052e1a0636', '1443bc59884d84e119036175256938eecaeb9483', '2a6ef83b752e3b6b542719b3ea05e79a8b55291e', '86685813c535f55f4f57f7e38fcc2cb71d89039a', '36609cb4237ffedcc908a7822823ea0f36176b27', '30b02740b1b21aea4b26288d7f8c8a7f817254de', 'f43bbd83f760de3c2b6ea4f752048b675df6a531', '1ea12819c82e9ea75598858ba28cc4ffd165b239', '0e1fbe635f671de75ca1ee07a569a775a28cc5a1', '362faec196a8f7328d9d4303580c85e9da636465', '0ae32a92374417c6b7b0d68b151dab0c2612de2a', '917ca30949fbb5b4d8c933c89811644c24aa732f', '73e78a56f93ef308ca08f2cf1b29174da8844bf6', 'b942f7d21155767a8e07a8d961d8dfc4698bffa3', 'b20752fcc238ab3a437b2054a080b32519c0ccaf', '1ab020ae67c26a8d398cce39b9b994f656778c04', '999a342a59cb4436db28c58ad4df1f33d9079c30', 'bddf8b7a909ad83b19aabe60d69d9af255b0f8b8', 'fa11d793e15252af2066aba9764d4e44541d6ac2', 'c29e3a6cfb7b7357b11ffbf4348a102ac241401d', '8fb76870e45ed2a683ea3d936a04d0944cb1038b', '1251adf2961f1c1914838177139b16eeddc70f6d', 'dfa1fba9adbefdf4767cd754df521c4500a8c113', 'ec9a48fc1735ff3b2687763969c6703ac4efcff4', '972ed74817a8a99c7e40ee302bacd8a3363c2dfe', '362d82fe4d770f60b21e88a9c491fc49cf4d5890', '6c499006b48a12792ffc5183ec0e95a70d1acb2c', 'b2bc0ff638d219d7dcbd2e01986a101e3735b2e5', 'a9b02bd15439ebdc618f084353c2d7cd343b338e', '51176b3f32262e8b374e92bbee8c5392c6192c4b', '9067976896c0ac033ff9026b40db5b6d5e8d9f3f', '85afb5539c10827590ac ...
#                                 commit_hash             author_email  \
# 0  cfa03556d2a50f5d3381bd12a97f25a1e9e8476b  tharik.kanaka@gmail.com
# 1  ecef3657b88330f2cae320f14ef30407dcb67b5a      azinneera@gmail.com
# 2  ac47d27abdb60e0b1a3146324183513aadb8fa27  tharik.kanaka@gmail.com
# 3  b2b3f93fba80d28c5b244baf3b6754b662eb872f      azinneera@gmail.com
# 4  e965df23ea6af12075af0901c2ea13880bbfdede      azinneera@gmail.com
#
#                  commit_date  lines_added  lines_deleted  files_changed  \
# 0  2025-06-14 08:32:25+05:30            1              1              1
# 1  2025-06-13 15:11:12+05:30         4655           1983            156
# 2  2025-06-13 11:17:24+05:30            2              2              2
# 3  2025-06-05 21:09:36+05:30         1565            999             34
# 4  2025-05-28 20:47:56+05:30            6              6              4
#
#    num_modified_subsystems  num_modified_dirs   entropy  previous_total_size  \
# 0                        1                  1  0.000000                18750
# 1                        5                 57  5.454747               788109
# 2                        2                  2  1.000000                17327
# 3                        3                 12  3.406617               485212
# 4                        2                  3  1.625815               129048
#
#    author_total_commits  time_since_last_commit  recent_commits  \
# 0                  1714                 76501.0               5
# 1                  1079                669696.0              16
# 2                  1713                954112.0               4
# 3                  1078                692500.0              16
# 4                  1077                 89930.0               7
#
#    prior_committers
# 0                20
# 1               199
# 2               166
# 3               120
# 4               116

# %%
results_df.to_csv("data/extract_features.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 results_df.to_csv("data/extract_features.csv", index=False)
#
# NameError: name 'results_df' is not defined

# %% [markdown]
# ## code-maat data processing

# %% [markdown]
# before process the data here we need to perfrom data extraction using [code-maat](https://github.com/adamtornhill/code-maat) tool
#  - generate git log file
#
#     - first clone the repository
#     - then generate the git log file **use gitbash**
#     >`git log --pretty=format:'[%h] %aN %ad %s' --date=short --numstat --all > gitlog.log`
#  - perform code-maat coupling analysis
#     - download the latest [release](https://github.com/adamtornhill/code-maat/releases) stanalone jar
#     - place that jar in the repository location
#     >run the tool `java -jar code-maat-1.0.4-standalone.jar -l gitlog.log -c git -a coupling -o coupling.csv`

# %% [markdown]
# ### extracting features from the code-maat output

# %% [markdown]
# I'm assuming  Number of highly coupled files Ft14 as the threshold level 75

# %%
import pandas as pd
import git
from collections import defaultdict
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor
from functools import partial
from loguru import logger

# Logger config
logger.add("logs/code_maat.log")

# --- Configuration (ensure these are set correctly) ---
COUPLING_RESULTS_PATH = "../data/final/coupling.csv"
MAIN_FEATURES_PATH = "../data/final/extract_features.csv"
FINAL_OUTPUT_PATH = "../data/final/final_training_dataset.csv"
REPO_PATH = "../../ballerina-lang/"
TARGET_BRANCH = 'master'
HIGH_COUPLING_THRESHOLD = 75
MAX_WORKERS = 6 # Number of threads to use

# %%
# --- Step 1: Load and Process code-maat's Coupling Data (Sequential - this is fast) ---
logger.info(f"Loading coupling data from '{COUPLING_RESULTS_PATH}'...")
try:
    coupling_df = pd.read_csv(COUPLING_RESULTS_PATH)
    coupling_df.dropna(inplace=True)
    
    coupling_map = defaultdict(set)
    high_coupling_map = defaultdict(set)

    for _, row in tqdm(coupling_df.iterrows(), total=len(coupling_df), desc="Building coupling map"):
        coupling_map[row['entity']].add(row['coupled'])
        coupling_map[row['coupled']].add(row['entity'])
        if row['degree'] >= HIGH_COUPLING_THRESHOLD:
            high_coupling_map[row['entity']].add(row['coupled'])
            high_coupling_map[row['coupled']].add(row['entity'])
            
    logger.success("Built coupling lookup maps for fast processing.")

except FileNotFoundError:
    logger.error(f"Coupling results file not found at '{COUPLING_RESULTS_PATH}'. Please run code-maat first.")
    raise
# Out:
# 2025-07-03 10:10:01.936 | INFO     | __main__:<module>:2 - Loading coupling data from '../data/final/coupling.csv'...
# Building coupling map: 100%|██████████| 15899/15899 [00:00<00:00, 16202.81it/s]
# 2025-07-03 10:10:02.982 | SUCCESS  | __main__:<module>:17 - Built coupling lookup maps for fast processing.

# %%
# --- Step 2: Define the Worker Function for Parallel Execution ---
def calculate_coupling_for_commit(commit, coupling_map, high_coupling_map):
    """
    Worker function to calculate coupling features for a single commit.
    This function is safe to be called from multiple threads.
    """
    if not commit.parents:
        return None

    try:
        modified_files = set(commit.stats.files.keys())
        highly_coupled_in_commit = set()
        any_coupled_in_commit = set()
        files_with_external_coupling = set()

        for file_path in modified_files:
            # Check for any coupling (for Ft15)
            all_coupled_files = coupling_map.get(file_path, set())
            if all_coupled_files.intersection(modified_files):
                any_coupled_in_commit.add(file_path)

            # Check for high coupling (for Ft14)
            high_coupled_files = high_coupling_map.get(file_path, set())
            if high_coupled_files.intersection(modified_files):
                highly_coupled_in_commit.add(file_path)

            # Check for non-modified coupled files (for Ft16)
            if all_coupled_files.difference(modified_files):
                files_with_external_coupling.add(file_path)

        return {
            'commit_hash': commit.hexsha,
            'ft14_highly_coupled_files': len(highly_coupled_in_commit),
            'ft15_any_coupled_files': len(any_coupled_in_commit),
            'ft16_non_modified_coupled_files': len(files_with_external_coupling)
        }
    except Exception as e:
        logger.warning(f"Could not process commit {commit.hexsha} for coupling. Error: {e}")
        return None

# %%
# --- Step 3: Run Per-Commit Calculations in Parallel ---
logger.info("Calculating per-commit coupling features using parallel processing...")
repo = git.Repo(REPO_PATH)
commits_to_process = list(repo.iter_commits(TARGET_BRANCH))
coupling_features_list = []

# Use functools.partial to "pre-fill" the map arguments for the worker
worker_with_maps = partial(calculate_coupling_for_commit, 
                           coupling_map=coupling_map, 
                           high_coupling_map=high_coupling_map)

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    # Use executor.map to apply the worker function to all commits
    results_iterator = executor.map(worker_with_maps, commits_to_process)
    
    # Process results as they complete with a tqdm progress bar
    for result in tqdm(results_iterator, total=len(commits_to_process), desc="Analyzing Commits for Coupling"):
        if result:
            coupling_features_list.append(result)

coupling_features_df = pd.DataFrame(coupling_features_list)
logger.success("Finished calculating per-commit coupling features.")
# Out:
# 2025-07-03 10:10:16.035 | INFO     | __main__:<module>:2 - Calculating per-commit coupling features using parallel processing...
# Analyzing Commits for Coupling:   0%|          | 0/126808 [00:00<?, ?it/s]

# %%
# --- Step 4: Merge Coupling Features with Main Feature Set (Sequential - this is fast) ---
logger.info("Merging coupling features into the main dataset...")
try:
    main_df = pd.read_csv(MAIN_FEATURES_PATH)
    final_df = pd.merge(main_df, coupling_features_df, on='commit_hash', how='left')
    
    coupling_cols = ['ft14_highly_coupled_files', 'ft15_any_coupled_files', 'ft16_non_modified_coupled_files']
    final_df[coupling_cols] = final_df[coupling_cols].fillna(0).astype(int)

    final_df.to_csv(FINAL_OUTPUT_PATH, index=False)
    
    logger.success(f"Successfully merged coupling features. Final dataset saved to '{FINAL_OUTPUT_PATH}'")
    display(final_df.head())
    
except FileNotFoundError:
    logger.error(f"Main features file not found at '{MAIN_FEATURES_PATH}'. Please ensure it has been generated.")
except Exception as e:
    logger.error(f"An error occurred during merging: {e}")

# %%
import pandas as pd
import git
from collections import defaultdict
from tqdm import tqdm

# --- Configuration ---
COUPLING_RESULTS_PATH = "../data/final/coupling.csv"
MAIN_FEATURES_PATH = "../data/final/extract_features.csv"
FINAL_OUTPUT_PATH = "../data/final/final_training_dataset.csv"
REPO_PATH = "../../ballerina-lang/"
TARGET_BRANCH = 'master'
HIGH_COUPLING_THRESHOLD = 75

# --- Step 1: Load code-maat data and create a fast lookup map ---
# This part is still necessary to avoid re-reading the coupling file for every commit.
print("Loading coupling data and building lookup map...")
coupling_df = pd.read_csv(COUPLING_RESULTS_PATH)
coupling_df.dropna(inplace=True)

coupling_map = defaultdict(set)
high_coupling_map = defaultdict(set)

for _, row in coupling_df.iterrows():
    coupling_map[row['entity']].add(row['coupled'])
    coupling_map[row['coupled']].add(row['entity'])
    if row['degree'] >= HIGH_COUPLING_THRESHOLD:
        high_coupling_map[row['entity']].add(row['coupled'])
        high_coupling_map[row['coupled']].add(row['entity'])
print("Coupling map ready.")


# --- Step 2: Process each commit one by one (Your proposed logic) ---
print("Analyzing each commit sequentially...")
repo = git.Repo(REPO_PATH)
# commits_to_process = list(repo.iter_commits(TARGET_BRANCH, max_count=1000)) # testing with 1000 commits
commits_to_process = list(repo.iter_commits(TARGET_BRANCH))

coupling_features_list = []

for commit in tqdm(commits_to_process, desc="Analyzing Commits"):
    if not commit.parents:
        continue

    # Get the set of files modified in this commit
    modified_files = set(commit.stats.files.keys())

    # Calculate the three coupling features for this single commit
    highly_coupled_in_commit = {f for f in modified_files if high_coupling_map.get(f, set()).intersection(modified_files)}
    any_coupled_in_commit = {f for f in modified_files if coupling_map.get(f, set()).intersection(modified_files)}
    files_with_external_coupling = {f for f in modified_files if coupling_map.get(f, set()).difference(modified_files)}
    
    # Append the results for this commit to our list
    coupling_features_list.append({
        'commit_hash': commit.hexsha,
        'ft14_highly_coupled_files': len(highly_coupled_in_commit),
        'ft15_any_coupled_files': len(any_coupled_in_commit),
        'ft16_non_modified_coupled_files': len(files_with_external_coupling)
    })

coupling_features_df = pd.DataFrame(coupling_features_list)
print("Finished calculating all per-commit coupling features.")


# --- Step 3: Merge the new features into your main dataset ---
print("Merging coupling features into the main dataset...")
main_df = pd.read_csv(MAIN_FEATURES_PATH)
final_df = pd.merge(main_df, coupling_features_df, on='commit_hash', how='left')

coupling_cols = ['ft14_highly_coupled_files', 'ft15_any_coupled_files', 'ft16_non_modified_coupled_files']
final_df[coupling_cols] = final_df[coupling_cols].fillna(0).astype(int)

final_df.to_csv(FINAL_OUTPUT_PATH, index=False)
print(f"Success! Final dataset with all features saved to '{FINAL_OUTPUT_PATH}'")
display(final_df.head())
# Out:
# Loading coupling data and building lookup map...
# Coupling map ready.
# Analyzing each commit sequentially...
# Analyzing Commits: 100%|██████████| 126808/126808 [8:37:41<00:00,  4.08it/s]
# Finished calculating all per-commit coupling features.
# Merging coupling features into the main dataset...
# Success! Final dataset with all features saved to '../data/final/final_training_dataset.csv'
#                                 commit_hash             author_email  \
# 0  cfa03556d2a50f5d3381bd12a97f25a1e9e8476b  tharik.kanaka@gmail.com
# 1  ecef3657b88330f2cae320f14ef30407dcb67b5a      azinneera@gmail.com
# 2  ac47d27abdb60e0b1a3146324183513aadb8fa27  tharik.kanaka@gmail.com
# 3  b2b3f93fba80d28c5b244baf3b6754b662eb872f      azinneera@gmail.com
# 4  e965df23ea6af12075af0901c2ea13880bbfdede      azinneera@gmail.com
#
#                  commit_date  lines_added  lines_deleted  files_changed  \
# 0  2025-06-14 08:32:25+05:30            1              1              1
# 1  2025-06-13 15:11:12+05:30         4655           1983            156
# 2  2025-06-13 11:17:24+05:30            2              2              2
# 3  2025-06-05 21:09:36+05:30         1565            999             34
# 4  2025-05-28 20:47:56+05:30            6              6              4
#
#    num_modified_subsystems  num_modified_dirs   entropy  previous_total_size  \
# 0                        1                  1  0.000000                18750
# 1                        5                 57  5.454747               788109
# 2                        2                  2  1.000000                17327
# 3                        3                 12  3.406617               485212
# 4                        2                  3  1.625815               129048
#
#    author_total_commits  time_since_last_commit  recent_commits  \
# 0                  1714                 76501.0               5
# 1                  1079                669696.0              16
# 2                  1713                954112.0               4
# 3                  1078                692500.0              16
# 4                  1077                 89930.0               7
#
#    prior_committers  ft14_highly_coupled_files  ft15_any_coupled_files  \
# 0                20                          0                       0
# 1               199                          8                      19
# 2               166                          0                       0
# 3               120                          0                       2
# 4               116                          0                       0
#
#    ft16_non_modified_coupled_files
# 0                                0
# 1                               13
# 2                                1
# 3                                2
# 4                                2

# %%
import pandas as pd
from collections import defaultdict
from tqdm import tqdm

# --- Configuration ---
# All paths should be correct as per your setup
COUPLING_RESULTS_PATH = "../data/final/coupling.csv"
MAIN_FEATURES_PATH = "../data/final/extract_features.csv"
LOG_WITH_FILES_PATH = "../data/final/commit_gitlog.txt" # The new file from Step 1
FINAL_OUTPUT_PATH = "../data/final/final_training_dataset.csv"

HIGH_COUPLING_THRESHOLD = 75

# --- Step 1: Load code-maat data (Same as before) ---
print("Loading coupling data and building lookup map...")
coupling_df = pd.read_csv(COUPLING_RESULTS_PATH) # Assuming this is tab-separated from previous steps
coupling_df.dropna(inplace=True)
coupling_map = defaultdict(set)
high_coupling_map = defaultdict(set)
for _, row in coupling_df.iterrows():
    coupling_map[row['entity']].add(row['coupled'])
    coupling_map[row['coupled']].add(row['entity'])
    if row['degree'] >= HIGH_COUPLING_THRESHOLD:
        high_coupling_map[row['entity']].add(row['coupled'])
        high_coupling_map[row['coupled']].add(row['entity'])
print("Coupling map ready.")

# --- Step 2: Parse the Pre-generated Log File ---
print(f"Parsing the pre-generated log file: '{LOG_WITH_FILES_PATH}'...")
all_commit_data = []
current_commit_hash = None
current_files = []

with open(LOG_WITH_FILES_PATH, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        if line.startswith('--'): # This marks a new commit
            # Save the previous commit's data before starting a new one
            if current_commit_hash:
                all_commit_data.append({'commit_hash': current_commit_hash, 'modified_files': set(current_files)})
            
            current_commit_hash = line.replace('--', '')
            current_files = []
        else: # This is a file path
            current_files.append(line)
# Add the very last commit in the file
if current_commit_hash:
    all_commit_data.append({'commit_hash': current_commit_hash, 'modified_files': set(current_files)})
print(f"Parsed {len(all_commit_data)} commits from the log file.")

# --- Step 3: Calculate Coupling Features Sequentially ---
coupling_features_list = []
for commit_data in tqdm(all_commit_data, desc="Calculating Coupling Features"):
    modified_files = commit_data['modified_files']
    
    highly_coupled_in_commit = {f for f in modified_files if high_coupling_map.get(f, set()).intersection(modified_files)}
    any_coupled_in_commit = {f for f in modified_files if coupling_map.get(f, set()).intersection(modified_files)}
    files_with_external_coupling = {f for f in modified_files if coupling_map.get(f, set()).difference(modified_files)}
    
    coupling_features_list.append({
        'commit_hash': commit_data['commit_hash'],
        'ft14_highly_coupled_files': len(highly_coupled_in_commit),
        'ft15_any_coupled_files': len(any_coupled_in_commit),
        'ft16_non_modified_coupled_files': len(files_with_external_coupling)
    })

coupling_features_df = pd.DataFrame(coupling_features_list)
print("Finished calculating coupling features.")

# --- Step 4: Merge and Save (Same as before) ---
print("Merging all features into the final dataset...")
main_df = pd.read_csv(MAIN_FEATURES_PATH)
final_df = pd.merge(main_df, coupling_features_df, on='commit_hash', how='left')
coupling_cols = ['ft14_highly_coupled_files', 'ft15_any_coupled_files', 'ft16_non_modified_coupled_files']
final_df[coupling_cols] = final_df[coupling_cols].fillna(0).astype(int)
final_df.to_csv(FINAL_OUTPUT_PATH, index=False)
print(f"Success! Final dataset with all features saved to '{FINAL_OUTPUT_PATH}'")
display(final_df.head())
# Out:
# Loading coupling data and building lookup map...
# Coupling map ready.
# Parsing the pre-generated log file: '../data/final/commit_gitlog.txt'...
# Parsed 136013 commits from the log file.
# Calculating Coupling Features: 100%|██████████| 136013/136013 [00:00<00:00, 764303.39it/s]
# Finished calculating coupling features.
# Merging all features into the final dataset...
# Success! Final dataset with all features saved to '../data/final/final_training_dataset.csv'
#                                 commit_hash             author_email  \
# 0  cfa03556d2a50f5d3381bd12a97f25a1e9e8476b  tharik.kanaka@gmail.com
# 1  ecef3657b88330f2cae320f14ef30407dcb67b5a      azinneera@gmail.com
# 2  ac47d27abdb60e0b1a3146324183513aadb8fa27  tharik.kanaka@gmail.com
# 3  b2b3f93fba80d28c5b244baf3b6754b662eb872f      azinneera@gmail.com
# 4  e965df23ea6af12075af0901c2ea13880bbfdede      azinneera@gmail.com
#
#                  commit_date  lines_added  lines_deleted  files_changed  \
# 0  2025-06-14 08:32:25+05:30            1              1              1
# 1  2025-06-13 15:11:12+05:30         4655           1983            156
# 2  2025-06-13 11:17:24+05:30            2              2              2
# 3  2025-06-05 21:09:36+05:30         1565            999             34
# 4  2025-05-28 20:47:56+05:30            6              6              4
#
#    num_modified_subsystems  num_modified_dirs   entropy  previous_total_size  \
# 0                        1                  1  0.000000                18750
# 1                        5                 57  5.454747               788109
# 2                        2                  2  1.000000                17327
# 3                        3                 12  3.406617               485212
# 4                        2                  3  1.625815               129048
#
#    author_total_commits  time_since_last_commit  recent_commits  \
# 0                  1714                 76501.0               5
# 1                  1079                669696.0              16
# 2                  1713                954112.0               4
# 3                  1078                692500.0              16
# 4                  1077                 89930.0               7
#
#    prior_committers  ft14_highly_coupled_files  ft15_any_coupled_files  \
# 0                20                          0                       0
# 1               199                          0                       0
# 2               166                          0                       0
# 3               120                          0                       0
# 4               116                          0                       0
#
#    ft16_non_modified_coupled_files
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
