# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

import re
import pandas as pd
from tqdm import tqdm
from loguru import logger
from pymongo import MongoClient
import requests 
import time 
import concurrent.futures

# GitHub Personal Access Token (optional, but recommended for higher rate limits)
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")
if not GITHUB_TOKEN:
    logger.warning("GitHub token not found. Rate limits may apply.")

BATCH_SIZE = 500 # Number of records to process before writing to CSV

# Logger config
logger.add("logs/pr-to-issues-keyword.log")
# Out:
# 3

# %% [markdown]
# # Initial data set

# %% [markdown]
# mongoDB connection

# %%
# Mongo connection
client = MongoClient("mongodb://localhost:27017/")
db = client.github_data
pull_request_collection = db.pull_requests
logger.info("🔌 MongoDB connected.")
# Out:
# 2025-06-03 15:08:35.844 | INFO     | __main__:<module>:5 - 🔌 MongoDB connected.

# %%
# Query to filter closed pull requests
qurey = {
    "pull_request.state": "closed",
}

# Fetch all records into a list to prevent cursor timeout during processing
logger.info("Fetching all records from MongoDB...")
all_records_list = list(pull_request_collection.find(qurey))
toal_pull_request_count = len(all_records_list) # Actual number of records fetched
logger.info(f"Successfully fetched {toal_pull_request_count} records.")
# Out:
# 2025-06-03 15:08:41.198 | INFO     | __main__:<module>:7 - Fetching all records from MongoDB...
# 2025-06-03 15:09:04.007 | INFO     | __main__:<module>:10 - Successfully fetched 25042 records.

# %%
pr_details_list = [] # List to store dictionaries of PR details

def extract_pr_details(record):
    """
    Extracts relevant details (number, link, title, body) from a pull request record.
    """
    pr_data = record.get("pull_request", {})
    # Handle cases where 'pull_request' key might be missing or empty
    if not pr_data: 
        logger.warning(f"Skipping record due to missing 'pull_request' data. Record ID: {record.get('_id', 'N/A')}")
        return None

    pr_number = pr_data.get("number")
    pr_link = pr_data.get("html_url", None)
    pr_title = pr_data.get("title", None)
    # Use "body" for description as it's the common field for PR description
    pr_body = pr_data.get("body", None) 

    if pr_number is None:
        logger.warning(f"Skipping record due to missing PR number. Record ID: {record.get('_id', 'N/A')}")
        return None

    return {
        "pr_number": pr_number,
        "pr_link": pr_link,
        "pr_title": pr_title,
        "pr_body": pr_body, # "description" in user request, mapped to "body"
    }

# Use ThreadPoolExecutor for processing records concurrently
# os.cpu_count() provides a sensible default for max_workers
# Adjust max_workers based on specific I/O vs CPU characteristics if needed
logger.info(f"Starting extraction of PR details for {toal_pull_request_count} records using concurrent.futures...")

with concurrent.futures.ThreadPoolExecutor(max_workers=os.cpu_count()) as executor:
    # Submit all tasks to the executor
    future_to_record = {executor.submit(extract_pr_details, record): record for record in all_records_list}
    
    # Process futures as they complete, with a progress bar
    for future in tqdm(concurrent.futures.as_completed(future_to_record), total=len(all_records_list), desc="Extracting PR Details"):
        record_for_future = future_to_record[future] # Get original record for logging in case of error
        try:
            result = future.result()
            if result:  # Add to list if extraction was successful (result is not None)
                pr_details_list.append(result)
        except Exception as exc:
            record_id = record_for_future.get("_id", "N/A")
            logger.error(f"Record ID {record_id} generated an exception during extraction: {exc}")

logger.info(f"Successfully processed all records. Extracted details for {len(pr_details_list)} pull requests.")
# Out:
# 2025-06-03 15:09:36.337 | INFO     | __main__:<module>:33 - Starting extraction of PR details for 25042 records using concurrent.futures...
# Extracting PR Details: 100%|██████████| 25042/25042 [00:00<00:00, 147144.03it/s]
# 2025-06-03 15:09:42.987 | INFO     | __main__:<module>:50 - Successfully processed all records. Extracted details for 25042 pull requests.

# %%
# Define the path for the output CSV file
output_csv_path = "../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv"

# Convert the list of dictionaries to a pandas DataFrame and save to CSV
if pr_details_list:
    df_prs = pd.DataFrame(pr_details_list)
    
    # Ensure the columns are in the desired order for the CSV
    # "description" from user request is mapped to "pr_body"
    csv_headers = ["pr_number", "pr_link", "pr_title", "pr_body"]
    df_prs = df_prs[csv_headers]

    try:
        # Save the DataFrame to CSV, overwriting if the file exists
        df_prs.to_csv(output_csv_path, index=False, mode='w')
        logger.info(f"Successfully saved PR details to {output_csv_path}")
    except Exception as e:
        logger.error(f"Failed to save PR details to CSV at {output_csv_path}: {e}")
else:
    logger.warning("No PR details were extracted (or all records were skipped). CSV file will not be created.")
# Out:
# 2025-06-03 15:10:25.477 | INFO     | __main__:<module>:16 - Successfully saved PR details to ../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv

# %% [markdown]
# # Key word processing

# %% [markdown]
# ## Title

# %%
import pandas as pd
import re
from loguru import logger
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
from typing import List, Tuple, Optional, Dict
import time


# Thread-safe lock for writing results
write_lock = threading.Lock()

csv_path = "../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv"

def extract_all_issue_numbers_from_title(title: str) -> List[Dict[str, str]]:
    """
    Extracts all issue numbers from pull request title.
    Returns a list of dictionaries with issue_number and issue_link (if found as URL).
    """
    if pd.isna(title) or not title.strip():
        return []

    # Covers: fix(es/ed/ing), clos(e/es/ed), resolv(e/es/ed), issue(s), Backport, Revert(s)
    keyword_pattern = r'\b(?:fix(?:es|ed|ing)?|clos(?:e|es|ed)|resolv(?:e|es|ed)|issue|Backport|Revert(?:s)?)\b'

    # Comprehensive patterns to find issue numbers, ordered by specificity
    issue_patterns = [
        # Priority 1: Keywords followed by colon and GitHub URL (most specific)
        rf'{keyword_pattern}:\s+(https?://github\.com/[^/\s]+/[^/\s]+/(?:issues|pull)/(\d+))',
        
        # Priority 2: Keywords followed by full GitHub issue URL
        rf'{keyword_pattern}\s+(https?://github\.com/[^/\s]+/[^/\s]+/(?:issues|pull)/(\d+))',
        
        # Priority 3: Keywords followed by repo path and issue number
        rf'{keyword_pattern}\s+[^/\s]+/[^/\s]+/issues/(\d+)',
        
        # Priority 4: Keywords + <text> + GitHub issue links + optional plain number
        rf'{keyword_pattern}.*<.*?>\s+(https?://github\.com/[^/\s]+/[^/\s]+/(?:issues|pull)/(\d+))(?:\s+(\d+))*',
        
        # Priority 5: Keywords + <text> + multiple issue numbers
        rf'{keyword_pattern}.*<.*?>\s+#(\d+)(?:\s+#(\d+))*',
        
        # Priority 6: Keywords followed by square brackets
        rf'{keyword_pattern}.*\[#(\d+)\]',
        
        # Priority 7: Square brackets followed by keywords
        rf'\[#(\d+)\].*{keyword_pattern}',
        
        # Priority 8: Keywords followed by (from #number)
        rf'{keyword_pattern}.*\(from\s+#(\d+)\)',
        
        # Priority 9: Keywords followed by "part of #number" or "part of issue #number"
        rf'{keyword_pattern}.*part\s+of\s+(?:issue\s+)?#(\d+)',
        
        # Priority 10: Keywords followed by "/fix-#number" or "/fix-number"
        rf'{keyword_pattern}.*(?:/fix-#(\d+)|/fix-(\d+))',
        
        # Priority 11: Multiple issues in one line (e.g., "fixes #123, #456, #789")
        rf'{keyword_pattern}[^#]*?((?:#\d+(?:\s*,\s*#\d+)*)+)',
        
        # Priority 12: Keywords followed by any text and #number
        rf'{keyword_pattern}.*#(\d+)',
        
        # Priority 13: Keywords followed by #number (direct)
        rf'{keyword_pattern}\s+#(\d+)',
        
        # Priority 14: Keywords followed by plain number (no #)
        rf'{keyword_pattern}\s+(\d+)\b',
        
        # Priority 15: #number followed by keyword
        rf'#(\d+)\s+{keyword_pattern}',
        
        # Priority 16: Specific "Address review suggestions" pattern
        rf'Address\s+review\s+suggestions.*#(\d+)',
        
        # Priority 17: Multiple issue numbers after "issues" (e.g., "issues #1159 #947")
        r'\bissues?\s+#(\d+)(?:\s+#(\d+))*',
        
        # Priority 18: GitHub URLs without keywords (issues only, not pull requests)
        r'(https?://github\.com/[^/\s]+/[^/\s]+/issues/(\d+))',
    ]

    found_issues = []
    
    for pattern in issue_patterns:
        matches = re.finditer(pattern, title, re.IGNORECASE)
        for match in matches:
            groups = match.groups()
            
            # Check if this is a URL pattern (contains full GitHub URL)
            full_url = None
            issue_number = None
            
            for group in groups:
                if group and group.startswith('http'):
                    full_url = group
                elif group and group.isdigit():
                    issue_number = group
                    
            if full_url and issue_number:
                # Found a full URL with issue number
                if not any(item['issue_number'] == issue_number for item in found_issues):
                    found_issues.append({
                        'issue_number': issue_number,
                        'issue_link': full_url
                    })
                continue
            
            # Handle non-URL patterns
            for group in groups:
                if group:
                    # Handle multiple issues in one match (e.g., "#123, #456")
                    if '#' in group:
                        issue_nums = re.findall(r'#(\d+)', group)
                        for issue_num in issue_nums:
                            if not any(item['issue_number'] == issue_num for item in found_issues):
                                found_issues.append({
                                    'issue_number': issue_num,
                                    'issue_link': None
                                })
                    elif group.isdigit():
                        if not any(item['issue_number'] == group for item in found_issues):
                            found_issues.append({
                                'issue_number': group,
                                'issue_link': None
                            })
    
    return found_issues

def generate_issue_link(issue_number: str, pr_link: str) -> str:
    """
    Generate GitHub issue link based on issue number and PR link.
    Assumes same repository as the PR.
    """
    if not issue_number or not pr_link:
        return ""
    
    # Extract repository info from PR link
    # Example: https://github.com/owner/repo/pull/123 -> https://github.com/owner/repo/issues/456
    match = re.match(r'(https?://github\.com/[^/]+/[^/]+)/', pr_link)
    if match:
        repo_base = match.group(1)
        return f"{repo_base}/issues/{issue_number}"
    
    return ""

def process_row(row_data: Tuple[int, pd.Series]) -> List[dict]:
    """
    Process a single row and return list of records (one per issue found).
    """
    idx, row = row_data
    
    try:
        title = str(row.get('pr_title', ''))
        pr_link = str(row.get('pr_link', ''))
        
        # Extract all issue numbers from title with their URLs (if found)
        issue_data = extract_all_issue_numbers_from_title(title)
        
        results = []
        
        if issue_data:
            # Create separate record for each issue found
            for issue_info in issue_data:
                issue_number = issue_info['issue_number']
                found_url = issue_info['issue_link']
                
                # Use found URL if available, otherwise generate one
                if found_url:
                    issue_link = found_url
                else:
                    issue_link = generate_issue_link(issue_number, pr_link)
                
                # Create new record with all original data plus extracted info
                new_record = row.to_dict()
                new_record.update({
                    'extracted_issue_number': issue_number,
                    'extracted_issue_link': issue_link,
                    'found_in_title': True,
                    'original_row_index': idx
                })
                results.append(new_record)
                
            logger.info(f"Row {idx}: Found {len(issue_data)} issues in title: {[item['issue_number'] for item in issue_data]}")
        else:
            # No issues found, keep original record with null values
            new_record = row.to_dict()
            new_record.update({
                'extracted_issue_number': None,
                'extracted_issue_link': None,
                'found_in_title': False,
                'original_row_index': idx
            })
            results.append(new_record)
            
        return results
        
    except Exception as e:
        logger.error(f"Error processing row {idx}: {str(e)}")
        # Return original record with error info
        new_record = row.to_dict()
        new_record.update({
            'extracted_issue_number': None,
            'extracted_issue_link': None,
            'found_in_title': False,
            'original_row_index': idx,
            'processing_error': str(e)
        })
        return [new_record]

def run():
    """
    Main function to process the CSV and create new output file.
    """
    logger.info("Starting issue number extraction process")
    
    try:
        # Load the CSV file
        logger.info(f"Loading CSV file: {csv_path}")
        df = pd.read_csv(csv_path)
        logger.info(f"Loaded {len(df)} records from CSV")
        
        # Prepare data for parallel processing
        row_data = list(df.iterrows())
        
        # Process rows in parallel
        all_results = []
        
        logger.info("Starting parallel processing...")
        with ThreadPoolExecutor(max_workers=4) as executor:
            # Submit all tasks
            future_to_row = {executor.submit(process_row, row): row[0] for row in row_data}
            
            # Process completed tasks with progress bar
            for future in tqdm(as_completed(future_to_row), total=len(future_to_row), desc="Processing rows"):
                try:
                    row_results = future.result()
                    with write_lock:
                        all_results.extend(row_results)
                except Exception as e:
                    row_idx = future_to_row[future]
                    logger.error(f"Failed to process row {row_idx}: {str(e)}")
        
        # Create new DataFrame from results
        logger.info(f"Creating new DataFrame with {len(all_results)} records")
        new_df = pd.DataFrame(all_results)
        
        # Generate output filename
        output_path = csv_path.replace('.csv', '_with_extracted_issues.csv')
        
        # Save to new CSV
        logger.info(f"Saving results to: {output_path}")
        new_df.to_csv(output_path, index=False)
        
        # Log statistics
        total_original_rows = len(df)
        total_new_rows = len(new_df)
        rows_with_issues = len(new_df[new_df['found_in_title'] == True])
        unique_issues_found = len(new_df[new_df['extracted_issue_number'].notna()]['extracted_issue_number'].unique())
        
        # Additional statistics for link sources
        extracted_links = len(new_df[(new_df['extracted_issue_link'].notna()) & 
                                    (new_df['extracted_issue_link'].str.startswith('http'))])
        generated_links = total_new_rows - extracted_links - len(new_df[new_df['extracted_issue_link'].isna()])
        
        logger.info("="*50)
        logger.info("PROCESSING SUMMARY")
        logger.info("="*50)
        logger.info(f"Original rows: {total_original_rows}")
        logger.info(f"New rows: {total_new_rows}")
        logger.info(f"Rows with issues found: {rows_with_issues}")
        logger.info(f"Unique issues extracted: {unique_issues_found}")
        logger.info(f"Links used from title: {extracted_links}")
        logger.info(f"Links generated: {generated_links}")
        logger.info(f"Expansion ratio: {total_new_rows/total_original_rows:.2f}x")
        logger.info(f"Output file: {output_path}")
        logger.info("="*50)
        
        print(f"\n✅ Processing completed successfully!")
        print(f"📊 Original rows: {total_original_rows}")
        print(f"📊 New rows: {total_new_rows}")
        print(f"📊 Rows with issues: {rows_with_issues}")
        print(f"📊 Unique issues found: {unique_issues_found}")
        print(f"🔗 Links from title: {extracted_links}")
        print(f"🔗 Generated links: {generated_links}")
        print(f"💾 Output saved to: {output_path}")
        
        return new_df
        
    except Exception as e:
        logger.error(f"Fatal error in main process: {str(e)}")
        raise

run()
# Out:
# 2025-06-06 15:18:02.008 | INFO     | __main__:run:216 - Starting issue number extraction process
# 2025-06-06 15:18:02.012 | INFO     | __main__:run:220 - Loading CSV file: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv
# 2025-06-06 15:18:02.370 | INFO     | __main__:run:222 - Loaded 25042 records from CSV
# 2025-06-06 15:18:03.987 | INFO     | __main__:run:230 - Starting parallel processing...
# 2025-06-06 15:18:04.015 | INFO     | __main__:process_row:185 - Row 41: Found 1 issues in title: ['12492']
# 2025-06-06 15:18:04.026 | INFO     | __main__:process_row:185 - Row 89: Found 1 issues in title: ['12492']
# 2025-06-06 15:18:04.033 | INFO     | __main__:process_row:185 - Row 131: Found 1 issues in title: ['12584']
# 2025-06-06 15:18:04.045 | INFO     | __main__:process_row:185 - Row 218: Found 1 issues in title: ['3440']
# 2025-06-06 15:18:04.054 | INFO     | __main__:process_row:185 - Row 239: Found 1 issues in title: ['4581']
# 2025-06-06 15:18:04.056 | INFO     | __main__:process_row:185 - Row 250: Found 1 issues in title: ['4716']
# 2025-06-06 15:18:04.108 | INFO     | __main__:process_row:185 - Row 521: Found 1 issues in title: ['13']
# 2025-06-06 15:18:04.125 | INFO     | __main__:process_row:185 - Row 613: Found 1 issues in title: ['42950']
# 2025-06-06 15:18:04.154 | INFO     | __main__:process_row:185 - Row 753: Found 1 issues in title: ['9983']
# 2025-06-06 15:18:04.161 | INFO     | __main__:process_row:185 - Row 786: Found 1 issues in title: ['12394']
# 2025-06-06 15:18:04.178 | INFO     | __main__:process_row:185 - Row 866: Found 1 issues in title: ['4617']
# 2025-06-06 15:18:04.193 | INFO     | __main__:process_row:185 - Row 929: Found 1 issues in title: ['4637']
# 2025-06-06 15:18:04.307 | INFO     | __main__:process_row:185 - Row 1230: Found 1 issues in title: ['4992']
# 2025-06-06 15:18:04.367 | INFO     | __main__:process_row:185 - Row 1489: Found 2 issues in title: ['12753', '12756']
# 2025-06-06 15:18:04.376 | INFO     | __main__:process_row:185 - Row 1524: Found 1 issues in title: ['4997']
# 2025-06-06 15:18:04.385 | INFO     | __main__:process_row:185 - Row 1548: Found 1 issues in title: ['4994']
# 2025-06-06 15:18:04.430 | INFO     | __main__:process_row:185 - Row 1712: Found 1 issues in title: ['12819']
# 2025-06-06 15:18:04.439 | INFO     | __main__:process_row:185 - Row 1742: Found 1 issues in title: ['32765']
# 2025-06-06 15:18:04.524 | INFO     | __main__:process_row:185 - Row 2085: Found 1 issues in title: ['4956']
# 2025-06-06 15:18:04.648 | INFO     | __main__:process_row:185 - Row 2686: Found 1 issues in title: ['125']
# 2025-06-06 15:18:04.653 | INFO     | __main__:process_row:185 - Row 2692: Found 1 issues in title: ['131']
# 2025-06-06 15:18:04.674 | INFO     | __main__:process_row:185 - Row 2748: Found 1 issues in title: ['26128']
# 2025-06-06 15:18:04.687 | INFO     | __main__:process_row:185 - Row 2781: Found 1 issues in title: ['8623']
# 2025-06-06 15:18:04.720 | INFO     | __main__:process_row:185 - Row 2881: Found 1 issues in title: ['1884']
# 2025-06-06 15:18:04.728 | INFO     | __main__:process_row:185 - Row 2887: Found 1 issues in title: ['20376']
# 2025-06-06 15:18:04.743 | INFO     | __main__:process_row:185 - Row 2908: Found 1 issues in title: ['20376']
# 2025-06-06 15:18:04.754 | INFO     | __main__:process_row:185 - Row 2930: Found 1 issues in title: ['9120']
# 2025-06-06 15:18:04.767 | INFO     | __main__:process_row:185 - Row 2959: Found 1 issues in title: ['7784']
# 2025-06-06 15:18:04.808 | INFO     | __main__:process_row:185 - Row 3050: Found 1 issues in title: ['17878']
# 2025-06-06 15:18:04.820 | INFO     | __main__:process_row:185 - Row 3077: Found 1 issues in title: ['4922']
# 2025-06-06 15:18:04.824 | INFO     | __main__:process_row:185 - Row 3081: Found 1 issues in title: ['4253']
# 2025-06-06 15:18:04.840 | INFO     | __main__:process_row:185 - Row 3136: Found 1 issues in title: ['15362']
# 2025-06-06 15:18:04.866 | INFO     | __main__:process_row:185 - Row 3184: Found 1 issues in title: ['9150']
# 2025-06-06 15:18:04.956 | INFO     | __main__:process_row:185 - Row 3421: Found 1 issues in title: ['9012']
# 2025-06-06 15:18:05.022 | INFO     | __main__:process_row:185 - Row 3588: Found 1 issues in title: ['29814']
# 2025-06-06 15:18:05.028 | INFO     | __main__:process_row:185 - Row 3596: Found 1 issues in title: ['9016']
# 2025-06-06 15:18:05.040 | INFO     | __main__:process_row:185 - Row 3620: Found 1 issues in title: ['1366']
# 2025-06-06 15:18:05.129 | INFO     | __main__:process_row:185 - Row 3847: Found 1 issues in title: ['8355']
# 2025-06-06 15:18:05.169 | INFO     | __main__:process_row:185 - Row 3950: Found 1 issues in title: ['2456']
# 2025-06-06 15:18:05.177 | INFO     | __main__:process_row:185 - Row 3966: Found 1 issues in title: ['2456']
# 2025-06-06 15:18:05.205 | INFO     | __main__:process_row:185 - Row 4034: Found 1 issues in title: ['1369']
# 2025-06-06 15:18:05.210 | INFO     | __main__:process_row:185 - Row 4062: Found 1 issues in title: ['4678']
# 2025-06-06 15:18:05.220 | INFO     | __main__:process_row:185 - Row 4072: Found 1 issues in title: ['1869']
# 2025-06-06 15:18:05.264 | INFO     | __main__:process_row:185 - Row 4218: Found 1 issues in title: ['18294']
# 2025-06-06 15:18:05.302 | INFO     | __main__:process_row:185 - Row 4373: Found 1 issues in title: ['2164']
# 2025-06-06 15:18:05.659 | INFO     | __main__:process_row:185 - Row 4403: Found 1 issues in title: ['2538']
# 2025-06-06 15:18:05.659 | INFO     | __main__:process_row:185 - Row 4405: Found 1 issues in title: ['2375']
# 2025-06-06 15:18:05.906 | INFO     | __main__:process_row:185 - Row 4835: Found 1 issues in title: ['1368']
# 2025-06-06 15:18:05.923 | INFO     | __main__:process_row:185 - Row 4904: Found 1 issues in title: ['320']
# 2025-06-06 15:18:05.931 | INFO     | __main__:process_row:185 - Row 4933: Found 1 issues in title: ['2587']
# 2025-06-06 15:18:05.940 | INFO     | __main__:process_row:185 - Row 4950: Found 1 issues in title: ['7363']
# 2025-06-06 15:18:05.970 | INFO     | __main__:process_row:185 - Row 5083: Found 1 issues in title: ['4748']
# 2025-06-06 15:18:06.005 | INFO     | __main__:process_row:185 - Row 5179: Found 1 issues in title: ['2260']
# 2025-06-06 15:18:06.005 | INFO     | __main__:process_row:185 - Row 5180: Found 1 issues in title: ['7363']
# 2025-06-06 15:18:06.014 | INFO     | __main__:process_row:185 - Row 5201: Found 1 issues in title: ['2136']
# 2025-06-06 15:18:06.036 | INFO     | __main__:process_row:185 - Row 5279: Found 2 issues in title: ['2631', '2632']
# 2025-06-06 15:18:06.047 | INFO     | __main__:process_row:185 - Row 5310: Found 1 issues in title: ['9321']
# 2025-06-06 15:18:06.054 | INFO     | __main__:process_row:185 - Row 5334: Found 1 issues in title: ['8694']
# 2025-06-06 15:18:06.060 | INFO     | __main__:process_row:185 - Row 5360: Found 1 issues in title: ['1375']
# 2025-06-06 15:18:06.088 | INFO     | __main__:process_row:185 - Row 5429: Found 1 issues in title: ['2620']
# 2025-06-06 15:18:06.090 | INFO     | __main__:process_row:185 - Row 5434: Found 1 issues in title: ['190']
# 2025-06-06 15:18:06.103 | INFO     | __main__:process_row:185 - Row 5458: Found 1 issues in title: ['2657']
# 2025-06-06 15:18:06.144 | INFO     | __main__:process_row:185 - Row 5607: Found 1 issues in title: ['4638']
# 2025-06-06 15:18:06.196 | INFO     | __main__:process_row:185 - Row 5784: Found 1 issues in title: ['32103']
# 2025-06-06 15:18:06.207 | INFO     | __main__:process_row:185 - Row 5813: Found 1 issues in title: ['2310']
# 2025-06-06 15:18:06.213 | INFO     | __main__:process_row:185 - Row 5827: Found 1 issues in title: ['2316']
# 2025-06-06 15:18:06.254 | INFO     | __main__:process_row:185 - Row 5968: Found 1 issues in title: ['18465']
# 2025-06-06 15:18:06.298 | INFO     | __main__:process_row:185 - Row 6120: Found 1 issues in title: ['2308']
# 2025-06-06 15:18:06.314 | INFO     | __main__:process_row:185 - Row 6170: Found 1 issues in title: ['33401']
# 2025-06-06 15:18:06.332 | INFO     | __main__:process_row:185 - Row 6227: Found 1 issues in title: ['18484']
# 2025-06-06 15:18:06.369 | INFO     | __main__:process_row:185 - Row 6352: Found 1 issues in title: ['2623']
# 2025-06-06 15:18:06.370 | INFO     | __main__:process_row:185 - Row 6370: Found 1 issues in title: ['1296']
# 2025-06-06 15:18:06.380 | INFO     | __main__:process_row:185 - Row 6382: Found 1 issues in title: ['2702']
# 2025-06-06 15:18:06.383 | INFO     | __main__:process_row:185 - Row 6384: Found 2 issues in title: ['2506', '2505']
# 2025-06-06 15:18:06.418 | INFO     | __main__:process_row:185 - Row 6494: Found 1 issues in title: ['8361']
# 2025-06-06 15:18:06.430 | INFO     | __main__:process_row:185 - Row 6531: Found 1 issues in title: ['27339']
# 2025-06-06 15:18:06.452 | INFO     | __main__:process_row:185 - Row 6591: Found 1 issues in title: ['5046']
# 2025-06-06 15:18:06.457 | INFO     | __main__:process_row:185 - Row 6603: Found 1 issues in title: ['30553']
# 2025-06-06 15:18:06.492 | INFO     | __main__:process_row:185 - Row 6727: Found 2 issues in title: ['2729', '2694']
# 2025-06-06 15:18:06.501 | INFO     | __main__:process_row:185 - Row 6757: Found 1 issues in title: ['2704']
# 2025-06-06 15:18:06.608 | INFO     | __main__:process_row:185 - Row 7180: Found 1 issues in title: ['8323']
# 2025-06-06 15:18:06.627 | INFO     | __main__:process_row:185 - Row 7259: Found 1 issues in title: ['11958']
# 2025-06-06 15:18:06.657 | INFO     | __main__:process_row:185 - Row 7410: Found 1 issues in title: ['2800']
# 2025-06-06 15:18:06.660 | INFO     | __main__:process_row:185 - Row 7413: Found 1 issues in title: ['2825']
# 2025-06-06 15:18:06.660 | INFO     | __main__:process_row:185 - Row 7420: Found 2 issues in title: ['1978', '1988']
# 2025-06-06 15:18:06.667 | INFO     | __main__:process_row:185 - Row 7426: Found 1 issues in title: ['2797']
# 2025-06-06 15:18:06.710 | INFO     | __main__:process_row:185 - Row 7617: Found 1 issues in title: ['4948']
# 2025-06-06 15:18:06.719 | INFO     | __main__:process_row:185 - Row 7659: Found 1 issues in title: ['1358']
# 2025-06-06 15:18:06.720 | INFO     | __main__:process_row:185 - Row 7661: Found 1 issues in title: ['4715']
# 2025-06-06 15:18:06.745 | INFO     | __main__:process_row:185 - Row 7773: Found 1 issues in title: ['2847']
# 2025-06-06 15:18:06.750 | INFO     | __main__:process_row:185 - Row 7795: Found 1 issues in title: ['2197']
# 2025-06-06 15:18:06.750 | INFO     | __main__:process_row:185 - Row 7815: Found 1 issues in title: ['2245']
# 2025-06-06 15:18:06.771 | INFO     | __main__:process_row:185 - Row 7870: Found 1 issues in title: ['9367']
# 2025-06-06 15:18:06.805 | INFO     | __main__:process_row:185 - Row 8032: Found 1 issues in title: ['30379']
# 2025-06-06 15:18:06.810 | INFO     | __main__:process_row:185 - Row 8057: Found 1 issues in title: ['11694']
# 2025-06-06 15:18:06.817 | INFO     | __main__:process_row:185 - Row 8077: Found 1 issues in title: ['11694']
# 2025-06-06 15:18:06.826 | INFO     | __main__:process_row:185 - Row 8106: Found 1 issues in title: ['2185']
# 2025-06-06 15:18:06.835 | INFO     | __main__:process_row:185 - Row 8129: Found 1 issues in title: ['2182']
# 2025-06-06 15:18:06.890 | INFO     | __main__:process_row:185 - Row 8416: Found 1 issues in title: ['21872']
# 2025-06-06 15:18:06.900 | INFO     | __main__:process_row:185 - Row 8494: Found 1 issues in title: ['2161']
# 2025-06-06 15:18:06.955 | INFO     | __main__:process_row:185 - Row 8767: Found 1 issues in title: ['2151']
# 2025-06-06 15:18:06.960 | INFO     | __main__:process_row:185 - Row 8770: Found 1 issues in title: ['1117']
# 2025-06-06 15:18:06.960 | INFO     | __main__:process_row:185 - Row 8774: Found 1 issues in title: ['2074']
# 2025-06-06 15:18:06.965 | INFO     | __main__:process_row:185 - Row 8789: Found 1 issues in title: ['2147']
# 2025-06-06 15:18:06.997 | INFO     | __main__:process_row:185 - Row 8938: Found 1 issues in title: ['9569']
# 2025-06-06 15:18:07.026 | INFO     | __main__:process_row:185 - Row 9083: Found 1 issues in title: ['2141']
# 2025-06-06 15:18:07.034 | INFO     | __main__:process_row:185 - Row 9119: Found 1 issues in title: ['2984']
# 2025-06-06 15:18:07.039 | INFO     | __main__:process_row:185 - Row 9135: Found 1 issues in title: ['1154']
# 2025-06-06 15:18:07.137 | INFO     | __main__:process_row:185 - Row 9639: Found 1 issues in title: ['3038']
# 2025-06-06 15:18:07.140 | INFO     | __main__:process_row:185 - Row 9669: Found 1 issues in title: ['3066']
# 2025-06-06 15:18:07.140 | INFO     | __main__:process_row:185 - Row 9680: Found 2 issues in title: ['3018', '3065']
# 2025-06-06 15:18:07.160 | INFO     | __main__:process_row:185 - Row 9761: Found 1 issues in title: ['7601']
# 2025-06-06 15:18:07.168 | INFO     | __main__:process_row:185 - Row 9781: Found 1 issues in title: ['9270']
# 2025-06-06 15:18:07.202 | INFO     | __main__:process_row:185 - Row 9952: Found 2 issues in title: ['25663', '25665']
# 2025-06-06 15:18:07.210 | INFO     | __main__:process_row:185 - Row 9997: Found 1 issues in title: ['36394']
# 2025-06-06 15:18:07.218 | INFO     | __main__:process_row:185 - Row 10022: Found 1 issues in title: ['2969']
# 2025-06-06 15:18:07.222 | INFO     | __main__:process_row:185 - Row 10037: Found 1 issues in title: ['2112']
# 2025-06-06 15:18:07.272 | INFO     | __main__:process_row:185 - Row 10291: Found 1 issues in title: ['1800']
# 2025-06-06 15:18:07.279 | INFO     | __main__:process_row:185 - Row 10322: Found 1 issues in title: ['1923']
# 2025-06-06 15:18:07.283 | INFO     | __main__:process_row:185 - Row 10332: Found 1 issues in title: ['3086']
# 2025-06-06 15:18:07.284 | INFO     | __main__:process_row:185 - Row 10334: Found 1 issues in title: ['1257']
# 2025-06-06 15:18:07.285 | INFO     | __main__:process_row:185 - Row 10336: Found 2 issues in title: ['3132', '112']
# 2025-06-06 15:18:07.292 | INFO     | __main__:process_row:185 - Row 10352: Found 1 issues in title: ['1963']
# 2025-06-06 15:18:07.309 | INFO     | __main__:process_row:185 - Row 10418: Found 1 issues in title: ['26770']
# 2025-06-06 15:18:07.319 | INFO     | __main__:process_row:185 - Row 10465: Found 1 issues in title: ['9766']
# 2025-06-06 15:18:07.375 | INFO     | __main__:process_row:185 - Row 10706: Found 1 issues in title: ['36586']
# 2025-06-06 15:18:07.391 | INFO     | __main__:process_row:185 - Row 10762: Found 1 issues in title: ['2917']
# 2025-06-06 15:18:07.489 | INFO     | __main__:process_row:185 - Row 11106: Found 1 issues in title: ['2005']
# 2025-06-06 15:18:07.497 | INFO     | __main__:process_row:185 - Row 11141: Found 1 issues in title: ['2747']
# 2025-06-06 15:18:07.506 | INFO     | __main__:process_row:185 - Row 11167: Found 1 issues in title: ['3134']
# 2025-06-06 15:18:07.511 | INFO     | __main__:process_row:185 - Row 11182: Found 1 issues in title: ['3174']
# 2025-06-06 15:18:07.565 | INFO     | __main__:process_row:185 - Row 11440: Found 1 issues in title: ['260']
# 2025-06-06 15:18:07.570 | INFO     | __main__:process_row:185 - Row 11507: Found 1 issues in title: ['20965']
# 2025-06-06 15:18:07.586 | INFO     | __main__:process_row:185 - Row 11531: Found 1 issues in title: ['1939']
# 2025-06-06 15:18:07.590 | INFO     | __main__:process_row:185 - Row 11552: Found 1 issues in title: ['36597']
# 2025-06-06 15:18:07.590 | INFO     | __main__:process_row:185 - Row 11558: Found 1 issues in title: ['36597']
# 2025-06-06 15:18:07.671 | INFO     | __main__:process_row:185 - Row 11942: Found 1 issues in title: ['1025']
# 2025-06-06 15:18:07.745 | INFO     | __main__:process_row:185 - Row 12359: Found 1 issues in title: ['36422']
# 2025-06-06 15:18:07.750 | INFO     | __main__:process_row:185 - Row 12420: Found 1 issues in title: ['36597']
# 2025-06-06 15:18:07.804 | INFO     | __main__:process_row:185 - Row 12444: Found 1 issues in title: ['36790']
# 2025-06-06 15:18:07.914 | INFO     | __main__:process_row:185 - Row 12736: Found 1 issues in title: ['768']
# 2025-06-06 15:18:07.924 | INFO     | __main__:process_row:185 - Row 12769: Found 1 issues in title: ['3258']
# 2025-06-06 15:18:07.927 | INFO     | __main__:process_row:185 - Row 12778: Found 1 issues in title: ['1675']
# 2025-06-06 15:18:07.946 | INFO     | __main__:process_row:185 - Row 12852: Found 1 issues in title: ['8151']
# 2025-06-06 15:18:07.949 | INFO     | __main__:process_row:185 - Row 12858: Found 1 issues in title: ['13962']
# 2025-06-06 15:18:07.994 | INFO     | __main__:process_row:185 - Row 13049: Found 1 issues in title: ['40826']
# 2025-06-06 15:18:08.008 | INFO     | __main__:process_row:185 - Row 13108: Found 1 issues in title: ['1848']
# 2025-06-06 15:18:08.012 | INFO     | __main__:process_row:185 - Row 13123: Found 1 issues in title: ['1309']
# 2025-06-06 15:18:08.022 | INFO     | __main__:process_row:185 - Row 13160: Found 1 issues in title: ['1863']
# 2025-06-06 15:18:08.060 | INFO     | __main__:process_row:185 - Row 13332: Found 1 issues in title: ['34199']
# 2025-06-06 15:18:08.066 | INFO     | __main__:process_row:185 - Row 13371: Found 2 issues in title: ['867', '866']
# 2025-06-06 15:18:08.070 | INFO     | __main__:process_row:185 - Row 13374: Found 1 issues in title: ['40826']
# 2025-06-06 15:18:08.075 | INFO     | __main__:process_row:185 - Row 13391: Found 1 issues in title: ['882']
# 2025-06-06 15:18:08.089 | INFO     | __main__:process_row:185 - Row 13445: Found 1 issues in title: ['1954']
# 2025-06-06 15:18:08.151 | INFO     | __main__:process_row:185 - Row 13768: Found 1 issues in title: ['889']
# 2025-06-06 15:18:08.174 | INFO     | __main__:process_row:185 - Row 13883: Found 1 issues in title: ['3348']
# 2025-06-06 15:18:08.210 | INFO     | __main__:process_row:185 - Row 14079: Found 1 issues in title: ['933']
# 2025-06-06 15:18:08.221 | INFO     | __main__:process_row:185 - Row 14112: Found 1 issues in title: ['8419']
# 2025-06-06 15:18:08.266 | INFO     | __main__:process_row:185 - Row 14339: Found 1 issues in title: ['7705']
# 2025-06-06 15:18:08.278 | INFO     | __main__:process_row:185 - Row 14402: Found 1 issues in title: ['969']
# 2025-06-06 15:18:08.280 | INFO     | __main__:process_row:185 - Row 14408: Found 1 issues in title: ['976']
# 2025-06-06 15:18:08.287 | INFO     | __main__:process_row:185 - Row 14433: Found 1 issues in title: ['927']
# 2025-06-06 15:18:08.290 | INFO     | __main__:process_row:185 - Row 14455: Found 1 issues in title: ['1012']
# 2025-06-06 15:18:08.295 | INFO     | __main__:process_row:185 - Row 14460: Found 1 issues in title: ['1014']
# 2025-06-06 15:18:08.295 | INFO     | __main__:process_row:185 - Row 14464: Found 1 issues in title: ['915']
# 2025-06-06 15:18:08.295 | INFO     | __main__:process_row:185 - Row 14467: Found 1 issues in title: ['1024']
# 2025-06-06 15:18:08.345 | INFO     | __main__:process_row:185 - Row 14729: Found 1 issues in title: ['9082']
# 2025-06-06 15:18:08.367 | INFO     | __main__:process_row:185 - Row 14826: Found 1 issues in title: ['1055']
# 2025-06-06 15:18:08.370 | INFO     | __main__:process_row:185 - Row 14850: Found 1 issues in title: ['20630']
# 2025-06-06 15:18:08.370 | INFO     | __main__:process_row:185 - Row 14860: Found 1 issues in title: ['1055']
# 2025-06-06 15:18:08.406 | INFO     | __main__:process_row:185 - Row 15005: Found 2 issues in title: ['903', '146']
# 2025-06-06 15:18:08.408 | INFO     | __main__:process_row:185 - Row 15014: Found 1 issues in title: ['1102']
# 2025-06-06 15:18:08.408 | INFO     | __main__:process_row:185 - Row 15017: Found 1 issues in title: ['1108']
# 2025-06-06 15:18:08.416 | INFO     | __main__:process_row:185 - Row 15039: Found 1 issues in title: ['957']
# 2025-06-06 15:18:08.420 | INFO     | __main__:process_row:185 - Row 15054: Found 1 issues in title: ['1105']
# 2025-06-06 15:18:08.472 | INFO     | __main__:process_row:185 - Row 15278: Found 1 issues in title: ['34358']
# 2025-06-06 15:18:08.494 | INFO     | __main__:process_row:185 - Row 15380: Found 1 issues in title: ['14775']
# 2025-06-06 15:18:08.508 | INFO     | __main__:process_row:185 - Row 15434: Found 1 issues in title: ['1121']
# 2025-06-06 15:18:08.514 | INFO     | __main__:process_row:185 - Row 15452: Found 1 issues in title: ['1132']
# 2025-06-06 15:18:08.532 | INFO     | __main__:process_row:185 - Row 15495: Found 1 issues in title: ['408']
# 2025-06-06 15:18:08.533 | INFO     | __main__:process_row:185 - Row 15496: Found 1 issues in title: ['34371']
# 2025-06-06 15:18:08.575 | INFO     | __main__:process_row:185 - Row 15640: Found 2 issues in title: ['1159', '947']
# 2025-06-06 15:18:08.584 | INFO     | __main__:process_row:185 - Row 15657: Found 4 issues in title: ['1014', '1155', '1158', '1160']
# 2025-06-06 15:18:08.588 | INFO     | __main__:process_row:185 - Row 15667: Found 1 issues in title: ['20241']
# 2025-06-06 15:18:08.589 | INFO     | __main__:process_row:185 - Row 15668: Found 1 issues in title: ['1190']
# 2025-06-06 15:18:08.594 | INFO     | __main__:process_row:185 - Row 15679: Found 1 issues in title: ['1176']
# 2025-06-06 15:18:08.602 | INFO     | __main__:process_row:185 - Row 15694: Found 2 issues in title: ['7703', '7704']
# 2025-06-06 15:18:08.625 | INFO     | __main__:process_row:185 - Row 15745: Found 1 issues in title: ['36005']
# 2025-06-06 15:18:08.690 | INFO     | __main__:process_row:185 - Row 15794: Found 1 issues in title: ['34421']
# 2025-06-06 15:18:09.127 | INFO     | __main__:process_row:185 - Row 16003: Found 1 issues in title: ['36004']
# 2025-06-06 15:18:09.140 | INFO     | __main__:process_row:185 - Row 16034: Found 1 issues in title: ['1208']
# 2025-06-06 15:18:09.140 | INFO     | __main__:process_row:185 - Row 16036: Found 2 issues in title: ['1198', '1205']
# 2025-06-06 15:18:09.140 | INFO     | __main__:process_row:185 - Row 16039: Found 1 issues in title: ['1214']
# 2025-06-06 15:18:09.157 | INFO     | __main__:process_row:185 - Row 16057: Found 2 issues in title: ['10277', '10291']
# 2025-06-06 15:18:09.245 | INFO     | __main__:process_row:185 - Row 16283: Found 1 issues in title: ['36647']
# 2025-06-06 15:18:09.257 | INFO     | __main__:process_row:185 - Row 16313: Found 1 issues in title: ['36647']
# 2025-06-06 15:18:09.355 | INFO     | __main__:process_row:185 - Row 16627: Found 1 issues in title: ['13200']
# 2025-06-06 15:18:09.359 | INFO     | __main__:process_row:185 - Row 16638: Found 1 issues in title: ['11350']
# 2025-06-06 15:18:09.440 | INFO     | __main__:process_row:185 - Row 16841: Found 1 issues in title: ['35986']
# 2025-06-06 15:18:09.546 | INFO     | __main__:process_row:185 - Row 17024: Found 1 issues in title: ['17012']
# 2025-06-06 15:18:09.587 | INFO     | __main__:process_row:185 - Row 17129: Found 1 issues in title: ['35210']
# 2025-06-06 15:18:09.691 | INFO     | __main__:process_row:185 - Row 17317: Found 1 issues in title: ['13137']
# 2025-06-06 15:18:09.852 | INFO     | __main__:process_row:185 - Row 17714: Found 1 issues in title: ['13016']
# 2025-06-06 15:18:10.097 | INFO     | __main__:process_row:185 - Row 18343: Found 1 issues in title: ['1246']
# 2025-06-06 15:18:10.099 | INFO     | __main__:process_row:185 - Row 18346: Found 1 issues in title: ['1493']
# 2025-06-06 15:18:10.106 | INFO     | __main__:process_row:185 - Row 18357: Found 1 issues in title: ['900']
# 2025-06-06 15:18:10.120 | INFO     | __main__:process_row:185 - Row 18381: Found 1 issues in title: ['1240']
# 2025-06-06 15:18:10.239 | INFO     | __main__:process_row:185 - Row 18593: Found 1 issues in title: ['37812']
# 2025-06-06 15:18:10.247 | INFO     | __main__:process_row:185 - Row 18604: Found 1 issues in title: ['34468']
# 2025-06-06 15:18:10.253 | INFO     | __main__:process_row:185 - Row 18611: Found 1 issues in title: ['1292']
# 2025-06-06 15:18:10.260 | INFO     | __main__:process_row:185 - Row 18624: Found 1 issues in title: ['1545']
# 2025-06-06 15:18:10.263 | INFO     | __main__:process_row:185 - Row 18626: Found 1 issues in title: ['1025']
# 2025-06-06 15:18:10.275 | INFO     | __main__:process_row:185 - Row 18645: Found 1 issues in title: ['1564']
# 2025-06-06 15:18:10.278 | INFO     | __main__:process_row:185 - Row 18649: Found 1 issues in title: ['1568']
# 2025-06-06 15:18:10.291 | INFO     | __main__:process_row:185 - Row 18661: Found 1 issues in title: ['1535']
# 2025-06-06 15:18:10.300 | INFO     | __main__:process_row:185 - Row 18672: Found 1 issues in title: ['2201']
# 2025-06-06 15:18:10.302 | INFO     | __main__:process_row:185 - Row 18674: Found 1 issues in title: ['2201']
# 2025-06-06 15:18:10.332 | INFO     | __main__:process_row:185 - Row 18723: Found 1 issues in title: ['7789']
# 2025-06-06 15:18:10.358 | INFO     | __main__:process_row:185 - Row 18779: Found 1 issues in title: ['37812']
# 2025-06-06 15:18:10.369 | INFO     | __main__:process_row:185 - Row 18790: Found 1 issues in title: ['37812']
# 2025-06-06 15:18:10.472 | INFO     | __main__:process_row:185 - Row 18995: Found 1 issues in title: ['100']
# 2025-06-06 15:18:10.480 | INFO     | __main__:process_row:185 - Row 19005: Found 1 issues in title: ['13']
# 2025-06-06 15:18:10.568 | INFO     | __main__:process_row:185 - Row 19199: Found 1 issues in title: ['1613']
# 2025-06-06 15:18:10.576 | INFO     | __main__:process_row:185 - Row 19208: Found 2 issues in title: ['1502', '1471']
# 2025-06-06 15:18:10.640 | INFO     | __main__:process_row:185 - Row 19347: Found 1 issues in title: ['10579']
# 2025-06-06 15:18:10.663 | INFO     | __main__:process_row:185 - Row 19387: Found 1 issues in title: ['14001']
# 2025-06-06 15:18:10.694 | INFO     | __main__:process_row:185 - Row 19454: Found 1 issues in title: ['3823']
# 2025-06-06 15:18:10.705 | INFO     | __main__:process_row:185 - Row 19473: Found 1 issues in title: ['1677']
# 2025-06-06 15:18:10.720 | INFO     | __main__:process_row:185 - Row 19502: Found 1 issues in title: ['1336']
# 2025-06-06 15:18:10.728 | INFO     | __main__:process_row:185 - Row 19512: Found 3 issues in title: ['1446', '1160', '1255']
# 2025-06-06 15:18:10.739 | INFO     | __main__:process_row:185 - Row 19529: Found 1 issues in title: ['1635']
# 2025-06-06 15:18:10.750 | INFO     | __main__:process_row:185 - Row 19543: Found 1 issues in title: ['1643']
# 2025-06-06 15:18:10.764 | INFO     | __main__:process_row:185 - Row 19559: Found 1 issues in title: ['1383']
# 2025-06-06 15:18:10.787 | INFO     | __main__:process_row:185 - Row 19602: Found 1 issues in title: ['5085']
# 2025-06-06 15:18:10.869 | INFO     | __main__:process_row:185 - Row 19746: Found 1 issues in title: ['3871']
# 2025-06-06 15:18:10.874 | INFO     | __main__:process_row:185 - Row 19751: Found 1 issues in title: ['1656']
# 2025-06-06 15:18:10.887 | INFO     | __main__:process_row:185 - Row 19771: Found 1 issues in title: ['1667']
# 2025-06-06 15:18:10.897 | INFO     | __main__:process_row:185 - Row 19785: Found 1 issues in title: ['1199']
# 2025-06-06 15:18:10.909 | INFO     | __main__:process_row:185 - Row 19794: Found 1 issues in title: ['1219']
# 2025-06-06 15:18:10.970 | INFO     | __main__:process_row:185 - Row 19900: Found 1 issues in title: ['42251']
# 2025-06-06 15:18:11.042 | INFO     | __main__:process_row:185 - Row 20048: Found 1 issues in title: ['3833']
# 2025-06-06 15:18:11.054 | INFO     | __main__:process_row:185 - Row 20075: Found 1 issues in title: ['1427']
# 2025-06-06 15:18:11.064 | INFO     | __main__:process_row:185 - Row 20095: Found 1 issues in title: ['1699']
# 2025-06-06 15:18:11.068 | INFO     | __main__:process_row:185 - Row 20098: Found 1 issues in title: ['1690']
# 2025-06-06 15:18:11.117 | INFO     | __main__:process_row:185 - Row 20190: Found 1 issues in title: ['21796']
# 2025-06-06 15:18:11.129 | INFO     | __main__:process_row:185 - Row 20211: Found 1 issues in title: ['37812']
# 2025-06-06 15:18:11.199 | INFO     | __main__:process_row:185 - Row 20359: Found 1 issues in title: ['2843']
# 2025-06-06 15:18:11.223 | INFO     | __main__:process_row:185 - Row 20401: Found 1 issues in title: ['2485']
# 2025-06-06 15:18:11.339 | INFO     | __main__:process_row:185 - Row 20604: Found 1 issues in title: ['6297']
# 2025-06-06 15:18:11.357 | INFO     | __main__:process_row:185 - Row 20652: Found 1 issues in title: ['14476']
# 2025-06-06 15:18:11.429 | INFO     | __main__:process_row:185 - Row 20772: Found 1 issues in title: ['1747']
# 2025-06-06 15:18:11.437 | INFO     | __main__:process_row:185 - Row 20781: Found 1 issues in title: ['35703']
# 2025-06-06 15:18:11.474 | INFO     | __main__:process_row:185 - Row 20846: Found 1 issues in title: ['23473']
# 2025-06-06 15:18:11.662 | INFO     | __main__:process_row:185 - Row 21241: Found 1 issues in title: ['13']
# 2025-06-06 15:18:11.703 | INFO     | __main__:process_row:185 - Row 21321: Found 1 issues in title: ['13']
# 2025-06-06 15:18:11.864 | INFO     | __main__:process_row:185 - Row 21657: Found 1 issues in title: ['10702']
# 2025-06-06 15:18:11.877 | INFO     | __main__:process_row:185 - Row 21682: Found 1 issues in title: ['10680']
# 2025-06-06 15:18:11.894 | INFO     | __main__:process_row:185 - Row 21716: Found 2 issues in title: ['3203', '4159']
# 2025-06-06 15:18:11.903 | INFO     | __main__:process_row:185 - Row 21725: Found 1 issues in title: ['3768']
# 2025-06-06 15:18:11.955 | INFO     | __main__:process_row:185 - Row 21837: Found 1 issues in title: ['10894']
# 2025-06-06 15:18:12.128 | INFO     | __main__:process_row:185 - Row 22211: Found 1 issues in title: ['15254']
# 2025-06-06 15:18:12.142 | INFO     | __main__:process_row:185 - Row 22236: Found 1 issues in title: ['15253']
# 2025-06-06 15:18:12.160 | INFO     | __main__:process_row:185 - Row 22261: Found 1 issues in title: ['15167']
# 2025-06-06 15:18:12.230 | INFO     | __main__:process_row:185 - Row 22408: Found 1 issues in title: ['21259']
# 2025-06-06 15:18:12.262 | INFO     | __main__:process_row:185 - Row 22474: Found 1 issues in title: ['10766']
# 2025-06-06 15:18:12.299 | INFO     | __main__:process_row:185 - Row 22552: Found 1 issues in title: ['6700']
# 2025-06-06 15:18:12.359 | INFO     | __main__:process_row:185 - Row 22687: Found 1 issues in title: ['1790']
# 2025-06-06 15:18:12.387 | INFO     | __main__:process_row:185 - Row 22730: Found 1 issues in title: ['14981']
# 2025-06-06 15:18:12.390 | INFO     | __main__:process_row:185 - Row 22736: Found 1 issues in title: ['14971']
# 2025-06-06 15:18:12.429 | INFO     | __main__:process_row:185 - Row 22808: Found 1 issues in title: ['4971']
# 2025-06-06 15:18:12.597 | INFO     | __main__:process_row:185 - Row 23101: Found 1 issues in title: ['19073']
# 2025-06-06 15:18:12.610 | INFO     | __main__:process_row:185 - Row 23119: Found 1 issues in title: ['6843']
# 2025-06-06 15:18:12.644 | INFO     | __main__:process_row:185 - Row 23192: Found 3 issues in title: ['15503', '14751', '14346']
# 2025-06-06 15:18:12.665 | INFO     | __main__:process_row:185 - Row 23235: Found 1 issues in title: ['35400']
# 2025-06-06 15:18:12.674 | INFO     | __main__:process_row:185 - Row 23243: Found 1 issues in title: ['12560']
# 2025-06-06 15:18:12.743 | INFO     | __main__:process_row:185 - Row 23403: Found 1 issues in title: ['3957']
# 2025-06-06 15:18:12.877 | INFO     | __main__:process_row:185 - Row 23634: Found 1 issues in title: ['4397']
# 2025-06-06 15:18:12.890 | INFO     | __main__:process_row:185 - Row 23639: Found 1 issues in title: ['4399']
# 2025-06-06 15:18:12.906 | INFO     | __main__:process_row:185 - Row 23670: Found 1 issues in title: ['3957']
# 2025-06-06 15:18:12.930 | INFO     | __main__:process_row:185 - Row 23716: Found 1 issues in title: ['21259']
# 2025-06-06 15:18:13.029 | INFO     | __main__:process_row:185 - Row 23911: Found 1 issues in title: ['17586']
# 2025-06-06 15:18:13.075 | INFO     | __main__:process_row:185 - Row 24010: Found 1 issues in title: ['3692']
# 2025-06-06 15:18:13.127 | INFO     | __main__:process_row:185 - Row 24106: Found 1 issues in title: ['12555']
# 2025-06-06 15:18:13.245 | INFO     | __main__:process_row:185 - Row 24391: Found 1 issues in title: ['4102']
# 2025-06-06 15:18:13.285 | INFO     | __main__:process_row:185 - Row 24471: Found 1 issues in title: ['9681']
# 2025-06-06 15:18:13.367 | INFO     | __main__:process_row:185 - Row 24638: Found 1 issues in title: ['3624']
# 2025-06-06 15:18:13.454 | INFO     | __main__:process_row:185 - Row 24882: Found 1 issues in title: ['7700']
# 2025-06-06 15:18:13.465 | INFO     | __main__:process_row:185 - Row 24911: Found 1 issues in title: ['4338']
# 2025-06-06 15:18:13.478 | INFO     | __main__:process_row:185 - Row 24961: Found 1 issues in title: ['10721']
# 2025-06-06 15:18:13.499 | INFO     | __main__:process_row:185 - Row 25032: Found 1 issues in title: ['18789']
# Processing rows: 100%|██████████| 25042/25042 [00:00<00:00, 85154.73it/s]
# 2025-06-06 15:18:13.819 | INFO     | __main__:run:246 - Creating new DataFrame with 25065 records
# 2025-06-06 15:18:13.940 | INFO     | __main__:run:253 - Saving results to: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues.csv
# 2025-06-06 15:18:15.425 | INFO     | __main__:run:267 - ==================================================
# 2025-06-06 15:18:15.428 | INFO     | __main__:run:268 - PROCESSING SUMMARY
# 2025-06-06 15:18:15.429 | INFO     | __main__:run:269 - ==================================================
# 2025-06-06 15:18:15.432 | INFO     | __main__:run:270 - Original rows: 25042
# 2025-06-06 15:18:15.434 | INFO     | __main__:run:271 - New rows: 25065
# 2025-06-06 15:18:15.436 | INFO     | __main__:run:272 - Rows with issues found: 313
# 2025-06-06 15:18:15.438 | INFO     | __main__:run:273 - Unique issues extracted: 291
# 2025-06-06 15:18:15.440 | INFO     | __main__:run:274 - Links used from title: 313
# 2025-06-06 15:18:15.442 | INFO     | __main__:run:275 - Links generated: 0
# 2025-06-06 15:18:15.445 | INFO     | __main__:run:276 - Expansion ratio: 1.00x
# 2025-06-06 15:18:15.448 | INFO     | __main__:run:277 - Output file: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues.csv
# 2025-06-06 15:18:15.451 | INFO     | __main__:run:278 - ==================================================
# ✅ Processing completed successfully!
# 📊 Original rows: 25042
# 📊 New rows: 25065
# 📊 Rows with issues: 313
# 📊 Unique issues found: 291
# 🔗 Links from title: 313
# 🔗 Generated links: 0
# 💾 Output saved to: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues.csv
#        pr_number                                            pr_link  \
# 0           3160  https://github.com/ballerina-platform/ballerin...
# 1          42658  https://github.com/ballerina-platform/ballerin...
# 2           8108  https://github.com/ballerina-platform/ballerin...
# 3          43690  https://github.com/ballerina-platform/ballerin...
# 4           9535  https://github.com/ballerina-platform/ballerin...
# ...          ...                                                ...
# 25060       8235  https://github.com/ballerina-platform/ballerin...
# 25061      12351  https://github.com/ballerina-platform/ballerin...
# 25062      25356  https://github.com/ballerina-platform/ballerin...
# 25063      39163  https://github.com/ballerina-platform/ballerin...
# 25064      10398  https://github.com/ballerina-platform/ballerin...
#
#                                                 pr_title  \
# 0      Update web socket sample for action invoation ...
# 1      Create resource jars separately to read the re...
# 2                        Fix issues in list command help
# 3                 Update full build pipeline of PR build
# 4        Update keyword for composer syntax highlighting
# ...                                                  ...
# 25060                              Fix WebSub doc issues
# 25061                Update BBE with sync send and flush
# 25062    Fix New Line Formatting in "java.jdbc" API Docs
# 25063  Move architecture model generator implementati...
# 25064      Fix invalid error outputs to standard outputs
#
#                                                  pr_body  \
# 0                                                    NaN
# 1      ## Purpose\r\n> Describe the problems, issues,...
# 2      ## Purpose\r\n> This PR fixes issues in list c...
# 3      ## Purpose\r\n> $title.\r\n\r\nFixes #<Issue N...
# 4      ## Purpose\r\nUpdate entries keywords in monar...
# ...                                                  ...
# 25060                ## Purpose\r\nFix WebSub doc issues
# 25061  ## Purpose\r\n> Add sync send and flush to the...
# 25062  ## Purpose\r\nFix the new line formatting in j...
# 25063  ## Purpose\r\n> This PR removes the architectu...
# 25064  ## Purpose\r\n> Output streams were set to err...
#
#       extracted_issue_number extracted_issue_link  found_in_title  \
# 0                       None                 None           False
# 1                       None                 None           False
# 2                       None                 None           False
# 3                       None                 None           False
# 4                       None                 None           False
# ...                      ...                  ...             ...
# 25060                   None                 None           False
# 25061                   None                 None           False
# 25062                   None                 None           False
# 25063                   None                 None           False
# 25064                   None                 None           False
#
#        original_row_index
# 0                   10799
# 1                    7855
# 2                    7854
# 3                    7853
# 4                    7852
# ...                   ...
# 25060               17195
# 25061               14039
# 25062               22298
# 25063               14038
# 25064               17194
#
# [25065 rows x 8 columns]

# %% [markdown]
# ## Discription

# %%
import pandas as pd
import os  
import re
from loguru import logger
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
from typing import List, Tuple, Optional
import time

def extract_all_issue_numbers_from_text(text: str) -> List[str]:
    """
    Extracts all issue numbers from a given text string.
    
    This function uses two methods:
    1. A list of regular expressions to find standard issue references (e.g., "fixes #123").
    2. A specific procedural search for lists of issues that appear after the phrase 
       "Following issues".
       
    Returns a list of unique issue numbers found.
    """
    if pd.isna(text) or not text.strip():
        return []

    found_issues = set()  # Use a set to automatically handle duplicates

    # --- Part 1: General Regex-Based Extraction (Your Original Method) ---
    
    # Covers: fix(es/ed/ing), clos(e/es/ed), resolv(e/es/ed), issue(s)
    keyword_pattern = r'\b(?:fix(?:es|ed|ing)?|clos(?:e|es|ed)|resolv(?:e|es|ed)|issue(?:s)?)\b'

    issue_patterns = [
        # Matches: keyword + full GitHub issue/PR URL
        rf'{keyword_pattern}\s+https?://github\.com/[^/]+/[^/]+/(?:issues|pull)/(\d+)',
        # Matches: keyword + #issue_number (e.g., "closes #456", "Fixes #32160")
        rf'{keyword_pattern}\s+#(\d+)\b',
        # Matches: keyword + issue_number
        rf'{keyword_pattern}\s+(\d+)\b',
        # Matches: keyword + text + (from #issue_number)
        rf'{keyword_pattern}.*\(from\s+#(\d+)\)',
        # Matches: keyword + text + #issue_number (a bit broad, but can be useful)
        rf'{keyword_pattern}.*#(\d+)\b',
        # Matches: keyword + text + (part of #issue_number)
        rf'{keyword_pattern}.*(?:part of\s+(?:issue\s+)?#(\d+)\b)',
        # Matches: keyword + text + /fix-#issue_number
        rf'{keyword_pattern}.*(?:/fix-#(\d+)\b|/fix-(\d+)\b)',
        # Matches: "Fixes: " + full GitHub issue URL
        rf'Fixes:\s+https?://github\.com/[^/]+/[^/]+/issues/(\d+)',
        # Matches: keyword + multiple #issue_numbers separated by commas
        rf'{keyword_pattern}[^#]*?((?:#\d+(?:\s*,\s*#\d+)*)+)',
        # Matches: standalone full GitHub issue URL
        r'https?://github\.com/[^/]+/[^/]+/issues/(\d+)',
        # Matches: "Fix " + org/repo/issues/issue_number
        rf'Fix\s+[^/]+/[^/]+/issues/(\d+)',
        # General fallback for any standalone #<number> not caught by other patterns
        r'#(\d+)\b'
    ]

    for pattern in issue_patterns:
        # Using re.IGNORECASE to match keywords like "Fixes" or "fixes"
        matches = re.finditer(pattern, text, re.IGNORECASE)
        for match in matches:
            for group_val in match.groups():
                if group_val:
                    # Handle multiple issues in one match (e.g., "#123, #456")
                    if '#' in group_val:
                        issue_nums_in_group = re.findall(r'#(\d+)', group_val)
                        found_issues.update(issue_nums_in_group)
                    else:
                        found_issues.add(group_val)

    # --- Part 2: Procedural Extraction for "Following issues" List ---
    
    is_in_remarks_section = False
    for line in text.splitlines():
        # Turn on the flag when the trigger phrase is found
        if "Following issues" in line:
            is_in_remarks_section = True
            continue

        # If the flag is on, start extracting numbers
        if is_in_remarks_section:
            # If the line is empty or starts a new section, the list is over
            if not line.strip() or line.strip().startswith("##"):
                break

            # Find all #<number> patterns on the line and add to the set
            found_in_line = re.findall(r'#(\d+)\b', line)
            if found_in_line:
                found_issues.update(found_in_line)
    
    return sorted(list(found_issues), key=int) # Return a sorted list

def process_row_for_body(row_data: Tuple[int, pd.Series]) -> List[dict]:
    """
    Process a single row to extract issue numbers from 'pr_body'.
    Returns a list of dictionaries, one for each issue found, or one original if none found.
    """
    idx, row = row_data
    
    try:
        pr_body = str(row.get('pr_body', ''))
        pr_link = str(row.get('pr_link', ''))
        
        # Extract all issue numbers from pr_body
        issue_numbers = extract_all_issue_numbers_from_text(pr_body)
        
        results = []
        
        if issue_numbers:
            # Create separate record for each issue found in body
            for issue_num in issue_numbers:
                issue_link = generate_issue_link(issue_num, pr_link) # generate_issue_link from CELL 11
                
                new_record = row.to_dict()
                new_record.update({
                    'extracted_issue_number_body': issue_num,
                    'extracted_issue_link_body': issue_link,
                    'found_in_body': True,
                    'original_row_index': idx  # Keep track of the original row
                })
                results.append(new_record)
                
            logger.info(f"Row {idx}: Found {len(issue_numbers)} issues in body: {issue_numbers}")
        else:
            # No issues found in body, keep original record with null/false values for body extraction
            new_record = row.to_dict()
            new_record.update({
                'extracted_issue_number_body': None,
                'extracted_issue_link_body': None,
                'found_in_body': False,
                'original_row_index': idx
            })
            results.append(new_record)
            
        return results
        
    except Exception as e:
        logger.error(f"Error processing row {idx} for body extraction: {str(e)}")
        # Return original record with error info for body extraction
        new_record = row.to_dict()
        new_record.update({
            'extracted_issue_number_body': None,
            'extracted_issue_link_body': None,
            'found_in_body': False,
            'original_row_index': idx,
            'processing_error_body': str(e)
        })
        return [new_record]

def run_body_extraction():
    """
    Main function to process the CSV for issues in 'pr_body' and create a new output file.
    """
    logger.info("Starting issue number extraction from PR BODY content")
    
    try:
        # csv_path is expected to be defined from a previous cell (e.g., CELL 11)
        # Defaulting if not found, but ideally it's already set.
        current_csv_path = csv_path if 'csv_path' in globals() else "../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv"

        logger.info(f"Loading CSV file: {current_csv_path}")
        df = pd.read_csv(current_csv_path)
        logger.info(f"Loaded {len(df)} records from CSV for body extraction")
        
        # Prepare data for parallel processing
        row_data_for_body = list(df.iterrows())
        
        all_results_body = []
        
        logger.info("Starting parallel processing for PR bodies...")
        # Using max_workers=4 for consistency with CELL 11, adjust if needed
        with ThreadPoolExecutor(max_workers= os.cpu_count()) as executor:
            future_to_row_body = {executor.submit(process_row_for_body, row_bd): row_bd[0] for row_bd in row_data_for_body}
            
            for future_bd in tqdm(as_completed(future_to_row_body), total=len(future_to_row_body), desc="Processing PR Bodies"):
                try:
                    row_results_bd = future_bd.result()
                    # write_lock is expected to be defined from a previous cell (e.g., CELL 11)
                    with write_lock: 
                        all_results_body.extend(row_results_bd)
                except Exception as e_bd:
                    row_idx_bd = future_to_row_body[future_bd]
                    logger.error(f"Failed to process row {row_idx_bd} for body extraction in main loop: {str(e_bd)}")
        
        logger.info(f"Creating new DataFrame with {len(all_results_body)} records from body extraction")
        new_df_body = pd.DataFrame(all_results_body)
        
        # Generate output filename for body extraction results
        output_path_body = current_csv_path.replace('.csv', '_with_extracted_issues_from_body.csv')
        
        logger.info(f"Saving body extraction results to: {output_path_body}")
        new_df_body.to_csv(output_path_body, index=False)
        
        # Log statistics for body extraction
        total_original_rows_bd = len(df)
        total_new_rows_bd = len(new_df_body)
        rows_with_issues_in_body = len(new_df_body[new_df_body['found_in_body'] == True])
        unique_issues_found_in_body = 0
        if 'extracted_issue_number_body' in new_df_body.columns:
             unique_issues_found_in_body = len(new_df_body[new_df_body['extracted_issue_number_body'].notna()]['extracted_issue_number_body'].unique())
        
        logger.info("="*50)
        logger.info("PR BODY EXTRACTION PROCESSING SUMMARY")
        logger.info("="*50)
        logger.info(f"Original rows processed: {total_original_rows_bd}")
        logger.info(f"New rows generated (from body): {total_new_rows_bd}")
        logger.info(f"Rows with issues found in body: {rows_with_issues_in_body}")
        logger.info(f"Unique issues extracted from body: {unique_issues_found_in_body}")
        if total_original_rows_bd > 0:
            logger.info(f"Expansion ratio (body): {total_new_rows_bd/total_original_rows_bd:.2f}x")
        logger.info(f"Output file (body extraction): {output_path_body}")
        logger.info("="*50)
        
        print(f"\n✅ PR Body issue extraction completed successfully!")
        print(f"📊 Original rows: {total_original_rows_bd}")
        print(f"📊 New rows (from body): {total_new_rows_bd}")
        print(f"📊 Rows with issues found in body: {rows_with_issues_in_body}")
        print(f"📊 Unique issues found in body: {unique_issues_found_in_body}")
        print(f"💾 Output saved to: {output_path_body}")
        
        return new_df_body
        
    except FileNotFoundError:
        logger.error(f"Error: The CSV file was not found at {current_csv_path}.")
        print(f"❌ Error: The CSV file was not found at {current_csv_path}.")
    except Exception as e:
        logger.error(f"Fatal error in PR body extraction process: {str(e)}")
        print(f"❌ Fatal error in PR body extraction process: {str(e)}")
        raise

# Execute the body extraction process
# This will use csv_path, generate_issue_link, and write_lock from the previous cells' scope.
result_df_body = run_body_extraction()
# Out:
# 2025-06-06 11:44:04.202 | INFO     | __main__:run_body_extraction:155 - Starting issue number extraction from PR BODY content
# 2025-06-06 11:44:04.210 | INFO     | __main__:run_body_extraction:162 - Loading CSV file: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv
# 2025-06-06 11:44:04.672 | INFO     | __main__:run_body_extraction:164 - Loaded 25042 records from CSV for body extraction
# 2025-06-06 11:44:06.760 | INFO     | __main__:run_body_extraction:171 - Starting parallel processing for PR bodies...
# 2025-06-06 11:44:06.772 | INFO     | __main__:process_row_for_body:124 - Row 16: Found 4 issues in body: ['6490', '6882', '6883', '6892']
# 2025-06-06 11:44:06.780 | INFO     | __main__:process_row_for_body:124 - Row 29: Found 1 issues in body: ['16625']
# 2025-06-06 11:44:06.780 | INFO     | __main__:process_row_for_body:124 - Row 31: Found 1 issues in body: ['29017']
# 2025-06-06 11:44:06.780 | INFO     | __main__:process_row_for_body:124 - Row 32: Found 1 issues in body: ['25709']
# 2025-06-06 11:44:06.793 | INFO     | __main__:process_row_for_body:124 - Row 37: Found 1 issues in body: ['17740']
# 2025-06-06 11:44:06.804 | INFO     | __main__:process_row_for_body:124 - Row 41: Found 1 issues in body: ['12492']
# 2025-06-06 11:44:06.806 | INFO     | __main__:process_row_for_body:124 - Row 42: Found 1 issues in body: ['29643']
# 2025-06-06 11:44:06.806 | INFO     | __main__:process_row_for_body:124 - Row 44: Found 1 issues in body: ['17806']
# 2025-06-06 11:44:06.810 | INFO     | __main__:process_row_for_body:124 - Row 46: Found 2 issues in body: ['32020', '32658']
# 2025-06-06 11:44:06.810 | INFO     | __main__:process_row_for_body:124 - Row 48: Found 2 issues in body: ['26284', '32848']
# 2025-06-06 11:44:06.810 | INFO     | __main__:process_row_for_body:124 - Row 49: Found 2 issues in body: ['12804', '24903']
# 2025-06-06 11:44:06.810 | INFO     | __main__:process_row_for_body:124 - Row 50: Found 1 issues in body: ['11085']
# 2025-06-06 11:44:06.810 | INFO     | __main__:process_row_for_body:124 - Row 53: Found 1 issues in body: ['29366']
# 2025-06-06 11:44:06.818 | INFO     | __main__:process_row_for_body:124 - Row 54: Found 2 issues in body: ['17811', '17862']
# 2025-06-06 11:44:06.820 | INFO     | __main__:process_row_for_body:124 - Row 55: Found 1 issues in body: ['31783']
# 2025-06-06 11:44:06.823 | INFO     | __main__:process_row_for_body:124 - Row 57: Found 1 issues in body: ['10825']
# 2025-06-06 11:44:06.957 | INFO     | __main__:process_row_for_body:124 - Row 59: Found 3 issues in body: ['10000', '12308', '12495']
# Processing PR Bodies:   0%|          | 0/25042 [00:00<?, ?it/s]2025-06-06 11:44:07.307 | INFO     | __main__:process_row_for_body:124 - Row 60: Found 1 issues in body: ['17296']
# 2025-06-06 11:44:07.321 | INFO     | __main__:process_row_for_body:124 - Row 61: Found 2 issues in body: ['18949', '28176']
# 2025-06-06 11:44:07.355 | INFO     | __main__:process_row_for_body:124 - Row 62: Found 1 issues in body: ['32092']
# 2025-06-06 11:44:07.405 | INFO     | __main__:process_row_for_body:124 - Row 64: Found 1 issues in body: ['27918']
# 2025-06-06 11:44:07.452 | INFO     | __main__:process_row_for_body:124 - Row 66: Found 5 issues in body: ['24944', '28077', '28424', '28521', '29089']
# 2025-06-06 11:44:07.503 | INFO     | __main__:process_row_for_body:124 - Row 68: Found 1 issues in body: ['17809']
# 2025-06-06 11:44:07.590 | INFO     | __main__:process_row_for_body:124 - Row 69: Found 3 issues in body: ['10434', '32171', '32608']
# 2025-06-06 11:44:07.641 | INFO     | __main__:process_row_for_body:124 - Row 71: Found 2 issues in body: ['29428', '29573']
# 2025-06-06 11:44:07.641 | INFO     | __main__:process_row_for_body:124 - Row 73: Found 1 issues in body: ['31601']
# 2025-06-06 11:44:07.641 | INFO     | __main__:process_row_for_body:124 - Row 77: Found 1 issues in body: ['17795']
# 2025-06-06 11:44:07.641 | INFO     | __main__:process_row_for_body:124 - Row 78: Found 1 issues in body: ['31159']
# 2025-06-06 11:44:07.641 | INFO     | __main__:process_row_for_body:124 - Row 79: Found 1 issues in body: ['29633']
# 2025-06-06 11:44:07.650 | INFO     | __main__:process_row_for_body:124 - Row 80: Found 1 issues in body: ['10825']
# 2025-06-06 11:44:07.650 | INFO     | __main__:process_row_for_body:124 - Row 81: Found 1 issues in body: ['11052']
# 2025-06-06 11:44:07.654 | INFO     | __main__:process_row_for_body:124 - Row 83: Found 1 issues in body: ['17727']
# 2025-06-06 11:44:07.655 | INFO     | __main__:process_row_for_body:124 - Row 85: Found 2 issues in body: ['420', '32612']
# 2025-06-06 11:44:07.656 | INFO     | __main__:process_row_for_body:124 - Row 87: Found 1 issues in body: ['14724']
# 2025-06-06 11:44:07.657 | INFO     | __main__:process_row_for_body:124 - Row 88: Found 1 issues in body: ['105']
# 2025-06-06 11:44:07.660 | INFO     | __main__:process_row_for_body:124 - Row 89: Found 1 issues in body: ['12492']
# 2025-06-06 11:44:07.662 | INFO     | __main__:process_row_for_body:124 - Row 94: Found 1 issues in body: ['17693']
# 2025-06-06 11:44:07.663 | INFO     | __main__:process_row_for_body:124 - Row 95: Found 1 issues in body: ['32575']
# 2025-06-06 11:44:07.664 | INFO     | __main__:process_row_for_body:124 - Row 102: Found 1 issues in body: ['17724']
# 2025-06-06 11:44:07.664 | INFO     | __main__:process_row_for_body:124 - Row 103: Found 1 issues in body: ['32558']
# 2025-06-06 11:44:07.670 | INFO     | __main__:process_row_for_body:124 - Row 104: Found 1 issues in body: ['14809']
# 2025-06-06 11:44:07.671 | INFO     | __main__:process_row_for_body:124 - Row 105: Found 1 issues in body: ['28634']
# 2025-06-06 11:44:07.672 | INFO     | __main__:process_row_for_body:124 - Row 107: Found 1 issues in body: ['12771']
# 2025-06-06 11:44:07.675 | INFO     | __main__:process_row_for_body:124 - Row 109: Found 1 issues in body: ['17746']
# 2025-06-06 11:44:07.680 | INFO     | __main__:process_row_for_body:124 - Row 111: Found 1 issues in body: ['32641']
# 2025-06-06 11:44:07.680 | INFO     | __main__:process_row_for_body:124 - Row 113: Found 2 issues in body: ['31537', '31698']
# 2025-06-06 11:44:07.680 | INFO     | __main__:process_row_for_body:124 - Row 114: Found 2 issues in body: ['7285', '12772']
# 2025-06-06 11:44:07.686 | INFO     | __main__:process_row_for_body:124 - Row 120: Found 2 issues in body: ['32136', '32580']
# 2025-06-06 11:44:07.688 | INFO     | __main__:process_row_for_body:124 - Row 123: Found 1 issues in body: ['12251']
# Processing PR Bodies:   0%|          | 125/25042 [00:00<00:19, 1249.47it/s]2025-06-06 11:44:07.690 | INFO     | __main__:process_row_for_body:124 - Row 125: Found 2 issues in body: ['17607', '17680']
# 2025-06-06 11:44:07.692 | INFO     | __main__:process_row_for_body:124 - Row 126: Found 3 issues in body: ['30980', '32365', '32402']
# 2025-06-06 11:44:07.694 | INFO     | __main__:process_row_for_body:124 - Row 128: Found 3 issues in body: ['29292', '31338', '31386']
# 2025-06-06 11:44:07.695 | INFO     | __main__:process_row_for_body:124 - Row 129: Found 1 issues in body: ['27799']
# 2025-06-06 11:44:07.697 | INFO     | __main__:process_row_for_body:124 - Row 130: Found 3 issues in body: ['28678', '28888', '29749']
# 2025-06-06 11:44:07.698 | INFO     | __main__:process_row_for_body:124 - Row 131: Found 1 issues in body: ['12584']
# 2025-06-06 11:44:07.700 | INFO     | __main__:process_row_for_body:124 - Row 133: Found 1 issues in body: ['28847']
# 2025-06-06 11:44:07.702 | INFO     | __main__:process_row_for_body:124 - Row 135: Found 1 issues in body: ['30982']
# 2025-06-06 11:44:07.704 | INFO     | __main__:process_row_for_body:124 - Row 137: Found 2 issues in body: ['10904', '12775']
# 2025-06-06 11:44:07.705 | INFO     | __main__:process_row_for_body:124 - Row 138: Found 1 issues in body: ['29449']
# 2025-06-06 11:44:07.707 | INFO     | __main__:process_row_for_body:124 - Row 142: Found 2 issues in body: ['17782', '17991']
# 2025-06-06 11:44:07.709 | INFO     | __main__:process_row_for_body:124 - Row 143: Found 5 issues in body: ['29628', '32159', '32660', '32661', '32662']
# 2025-06-06 11:44:07.709 | INFO     | __main__:process_row_for_body:124 - Row 148: Found 1 issues in body: ['17950']
# 2025-06-06 11:44:07.709 | INFO     | __main__:process_row_for_body:124 - Row 151: Found 1 issues in body: ['29076']
# 2025-06-06 11:44:07.709 | INFO     | __main__:process_row_for_body:124 - Row 152: Found 1 issues in body: ['1466']
# 2025-06-06 11:44:07.709 | INFO     | __main__:process_row_for_body:124 - Row 153: Found 1 issues in body: ['10499']
# 2025-06-06 11:44:07.718 | INFO     | __main__:process_row_for_body:124 - Row 157: Found 1 issues in body: ['17788']
# 2025-06-06 11:44:07.721 | INFO     | __main__:process_row_for_body:124 - Row 159: Found 1 issues in body: ['32417']
# 2025-06-06 11:44:07.723 | INFO     | __main__:process_row_for_body:124 - Row 160: Found 1 issues in body: ['28406']
# 2025-06-06 11:44:07.724 | INFO     | __main__:process_row_for_body:124 - Row 161: Found 2 issues in body: ['34990', '35178']
# 2025-06-06 11:44:07.725 | INFO     | __main__:process_row_for_body:124 - Row 164: Found 2 issues in body: ['37669', '37751']
# 2025-06-06 11:44:07.726 | INFO     | __main__:process_row_for_body:124 - Row 165: Found 1 issues in body: ['25983']
# 2025-06-06 11:44:07.726 | INFO     | __main__:process_row_for_body:124 - Row 166: Found 1 issues in body: ['40226']
# 2025-06-06 11:44:07.730 | INFO     | __main__:process_row_for_body:124 - Row 168: Found 3 issues in body: ['25970', '25978', '26541']
# 2025-06-06 11:44:07.730 | INFO     | __main__:process_row_for_body:124 - Row 169: Found 1 issues in body: ['22048']
# 2025-06-06 11:44:07.730 | INFO     | __main__:process_row_for_body:124 - Row 170: Found 1 issues in body: ['24643']
# 2025-06-06 11:44:07.730 | INFO     | __main__:process_row_for_body:124 - Row 171: Found 1 issues in body: ['25441']
# 2025-06-06 11:44:07.736 | INFO     | __main__:process_row_for_body:124 - Row 172: Found 1 issues in body: ['22002']
# 2025-06-06 11:44:07.738 | INFO     | __main__:process_row_for_body:124 - Row 173: Found 1 issues in body: ['40127']
# 2025-06-06 11:44:07.742 | INFO     | __main__:process_row_for_body:124 - Row 174: Found 2 issues in body: ['34919', '35057']
# 2025-06-06 11:44:07.744 | INFO     | __main__:process_row_for_body:124 - Row 175: Found 1 issues in body: ['26346']
# 2025-06-06 11:44:07.744 | INFO     | __main__:process_row_for_body:124 - Row 176: Found 2 issues in body: ['22025', '23000']
# 2025-06-06 11:44:07.744 | INFO     | __main__:process_row_for_body:124 - Row 177: Found 3 issues in body: ['19804', '39324', '41174']
# 2025-06-06 11:44:07.744 | INFO     | __main__:process_row_for_body:124 - Row 178: Found 1 issues in body: ['26587']
# 2025-06-06 11:44:07.750 | INFO     | __main__:process_row_for_body:124 - Row 179: Found 1 issues in body: ['39892']
# 2025-06-06 11:44:07.754 | INFO     | __main__:process_row_for_body:124 - Row 182: Found 2 issues in body: ['20884', '20901']
# 2025-06-06 11:44:07.756 | INFO     | __main__:process_row_for_body:124 - Row 184: Found 2 issues in body: ['26430', '26584']
# 2025-06-06 11:44:07.759 | INFO     | __main__:process_row_for_body:124 - Row 185: Found 1 issues in body: ['24158']
# 2025-06-06 11:44:07.760 | INFO     | __main__:process_row_for_body:124 - Row 186: Found 1 issues in body: ['40127']
# 2025-06-06 11:44:07.760 | INFO     | __main__:process_row_for_body:124 - Row 187: Found 1 issues in body: ['35578']
# 2025-06-06 11:44:07.764 | INFO     | __main__:process_row_for_body:124 - Row 188: Found 3 issues in body: ['517', '22927', '25955']
# 2025-06-06 11:44:07.764 | INFO     | __main__:process_row_for_body:124 - Row 189: Found 1 issues in body: ['36810']
# 2025-06-06 11:44:07.764 | INFO     | __main__:process_row_for_body:124 - Row 190: Found 1 issues in body: ['37666']
# 2025-06-06 11:44:07.768 | INFO     | __main__:process_row_for_body:124 - Row 192: Found 1 issues in body: ['24959']
# 2025-06-06 11:44:07.771 | INFO     | __main__:process_row_for_body:124 - Row 193: Found 1 issues in body: ['40289']
# 2025-06-06 11:44:07.773 | INFO     | __main__:process_row_for_body:124 - Row 196: Found 1 issues in body: ['29183']
# 2025-06-06 11:44:07.775 | INFO     | __main__:process_row_for_body:124 - Row 197: Found 2 issues in body: ['37199', '37734']
# 2025-06-06 11:44:07.777 | INFO     | __main__:process_row_for_body:124 - Row 198: Found 1 issues in body: ['25395']
# 2025-06-06 11:44:07.777 | INFO     | __main__:process_row_for_body:124 - Row 199: Found 1 issues in body: ['22037']
# 2025-06-06 11:44:07.780 | INFO     | __main__:process_row_for_body:124 - Row 200: Found 1 issues in body: ['40292']
# 2025-06-06 11:44:07.784 | INFO     | __main__:process_row_for_body:124 - Row 205: Found 1 issues in body: ['26587']
# 2025-06-06 11:44:07.787 | INFO     | __main__:process_row_for_body:124 - Row 206: Found 1 issues in body: ['40045']
# 2025-06-06 11:44:07.789 | INFO     | __main__:process_row_for_body:124 - Row 207: Found 1 issues in body: ['173']
# 2025-06-06 11:44:07.793 | INFO     | __main__:process_row_for_body:124 - Row 209: Found 2 issues in body: ['12804', '24412']
# 2025-06-06 11:44:07.794 | INFO     | __main__:process_row_for_body:124 - Row 210: Found 1 issues in body: ['40313']
# 2025-06-06 11:44:07.796 | INFO     | __main__:process_row_for_body:124 - Row 211: Found 3 issues in body: ['26071', '26251', '26265']
# 2025-06-06 11:44:07.798 | INFO     | __main__:process_row_for_body:124 - Row 213: Found 1 issues in body: ['36652']
# 2025-06-06 11:44:07.799 | INFO     | __main__:process_row_for_body:124 - Row 214: Found 2 issues in body: ['25326', '25592']
# 2025-06-06 11:44:07.803 | INFO     | __main__:process_row_for_body:124 - Row 215: Found 1 issues in body: ['1394']
# 2025-06-06 11:44:07.806 | INFO     | __main__:process_row_for_body:124 - Row 219: Found 1 issues in body: ['5106']
# 2025-06-06 11:44:07.808 | INFO     | __main__:process_row_for_body:124 - Row 220: Found 3 issues in body: ['2637', '3334', '4386']
# 2025-06-06 11:44:07.811 | INFO     | __main__:process_row_for_body:124 - Row 225: Found 1 issues in body: ['4950']
# 2025-06-06 11:44:07.812 | INFO     | __main__:process_row_for_body:124 - Row 227: Found 2 issues in body: ['2774', '3655']
# 2025-06-06 11:44:07.812 | INFO     | __main__:process_row_for_body:124 - Row 228: Found 1 issues in body: ['4589']
# 2025-06-06 11:44:07.817 | INFO     | __main__:process_row_for_body:124 - Row 229: Found 1 issues in body: ['4575']
# 2025-06-06 11:44:07.821 | INFO     | __main__:process_row_for_body:124 - Row 240: Found 1 issues in body: ['4950']
# Processing PR Bodies:   1%|          | 250/25042 [00:00<00:24, 1006.20it/s]2025-06-06 11:44:07.824 | INFO     | __main__:process_row_for_body:124 - Row 243: Found 1 issues in body: ['4509']
# 2025-06-06 11:44:07.825 | INFO     | __main__:process_row_for_body:124 - Row 244: Found 1 issues in body: ['3601']
# 2025-06-06 11:44:07.827 | INFO     | __main__:process_row_for_body:124 - Row 246: Found 1 issues in body: ['4504']
# 2025-06-06 11:44:07.830 | INFO     | __main__:process_row_for_body:124 - Row 250: Found 1 issues in body: ['4716']
# 2025-06-06 11:44:07.835 | INFO     | __main__:process_row_for_body:124 - Row 254: Found 1 issues in body: ['3997']
# 2025-06-06 11:44:07.838 | INFO     | __main__:process_row_for_body:124 - Row 256: Found 1 issues in body: ['161']
# 2025-06-06 11:44:07.841 | INFO     | __main__:process_row_for_body:124 - Row 261: Found 1 issues in body: ['4567']
# 2025-06-06 11:44:07.843 | INFO     | __main__:process_row_for_body:124 - Row 263: Found 2 issues in body: ['5262', '5263']
# 2025-06-06 11:44:07.843 | INFO     | __main__:process_row_for_body:124 - Row 267: Found 1 issues in body: ['4532']
# 2025-06-06 11:44:07.846 | INFO     | __main__:process_row_for_body:124 - Row 270: Found 1 issues in body: ['32']
# 2025-06-06 11:44:07.848 | INFO     | __main__:process_row_for_body:124 - Row 271: Found 1 issues in body: ['12926']
# 2025-06-06 11:44:07.850 | INFO     | __main__:process_row_for_body:124 - Row 273: Found 1 issues in body: ['22214']
# 2025-06-06 11:44:07.853 | INFO     | __main__:process_row_for_body:124 - Row 275: Found 1 issues in body: ['24534']
# 2025-06-06 11:44:07.856 | INFO     | __main__:process_row_for_body:124 - Row 276: Found 1 issues in body: ['10959']
# 2025-06-06 11:44:07.857 | INFO     | __main__:process_row_for_body:124 - Row 277: Found 1 issues in body: ['24599']
# 2025-06-06 11:44:07.859 | INFO     | __main__:process_row_for_body:124 - Row 279: Found 1 issues in body: ['20829']
# 2025-06-06 11:44:07.860 | INFO     | __main__:process_row_for_body:124 - Row 281: Found 1 issues in body: ['22199']
# 2025-06-06 11:44:07.864 | INFO     | __main__:process_row_for_body:124 - Row 285: Found 2 issues in body: ['21801', '22230']
# 2025-06-06 11:44:07.864 | INFO     | __main__:process_row_for_body:124 - Row 288: Found 1 issues in body: ['24584']
# 2025-06-06 11:44:07.864 | INFO     | __main__:process_row_for_body:124 - Row 289: Found 1 issues in body: ['22227']
# 2025-06-06 11:44:07.871 | INFO     | __main__:process_row_for_body:124 - Row 291: Found 1 issues in body: ['24541']
# 2025-06-06 11:44:07.872 | INFO     | __main__:process_row_for_body:124 - Row 292: Found 2 issues in body: ['21923', '22206']
# 2025-06-06 11:44:07.873 | INFO     | __main__:process_row_for_body:124 - Row 293: Found 1 issues in body: ['20829']
# 2025-06-06 11:44:07.877 | INFO     | __main__:process_row_for_body:124 - Row 297: Found 3 issues in body: ['21850', '22201', '22209']
# 2025-06-06 11:44:07.878 | INFO     | __main__:process_row_for_body:124 - Row 298: Found 1 issues in body: ['24631']
# 2025-06-06 11:44:07.880 | INFO     | __main__:process_row_for_body:124 - Row 299: Found 2 issues in body: ['19981', '20146']
# 2025-06-06 11:44:07.882 | INFO     | __main__:process_row_for_body:124 - Row 301: Found 1 issues in body: ['19300']
# 2025-06-06 11:44:07.884 | INFO     | __main__:process_row_for_body:124 - Row 302: Found 1 issues in body: ['19877']
# 2025-06-06 11:44:07.885 | INFO     | __main__:process_row_for_body:124 - Row 303: Found 2 issues in body: ['19871', '20150']
# 2025-06-06 11:44:07.888 | INFO     | __main__:process_row_for_body:124 - Row 305: Found 2 issues in body: ['19981', '20146']
# 2025-06-06 11:44:07.890 | INFO     | __main__:process_row_for_body:124 - Row 306: Found 1 issues in body: ['19075']
# 2025-06-06 11:44:07.892 | INFO     | __main__:process_row_for_body:124 - Row 309: Found 1 issues in body: ['18791']
# 2025-06-06 11:44:07.894 | INFO     | __main__:process_row_for_body:124 - Row 310: Found 1 issues in body: ['20056']
# 2025-06-06 11:44:07.895 | INFO     | __main__:process_row_for_body:124 - Row 311: Found 5 issues in body: ['19842', '20063', '20069', '20101', '20103']
# 2025-06-06 11:44:07.897 | INFO     | __main__:process_row_for_body:124 - Row 313: Found 3 issues in body: ['19939', '20081', '20126']
# 2025-06-06 11:44:07.897 | INFO     | __main__:process_row_for_body:124 - Row 314: Found 1 issues in body: ['10050']
# 2025-06-06 11:44:07.900 | INFO     | __main__:process_row_for_body:124 - Row 315: Found 1 issues in body: ['19994']
# 2025-06-06 11:44:07.902 | INFO     | __main__:process_row_for_body:124 - Row 316: Found 1 issues in body: ['19299']
# 2025-06-06 11:44:07.904 | INFO     | __main__:process_row_for_body:124 - Row 317: Found 1 issues in body: ['18907']
# 2025-06-06 11:44:07.906 | INFO     | __main__:process_row_for_body:124 - Row 319: Found 1 issues in body: ['19456']
# 2025-06-06 11:44:07.906 | INFO     | __main__:process_row_for_body:124 - Row 320: Found 1 issues in body: ['20119']
# 2025-06-06 11:44:07.910 | INFO     | __main__:process_row_for_body:124 - Row 321: Found 1 issues in body: ['18427']
# 2025-06-06 11:44:07.910 | INFO     | __main__:process_row_for_body:124 - Row 322: Found 1 issues in body: ['20117']
# 2025-06-06 11:44:07.910 | INFO     | __main__:process_row_for_body:124 - Row 324: Found 1 issues in body: ['19858']
# 2025-06-06 11:44:07.910 | INFO     | __main__:process_row_for_body:124 - Row 328: Found 1 issues in body: ['29077']
# 2025-06-06 11:44:07.910 | INFO     | __main__:process_row_for_body:124 - Row 332: Found 1 issues in body: ['29627']
# 2025-06-06 11:44:07.918 | INFO     | __main__:process_row_for_body:124 - Row 333: Found 2 issues in body: ['28352', '29160']
# 2025-06-06 11:44:07.921 | INFO     | __main__:process_row_for_body:124 - Row 334: Found 2 issues in body: ['29219', '29368']
# 2025-06-06 11:44:07.922 | INFO     | __main__:process_row_for_body:124 - Row 336: Found 1 issues in body: ['29086']
# 2025-06-06 11:44:07.922 | INFO     | __main__:process_row_for_body:124 - Row 339: Found 1 issues in body: ['29385']
# 2025-06-06 11:44:07.922 | INFO     | __main__:process_row_for_body:124 - Row 340: Found 1 issues in body: ['29066']
# 2025-06-06 11:44:07.930 | INFO     | __main__:process_row_for_body:124 - Row 342: Found 2 issues in body: ['28018', '28711']
# 2025-06-06 11:44:07.930 | INFO     | __main__:process_row_for_body:124 - Row 344: Found 1 issues in body: ['29071']
# 2025-06-06 11:44:07.930 | INFO     | __main__:process_row_for_body:124 - Row 345: Found 1 issues in body: ['29572']
# Processing PR Bodies:   1%|▏         | 354/25042 [00:00<00:25, 964.37it/s] 2025-06-06 11:44:07.937 | INFO     | __main__:process_row_for_body:124 - Row 346: Found 1 issues in body: ['28998']
# 2025-06-06 11:44:07.940 | INFO     | __main__:process_row_for_body:124 - Row 347: Found 1 issues in body: ['28998']
# 2025-06-06 11:44:07.940 | INFO     | __main__:process_row_for_body:124 - Row 350: Found 2 issues in body: ['28883', '32477']
# 2025-06-06 11:44:07.940 | INFO     | __main__:process_row_for_body:124 - Row 352: Found 1 issues in body: ['27765']
# 2025-06-06 11:44:07.940 | INFO     | __main__:process_row_for_body:124 - Row 355: Found 1 issues in body: ['32648']
# 2025-06-06 11:44:07.980 | INFO     | __main__:process_row_for_body:124 - Row 391: Found 2 issues in body: ['32230', '32369']
# 2025-06-06 11:44:07.990 | INFO     | __main__:process_row_for_body:124 - Row 393: Found 1 issues in body: ['24697']
# 2025-06-06 11:44:07.960 | INFO     | __main__:process_row_for_body:124 - Row 366: Found 2 issues in body: ['28064', '31385']
# 2025-06-06 11:44:08.003 | INFO     | __main__:process_row_for_body:124 - Row 399: Found 1 issues in body: ['11024']
# 2025-06-06 11:44:08.006 | INFO     | __main__:process_row_for_body:124 - Row 402: Found 3 issues in body: ['13158', '31707', '31822']
# 2025-06-06 11:44:07.960 | INFO     | __main__:process_row_for_body:124 - Row 368: Found 1 issues in body: ['32648']
# 2025-06-06 11:44:07.974 | INFO     | __main__:process_row_for_body:124 - Row 385: Found 1 issues in body: ['22052']
# 2025-06-06 11:44:07.950 | INFO     | __main__:process_row_for_body:124 - Row 358: Found 1 issues in body: ['26915']
# 2025-06-06 11:44:07.955 | INFO     | __main__:process_row_for_body:124 - Row 363: Found 1 issues in body: ['32531']
# 2025-06-06 11:44:08.000 | INFO     | __main__:process_row_for_body:124 - Row 396: Found 1 issues in body: ['32589']
# 2025-06-06 11:44:07.960 | INFO     | __main__:process_row_for_body:124 - Row 371: Found 1 issues in body: ['7869']
# 2025-06-06 11:44:07.968 | INFO     | __main__:process_row_for_body:124 - Row 378: Found 1 issues in body: ['32328']
# 2025-06-06 11:44:08.010 | INFO     | __main__:process_row_for_body:124 - Row 406: Found 2 issues in body: ['9144', '28439']
# 2025-06-06 11:44:08.018 | INFO     | __main__:process_row_for_body:124 - Row 409: Found 1 issues in body: ['6049']
# 2025-06-06 11:44:08.021 | INFO     | __main__:process_row_for_body:124 - Row 411: Found 1 issues in body: ['7346']
# 2025-06-06 11:44:08.023 | INFO     | __main__:process_row_for_body:124 - Row 412: Found 1 issues in body: ['32437']
# 2025-06-06 11:44:08.032 | INFO     | __main__:process_row_for_body:124 - Row 418: Found 1 issues in body: ['32683']
# 2025-06-06 11:44:08.036 | INFO     | __main__:process_row_for_body:124 - Row 424: Found 1 issues in body: ['32493']
# 2025-06-06 11:44:08.042 | INFO     | __main__:process_row_for_body:124 - Row 429: Found 3 issues in body: ['31444', '31713', '31717']
# 2025-06-06 11:44:08.054 | INFO     | __main__:process_row_for_body:124 - Row 432: Found 1 issues in body: ['32663']
# 2025-06-06 11:44:08.058 | INFO     | __main__:process_row_for_body:124 - Row 435: Found 1 issues in body: ['22141']
# 2025-06-06 11:44:08.061 | INFO     | __main__:process_row_for_body:124 - Row 436: Found 1 issues in body: ['40131']
# 2025-06-06 11:44:08.070 | INFO     | __main__:process_row_for_body:124 - Row 437: Found 1 issues in body: ['37379']
# 2025-06-06 11:44:08.085 | INFO     | __main__:process_row_for_body:124 - Row 438: Found 1 issues in body: ['26707']
# 2025-06-06 11:44:08.087 | INFO     | __main__:process_row_for_body:124 - Row 439: Found 2 issues in body: ['12661', '12667']
# 2025-06-06 11:44:08.089 | INFO     | __main__:process_row_for_body:124 - Row 442: Found 1 issues in body: ['38510']
# 2025-06-06 11:44:08.091 | INFO     | __main__:process_row_for_body:124 - Row 443: Found 1 issues in body: ['26707']
# 2025-06-06 11:44:08.092 | INFO     | __main__:process_row_for_body:124 - Row 445: Found 1 issues in body: ['38065']
# 2025-06-06 11:44:08.092 | INFO     | __main__:process_row_for_body:124 - Row 446: Found 1 issues in body: ['12497']
# 2025-06-06 11:44:08.092 | INFO     | __main__:process_row_for_body:124 - Row 447: Found 1 issues in body: ['26678']
# Processing PR Bodies:   2%|▏         | 452/25042 [00:00<00:30, 804.54it/s]2025-06-06 11:44:08.100 | INFO     | __main__:process_row_for_body:124 - Row 448: Found 1 issues in body: ['25041']
# 2025-06-06 11:44:08.105 | INFO     | __main__:process_row_for_body:124 - Row 449: Found 1 issues in body: ['12785']
# 2025-06-06 11:44:08.107 | INFO     | __main__:process_row_for_body:124 - Row 450: Found 1 issues in body: ['39717']
# 2025-06-06 11:44:08.108 | INFO     | __main__:process_row_for_body:124 - Row 452: Found 2 issues in body: ['17208', '26362']
# 2025-06-06 11:44:08.109 | INFO     | __main__:process_row_for_body:124 - Row 454: Found 1 issues in body: ['36811']
# 2025-06-06 11:44:08.113 | INFO     | __main__:process_row_for_body:124 - Row 457: Found 1 issues in body: ['26204']
# 2025-06-06 11:44:08.113 | INFO     | __main__:process_row_for_body:124 - Row 459: Found 1 issues in body: ['40220']
# 2025-06-06 11:44:08.120 | INFO     | __main__:process_row_for_body:124 - Row 460: Found 2 issues in body: ['37629', '37688']
# 2025-06-06 11:44:08.124 | INFO     | __main__:process_row_for_body:124 - Row 461: Found 1 issues in body: ['26716']
# 2025-06-06 11:44:08.128 | INFO     | __main__:process_row_for_body:124 - Row 462: Found 1 issues in body: ['12781']
# 2025-06-06 11:44:08.130 | INFO     | __main__:process_row_for_body:124 - Row 463: Found 1 issues in body: ['25185']
# 2025-06-06 11:44:08.130 | INFO     | __main__:process_row_for_body:124 - Row 464: Found 1 issues in body: ['39905']
# 2025-06-06 11:44:08.130 | INFO     | __main__:process_row_for_body:124 - Row 466: Found 1 issues in body: ['25971']
# 2025-06-06 11:44:08.136 | INFO     | __main__:process_row_for_body:124 - Row 467: Found 1 issues in body: ['12747']
# 2025-06-06 11:44:08.138 | INFO     | __main__:process_row_for_body:124 - Row 468: Found 1 issues in body: ['40280']
# 2025-06-06 11:44:08.142 | INFO     | __main__:process_row_for_body:124 - Row 472: Found 2 issues in body: ['22757', '24984']
# 2025-06-06 11:44:08.144 | INFO     | __main__:process_row_for_body:124 - Row 473: Found 1 issues in body: ['12791']
# 2025-06-06 11:44:08.146 | INFO     | __main__:process_row_for_body:124 - Row 477: Found 1 issues in body: ['12789']
# 2025-06-06 11:44:08.148 | INFO     | __main__:process_row_for_body:124 - Row 480: Found 1 issues in body: ['32398']
# 2025-06-06 11:44:08.151 | INFO     | __main__:process_row_for_body:124 - Row 481: Found 2 issues in body: ['24443', '26054']
# 2025-06-06 11:44:08.155 | INFO     | __main__:process_row_for_body:124 - Row 482: Found 2 issues in body: ['20884', '20906']
# 2025-06-06 11:44:08.157 | INFO     | __main__:process_row_for_body:124 - Row 483: Found 1 issues in body: ['12795']
# 2025-06-06 11:44:08.159 | INFO     | __main__:process_row_for_body:124 - Row 484: Found 1 issues in body: ['40309']
# 2025-06-06 11:44:08.161 | INFO     | __main__:process_row_for_body:124 - Row 485: Found 1 issues in body: ['26701']
# 2025-06-06 11:44:08.163 | INFO     | __main__:process_row_for_body:124 - Row 486: Found 1 issues in body: ['12700']
# 2025-06-06 11:44:08.164 | INFO     | __main__:process_row_for_body:124 - Row 487: Found 1 issues in body: ['24995']
# 2025-06-06 11:44:08.170 | INFO     | __main__:process_row_for_body:124 - Row 488: Found 1 issues in body: ['40309']
# 2025-06-06 11:44:08.174 | INFO     | __main__:process_row_for_body:124 - Row 492: Found 1 issues in body: ['21791']
# 2025-06-06 11:44:08.176 | INFO     | __main__:process_row_for_body:124 - Row 494: Found 1 issues in body: ['1212']
# 2025-06-06 11:44:08.178 | INFO     | __main__:process_row_for_body:124 - Row 497: Found 1 issues in body: ['35543']
# 2025-06-06 11:44:08.181 | INFO     | __main__:process_row_for_body:124 - Row 499: Found 1 issues in body: ['24956']
# 2025-06-06 11:44:08.182 | INFO     | __main__:process_row_for_body:124 - Row 500: Found 1 issues in body: ['10818']
# 2025-06-06 11:44:08.185 | INFO     | __main__:process_row_for_body:124 - Row 501: Found 1 issues in body: ['40278']
# 2025-06-06 11:44:08.188 | INFO     | __main__:process_row_for_body:124 - Row 503: Found 1 issues in body: ['12754']
# 2025-06-06 11:44:08.190 | INFO     | __main__:process_row_for_body:124 - Row 504: Found 2 issues in body: ['40296', '40308']
# 2025-06-06 11:44:08.192 | INFO     | __main__:process_row_for_body:124 - Row 508: Found 1 issues in body: ['91']
# 2025-06-06 11:44:08.194 | INFO     | __main__:process_row_for_body:124 - Row 511: Found 1 issues in body: ['40318']
# 2025-06-06 11:44:08.195 | INFO     | __main__:process_row_for_body:124 - Row 513: Found 1 issues in body: ['25598']
# 2025-06-06 11:44:08.198 | INFO     | __main__:process_row_for_body:124 - Row 515: Found 1 issues in body: ['25164']
# 2025-06-06 11:44:08.200 | INFO     | __main__:process_row_for_body:124 - Row 516: Found 1 issues in body: ['40302']
# 2025-06-06 11:44:08.203 | INFO     | __main__:process_row_for_body:124 - Row 518: Found 1 issues in body: ['26740']
# 2025-06-06 11:44:08.206 | INFO     | __main__:process_row_for_body:124 - Row 521: Found 1 issues in body: ['40560']
# 2025-06-06 11:44:08.210 | INFO     | __main__:process_row_for_body:124 - Row 525: Found 8 issues in body: ['12968', '12998', '13537', '13577', '13735', '13739', '13752', '13756']
# 2025-06-06 11:44:08.213 | INFO     | __main__:process_row_for_body:124 - Row 528: Found 1 issues in body: ['42523']
# 2025-06-06 11:44:08.215 | INFO     | __main__:process_row_for_body:124 - Row 530: Found 1 issues in body: ['40264']
# Processing PR Bodies:   2%|▏         | 536/25042 [00:00<00:31, 770.63it/s]2025-06-06 11:44:08.217 | INFO     | __main__:process_row_for_body:124 - Row 532: Found 1 issues in body: ['4582']
# 2025-06-06 11:44:08.220 | INFO     | __main__:process_row_for_body:124 - Row 534: Found 1 issues in body: ['42555']
# 2025-06-06 11:44:08.222 | INFO     | __main__:process_row_for_body:124 - Row 536: Found 2 issues in body: ['17353', '17774']
# 2025-06-06 11:44:08.224 | INFO     | __main__:process_row_for_body:124 - Row 538: Found 1 issues in body: ['4578']
# 2025-06-06 11:44:08.228 | INFO     | __main__:process_row_for_body:124 - Row 540: Found 1 issues in body: ['41451']
# 2025-06-06 11:44:08.230 | INFO     | __main__:process_row_for_body:124 - Row 541: Found 2 issues in body: ['17781', '17786']
# 2025-06-06 11:44:08.232 | INFO     | __main__:process_row_for_body:124 - Row 547: Found 1 issues in body: ['39814']
# 2025-06-06 11:44:08.235 | INFO     | __main__:process_row_for_body:124 - Row 549: Found 1 issues in body: ['40472']
# 2025-06-06 11:44:08.241 | INFO     | __main__:process_row_for_body:124 - Row 558: Found 1 issues in body: ['14003']
# 2025-06-06 11:44:08.244 | INFO     | __main__:process_row_for_body:124 - Row 569: Found 1 issues in body: ['40264']
# 2025-06-06 11:44:08.244 | INFO     | __main__:process_row_for_body:124 - Row 574: Found 1 issues in body: ['42504']
# 2025-06-06 11:44:08.253 | INFO     | __main__:process_row_for_body:124 - Row 576: Found 1 issues in body: ['5106']
# 2025-06-06 11:44:08.256 | INFO     | __main__:process_row_for_body:124 - Row 580: Found 1 issues in body: ['42482']
# 2025-06-06 11:44:08.258 | INFO     | __main__:process_row_for_body:124 - Row 581: Found 2 issues in body: ['17825', '17928']
# 2025-06-06 11:44:08.260 | INFO     | __main__:process_row_for_body:124 - Row 582: Found 2 issues in body: ['41226', '41227']
# 2025-06-06 11:44:08.264 | INFO     | __main__:process_row_for_body:124 - Row 587: Found 1 issues in body: ['14381']
# 2025-06-06 11:44:08.267 | INFO     | __main__:process_row_for_body:124 - Row 591: Found 1 issues in body: ['42566']
# 2025-06-06 11:44:08.271 | INFO     | __main__:process_row_for_body:124 - Row 592: Found 1 issues in body: ['17933']
# 2025-06-06 11:44:08.274 | INFO     | __main__:process_row_for_body:124 - Row 593: Found 1 issues in body: ['35517']
# 2025-06-06 11:44:08.276 | INFO     | __main__:process_row_for_body:124 - Row 594: Found 2 issues in body: ['5282', '5283']
# 2025-06-06 11:44:08.277 | INFO     | __main__:process_row_for_body:124 - Row 598: Found 1 issues in body: ['42566']
# 2025-06-06 11:44:08.279 | INFO     | __main__:process_row_for_body:124 - Row 600: Found 2 issues in body: ['40604', '40717']
# 2025-06-06 11:44:08.285 | INFO     | __main__:process_row_for_body:124 - Row 604: Found 1 issues in body: ['5013']
# 2025-06-06 11:44:08.288 | INFO     | __main__:process_row_for_body:124 - Row 606: Found 1 issues in body: ['17779']
# 2025-06-06 11:44:08.293 | INFO     | __main__:process_row_for_body:124 - Row 614: Found 2 issues in body: ['17914', '17948']
# 2025-06-06 11:44:08.296 | INFO     | __main__:process_row_for_body:124 - Row 615: Found 1 issues in body: ['5272']
# 2025-06-06 11:44:08.297 | INFO     | __main__:process_row_for_body:124 - Row 616: Found 2 issues in body: ['32976', '33066']
# 2025-06-06 11:44:08.300 | INFO     | __main__:process_row_for_body:124 - Row 617: Found 1 issues in body: ['4534']
# 2025-06-06 11:44:08.303 | INFO     | __main__:process_row_for_body:124 - Row 618: Found 1 issues in body: ['40264']
# 2025-06-06 11:44:08.306 | INFO     | __main__:process_row_for_body:124 - Row 621: Found 1 issues in body: ['5279']
# 2025-06-06 11:44:08.308 | INFO     | __main__:process_row_for_body:124 - Row 622: Found 1 issues in body: ['4558']
# 2025-06-06 11:44:08.311 | INFO     | __main__:process_row_for_body:124 - Row 625: Found 1 issues in body: ['17934']
# 2025-06-06 11:44:08.313 | INFO     | __main__:process_row_for_body:124 - Row 628: Found 1 issues in body: ['42933']
# 2025-06-06 11:44:08.316 | INFO     | __main__:process_row_for_body:124 - Row 629: Found 1 issues in body: ['44117']
# 2025-06-06 11:44:08.317 | INFO     | __main__:process_row_for_body:124 - Row 630: Found 1 issues in body: ['18931']
# Processing PR Bodies:   3%|▎         | 632/25042 [00:00<00:29, 822.65it/s]2025-06-06 11:44:08.320 | INFO     | __main__:process_row_for_body:124 - Row 631: Found 1 issues in body: ['18902']
# 2025-06-06 11:44:08.323 | INFO     | __main__:process_row_for_body:124 - Row 633: Found 1 issues in body: ['19914']
# 2025-06-06 11:44:08.325 | INFO     | __main__:process_row_for_body:124 - Row 634: Found 2 issues in body: ['29682', '29691']
# 2025-06-06 11:44:08.326 | INFO     | __main__:process_row_for_body:124 - Row 635: Found 1 issues in body: ['20139']
# 2025-06-06 11:44:08.328 | INFO     | __main__:process_row_for_body:124 - Row 636: Found 2 issues in body: ['18713', '18751']
# 2025-06-06 11:44:08.330 | INFO     | __main__:process_row_for_body:124 - Row 637: Found 1 issues in body: ['28714']
# 2025-06-06 11:44:08.332 | INFO     | __main__:process_row_for_body:124 - Row 638: Found 1 issues in body: ['28879']
# 2025-06-06 11:44:08.333 | INFO     | __main__:process_row_for_body:124 - Row 639: Found 1 issues in body: ['20128']
# 2025-06-06 11:44:08.337 | INFO     | __main__:process_row_for_body:124 - Row 640: Found 2 issues in body: ['28665', '29070']
# 2025-06-06 11:44:08.339 | INFO     | __main__:process_row_for_body:124 - Row 642: Found 2 issues in body: ['29682', '29691']
# 2025-06-06 11:44:08.342 | INFO     | __main__:process_row_for_body:124 - Row 643: Found 2 issues in body: ['20007', '20014']
# 2025-06-06 11:44:08.344 | INFO     | __main__:process_row_for_body:124 - Row 644: Found 1 issues in body: ['18955']
# 2025-06-06 11:44:08.346 | INFO     | __main__:process_row_for_body:124 - Row 645: Found 1 issues in body: ['28893']
# 2025-06-06 11:44:08.349 | INFO     | __main__:process_row_for_body:124 - Row 646: Found 1 issues in body: ['19662']
# 2025-06-06 11:44:08.350 | INFO     | __main__:process_row_for_body:124 - Row 647: Found 7 issues in body: ['28714', '28737', '28791', '29064', '29074', '29273', '29367']
# 2025-06-06 11:44:08.354 | INFO     | __main__:process_row_for_body:124 - Row 648: Found 2 issues in body: ['19981', '20092']
# 2025-06-06 11:44:08.356 | INFO     | __main__:process_row_for_body:124 - Row 649: Found 1 issues in body: ['28285']
# 2025-06-06 11:44:08.357 | INFO     | __main__:process_row_for_body:124 - Row 651: Found 1 issues in body: ['19954']
# 2025-06-06 11:44:08.360 | INFO     | __main__:process_row_for_body:124 - Row 652: Found 5 issues in body: ['26044', '29392', '29450', '29455', '29561']
# 2025-06-06 11:44:08.361 | INFO     | __main__:process_row_for_body:124 - Row 653: Found 1 issues in body: ['19216']
# 2025-06-06 11:44:08.363 | INFO     | __main__:process_row_for_body:124 - Row 654: Found 2 issues in body: ['26856', '29133']
# 2025-06-06 11:44:08.366 | INFO     | __main__:process_row_for_body:124 - Row 656: Found 1 issues in body: ['20129']
# 2025-06-06 11:44:08.368 | INFO     | __main__:process_row_for_body:124 - Row 657: Found 1 issues in body: ['29435']
# 2025-06-06 11:44:08.371 | INFO     | __main__:process_row_for_body:124 - Row 659: Found 3 issues in body: ['18449', '18505', '19224']
# 2025-06-06 11:44:08.373 | INFO     | __main__:process_row_for_body:124 - Row 660: Found 1 issues in body: ['19188']
# 2025-06-06 11:44:08.376 | INFO     | __main__:process_row_for_body:124 - Row 661: Found 1 issues in body: ['29703']
# 2025-06-06 11:44:08.378 | INFO     | __main__:process_row_for_body:124 - Row 663: Found 1 issues in body: ['29703']
# 2025-06-06 11:44:08.380 | INFO     | __main__:process_row_for_body:124 - Row 664: Found 1 issues in body: ['20153']
# 2025-06-06 11:44:08.383 | INFO     | __main__:process_row_for_body:124 - Row 665: Found 1 issues in body: ['15800']
# 2025-06-06 11:44:08.385 | INFO     | __main__:process_row_for_body:124 - Row 667: Found 1 issues in body: ['20153']
# 2025-06-06 11:44:08.387 | INFO     | __main__:process_row_for_body:124 - Row 668: Found 1 issues in body: ['29703']
# 2025-06-06 11:44:08.391 | INFO     | __main__:process_row_for_body:124 - Row 670: Found 2 issues in body: ['28855', '29100']
# 2025-06-06 11:44:08.393 | INFO     | __main__:process_row_for_body:124 - Row 671: Found 1 issues in body: ['14214']
# 2025-06-06 11:44:08.396 | INFO     | __main__:process_row_for_body:124 - Row 673: Found 8 issues in body: ['25153', '25154', '28194', '28207', '28297', '28970', '28979', '29022']
# 2025-06-06 11:44:08.398 | INFO     | __main__:process_row_for_body:124 - Row 674: Found 1 issues in body: ['19104']
# 2025-06-06 11:44:08.400 | INFO     | __main__:process_row_for_body:124 - Row 675: Found 1 issues in body: ['19105']
# 2025-06-06 11:44:08.428 | INFO     | __main__:process_row_for_body:124 - Row 686: Found 2 issues in body: ['23532', '23577']
# 2025-06-06 11:44:08.408 | INFO     | __main__:process_row_for_body:124 - Row 678: Found 1 issues in body: ['20159']
# 2025-06-06 11:44:08.411 | INFO     | __main__:process_row_for_body:124 - Row 679: Found 1 issues in body: ['28876']
# 2025-06-06 11:44:08.414 | INFO     | __main__:process_row_for_body:124 - Row 681: Found 1 issues in body: ['20160']
# 2025-06-06 11:44:08.416 | INFO     | __main__:process_row_for_body:124 - Row 682: Found 1 issues in body: ['20832']
# 2025-06-06 11:44:08.418 | INFO     | __main__:process_row_for_body:124 - Row 684: Found 1 issues in body: ['22213']
# 2025-06-06 11:44:08.420 | INFO     | __main__:process_row_for_body:124 - Row 685: Found 1 issues in body: ['24534']
# 2025-06-06 11:44:08.406 | INFO     | __main__:process_row_for_body:124 - Row 676: Found 8 issues in body: ['8203', '14242', '14816', '15100', '15118', '15120', '15139', '15158']
# 2025-06-06 11:44:08.436 | INFO     | __main__:process_row_for_body:124 - Row 688: Found 2 issues in body: ['23816', '24564']
# 2025-06-06 11:44:08.458 | INFO     | __main__:process_row_for_body:124 - Row 693: Found 1 issues in body: ['24393']
# 2025-06-06 11:44:08.461 | INFO     | __main__:process_row_for_body:124 - Row 694: Found 2 issues in body: ['24293', '24388']
# 2025-06-06 11:44:08.463 | INFO     | __main__:process_row_for_body:124 - Row 695: Found 1 issues in body: ['20832']
# 2025-06-06 11:44:08.464 | INFO     | __main__:process_row_for_body:124 - Row 696: Found 1 issues in body: ['24606']
# 2025-06-06 11:44:08.466 | INFO     | __main__:process_row_for_body:124 - Row 698: Found 1 issues in body: ['24566']
# 2025-06-06 11:44:08.468 | INFO     | __main__:process_row_for_body:124 - Row 700: Found 2 issues in body: ['21652', '21676']
# 2025-06-06 11:44:08.475 | INFO     | __main__:process_row_for_body:124 - Row 702: Found 1 issues in body: ['24421']
# Processing PR Bodies:   3%|▎         | 717/25042 [00:00<00:34, 699.24it/s]2025-06-06 11:44:08.478 | INFO     | __main__:process_row_for_body:124 - Row 703: Found 1 issues in body: ['20832']
# 2025-06-06 11:44:08.482 | INFO     | __main__:process_row_for_body:124 - Row 708: Found 1 issues in body: ['20825']
# 2025-06-06 11:44:08.485 | INFO     | __main__:process_row_for_body:124 - Row 711: Found 1 issues in body: ['11178']
# 2025-06-06 11:44:08.489 | INFO     | __main__:process_row_for_body:124 - Row 717: Found 1 issues in body: ['11046']
# 2025-06-06 11:44:08.491 | INFO     | __main__:process_row_for_body:124 - Row 718: Found 1 issues in body: ['11152']
# 2025-06-06 11:44:08.494 | INFO     | __main__:process_row_for_body:124 - Row 720: Found 1 issues in body: ['12703']
# 2025-06-06 11:44:08.499 | INFO     | __main__:process_row_for_body:124 - Row 726: Found 1 issues in body: ['10909']
# 2025-06-06 11:44:08.502 | INFO     | __main__:process_row_for_body:124 - Row 731: Found 1 issues in body: ['10723']
# 2025-06-06 11:44:08.505 | INFO     | __main__:process_row_for_body:124 - Row 736: Found 1 issues in body: ['11165']
# 2025-06-06 11:44:08.507 | INFO     | __main__:process_row_for_body:124 - Row 747: Found 3 issues in body: ['12256', '12369', '12387']
# 2025-06-06 11:44:08.512 | INFO     | __main__:process_row_for_body:124 - Row 752: Found 1 issues in body: ['5210']
# 2025-06-06 11:44:08.514 | INFO     | __main__:process_row_for_body:124 - Row 753: Found 1 issues in body: ['9983']
# 2025-06-06 11:44:08.519 | INFO     | __main__:process_row_for_body:124 - Row 758: Found 1 issues in body: ['12755']
# 2025-06-06 11:44:08.524 | INFO     | __main__:process_row_for_body:124 - Row 761: Found 1 issues in body: ['12220']
# 2025-06-06 11:44:08.529 | INFO     | __main__:process_row_for_body:124 - Row 773: Found 1 issues in body: ['11014']
# 2025-06-06 11:44:08.532 | INFO     | __main__:process_row_for_body:124 - Row 775: Found 1 issues in body: ['8398']
# 2025-06-06 11:44:08.534 | INFO     | __main__:process_row_for_body:124 - Row 779: Found 1 issues in body: ['6890']
# 2025-06-06 11:44:08.539 | INFO     | __main__:process_row_for_body:124 - Row 785: Found 1 issues in body: ['7747']
# 2025-06-06 11:44:08.541 | INFO     | __main__:process_row_for_body:124 - Row 787: Found 1 issues in body: ['11186']
# 2025-06-06 11:44:08.545 | INFO     | __main__:process_row_for_body:124 - Row 794: Found 1 issues in body: ['9902']
# 2025-06-06 11:44:08.548 | INFO     | __main__:process_row_for_body:124 - Row 796: Found 1 issues in body: ['32673']
# 2025-06-06 11:44:08.550 | INFO     | __main__:process_row_for_body:124 - Row 798: Found 1 issues in body: ['40343']
# 2025-06-06 11:44:08.555 | INFO     | __main__:process_row_for_body:124 - Row 799: Found 1 issues in body: ['32676']
# 2025-06-06 11:44:08.559 | INFO     | __main__:process_row_for_body:124 - Row 801: Found 1 issues in body: ['40277']
# 2025-06-06 11:44:08.562 | INFO     | __main__:process_row_for_body:124 - Row 802: Found 1 issues in body: ['32676']
# 2025-06-06 11:44:08.566 | INFO     | __main__:process_row_for_body:124 - Row 805: Found 1 issues in body: ['40315']
# 2025-06-06 11:44:08.569 | INFO     | __main__:process_row_for_body:124 - Row 807: Found 1 issues in body: ['32214']
# 2025-06-06 11:44:08.571 | INFO     | __main__:process_row_for_body:124 - Row 808: Found 1 issues in body: ['35488']
# 2025-06-06 11:44:08.573 | INFO     | __main__:process_row_for_body:124 - Row 809: Found 1 issues in body: ['31791']
# 2025-06-06 11:44:08.576 | INFO     | __main__:process_row_for_body:124 - Row 810: Found 3 issues in body: ['38072', '38826', '38968']
# 2025-06-06 11:44:08.578 | INFO     | __main__:process_row_for_body:124 - Row 811: Found 1 issues in body: ['32653']
# 2025-06-06 11:44:08.581 | INFO     | __main__:process_row_for_body:124 - Row 812: Found 1 issues in body: ['40120']
# Processing PR Bodies:   3%|▎         | 813/25042 [00:01<00:31, 760.77it/s]2025-06-06 11:44:08.584 | INFO     | __main__:process_row_for_body:124 - Row 813: Found 1 issues in body: ['32567']
# 2025-06-06 11:44:08.588 | INFO     | __main__:process_row_for_body:124 - Row 814: Found 1 issues in body: ['34034']
# 2025-06-06 11:44:08.590 | INFO     | __main__:process_row_for_body:124 - Row 816: Found 2 issues in body: ['32613', '32658']
# 2025-06-06 11:44:08.592 | INFO     | __main__:process_row_for_body:124 - Row 817: Found 1 issues in body: ['36559']
# 2025-06-06 11:44:08.594 | INFO     | __main__:process_row_for_body:124 - Row 818: Found 1 issues in body: ['31719']
# 2025-06-06 11:44:08.598 | INFO     | __main__:process_row_for_body:124 - Row 819: Found 1 issues in body: ['36810']
# 2025-06-06 11:44:08.601 | INFO     | __main__:process_row_for_body:124 - Row 822: Found 1 issues in body: ['32653']
# 2025-06-06 11:44:08.605 | INFO     | __main__:process_row_for_body:124 - Row 824: Found 1 issues in body: ['31449']
# 2025-06-06 11:44:08.606 | INFO     | __main__:process_row_for_body:124 - Row 825: Found 1 issues in body: ['39882']
# 2025-06-06 11:44:08.610 | INFO     | __main__:process_row_for_body:124 - Row 826: Found 1 issues in body: ['32098']
# 2025-06-06 11:44:08.610 | INFO     | __main__:process_row_for_body:124 - Row 827: Found 1 issues in body: ['36810']
# 2025-06-06 11:44:08.610 | INFO     | __main__:process_row_for_body:124 - Row 828: Found 2 issues in body: ['32133', '32730']
# 2025-06-06 11:44:08.610 | INFO     | __main__:process_row_for_body:124 - Row 831: Found 2 issues in body: ['36543', '38120']
# 2025-06-06 11:44:08.618 | INFO     | __main__:process_row_for_body:124 - Row 832: Found 3 issues in body: ['30378', '32555', '32753']
# 2025-06-06 11:44:08.638 | INFO     | __main__:process_row_for_body:124 - Row 833: Found 31 issues in body: ['13', '8704', '12727', '12930', '13023', '13036', '13037', '13058', '13117', '13123', '13124', '13141', '13142', '13156', '13177', '13179', '13181', '13184', '13188', '13190', '13191', '13194', '13202', '13203', '13207', '13211', '13217', '13226', '13235', '13240', '13242']
# 2025-06-06 11:44:08.642 | INFO     | __main__:process_row_for_body:124 - Row 834: Found 2 issues in body: ['28983', '31197']
# 2025-06-06 11:44:08.645 | INFO     | __main__:process_row_for_body:124 - Row 835: Found 1 issues in body: ['40299']
# 2025-06-06 11:44:08.647 | INFO     | __main__:process_row_for_body:124 - Row 836: Found 1 issues in body: ['32652']
# 2025-06-06 11:44:08.650 | INFO     | __main__:process_row_for_body:124 - Row 837: Found 1 issues in body: ['40291']
# 2025-06-06 11:44:08.653 | INFO     | __main__:process_row_for_body:124 - Row 839: Found 1 issues in body: ['32675']
# 2025-06-06 11:44:08.656 | INFO     | __main__:process_row_for_body:124 - Row 840: Found 2 issues in body: ['32940', '35179']
# 2025-06-06 11:44:08.661 | INFO     | __main__:process_row_for_body:124 - Row 842: Found 1 issues in body: ['40324']
# ...
# 2025-06-06 11:45:03.040 | INFO     | __main__:process_row_for_body:124 - Row 24797: Found 2 issues in body: ['27804', '29287']
# 2025-06-06 11:45:03.088 | INFO     | __main__:process_row_for_body:124 - Row 24809: Found 1 issues in body: ['35347']
# 2025-06-06 11:45:03.051 | INFO     | __main__:process_row_for_body:124 - Row 24800: Found 1 issues in body: ['40']
# 2025-06-06 11:45:03.056 | INFO     | __main__:process_row_for_body:124 - Row 24801: Found 1 issues in body: ['12363']
# 2025-06-06 11:45:03.058 | INFO     | __main__:process_row_for_body:124 - Row 24802: Found 1 issues in body: ['167']
# 2025-06-06 11:45:03.064 | INFO     | __main__:process_row_for_body:124 - Row 24804: Found 1 issues in body: ['25139']
# 2025-06-06 11:45:03.071 | INFO     | __main__:process_row_for_body:124 - Row 24806: Found 1 issues in body: ['29274']
# 2025-06-06 11:45:03.076 | INFO     | __main__:process_row_for_body:124 - Row 24807: Found 1 issues in body: ['39893']
# 2025-06-06 11:45:03.047 | INFO     | __main__:process_row_for_body:124 - Row 24799: Found 1 issues in body: ['36810']
# 2025-06-06 11:45:03.093 | INFO     | __main__:process_row_for_body:124 - Row 24810: Found 2 issues in body: ['20164', '20644']
# 2025-06-06 11:45:03.106 | INFO     | __main__:process_row_for_body:124 - Row 24812: Found 1 issues in body: ['40262']
# 2025-06-06 11:45:03.110 | INFO     | __main__:process_row_for_body:124 - Row 24814: Found 1 issues in body: ['29309']
# 2025-06-06 11:45:03.117 | INFO     | __main__:process_row_for_body:124 - Row 24817: Found 1 issues in body: ['25441']
# 2025-06-06 11:45:03.122 | INFO     | __main__:process_row_for_body:124 - Row 24818: Found 1 issues in body: ['29113']
# 2025-06-06 11:45:03.126 | INFO     | __main__:process_row_for_body:124 - Row 24819: Found 1 issues in body: ['11239']
# 2025-06-06 11:45:03.130 | INFO     | __main__:process_row_for_body:124 - Row 24820: Found 2 issues in body: ['17749', '21303']
# 2025-06-06 11:45:03.138 | INFO     | __main__:process_row_for_body:124 - Row 24822: Found 2 issues in body: ['35546', '35548']
# 2025-06-06 11:45:03.144 | INFO     | __main__:process_row_for_body:124 - Row 24824: Found 2 issues in body: ['25833', '25873']
# Processing PR Bodies:  99%|█████████▉| 24826/25042 [00:55<00:00, 292.14it/s]2025-06-06 11:45:03.149 | INFO     | __main__:process_row_for_body:124 - Row 24826: Found 1 issues in body: ['24922']
# 2025-06-06 11:45:03.154 | INFO     | __main__:process_row_for_body:124 - Row 24827: Found 1 issues in body: ['4366']
# 2025-06-06 11:45:03.158 | INFO     | __main__:process_row_for_body:124 - Row 24828: Found 2 issues in body: ['36559', '36984']
# 2025-06-06 11:45:03.165 | INFO     | __main__:process_row_for_body:124 - Row 24829: Found 1 issues in body: ['26659']
# 2025-06-06 11:45:03.170 | INFO     | __main__:process_row_for_body:124 - Row 24830: Found 1 issues in body: ['29325']
# 2025-06-06 11:45:03.174 | INFO     | __main__:process_row_for_body:124 - Row 24831: Found 1 issues in body: ['19347']
# 2025-06-06 11:45:03.179 | INFO     | __main__:process_row_for_body:124 - Row 24833: Found 1 issues in body: ['40264']
# 2025-06-06 11:45:03.184 | INFO     | __main__:process_row_for_body:124 - Row 24834: Found 1 issues in body: ['28959']
# 2025-06-06 11:45:03.234 | INFO     | __main__:process_row_for_body:124 - Row 24848: Found 1 issues in body: ['23691']
# 2025-06-06 11:45:03.196 | INFO     | __main__:process_row_for_body:124 - Row 24838: Found 1 issues in body: ['24259']
# 2025-06-06 11:45:03.201 | INFO     | __main__:process_row_for_body:124 - Row 24839: Found 1 issues in body: ['29239']
# 2025-06-06 11:45:03.204 | INFO     | __main__:process_row_for_body:124 - Row 24840: Found 1 issues in body: ['11312']
# 2025-06-06 11:45:03.209 | INFO     | __main__:process_row_for_body:124 - Row 24841: Found 1 issues in body: ['4367']
# 2025-06-06 11:45:03.215 | INFO     | __main__:process_row_for_body:124 - Row 24845: Found 1 issues in body: ['28172']
# 2025-06-06 11:45:03.229 | INFO     | __main__:process_row_for_body:124 - Row 24846: Found 1 issues in body: ['26621']
# 2025-06-06 11:45:03.191 | INFO     | __main__:process_row_for_body:124 - Row 24837: Found 1 issues in body: ['26601']
# 2025-06-06 11:45:03.244 | INFO     | __main__:process_row_for_body:124 - Row 24849: Found 1 issues in body: ['40163']
# 2025-06-06 11:45:03.249 | INFO     | __main__:process_row_for_body:124 - Row 24851: Found 1 issues in body: ['26636']
# 2025-06-06 11:45:03.253 | INFO     | __main__:process_row_for_body:124 - Row 24852: Found 1 issues in body: ['10584']
# 2025-06-06 11:45:03.257 | INFO     | __main__:process_row_for_body:124 - Row 24853: Found 1 issues in body: ['40262']
# Processing PR Bodies:  99%|█████████▉| 24856/25042 [00:55<00:00, 278.16it/s]2025-06-06 11:45:03.262 | INFO     | __main__:process_row_for_body:124 - Row 24854: Found 1 issues in body: ['28128']
# 2025-06-06 11:45:03.270 | INFO     | __main__:process_row_for_body:124 - Row 24856: Found 1 issues in body: ['29073']
# 2025-06-06 11:45:03.275 | INFO     | __main__:process_row_for_body:124 - Row 24858: Found 1 issues in body: ['25196']
# 2025-06-06 11:45:03.279 | INFO     | __main__:process_row_for_body:124 - Row 24859: Found 1 issues in body: ['40012']
# 2025-06-06 11:45:03.282 | INFO     | __main__:process_row_for_body:124 - Row 24860: Found 1 issues in body: ['37541']
# 2025-06-06 11:45:03.288 | INFO     | __main__:process_row_for_body:124 - Row 24862: Found 1 issues in body: ['1163']
# 2025-06-06 11:45:03.302 | INFO     | __main__:process_row_for_body:124 - Row 24869: Found 2 issues in body: ['29161', '29426']
# 2025-06-06 11:45:03.307 | INFO     | __main__:process_row_for_body:124 - Row 24871: Found 1 issues in body: ['12748']
# 2025-06-06 11:45:03.312 | INFO     | __main__:process_row_for_body:124 - Row 24873: Found 2 issues in body: ['40119', '40215']
# 2025-06-06 11:45:03.318 | INFO     | __main__:process_row_for_body:124 - Row 24877: Found 1 issues in body: ['16625']
# 2025-06-06 11:45:03.322 | INFO     | __main__:process_row_for_body:124 - Row 24882: Found 1 issues in body: ['7700']
# 2025-06-06 11:45:03.326 | INFO     | __main__:process_row_for_body:124 - Row 24884: Found 2 issues in body: ['13171', '14480']
# 2025-06-06 11:45:03.329 | INFO     | __main__:process_row_for_body:124 - Row 24885: Found 1 issues in body: ['5024']
# 2025-06-06 11:45:03.346 | INFO     | __main__:process_row_for_body:124 - Row 24892: Found 12 issues in body: ['6222', '6232', '6240', '6263', '6267', '6281', '6290', '6297', '6301', '6385', '6441', '6480']
# 2025-06-06 11:45:03.355 | INFO     | __main__:process_row_for_body:124 - Row 24897: Found 3 issues in body: ['13950', '16922', '17645']
# Processing PR Bodies:  99%|█████████▉| 24913/25042 [00:55<00:00, 349.34it/s]2025-06-06 11:45:03.360 | INFO     | __main__:process_row_for_body:124 - Row 24902: Found 2 issues in body: ['17743', '17780']
# 2025-06-06 11:45:03.365 | INFO     | __main__:process_row_for_body:124 - Row 24906: Found 3 issues in body: ['13758', '13769', '14673']
# 2025-06-06 11:45:03.370 | INFO     | __main__:process_row_for_body:124 - Row 24908: Found 1 issues in body: ['17929']
# 2025-06-06 11:45:03.374 | INFO     | __main__:process_row_for_body:124 - Row 24911: Found 1 issues in body: ['4338']
# 2025-06-06 11:45:03.392 | INFO     | __main__:process_row_for_body:124 - Row 24913: Found 24 issues in body: ['5998', '6124', '6143', '6159', '6180', '6186', '6193', '6203', '6209', '6222', '6232', '6236', '6238', '6240', '6245', '6263', '6267', '6281', '6290', '6297', '6301', '6385', '6441', '6480']
# 2025-06-06 11:45:03.401 | INFO     | __main__:process_row_for_body:124 - Row 24919: Found 1 issues in body: ['4275']
# 2025-06-06 11:45:03.405 | INFO     | __main__:process_row_for_body:124 - Row 24921: Found 1 issues in body: ['17669']
# 2025-06-06 11:45:03.416 | INFO     | __main__:process_row_for_body:124 - Row 24925: Found 1 issues in body: ['4086']
# 2025-06-06 11:45:03.423 | INFO     | __main__:process_row_for_body:124 - Row 24926: Found 3 issues in body: ['803', '815', '818']
# 2025-06-06 11:45:03.431 | INFO     | __main__:process_row_for_body:124 - Row 24927: Found 1 issues in body: ['3333']
# 2025-06-06 11:45:03.440 | INFO     | __main__:process_row_for_body:124 - Row 24936: Found 1 issues in body: ['14003']
# 2025-06-06 11:45:03.446 | INFO     | __main__:process_row_for_body:124 - Row 24941: Found 1 issues in body: ['17262']
# 2025-06-06 11:45:03.449 | INFO     | __main__:process_row_for_body:124 - Row 24942: Found 1 issues in body: ['6851']
# 2025-06-06 11:45:03.456 | INFO     | __main__:process_row_for_body:124 - Row 24951: Found 3 issues in body: ['4569', '12035', '15818']
# 2025-06-06 11:45:03.460 | INFO     | __main__:process_row_for_body:124 - Row 24952: Found 1 issues in body: ['4530']
# 2025-06-06 11:45:03.466 | INFO     | __main__:process_row_for_body:124 - Row 24956: Found 1 issues in body: ['16625']
# 2025-06-06 11:45:03.471 | INFO     | __main__:process_row_for_body:124 - Row 24958: Found 3 issues in body: ['4878', '15031', '15035']
# Processing PR Bodies: 100%|█████████▉| 24969/25042 [00:55<00:00, 402.24it/s]2025-06-06 11:45:03.474 | INFO     | __main__:process_row_for_body:124 - Row 24961: Found 1 issues in body: ['10721']
# 2025-06-06 11:45:03.477 | INFO     | __main__:process_row_for_body:124 - Row 24962: Found 1 issues in body: ['12949']
# 2025-06-06 11:45:03.484 | INFO     | __main__:process_row_for_body:124 - Row 24967: Found 1 issues in body: ['17763']
# 2025-06-06 11:45:03.490 | INFO     | __main__:process_row_for_body:124 - Row 24969: Found 1 issues in body: ['4556']
# 2025-06-06 11:45:03.494 | INFO     | __main__:process_row_for_body:124 - Row 24970: Found 2 issues in body: ['14415', '14479']
# 2025-06-06 11:45:03.501 | INFO     | __main__:process_row_for_body:124 - Row 24975: Found 1 issues in body: ['14352']
# 2025-06-06 11:45:03.508 | INFO     | __main__:process_row_for_body:124 - Row 24981: Found 1 issues in body: ['17794']
# 2025-06-06 11:45:03.512 | INFO     | __main__:process_row_for_body:124 - Row 24986: Found 1 issues in body: ['18995']
# 2025-06-06 11:45:03.518 | INFO     | __main__:process_row_for_body:124 - Row 24988: Found 1 issues in body: ['18881']
# 2025-06-06 11:45:03.523 | INFO     | __main__:process_row_for_body:124 - Row 24991: Found 1 issues in body: ['24405']
# 2025-06-06 11:45:03.527 | INFO     | __main__:process_row_for_body:124 - Row 24992: Found 1 issues in body: ['22236']
# 2025-06-06 11:45:03.530 | INFO     | __main__:process_row_for_body:124 - Row 24993: Found 1 issues in body: ['20499']
# 2025-06-06 11:45:03.534 | INFO     | __main__:process_row_for_body:124 - Row 24995: Found 1 issues in body: ['23233']
# 2025-06-06 11:45:03.538 | INFO     | __main__:process_row_for_body:124 - Row 24997: Found 1 issues in body: ['22543']
# 2025-06-06 11:45:03.542 | INFO     | __main__:process_row_for_body:124 - Row 24998: Found 1 issues in body: ['22248']
# 2025-06-06 11:45:03.546 | INFO     | __main__:process_row_for_body:124 - Row 25000: Found 1 issues in body: ['3751']
# 2025-06-06 11:45:03.551 | INFO     | __main__:process_row_for_body:124 - Row 25002: Found 3 issues in body: ['21850', '22201', '22209']
# 2025-06-06 11:45:03.554 | INFO     | __main__:process_row_for_body:124 - Row 25003: Found 1 issues in body: ['23621']
# 2025-06-06 11:45:03.557 | INFO     | __main__:process_row_for_body:124 - Row 25004: Found 1 issues in body: ['24542']
# 2025-06-06 11:45:03.558 | INFO     | __main__:process_row_for_body:124 - Row 25005: Found 1 issues in body: ['24585']
# 2025-06-06 11:45:03.563 | INFO     | __main__:process_row_for_body:124 - Row 25006: Found 1 issues in body: ['21862']
# 2025-06-06 11:45:03.568 | INFO     | __main__:process_row_for_body:124 - Row 25010: Found 1 issues in body: ['24540']
# 2025-06-06 11:45:03.572 | INFO     | __main__:process_row_for_body:124 - Row 25011: Found 1 issues in body: ['24879']
# 2025-06-06 11:45:03.575 | INFO     | __main__:process_row_for_body:124 - Row 25012: Found 1 issues in body: ['19229']
# 2025-06-06 11:45:03.580 | INFO     | __main__:process_row_for_body:124 - Row 25014: Found 1 issues in body: ['16030']
# 2025-06-06 11:45:03.580 | INFO     | __main__:process_row_for_body:124 - Row 25015: Found 1 issues in body: ['19893']
# 2025-06-06 11:45:03.587 | INFO     | __main__:process_row_for_body:124 - Row 25017: Found 1 issues in body: ['19898']
# Processing PR Bodies: 100%|█████████▉| 25018/25042 [00:56<00:00, 422.40it/s]2025-06-06 11:45:03.590 | INFO     | __main__:process_row_for_body:124 - Row 25019: Found 1 issues in body: ['19896']
# 2025-06-06 11:45:03.593 | INFO     | __main__:process_row_for_body:124 - Row 25020: Found 1 issues in body: ['19169']
# 2025-06-06 11:45:03.596 | INFO     | __main__:process_row_for_body:124 - Row 25021: Found 1 issues in body: ['19690']
# 2025-06-06 11:45:03.599 | INFO     | __main__:process_row_for_body:124 - Row 25022: Found 1 issues in body: ['19883']
# 2025-06-06 11:45:03.668 | INFO     | __main__:process_row_for_body:124 - Row 25038: Found 2 issues in body: ['17892', '19262']
# 2025-06-06 11:45:03.675 | INFO     | __main__:process_row_for_body:124 - Row 25039: Found 1 issues in body: ['13811']
# 2025-06-06 11:45:03.612 | INFO     | __main__:process_row_for_body:124 - Row 25026: Found 1 issues in body: ['19895']
# 2025-06-06 11:45:03.623 | INFO     | __main__:process_row_for_body:124 - Row 25032: Found 1 issues in body: ['18789']
# 2025-06-06 11:45:03.653 | INFO     | __main__:process_row_for_body:124 - Row 25033: Found 1 issues in body: ['19699']
# 2025-06-06 11:45:03.660 | INFO     | __main__:process_row_for_body:124 - Row 25036: Found 1 issues in body: ['19304']
# 2025-06-06 11:45:03.664 | INFO     | __main__:process_row_for_body:124 - Row 25037: Found 1 issues in body: ['19939']
# 2025-06-06 11:45:03.604 | INFO     | __main__:process_row_for_body:124 - Row 25023: Found 1 issues in body: ['19883']
# 2025-06-06 11:45:03.607 | INFO     | __main__:process_row_for_body:124 - Row 25024: Found 1 issues in body: ['19291']
# 2025-06-06 11:45:03.679 | INFO     | __main__:process_row_for_body:124 - Row 25040: Found 2 issues in body: ['19799', '20023']
# 2025-06-06 11:45:03.683 | INFO     | __main__:process_row_for_body:124 - Row 25041: Found 1 issues in body: ['18956']
# Processing PR Bodies: 100%|██████████| 25042/25042 [00:56<00:00, 446.08it/s]
# 2025-06-06 11:45:03.744 | INFO     | __main__:run_body_extraction:186 - Creating new DataFrame with 30058 records from body extraction
# 2025-06-06 11:45:03.878 | INFO     | __main__:run_body_extraction:192 - Saving body extraction results to: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues_from_body.csv
# 2025-06-06 11:45:07.763 | INFO     | __main__:run_body_extraction:203 - ==================================================
# 2025-06-06 11:45:07.766 | INFO     | __main__:run_body_extraction:204 - PR BODY EXTRACTION PROCESSING SUMMARY
# 2025-06-06 11:45:07.767 | INFO     | __main__:run_body_extraction:205 - ==================================================
# 2025-06-06 11:45:07.769 | INFO     | __main__:run_body_extraction:206 - Original rows processed: 25042
# 2025-06-06 11:45:07.772 | INFO     | __main__:run_body_extraction:207 - New rows generated (from body): 30058
# 2025-06-06 11:45:07.774 | INFO     | __main__:run_body_extraction:208 - Rows with issues found in body: 15565
# 2025-06-06 11:45:07.776 | INFO     | __main__:run_body_extraction:209 - Unique issues extracted from body: 11253
# 2025-06-06 11:45:07.778 | INFO     | __main__:run_body_extraction:211 - Expansion ratio (body): 1.20x
# 2025-06-06 11:45:07.785 | INFO     | __main__:run_body_extraction:212 - Output file (body extraction): ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues_from_body.csv
# 2025-06-06 11:45:07.788 | INFO     | __main__:run_body_extraction:213 - ==================================================
# ✅ PR Body issue extraction completed successfully!
# 📊 Original rows: 25042
# 📊 New rows (from body): 30058
# 📊 Rows with issues found in body: 15565
# 📊 Unique issues found in body: 11253
# 💾 Output saved to: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues_from_body.csv
