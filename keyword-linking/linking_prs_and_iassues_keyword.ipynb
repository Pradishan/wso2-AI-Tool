# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

import re
import pandas as pd
from tqdm import tqdm
from loguru import logger
from pymongo import MongoClient
import requests 
import time 
import concurrent.futures

# GitHub Personal Access Token (optional, but recommended for higher rate limits)
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")
if not GITHUB_TOKEN:
    logger.warning("GitHub token not found. Rate limits may apply.")

BATCH_SIZE = 500 # Number of records to process before writing to CSV

# Logger config
logger.add("logs/pr-to-issues-keyword.log")
# Out:
# 3

# %% [markdown]
# # Initial data set

# %% [markdown]
# mongoDB connection

# %%
# Mongo connection
client = MongoClient("mongodb://localhost:27017/")
db = client.github_data
pull_request_collection = db.pull_requests
logger.info("🔌 MongoDB connected.")
# Out:
# 2025-06-03 15:08:35.844 | INFO     | __main__:<module>:5 - 🔌 MongoDB connected.

# %%
# Query to filter closed pull requests
qurey = {
    "pull_request.state": "closed",
}

# Fetch all records into a list to prevent cursor timeout during processing
logger.info("Fetching all records from MongoDB...")
all_records_list = list(pull_request_collection.find(qurey))
toal_pull_request_count = len(all_records_list) # Actual number of records fetched
logger.info(f"Successfully fetched {toal_pull_request_count} records.")
# Out:
# 2025-06-03 15:08:41.198 | INFO     | __main__:<module>:7 - Fetching all records from MongoDB...
# 2025-06-03 15:09:04.007 | INFO     | __main__:<module>:10 - Successfully fetched 25042 records.

# %%
pr_details_list = [] # List to store dictionaries of PR details

def extract_pr_details(record):
    """
    Extracts relevant details (number, link, title, body) from a pull request record.
    """
    pr_data = record.get("pull_request", {})
    # Handle cases where 'pull_request' key might be missing or empty
    if not pr_data: 
        logger.warning(f"Skipping record due to missing 'pull_request' data. Record ID: {record.get('_id', 'N/A')}")
        return None

    pr_number = pr_data.get("number")
    pr_link = pr_data.get("html_url", None)
    pr_title = pr_data.get("title", None)
    # Use "body" for description as it's the common field for PR description
    pr_body = pr_data.get("body", None) 

    if pr_number is None:
        logger.warning(f"Skipping record due to missing PR number. Record ID: {record.get('_id', 'N/A')}")
        return None

    return {
        "pr_number": pr_number,
        "pr_link": pr_link,
        "pr_title": pr_title,
        "pr_body": pr_body, # "description" in user request, mapped to "body"
    }

# Use ThreadPoolExecutor for processing records concurrently
# os.cpu_count() provides a sensible default for max_workers
# Adjust max_workers based on specific I/O vs CPU characteristics if needed
logger.info(f"Starting extraction of PR details for {toal_pull_request_count} records using concurrent.futures...")

with concurrent.futures.ThreadPoolExecutor(max_workers=os.cpu_count()) as executor:
    # Submit all tasks to the executor
    future_to_record = {executor.submit(extract_pr_details, record): record for record in all_records_list}
    
    # Process futures as they complete, with a progress bar
    for future in tqdm(concurrent.futures.as_completed(future_to_record), total=len(all_records_list), desc="Extracting PR Details"):
        record_for_future = future_to_record[future] # Get original record for logging in case of error
        try:
            result = future.result()
            if result:  # Add to list if extraction was successful (result is not None)
                pr_details_list.append(result)
        except Exception as exc:
            record_id = record_for_future.get("_id", "N/A")
            logger.error(f"Record ID {record_id} generated an exception during extraction: {exc}")

logger.info(f"Successfully processed all records. Extracted details for {len(pr_details_list)} pull requests.")
# Out:
# 2025-06-03 15:09:36.337 | INFO     | __main__:<module>:33 - Starting extraction of PR details for 25042 records using concurrent.futures...
# Extracting PR Details: 100%|██████████| 25042/25042 [00:00<00:00, 147144.03it/s]
# 2025-06-03 15:09:42.987 | INFO     | __main__:<module>:50 - Successfully processed all records. Extracted details for 25042 pull requests.

# %%
# Define the path for the output CSV file
output_csv_path = "../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv"

# Convert the list of dictionaries to a pandas DataFrame and save to CSV
if pr_details_list:
    df_prs = pd.DataFrame(pr_details_list)
    
    # Ensure the columns are in the desired order for the CSV
    # "description" from user request is mapped to "pr_body"
    csv_headers = ["pr_number", "pr_link", "pr_title", "pr_body"]
    df_prs = df_prs[csv_headers]

    try:
        # Save the DataFrame to CSV, overwriting if the file exists
        df_prs.to_csv(output_csv_path, index=False, mode='w')
        logger.info(f"Successfully saved PR details to {output_csv_path}")
    except Exception as e:
        logger.error(f"Failed to save PR details to CSV at {output_csv_path}: {e}")
else:
    logger.warning("No PR details were extracted (or all records were skipped). CSV file will not be created.")
# Out:
# 2025-06-03 15:10:25.477 | INFO     | __main__:<module>:16 - Successfully saved PR details to ../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv

# %% [markdown]
# # Key word processing

# %% [markdown]
# ## Title

# %%
import pandas as pd
import re
from loguru import logger
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
from typing import List, Tuple, Optional
import time


# Thread-safe lock for writing results
write_lock = threading.Lock()

csv_path = "../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv"

def extract_all_issue_numbers_from_title(title: str) -> List[str]:
    """
    Extracts all issue numbers from pull request title.
    Returns a list of issue numbers found.
    """
    if pd.isna(title) or not title.strip():
        return []

   # Covers: fix(es/ed/ing), clos(e/es/ed), resolv(e/es/ed), issue(s), Backport, Revert(s)
    keyword_pattern = r'\b(?:fix(?:es|ed|ing)?|clos(?:e|es|ed)|resolv(?:e|es|ed)|issue|Backport|Revert(?:s)?)\b'

   # Comprehensive patterns to find issue numbers, ordered by specificity
    issue_patterns = [
        # Priority 1: Keywords followed by colon and GitHub URL (most specific)
        rf'{keyword_pattern}:\s+https?://github\.com/[^/\s]+/[^/\s]+/(?:issues|pull)/(\d+)',
        
        # Priority 2: Keywords followed by full GitHub issue URL
        rf'{keyword_pattern}\s+https?://github\.com/[^/\s]+/[^/\s]+/(?:issues|pull)/(\d+)',
        
        # Priority 3: Keywords followed by repo path and issue number
        rf'{keyword_pattern}\s+[^/\s]+/[^/\s]+/issues/(\d+)',
        
        # Priority 4: Keywords + <text> + GitHub issue links + optional plain number
        rf'{keyword_pattern}.*<.*?>\s+https?://github\.com/[^/\s]+/[^/\s]+/(?:issues|pull)/(\d+)(?:\s+(\d+))*',
        
        # Priority 5: Keywords + <text> + multiple issue numbers
        rf'{keyword_pattern}.*<.*?>\s+#(\d+)(?:\s+#(\d+))*',
        
        # Priority 6: Keywords followed by square brackets
        rf'{keyword_pattern}.*\[#(\d+)\]',
        
        # Priority 7: Square brackets followed by keywords
        rf'\[#(\d+)\].*{keyword_pattern}',
        
        # Priority 8: Keywords followed by (from #number)
        rf'{keyword_pattern}.*\(from\s+#(\d+)\)',
        
        # Priority 9: Keywords followed by "part of #number" or "part of issue #number"
        rf'{keyword_pattern}.*part\s+of\s+(?:issue\s+)?#(\d+)',
        
        # Priority 10: Keywords followed by "/fix-#number" or "/fix-number"
        rf'{keyword_pattern}.*(?:/fix-#(\d+)|/fix-(\d+))',
        
        # Priority 11: Multiple issues in one line (e.g., "fixes #123, #456, #789")
        rf'{keyword_pattern}[^#]*?((?:#\d+(?:\s*,\s*#\d+)*)+)',
        
        # Priority 12: Keywords followed by any text and #number
        rf'{keyword_pattern}.*#(\d+)',
        
        # Priority 13: Keywords followed by #number (direct)
        rf'{keyword_pattern}\s+#(\d+)',
        
        # Priority 14: Keywords followed by plain number (no #)
        rf'{keyword_pattern}\s+(\d+)\b',
        
        # Priority 15: #number followed by keyword
        rf'#(\d+)\s+{keyword_pattern}',
        
        # Priority 16: Specific "Address review suggestions" pattern
        rf'Address\s+review\s+suggestions.*#(\d+)',
        
        # Priority 17: Multiple issue numbers after "issues" (e.g., "issues #1159 #947")
        r'\bissues?\s+#(\d+)(?:\s+#(\d+))*',
        
        # Priority 18: GitHub URLs without keywords (issues only, not pull requests)
        r'https?://github\.com/[^/\s]+/[^/\s]+/issues/(\d+)',
    ]

    found_issues = set()  # Use set to avoid duplicates
    
    for pattern in issue_patterns:
        matches = re.finditer(pattern, title, re.IGNORECASE)
        for match in matches:
            groups = match.groups()
            for group in groups:
                if group:
                    # Handle multiple issues in one match (e.g., "#123, #456")
                    if '#' in group:
                        issue_nums = re.findall(r'#(\d+)', group)
                        found_issues.update(issue_nums)
                    else:
                        found_issues.add(group)
    
    return list(found_issues)

def generate_issue_link(issue_number: str, pr_link: str) -> str:
    """
    Generate GitHub issue link based on issue number and PR link.
    Assumes same repository as the PR.
    """
    if not issue_number or not pr_link:
        return ""
    
    # Extract repository info from PR link
    # Example: https://github.com/owner/repo/pull/123 -> https://github.com/owner/repo/issues/456
    match = re.match(r'(https?://github\.com/[^/]+/[^/]+)/', pr_link)
    if match:
        repo_base = match.group(1)
        return f"{repo_base}/issues/{issue_number}"
    
    return ""

def process_row(row_data: Tuple[int, pd.Series]) -> List[dict]:
    """
    Process a single row and return list of records (one per issue found).
    """
    idx, row = row_data
    
    try:
        title = str(row.get('pr_title', ''))
        pr_link = str(row.get('pr_link', ''))
        
        # Extract all issue numbers from title
        issue_numbers = extract_all_issue_numbers_from_title(title)
        
        results = []
        
        if issue_numbers:
            # Create separate record for each issue found
            for issue_num in issue_numbers:
                issue_link = generate_issue_link(issue_num, pr_link)
                
                # Create new record with all original data plus extracted info
                new_record = row.to_dict()
                new_record.update({
                    'extracted_issue_number': issue_num,
                    'extracted_issue_link': issue_link,
                    'found_in_title': True,
                    'original_row_index': idx
                })
                results.append(new_record)
                
            logger.info(f"Row {idx}: Found {len(issue_numbers)} issues in title: {issue_numbers}")
        else:
            # No issues found, keep original record with null values
            new_record = row.to_dict()
            new_record.update({
                'extracted_issue_number': None,
                'extracted_issue_link': None,
                'found_in_title': False,
                'original_row_index': idx
            })
            results.append(new_record)
            
        return results
        
    except Exception as e:
        logger.error(f"Error processing row {idx}: {str(e)}")
        # Return original record with error info
        new_record = row.to_dict()
        new_record.update({
            'extracted_issue_number': None,
            'extracted_issue_link': None,
            'found_in_title': False,
            'original_row_index': idx,
            'processing_error': str(e)
        })
        return [new_record]

def run():
    """
    Main function to process the CSV and create new output file.
    """
    logger.info("Starting issue number extraction process")
    
    try:
        # Load the CSV file
        logger.info(f"Loading CSV file: {csv_path}")
        df = pd.read_csv(csv_path)
        logger.info(f"Loaded {len(df)} records from CSV")
        
        # Prepare data for parallel processing
        row_data = list(df.iterrows())
        
        # Process rows in parallel
        all_results = []
        
        logger.info("Starting parallel processing...")
        with ThreadPoolExecutor(max_workers=4) as executor:
            # Submit all tasks
            future_to_row = {executor.submit(process_row, row): row[0] for row in row_data}
            
            # Process completed tasks with progress bar
            for future in tqdm(as_completed(future_to_row), total=len(future_to_row), desc="Processing rows"):
                try:
                    row_results = future.result()
                    with write_lock:
                        all_results.extend(row_results)
                except Exception as e:
                    row_idx = future_to_row[future]
                    logger.error(f"Failed to process row {row_idx}: {str(e)}")
        
        # Create new DataFrame from results
        logger.info(f"Creating new DataFrame with {len(all_results)} records")
        new_df = pd.DataFrame(all_results)
        
        # Generate output filename
        output_path = csv_path.replace('.csv', '_with_extracted_issues.csv')
        
        # Save to new CSV
        logger.info(f"Saving results to: {output_path}")
        new_df.to_csv(output_path, index=False)
        
        # Log statistics
        total_original_rows = len(df)
        total_new_rows = len(new_df)
        rows_with_issues = len(new_df[new_df['found_in_title'] == True])
        unique_issues_found = len(new_df[new_df['extracted_issue_number'].notna()]['extracted_issue_number'].unique())
        
        logger.info("="*50)
        logger.info("PROCESSING SUMMARY")
        logger.info("="*50)
        logger.info(f"Original rows: {total_original_rows}")
        logger.info(f"New rows: {total_new_rows}")
        logger.info(f"Rows with issues found: {rows_with_issues}")
        logger.info(f"Unique issues extracted: {unique_issues_found}")
        logger.info(f"Expansion ratio: {total_new_rows/total_original_rows:.2f}x")
        logger.info(f"Output file: {output_path}")
        logger.info("="*50)
        
        print(f"\n✅ Processing completed successfully!")
        print(f"📊 Original rows: {total_original_rows}")
        print(f"📊 New rows: {total_new_rows}")
        print(f"📊 Rows with issues: {rows_with_issues}")
        print(f"📊 Unique issues found: {unique_issues_found}")
        print(f"💾 Output saved to: {output_path}")
        
        return new_df
        
    except Exception as e:
        logger.error(f"Fatal error in main process: {str(e)}")
        raise

run()
# Out:
# 2025-06-05 11:20:43.995 | INFO     | __main__:run:179 - Starting issue number extraction process
# 2025-06-05 11:20:43.995 | INFO     | __main__:run:183 - Loading CSV file: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv
# 2025-06-05 11:20:44.332 | INFO     | __main__:run:185 - Loaded 25042 records from CSV
# 2025-06-05 11:20:45.488 | INFO     | __main__:run:193 - Starting parallel processing...
# 2025-06-05 11:20:45.521 | INFO     | __main__:process_row:148 - Row 41: Found 1 issues in title: ['12492']
# 2025-06-05 11:20:45.531 | INFO     | __main__:process_row:148 - Row 89: Found 1 issues in title: ['12492']
# 2025-06-05 11:20:45.539 | INFO     | __main__:process_row:148 - Row 131: Found 1 issues in title: ['12584']
# 2025-06-05 11:20:45.549 | INFO     | __main__:process_row:148 - Row 218: Found 1 issues in title: ['3440']
# 2025-06-05 11:20:45.549 | INFO     | __main__:process_row:148 - Row 239: Found 1 issues in title: ['4581']
# 2025-06-05 11:20:45.549 | INFO     | __main__:process_row:148 - Row 250: Found 1 issues in title: ['4716']
# 2025-06-05 11:20:45.588 | INFO     | __main__:process_row:148 - Row 521: Found 1 issues in title: ['13']
# 2025-06-05 11:20:45.601 | INFO     | __main__:process_row:148 - Row 613: Found 1 issues in title: ['42950']
# 2025-06-05 11:20:45.616 | INFO     | __main__:process_row:148 - Row 753: Found 1 issues in title: ['9983']
# 2025-06-05 11:20:45.632 | INFO     | __main__:process_row:148 - Row 786: Found 1 issues in title: ['12394']
# 2025-06-05 11:20:45.633 | INFO     | __main__:process_row:148 - Row 866: Found 1 issues in title: ['4617']
# 2025-06-05 11:20:45.649 | INFO     | __main__:process_row:148 - Row 929: Found 1 issues in title: ['4637']
# 2025-06-05 11:20:45.691 | INFO     | __main__:process_row:148 - Row 1230: Found 1 issues in title: ['4992']
# 2025-06-05 11:20:45.717 | INFO     | __main__:process_row:148 - Row 1489: Found 2 issues in title: ['12756', '12753']
# 2025-06-05 11:20:45.732 | INFO     | __main__:process_row:148 - Row 1524: Found 1 issues in title: ['4997']
# 2025-06-05 11:20:45.733 | INFO     | __main__:process_row:148 - Row 1548: Found 1 issues in title: ['4994']
# 2025-06-05 11:20:45.749 | INFO     | __main__:process_row:148 - Row 1712: Found 1 issues in title: ['12819']
# 2025-06-05 11:20:45.788 | INFO     | __main__:process_row:148 - Row 1742: Found 1 issues in title: ['32765']
# 2025-06-05 11:20:45.831 | INFO     | __main__:process_row:148 - Row 2085: Found 1 issues in title: ['4956']
# 2025-06-05 11:20:45.904 | INFO     | __main__:process_row:148 - Row 2686: Found 1 issues in title: ['125']
# 2025-06-05 11:20:45.905 | INFO     | __main__:process_row:148 - Row 2692: Found 1 issues in title: ['131']
# 2025-06-05 11:20:45.913 | INFO     | __main__:process_row:148 - Row 2748: Found 1 issues in title: ['26128']
# 2025-06-05 11:20:45.916 | INFO     | __main__:process_row:148 - Row 2781: Found 1 issues in title: ['8623']
# 2025-06-05 11:20:45.931 | INFO     | __main__:process_row:148 - Row 2881: Found 1 issues in title: ['1884']
# 2025-06-05 11:20:45.932 | INFO     | __main__:process_row:148 - Row 2887: Found 1 issues in title: ['20376']
# 2025-06-05 11:20:45.932 | INFO     | __main__:process_row:148 - Row 2908: Found 1 issues in title: ['20376']
# 2025-06-05 11:20:45.932 | INFO     | __main__:process_row:148 - Row 2930: Found 1 issues in title: ['9120']
# 2025-06-05 11:20:45.932 | INFO     | __main__:process_row:148 - Row 2959: Found 1 issues in title: ['7784']
# 2025-06-05 11:20:45.959 | INFO     | __main__:process_row:148 - Row 3050: Found 1 issues in title: ['17878']
# 2025-06-05 11:20:45.965 | INFO     | __main__:process_row:148 - Row 3077: Found 1 issues in title: ['4922']
# 2025-06-05 11:20:45.967 | INFO     | __main__:process_row:148 - Row 3081: Found 1 issues in title: ['4253']
# 2025-06-05 11:20:45.967 | INFO     | __main__:process_row:148 - Row 3136: Found 1 issues in title: ['15362']
# 2025-06-05 11:20:45.983 | INFO     | __main__:process_row:148 - Row 3184: Found 1 issues in title: ['9150']
# 2025-06-05 11:20:45.999 | INFO     | __main__:process_row:148 - Row 3421: Found 1 issues in title: ['9012']
# 2025-06-05 11:20:46.033 | INFO     | __main__:process_row:148 - Row 3588: Found 1 issues in title: ['29814']
# 2025-06-05 11:20:46.033 | INFO     | __main__:process_row:148 - Row 3596: Found 1 issues in title: ['9016']
# 2025-06-05 11:20:46.033 | INFO     | __main__:process_row:148 - Row 3620: Found 1 issues in title: ['1366']
# 2025-06-05 11:20:46.069 | INFO     | __main__:process_row:148 - Row 3847: Found 1 issues in title: ['8355']
# 2025-06-05 11:20:46.080 | INFO     | __main__:process_row:148 - Row 3950: Found 1 issues in title: ['2456']
# 2025-06-05 11:20:46.080 | INFO     | __main__:process_row:148 - Row 3966: Found 1 issues in title: ['2456']
# 2025-06-05 11:20:46.095 | INFO     | __main__:process_row:148 - Row 4034: Found 1 issues in title: ['1369']
# 2025-06-05 11:20:46.099 | INFO     | __main__:process_row:148 - Row 4062: Found 1 issues in title: ['4678']
# 2025-06-05 11:20:46.102 | INFO     | __main__:process_row:148 - Row 4072: Found 1 issues in title: ['1869']
# 2025-06-05 11:20:46.350 | INFO     | __main__:process_row:148 - Row 4218: Found 1 issues in title: ['18294']
# 2025-06-05 11:20:46.365 | INFO     | __main__:process_row:148 - Row 4373: Found 1 issues in title: ['2164']
# 2025-06-05 11:20:46.382 | INFO     | __main__:process_row:148 - Row 4403: Found 1 issues in title: ['2538']
# 2025-06-05 11:20:46.383 | INFO     | __main__:process_row:148 - Row 4405: Found 1 issues in title: ['2375']
# 2025-06-05 11:20:46.430 | INFO     | __main__:process_row:148 - Row 4835: Found 1 issues in title: ['1368']
# 2025-06-05 11:20:46.449 | INFO     | __main__:process_row:148 - Row 4904: Found 1 issues in title: ['320']
# 2025-06-05 11:20:46.449 | INFO     | __main__:process_row:148 - Row 4933: Found 1 issues in title: ['2587']
# 2025-06-05 11:20:46.488 | INFO     | __main__:process_row:148 - Row 4950: Found 1 issues in title: ['7363']
# 2025-06-05 11:20:46.540 | INFO     | __main__:process_row:148 - Row 5083: Found 1 issues in title: ['4748']
# 2025-06-05 11:20:46.604 | INFO     | __main__:process_row:148 - Row 5179: Found 1 issues in title: ['2260']
# 2025-06-05 11:20:46.605 | INFO     | __main__:process_row:148 - Row 5180: Found 1 issues in title: ['7363']
# 2025-06-05 11:20:46.606 | INFO     | __main__:process_row:148 - Row 5201: Found 1 issues in title: ['2136']
# 2025-06-05 11:20:46.626 | INFO     | __main__:process_row:148 - Row 5279: Found 2 issues in title: ['2631', '2632']
# 2025-06-05 11:20:46.634 | INFO     | __main__:process_row:148 - Row 5310: Found 1 issues in title: ['9321']
# 2025-06-05 11:20:46.638 | INFO     | __main__:process_row:148 - Row 5334: Found 1 issues in title: ['8694']
# 2025-06-05 11:20:46.644 | INFO     | __main__:process_row:148 - Row 5360: Found 1 issues in title: ['1375']
# 2025-06-05 11:20:46.650 | INFO     | __main__:process_row:148 - Row 5429: Found 1 issues in title: ['2620']
# 2025-06-05 11:20:46.650 | INFO     | __main__:process_row:148 - Row 5434: Found 1 issues in title: ['190']
# 2025-06-05 11:20:46.667 | INFO     | __main__:process_row:148 - Row 5458: Found 1 issues in title: ['2657']
# 2025-06-05 11:20:46.689 | INFO     | __main__:process_row:148 - Row 5607: Found 1 issues in title: ['4638']
# 2025-06-05 11:20:46.722 | INFO     | __main__:process_row:148 - Row 5784: Found 1 issues in title: ['32103']
# 2025-06-05 11:20:46.727 | INFO     | __main__:process_row:148 - Row 5813: Found 1 issues in title: ['2310']
# 2025-06-05 11:20:46.730 | INFO     | __main__:process_row:148 - Row 5827: Found 1 issues in title: ['2316']
# 2025-06-05 11:20:46.751 | INFO     | __main__:process_row:148 - Row 5968: Found 1 issues in title: ['18465']
# 2025-06-05 11:20:46.776 | INFO     | __main__:process_row:148 - Row 6120: Found 1 issues in title: ['2308']
# 2025-06-05 11:20:46.785 | INFO     | __main__:process_row:148 - Row 6170: Found 1 issues in title: ['33401']
# 2025-06-05 11:20:46.793 | INFO     | __main__:process_row:148 - Row 6227: Found 1 issues in title: ['18484']
# 2025-06-05 11:20:46.814 | INFO     | __main__:process_row:148 - Row 6352: Found 1 issues in title: ['2623']
# 2025-06-05 11:20:46.819 | INFO     | __main__:process_row:148 - Row 6370: Found 1 issues in title: ['1296']
# 2025-06-05 11:20:46.822 | INFO     | __main__:process_row:148 - Row 6382: Found 1 issues in title: ['2702']
# 2025-06-05 11:20:46.822 | INFO     | __main__:process_row:148 - Row 6384: Found 2 issues in title: ['2505', '2506']
# 2025-06-05 11:20:46.834 | INFO     | __main__:process_row:148 - Row 6494: Found 1 issues in title: ['8361']
# 2025-06-05 11:20:46.849 | INFO     | __main__:process_row:148 - Row 6531: Found 1 issues in title: ['27339']
# 2025-06-05 11:20:46.852 | INFO     | __main__:process_row:148 - Row 6591: Found 1 issues in title: ['5046']
# 2025-06-05 11:20:46.861 | INFO     | __main__:process_row:148 - Row 6603: Found 1 issues in title: ['30553']
# 2025-06-05 11:20:46.885 | INFO     | __main__:process_row:148 - Row 6727: Found 2 issues in title: ['2694', '2729']
# 2025-06-05 11:20:46.889 | INFO     | __main__:process_row:148 - Row 6757: Found 1 issues in title: ['2704']
# 2025-06-05 11:20:46.930 | INFO     | __main__:process_row:148 - Row 7180: Found 1 issues in title: ['8323']
# 2025-06-05 11:20:46.946 | INFO     | __main__:process_row:148 - Row 7259: Found 1 issues in title: ['11958']
# 2025-06-05 11:20:46.970 | INFO     | __main__:process_row:148 - Row 7410: Found 1 issues in title: ['2800']
# 2025-06-05 11:20:46.970 | INFO     | __main__:process_row:148 - Row 7413: Found 1 issues in title: ['2825']
# 2025-06-05 11:20:46.972 | INFO     | __main__:process_row:148 - Row 7420: Found 2 issues in title: ['1978', '1988']
# 2025-06-05 11:20:46.974 | INFO     | __main__:process_row:148 - Row 7426: Found 1 issues in title: ['2797']
# 2025-06-05 11:20:46.998 | INFO     | __main__:process_row:148 - Row 7617: Found 1 issues in title: ['4948']
# 2025-06-05 11:20:47.001 | INFO     | __main__:process_row:148 - Row 7659: Found 1 issues in title: ['1358']
# 2025-06-05 11:20:47.001 | INFO     | __main__:process_row:148 - Row 7661: Found 1 issues in title: ['4715']
# 2025-06-05 11:20:47.019 | INFO     | __main__:process_row:148 - Row 7773: Found 1 issues in title: ['2847']
# 2025-06-05 11:20:47.023 | INFO     | __main__:process_row:148 - Row 7795: Found 1 issues in title: ['2197']
# 2025-06-05 11:20:47.023 | INFO     | __main__:process_row:148 - Row 7815: Found 1 issues in title: ['2245']
# 2025-06-05 11:20:47.034 | INFO     | __main__:process_row:148 - Row 7870: Found 1 issues in title: ['9367']
# 2025-06-05 11:20:47.055 | INFO     | __main__:process_row:148 - Row 8032: Found 1 issues in title: ['30379']
# 2025-06-05 11:20:47.059 | INFO     | __main__:process_row:148 - Row 8057: Found 1 issues in title: ['11694']
# 2025-06-05 11:20:47.063 | INFO     | __main__:process_row:148 - Row 8077: Found 1 issues in title: ['11694']
# 2025-06-05 11:20:47.066 | INFO     | __main__:process_row:148 - Row 8106: Found 1 issues in title: ['2185']
# 2025-06-05 11:20:47.066 | INFO     | __main__:process_row:148 - Row 8129: Found 1 issues in title: ['2182']
# 2025-06-05 11:20:47.102 | INFO     | __main__:process_row:148 - Row 8416: Found 1 issues in title: ['21872']
# 2025-06-05 11:20:47.119 | INFO     | __main__:process_row:148 - Row 8494: Found 1 issues in title: ['2161']
# 2025-06-05 11:20:47.146 | INFO     | __main__:process_row:148 - Row 8767: Found 1 issues in title: ['2151']
# 2025-06-05 11:20:47.146 | INFO     | __main__:process_row:148 - Row 8770: Found 1 issues in title: ['1117']
# 2025-06-05 11:20:47.146 | INFO     | __main__:process_row:148 - Row 8774: Found 1 issues in title: ['2074']
# 2025-06-05 11:20:47.146 | INFO     | __main__:process_row:148 - Row 8789: Found 1 issues in title: ['2147']
# 2025-06-05 11:20:47.181 | INFO     | __main__:process_row:148 - Row 8938: Found 1 issues in title: ['9569']
# 2025-06-05 11:20:47.200 | INFO     | __main__:process_row:148 - Row 9083: Found 1 issues in title: ['2141']
# 2025-06-05 11:20:47.200 | INFO     | __main__:process_row:148 - Row 9119: Found 1 issues in title: ['2984']
# 2025-06-05 11:20:47.215 | INFO     | __main__:process_row:148 - Row 9135: Found 1 issues in title: ['1154']
# 2025-06-05 11:20:47.281 | INFO     | __main__:process_row:148 - Row 9639: Found 1 issues in title: ['3038']
# 2025-06-05 11:20:47.283 | INFO     | __main__:process_row:148 - Row 9669: Found 1 issues in title: ['3066']
# 2025-06-05 11:20:47.283 | INFO     | __main__:process_row:148 - Row 9680: Found 2 issues in title: ['3018', '3065']
# 2025-06-05 11:20:47.299 | INFO     | __main__:process_row:148 - Row 9761: Found 1 issues in title: ['7601']
# 2025-06-05 11:20:47.304 | INFO     | __main__:process_row:148 - Row 9781: Found 1 issues in title: ['9270']
# 2025-06-05 11:20:47.326 | INFO     | __main__:process_row:148 - Row 9952: Found 2 issues in title: ['25663', '25665']
# 2025-06-05 11:20:47.335 | INFO     | __main__:process_row:148 - Row 9997: Found 1 issues in title: ['36394']
# 2025-06-05 11:20:47.339 | INFO     | __main__:process_row:148 - Row 10022: Found 1 issues in title: ['2969']
# 2025-06-05 11:20:47.342 | INFO     | __main__:process_row:148 - Row 10037: Found 1 issues in title: ['2112']
# 2025-06-05 11:20:47.371 | INFO     | __main__:process_row:148 - Row 10291: Found 1 issues in title: ['1800']
# 2025-06-05 11:20:47.382 | INFO     | __main__:process_row:148 - Row 10322: Found 1 issues in title: ['1923']
# 2025-06-05 11:20:47.384 | INFO     | __main__:process_row:148 - Row 10332: Found 1 issues in title: ['3086']
# 2025-06-05 11:20:47.385 | INFO     | __main__:process_row:148 - Row 10334: Found 1 issues in title: ['1257']
# 2025-06-05 11:20:47.385 | INFO     | __main__:process_row:148 - Row 10336: Found 2 issues in title: ['3132', '112']
# 2025-06-05 11:20:47.391 | INFO     | __main__:process_row:148 - Row 10352: Found 1 issues in title: ['1963']
# 2025-06-05 11:20:47.399 | INFO     | __main__:process_row:148 - Row 10418: Found 1 issues in title: ['26770']
# 2025-06-05 11:20:47.399 | INFO     | __main__:process_row:148 - Row 10465: Found 1 issues in title: ['9766']
# 2025-06-05 11:20:47.439 | INFO     | __main__:process_row:148 - Row 10706: Found 1 issues in title: ['36586']
# 2025-06-05 11:20:47.450 | INFO     | __main__:process_row:148 - Row 10762: Found 1 issues in title: ['2917']
# 2025-06-05 11:20:47.490 | INFO     | __main__:process_row:148 - Row 11106: Found 1 issues in title: ['2005']
# 2025-06-05 11:20:47.499 | INFO     | __main__:process_row:148 - Row 11141: Found 1 issues in title: ['2747']
# 2025-06-05 11:20:47.499 | INFO     | __main__:process_row:148 - Row 11167: Found 1 issues in title: ['3134']
# 2025-06-05 11:20:47.499 | INFO     | __main__:process_row:148 - Row 11182: Found 1 issues in title: ['3174']
# 2025-06-05 11:20:47.539 | INFO     | __main__:process_row:148 - Row 11440: Found 1 issues in title: ['260']
# 2025-06-05 11:20:47.554 | INFO     | __main__:process_row:148 - Row 11507: Found 1 issues in title: ['20965']
# 2025-06-05 11:20:47.558 | INFO     | __main__:process_row:148 - Row 11531: Found 1 issues in title: ['1939']
# 2025-06-05 11:20:47.563 | INFO     | __main__:process_row:148 - Row 11552: Found 1 issues in title: ['36597']
# 2025-06-05 11:20:47.565 | INFO     | __main__:process_row:148 - Row 11558: Found 1 issues in title: ['36597']
# 2025-06-05 11:20:47.614 | INFO     | __main__:process_row:148 - Row 11942: Found 1 issues in title: ['1025']
# 2025-06-05 11:20:47.664 | INFO     | __main__:process_row:148 - Row 12359: Found 1 issues in title: ['36422']
# 2025-06-05 11:20:47.664 | INFO     | __main__:process_row:148 - Row 12420: Found 1 issues in title: ['36597']
# 2025-06-05 11:20:47.664 | INFO     | __main__:process_row:148 - Row 12444: Found 1 issues in title: ['36790']
# 2025-06-05 11:20:47.714 | INFO     | __main__:process_row:148 - Row 12736: Found 1 issues in title: ['768']
# 2025-06-05 11:20:47.714 | INFO     | __main__:process_row:148 - Row 12769: Found 1 issues in title: ['3258']
# 2025-06-05 11:20:47.714 | INFO     | __main__:process_row:148 - Row 12778: Found 1 issues in title: ['1675']
# 2025-06-05 11:20:47.733 | INFO     | __main__:process_row:148 - Row 12852: Found 1 issues in title: ['8151']
# 2025-06-05 11:20:47.735 | INFO     | __main__:process_row:148 - Row 12858: Found 1 issues in title: ['13962']
# 2025-06-05 11:20:47.763 | INFO     | __main__:process_row:148 - Row 13049: Found 1 issues in title: ['40826']
# 2025-06-05 11:20:47.772 | INFO     | __main__:process_row:148 - Row 13108: Found 1 issues in title: ['1848']
# 2025-06-05 11:20:47.775 | INFO     | __main__:process_row:148 - Row 13123: Found 1 issues in title: ['1309']
# 2025-06-05 11:20:47.781 | INFO     | __main__:process_row:148 - Row 13160: Found 1 issues in title: ['1863']
# 2025-06-05 11:20:47.805 | INFO     | __main__:process_row:148 - Row 13332: Found 1 issues in title: ['34199']
# 2025-06-05 11:20:47.811 | INFO     | __main__:process_row:148 - Row 13371: Found 2 issues in title: ['867', '866']
# 2025-06-05 11:20:47.812 | INFO     | __main__:process_row:148 - Row 13374: Found 1 issues in title: ['40826']
# 2025-06-05 11:20:47.818 | INFO     | __main__:process_row:148 - Row 13391: Found 1 issues in title: ['882']
# 2025-06-05 11:20:47.826 | INFO     | __main__:process_row:148 - Row 13445: Found 1 issues in title: ['1954']
# 2025-06-05 11:20:47.870 | INFO     | __main__:process_row:148 - Row 13768: Found 1 issues in title: ['889']
# 2025-06-05 11:20:47.886 | INFO     | __main__:process_row:148 - Row 13883: Found 1 issues in title: ['3348']
# 2025-06-05 11:20:47.915 | INFO     | __main__:process_row:148 - Row 14079: Found 1 issues in title: ['933']
# 2025-06-05 11:20:47.920 | INFO     | __main__:process_row:148 - Row 14112: Found 1 issues in title: ['8419']
# 2025-06-05 11:20:47.947 | INFO     | __main__:process_row:148 - Row 14339: Found 1 issues in title: ['7705']
# 2025-06-05 11:20:47.949 | INFO     | __main__:process_row:148 - Row 14402: Found 1 issues in title: ['969']
# 2025-06-05 11:20:47.949 | INFO     | __main__:process_row:148 - Row 14408: Found 1 issues in title: ['976']
# 2025-06-05 11:20:47.965 | INFO     | __main__:process_row:148 - Row 14433: Found 1 issues in title: ['927']
# 2025-06-05 11:20:47.968 | INFO     | __main__:process_row:148 - Row 14455: Found 1 issues in title: ['1012']
# 2025-06-05 11:20:47.970 | INFO     | __main__:process_row:148 - Row 14460: Found 1 issues in title: ['1014']
# 2025-06-05 11:20:47.970 | INFO     | __main__:process_row:148 - Row 14464: Found 1 issues in title: ['915']
# 2025-06-05 11:20:47.970 | INFO     | __main__:process_row:148 - Row 14467: Found 1 issues in title: ['1024']
# 2025-06-05 11:20:48.005 | INFO     | __main__:process_row:148 - Row 14729: Found 1 issues in title: ['9082']
# 2025-06-05 11:20:48.013 | INFO     | __main__:process_row:148 - Row 14826: Found 1 issues in title: ['1055']
# 2025-06-05 11:20:48.013 | INFO     | __main__:process_row:148 - Row 14850: Found 1 issues in title: ['20630']
# 2025-06-05 11:20:48.013 | INFO     | __main__:process_row:148 - Row 14860: Found 1 issues in title: ['1055']
# 2025-06-05 11:20:48.033 | INFO     | __main__:process_row:148 - Row 15005: Found 2 issues in title: ['903', '146']
# 2025-06-05 11:20:48.033 | INFO     | __main__:process_row:148 - Row 15014: Found 1 issues in title: ['1102']
# 2025-06-05 11:20:48.033 | INFO     | __main__:process_row:148 - Row 15017: Found 1 issues in title: ['1108']
# 2025-06-05 11:20:48.052 | INFO     | __main__:process_row:148 - Row 15039: Found 1 issues in title: ['957']
# 2025-06-05 11:20:48.054 | INFO     | __main__:process_row:148 - Row 15054: Found 1 issues in title: ['1105']
# 2025-06-05 11:20:48.083 | INFO     | __main__:process_row:148 - Row 15278: Found 1 issues in title: ['34358']
# 2025-06-05 11:20:48.096 | INFO     | __main__:process_row:148 - Row 15380: Found 1 issues in title: ['14775']
# 2025-06-05 11:20:48.099 | INFO     | __main__:process_row:148 - Row 15434: Found 1 issues in title: ['1121']
# 2025-06-05 11:20:48.099 | INFO     | __main__:process_row:148 - Row 15452: Found 1 issues in title: ['1132']
# 2025-06-05 11:20:48.116 | INFO     | __main__:process_row:148 - Row 15495: Found 1 issues in title: ['408']
# 2025-06-05 11:20:48.116 | INFO     | __main__:process_row:148 - Row 15496: Found 1 issues in title: ['34371']
# 2025-06-05 11:20:48.136 | INFO     | __main__:process_row:148 - Row 15640: Found 2 issues in title: ['1159', '947']
# 2025-06-05 11:20:48.139 | INFO     | __main__:process_row:148 - Row 15657: Found 4 issues in title: ['1158', '1160', '1014', '1155']
# 2025-06-05 11:20:48.142 | INFO     | __main__:process_row:148 - Row 15667: Found 1 issues in title: ['20241']
# 2025-06-05 11:20:48.142 | INFO     | __main__:process_row:148 - Row 15668: Found 1 issues in title: ['1190']
# 2025-06-05 11:20:48.142 | INFO     | __main__:process_row:148 - Row 15679: Found 1 issues in title: ['1176']
# 2025-06-05 11:20:48.149 | INFO     | __main__:process_row:148 - Row 15694: Found 2 issues in title: ['7703', '7704']
# 2025-06-05 11:20:48.157 | INFO     | __main__:process_row:148 - Row 15745: Found 1 issues in title: ['36005']
# 2025-06-05 11:20:48.164 | INFO     | __main__:process_row:148 - Row 15794: Found 1 issues in title: ['34421']
# 2025-06-05 11:20:48.192 | INFO     | __main__:process_row:148 - Row 16003: Found 1 issues in title: ['36004']
# 2025-06-05 11:20:48.197 | INFO     | __main__:process_row:148 - Row 16034: Found 1 issues in title: ['1208']
# 2025-06-05 11:20:48.197 | INFO     | __main__:process_row:148 - Row 16036: Found 2 issues in title: ['1198', '1205']
# 2025-06-05 11:20:48.197 | INFO     | __main__:process_row:148 - Row 16039: Found 1 issues in title: ['1214']
# 2025-06-05 11:20:48.197 | INFO     | __main__:process_row:148 - Row 16057: Found 2 issues in title: ['10277', '10291']
# 2025-06-05 11:20:48.247 | INFO     | __main__:process_row:148 - Row 16283: Found 1 issues in title: ['36647']
# 2025-06-05 11:20:48.247 | INFO     | __main__:process_row:148 - Row 16313: Found 1 issues in title: ['36647']
# 2025-06-05 11:20:48.297 | INFO     | __main__:process_row:148 - Row 16627: Found 1 issues in title: ['13200']
# 2025-06-05 11:20:48.300 | INFO     | __main__:process_row:148 - Row 16638: Found 1 issues in title: ['11350']
# 2025-06-05 11:20:48.317 | INFO     | __main__:process_row:148 - Row 16841: Found 1 issues in title: ['35986']
# 2025-06-05 11:20:48.352 | INFO     | __main__:process_row:148 - Row 17024: Found 1 issues in title: ['17012']
# 2025-06-05 11:20:48.367 | INFO     | __main__:process_row:148 - Row 17129: Found 1 issues in title: ['35210']
# 2025-06-05 11:20:48.389 | INFO     | __main__:process_row:148 - Row 17317: Found 1 issues in title: ['13137']
# 2025-06-05 11:20:48.437 | INFO     | __main__:process_row:148 - Row 17714: Found 1 issues in title: ['13016']
# 2025-06-05 11:20:48.533 | INFO     | __main__:process_row:148 - Row 18343: Found 1 issues in title: ['1246']
# 2025-06-05 11:20:48.533 | INFO     | __main__:process_row:148 - Row 18346: Found 1 issues in title: ['1493']
# 2025-06-05 11:20:48.830 | INFO     | __main__:process_row:148 - Row 18357: Found 1 issues in title: ['900']
# Processing rows:   0%|          | 0/25042 [00:00<?, ?it/s]2025-06-05 11:20:48.830 | INFO     | __main__:process_row:148 - Row 18381: Found 1 issues in title: ['1240']
# 2025-06-05 11:20:48.877 | INFO     | __main__:process_row:148 - Row 18593: Found 1 issues in title: ['37812']
# 2025-06-05 11:20:48.891 | INFO     | __main__:process_row:148 - Row 18604: Found 1 issues in title: ['34468']
# Processing rows:  74%|███████▍  | 18634/25042 [00:00<00:00, 162020.66it/s]2025-06-05 11:20:48.896 | INFO     | __main__:process_row:148 - Row 18611: Found 1 issues in title: ['1292']
# 2025-06-05 11:20:48.960 | INFO     | __main__:process_row:148 - Row 18624: Found 1 issues in title: ['1545']
# 2025-06-05 11:20:48.996 | INFO     | __main__:process_row:148 - Row 18626: Found 1 issues in title: ['1025']
# 2025-06-05 11:20:48.996 | INFO     | __main__:process_row:148 - Row 18645: Found 1 issues in title: ['1564']
# 2025-06-05 11:20:49.015 | INFO     | __main__:process_row:148 - Row 18649: Found 1 issues in title: ['1568']
# 2025-06-05 11:20:49.017 | INFO     | __main__:process_row:148 - Row 18661: Found 1 issues in title: ['1535']
# 2025-06-05 11:20:49.019 | INFO     | __main__:process_row:148 - Row 18672: Found 1 issues in title: ['2201']
# 2025-06-05 11:20:49.021 | INFO     | __main__:process_row:148 - Row 18674: Found 1 issues in title: ['2201']
# 2025-06-05 11:20:49.022 | INFO     | __main__:process_row:148 - Row 18723: Found 1 issues in title: ['7789']
# 2025-06-05 11:20:49.035 | INFO     | __main__:process_row:148 - Row 18779: Found 1 issues in title: ['37812']
# 2025-06-05 11:20:49.037 | INFO     | __main__:process_row:148 - Row 18790: Found 1 issues in title: ['37812']
# 2025-06-05 11:20:49.055 | INFO     | __main__:process_row:148 - Row 18995: Found 1 issues in title: ['100']
# 2025-06-05 11:20:49.058 | INFO     | __main__:process_row:148 - Row 19005: Found 1 issues in title: ['13']
# 2025-06-05 11:20:49.075 | INFO     | __main__:process_row:148 - Row 19199: Found 1 issues in title: ['1613']
# 2025-06-05 11:20:49.077 | INFO     | __main__:process_row:148 - Row 19208: Found 2 issues in title: ['1471', '1502']
# 2025-06-05 11:20:49.095 | INFO     | __main__:process_row:148 - Row 19347: Found 1 issues in title: ['10579']
# 2025-06-05 11:20:49.096 | INFO     | __main__:process_row:148 - Row 19387: Found 1 issues in title: ['14001']
# 2025-06-05 11:20:49.096 | INFO     | __main__:process_row:148 - Row 19454: Found 1 issues in title: ['3823']
# 2025-06-05 11:20:49.096 | INFO     | __main__:process_row:148 - Row 19473: Found 1 issues in title: ['1677']
# 2025-06-05 11:20:49.114 | INFO     | __main__:process_row:148 - Row 19502: Found 1 issues in title: ['1336']
# 2025-06-05 11:20:49.117 | INFO     | __main__:process_row:148 - Row 19512: Found 3 issues in title: ['1255', '1446', '1160']
# 2025-06-05 11:20:49.119 | INFO     | __main__:process_row:148 - Row 19529: Found 1 issues in title: ['1635']
# 2025-06-05 11:20:49.122 | INFO     | __main__:process_row:148 - Row 19543: Found 1 issues in title: ['1643']
# 2025-06-05 11:20:49.122 | INFO     | __main__:process_row:148 - Row 19559: Found 1 issues in title: ['1383']
# 2025-06-05 11:20:49.129 | INFO     | __main__:process_row:148 - Row 19602: Found 1 issues in title: ['5085']
# 2025-06-05 11:20:49.132 | INFO     | __main__:process_row:148 - Row 19746: Found 1 issues in title: ['3871']
# 2025-06-05 11:20:49.132 | INFO     | __main__:process_row:148 - Row 19751: Found 1 issues in title: ['1656']
# 2025-06-05 11:20:49.147 | INFO     | __main__:process_row:148 - Row 19771: Found 1 issues in title: ['1667']
# 2025-06-05 11:20:49.150 | INFO     | __main__:process_row:148 - Row 19785: Found 1 issues in title: ['1199']
# 2025-06-05 11:20:49.152 | INFO     | __main__:process_row:148 - Row 19794: Found 1 issues in title: ['1219']
# 2025-06-05 11:20:49.156 | INFO     | __main__:process_row:148 - Row 19900: Found 1 issues in title: ['42251']
# 2025-06-05 11:20:49.175 | INFO     | __main__:process_row:148 - Row 20048: Found 1 issues in title: ['3833']
# 2025-06-05 11:20:49.179 | INFO     | __main__:process_row:148 - Row 20075: Found 1 issues in title: ['1427']
# 2025-06-05 11:20:49.182 | INFO     | __main__:process_row:148 - Row 20095: Found 1 issues in title: ['1699']
# 2025-06-05 11:20:49.183 | INFO     | __main__:process_row:148 - Row 20098: Found 1 issues in title: ['1690']
# 2025-06-05 11:20:49.192 | INFO     | __main__:process_row:148 - Row 20190: Found 1 issues in title: ['21796']
# 2025-06-05 11:20:49.192 | INFO     | __main__:process_row:148 - Row 20211: Found 1 issues in title: ['37812']
# 2025-06-05 11:20:49.205 | INFO     | __main__:process_row:148 - Row 20359: Found 1 issues in title: ['2843']
# 2025-06-05 11:20:49.214 | INFO     | __main__:process_row:148 - Row 20401: Found 1 issues in title: ['2485']
# 2025-06-05 11:20:49.231 | INFO     | __main__:process_row:148 - Row 20604: Found 1 issues in title: ['6297']
# 2025-06-05 11:20:49.236 | INFO     | __main__:process_row:148 - Row 20652: Found 1 issues in title: ['14476']
# 2025-06-05 11:20:49.248 | INFO     | __main__:process_row:148 - Row 20772: Found 1 issues in title: ['1747']
# 2025-06-05 11:20:49.249 | INFO     | __main__:process_row:148 - Row 20781: Found 1 issues in title: ['35703']
# 2025-06-05 11:20:49.256 | INFO     | __main__:process_row:148 - Row 20846: Found 1 issues in title: ['23473']
# 2025-06-05 11:20:49.288 | INFO     | __main__:process_row:148 - Row 21241: Found 1 issues in title: ['13']
# 2025-06-05 11:20:49.297 | INFO     | __main__:process_row:148 - Row 21321: Found 1 issues in title: ['13']
# 2025-06-05 11:20:49.323 | INFO     | __main__:process_row:148 - Row 21657: Found 1 issues in title: ['10702']
# 2025-06-05 11:20:49.323 | INFO     | __main__:process_row:148 - Row 21682: Found 1 issues in title: ['10680']
# 2025-06-05 11:20:49.331 | INFO     | __main__:process_row:148 - Row 21716: Found 2 issues in title: ['4159', '3203']
# 2025-06-05 11:20:49.333 | INFO     | __main__:process_row:148 - Row 21725: Found 1 issues in title: ['3768']
# 2025-06-05 11:20:49.344 | INFO     | __main__:process_row:148 - Row 21837: Found 1 issues in title: ['10894']
# 2025-06-05 11:20:49.376 | INFO     | __main__:process_row:148 - Row 22211: Found 1 issues in title: ['15254']
# 2025-06-05 11:20:49.380 | INFO     | __main__:process_row:148 - Row 22236: Found 1 issues in title: ['15253']
# 2025-06-05 11:20:49.384 | INFO     | __main__:process_row:148 - Row 22261: Found 1 issues in title: ['15167']
# 2025-06-05 11:20:49.398 | INFO     | __main__:process_row:148 - Row 22408: Found 1 issues in title: ['21259']
# 2025-06-05 11:20:49.404 | INFO     | __main__:process_row:148 - Row 22474: Found 1 issues in title: ['10766']
# 2025-06-05 11:20:49.404 | INFO     | __main__:process_row:148 - Row 22552: Found 1 issues in title: ['6700']
# 2025-06-05 11:20:49.417 | INFO     | __main__:process_row:148 - Row 22687: Found 1 issues in title: ['1790']
# 2025-06-05 11:20:49.432 | INFO     | __main__:process_row:148 - Row 22730: Found 1 issues in title: ['14981']
# 2025-06-05 11:20:49.433 | INFO     | __main__:process_row:148 - Row 22736: Found 1 issues in title: ['14971']
# 2025-06-05 11:20:49.440 | INFO     | __main__:process_row:148 - Row 22808: Found 1 issues in title: ['4971']
# 2025-06-05 11:20:49.464 | INFO     | __main__:process_row:148 - Row 23101: Found 1 issues in title: ['19073']
# 2025-06-05 11:20:49.467 | INFO     | __main__:process_row:148 - Row 23119: Found 1 issues in title: ['6843']
# 2025-06-05 11:20:49.469 | INFO     | __main__:process_row:148 - Row 23192: Found 3 issues in title: ['15503', '14751', '14346']
# 2025-06-05 11:20:49.469 | INFO     | __main__:process_row:148 - Row 23235: Found 1 issues in title: ['35400']
# 2025-06-05 11:20:49.480 | INFO     | __main__:process_row:148 - Row 23243: Found 1 issues in title: ['12560']
# 2025-06-05 11:20:49.494 | INFO     | __main__:process_row:148 - Row 23403: Found 1 issues in title: ['3957']
# 2025-06-05 11:20:49.540 | INFO     | __main__:process_row:148 - Row 23634: Found 1 issues in title: ['4397']
# 2025-06-05 11:20:49.547 | INFO     | __main__:process_row:148 - Row 23639: Found 1 issues in title: ['4399']
# 2025-06-05 11:20:49.553 | INFO     | __main__:process_row:148 - Row 23670: Found 1 issues in title: ['3957']
# 2025-06-05 11:20:49.559 | INFO     | __main__:process_row:148 - Row 23716: Found 1 issues in title: ['21259']
# 2025-06-05 11:20:49.584 | INFO     | __main__:process_row:148 - Row 23911: Found 1 issues in title: ['17586']
# 2025-06-05 11:20:49.592 | INFO     | __main__:process_row:148 - Row 24010: Found 1 issues in title: ['3692']
# 2025-06-05 11:20:49.600 | INFO     | __main__:process_row:148 - Row 24106: Found 1 issues in title: ['12555']
# 2025-06-05 11:20:49.615 | INFO     | __main__:process_row:148 - Row 24391: Found 1 issues in title: ['4102']
# 2025-06-05 11:20:49.631 | INFO     | __main__:process_row:148 - Row 24471: Found 1 issues in title: ['9681']
# 2025-06-05 11:20:49.644 | INFO     | __main__:process_row:148 - Row 24638: Found 1 issues in title: ['3624']
# 2025-06-05 11:20:49.666 | INFO     | __main__:process_row:148 - Row 24882: Found 1 issues in title: ['7700']
# 2025-06-05 11:20:49.666 | INFO     | __main__:process_row:148 - Row 24911: Found 1 issues in title: ['4338']
# 2025-06-05 11:20:49.666 | INFO     | __main__:process_row:148 - Row 24961: Found 1 issues in title: ['10721']
# 2025-06-05 11:20:49.681 | INFO     | __main__:process_row:148 - Row 25032: Found 1 issues in title: ['18789']
# Processing rows: 100%|██████████| 25042/25042 [00:00<00:00, 31666.27it/s]
# 2025-06-05 11:20:49.688 | INFO     | __main__:run:209 - Creating new DataFrame with 25065 records
# 2025-06-05 11:20:49.732 | INFO     | __main__:run:216 - Saving results to: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues.csv
# 2025-06-05 11:20:50.264 | INFO     | __main__:run:225 - ==================================================
# 2025-06-05 11:20:50.264 | INFO     | __main__:run:226 - PROCESSING SUMMARY
# 2025-06-05 11:20:50.264 | INFO     | __main__:run:227 - ==================================================
# 2025-06-05 11:20:50.264 | INFO     | __main__:run:228 - Original rows: 25042
# 2025-06-05 11:20:50.264 | INFO     | __main__:run:229 - New rows: 25065
# 2025-06-05 11:20:50.264 | INFO     | __main__:run:230 - Rows with issues found: 313
# 2025-06-05 11:20:50.279 | INFO     | __main__:run:231 - Unique issues extracted: 291
# 2025-06-05 11:20:50.280 | INFO     | __main__:run:232 - Expansion ratio: 1.00x
# 2025-06-05 11:20:50.280 | INFO     | __main__:run:233 - Output file: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues.csv
# 2025-06-05 11:20:50.280 | INFO     | __main__:run:234 - ==================================================
# ✅ Processing completed successfully!
# 📊 Original rows: 25042
# 📊 New rows: 25065
# 📊 Rows with issues: 313
# 📊 Unique issues found: 291
# 💾 Output saved to: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues.csv
#        pr_number                                            pr_link  \
# 0          18210  https://github.com/ballerina-platform/ballerin...
# 1          36110  https://github.com/ballerina-platform/ballerin...
# 2           5663  https://github.com/ballerina-platform/ballerin...
# 3          37005  https://github.com/ballerina-platform/ballerin...
# 4          27149  https://github.com/ballerina-platform/ballerin...
# ...          ...                                                ...
# 25060      20086  https://github.com/ballerina-platform/ballerin...
# 25061      19302  https://github.com/ballerina-platform/ballerin...
# 25062       4547  https://github.com/ballerina-platform/ballerin...
# 25063      11109  https://github.com/ballerina-platform/ballerin...
# 25064      19306  https://github.com/ballerina-platform/ballerin...
#
#                                                 pr_title  \
# 0          Fix intermittent test failures in Kafka tests
# 1      Extend the Type Cast code action for unsupport...
# 2         Add initial packerina v4 lang server migration
# 3         Support type reference for function parameters
# 4                                     Fix build failures
# ...                                                  ...
# 25060  Fix API Doc generation issue with private type...
# 25061                Fix closure var init in worker decl
# 25062  Fix #4338: stop all server connectors if one f...
# 25063                                   Fix issue #10721
# 25064             Fix annotation suggestion issue #18789
#
#                                                  pr_body  \
# 0      ## Purpose\r\n> $subject\r\n\r\nFixes #18209 \...
# 1      ## Purpose\r\n$subject to add a new code actio...
# 2      ## Purpose\r\n> Initial packerina v4 related m...
# 3      ## Purpose\r\n$subject\r\nFixes #36991\r\n\r\n...
# 4      ## Purpose\r\n> Describe the problems, issues,...
# ...                                                  ...
# 25060  ## Purpose\r\n> Fix API Doc generation issue w...
# 25061  ## Purpose\r\n```ballerina\r\npublic function ...
# 25062  ## Purpose\r\n> Currently, if at least one ser...
# 25063  ## Purpose\r\nFix #10721 and the relevant exam...
# 25064  ## Purpose\r\n> Fix the following annotation c...
#
#       extracted_issue_number  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 25060                   None
# 25061                   None
# 25062                   4338
# 25063                  10721
# 25064                  18789
#
#                                     extracted_issue_link  found_in_title  \
# 0                                                   None           False
# 1                                                   None           False
# 2                                                   None           False
# 3                                                   None           False
# 4                                                   None           False
# ...                                                  ...             ...
# 25060                                               None           False
# 25061                                               None           False
# 25062  https://github.com/ballerina-platform/ballerin...            True
# 25063  https://github.com/ballerina-platform/ballerin...            True
# 25064  https://github.com/ballerina-platform/ballerin...            True
#
#        original_row_index
# 0                    3310
# 1                   15162
# 2                    5949
# 3                   15169
# 4                    4685
# ...                   ...
# 25060               25040
# 25061               25041
# 25062               24911
# 25063               24961
# 25064               25032
#
# [25065 rows x 8 columns]

# %% [markdown]
# ## Discription

# %%
import pandas as pd
import os  
import re
from loguru import logger
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
from typing import List, Tuple, Optional
import time


def extract_all_issue_numbers_from_text(text: str) -> List[str]:
    """
    Extracts all issue numbers from a given text string.
    Returns a list of unique issue numbers found.
    """
    if pd.isna(text) or not text.strip():
        return []

    # Covers: fix(es/ed/ing), clos(e/es/ed), resolv(e/es/ed), issue(s)
    keyword_pattern = r'\b(?:fix(?:es|ed|ing)?|clos(?:e|es|ed)|resolv(?:e|es|ed)|issue(?:s)?)\b'

    # Patterns to find issue numbers, ordered by specificity (same as in CELL 11)
    issue_patterns = [
        # Matches: keyword + full GitHub issue/PR URL (e.g., "fixes https://github.com/org/repo/issues/123")
        rf'{keyword_pattern}\s+https?://github\.com/[^/]+/[^/]+/(?:issues|pull)/(\d+)',
        # Matches: keyword + #issue_number (e.g., "closes #456")
        rf'{keyword_pattern}\s+#(\d+)\b',
        # Matches: keyword + issue_number (e.g., "resolves 789") - less common, but possible
        rf'{keyword_pattern}\s+(\d+)\b',
        # Matches: keyword + text + (from #issue_number) (e.g., "fix: cherry pick (from #101)")
        rf'{keyword_pattern}.*\(from\s+#(\d+)\)',
        # Matches: keyword + text + #issue_number (e.g., "fixed: related to #112")
        rf'{keyword_pattern}.*#(\d+)\b',
        # Matches: keyword + text + (part of #issue_number or part of issue #issue_number) (e.g. "Fixes part of #123", "resolves part of issue #456")
        rf'{keyword_pattern}.*(?:part of\s+(?:issue\s+)?#(\d+)\b)',
        # Matches: keyword + text + /fix-#issue_number or /fix-issue_number (e.g. "fix /fix-#123", "closes /fix-456")
        rf'{keyword_pattern}.*(?:/fix-#(\d+)\b|/fix-(\d+)\b)',
        # Matches: "Fixes: " + full GitHub issue URL (e.g., "Fixes: https://github.com/org/repo/issues/123") - common in commit messages
        rf'Fixes:\s+https?://github\.com/[^/]+/[^/]+/issues/(\d+)',
        # Matches: keyword + multiple #issue_numbers separated by commas (e.g., "fixes #123, #456, #789")
        rf'{keyword_pattern}[^#]*?((?:#\d+(?:\s*,\s*#\d+)*)+)',
        # Matches: standalone full GitHub issue URL (e.g., "https://github.com/org/repo/issues/334") - broad
        r'https?://github\.com/[^/]+/[^/]+/issues/(\d+)',
        # Matches: "Fix " + org/repo/issues/issue_number (e.g., "Fix org/repo/issues/556") - specific to a common typo/format
        rf'Fix\s+[^/]+/[^/]+/issues/(\d+)'
    ]

    found_issues = set()  # Use set to avoid duplicates
    
    for pattern in issue_patterns:
        matches = re.finditer(pattern, text, re.IGNORECASE)
        for match in matches:
            groups = match.groups()
            for group_val in groups:
                if group_val:
                    # Handle multiple issues in one match (e.g., "#123, #456")
                    if '#' in group_val:
                        issue_nums_in_group = re.findall(r'#(\d+)', group_val)
                        found_issues.update(issue_nums_in_group)
                    else:
                        found_issues.add(group_val)
    
    return list(found_issues)

def process_row_for_body(row_data: Tuple[int, pd.Series]) -> List[dict]:
    """
    Process a single row to extract issue numbers from 'pr_body'.
    Returns a list of dictionaries, one for each issue found, or one original if none found.
    """
    idx, row = row_data
    
    try:
        pr_body = str(row.get('pr_body', ''))
        pr_link = str(row.get('pr_link', ''))
        
        # Extract all issue numbers from pr_body
        issue_numbers = extract_all_issue_numbers_from_text(pr_body)
        
        results = []
        
        if issue_numbers:
            # Create separate record for each issue found in body
            for issue_num in issue_numbers:
                issue_link = generate_issue_link(issue_num, pr_link) # generate_issue_link from CELL 11
                
                new_record = row.to_dict()
                new_record.update({
                    'extracted_issue_number_body': issue_num,
                    'extracted_issue_link_body': issue_link,
                    'found_in_body': True,
                    'original_row_index': idx  # Keep track of the original row
                })
                results.append(new_record)
                
            logger.info(f"Row {idx}: Found {len(issue_numbers)} issues in body: {issue_numbers}")
        else:
            # No issues found in body, keep original record with null/false values for body extraction
            new_record = row.to_dict()
            new_record.update({
                'extracted_issue_number_body': None,
                'extracted_issue_link_body': None,
                'found_in_body': False,
                'original_row_index': idx
            })
            results.append(new_record)
            
        return results
        
    except Exception as e:
        logger.error(f"Error processing row {idx} for body extraction: {str(e)}")
        # Return original record with error info for body extraction
        new_record = row.to_dict()
        new_record.update({
            'extracted_issue_number_body': None,
            'extracted_issue_link_body': None,
            'found_in_body': False,
            'original_row_index': idx,
            'processing_error_body': str(e)
        })
        return [new_record]

def run_body_extraction():
    """
    Main function to process the CSV for issues in 'pr_body' and create a new output file.
    """
    logger.info("Starting issue number extraction from PR BODY content")
    
    try:
        # csv_path is expected to be defined from a previous cell (e.g., CELL 11)
        # Defaulting if not found, but ideally it's already set.
        current_csv_path = csv_path if 'csv_path' in globals() else "../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv"

        logger.info(f"Loading CSV file: {current_csv_path}")
        df = pd.read_csv(current_csv_path)
        logger.info(f"Loaded {len(df)} records from CSV for body extraction")
        
        # Prepare data for parallel processing
        row_data_for_body = list(df.iterrows())
        
        all_results_body = []
        
        logger.info("Starting parallel processing for PR bodies...")
        # Using max_workers=4 for consistency with CELL 11, adjust if needed
        with ThreadPoolExecutor(max_workers= os.cpu_count()) as executor:
            future_to_row_body = {executor.submit(process_row_for_body, row_bd): row_bd[0] for row_bd in row_data_for_body}
            
            for future_bd in tqdm(as_completed(future_to_row_body), total=len(future_to_row_body), desc="Processing PR Bodies"):
                try:
                    row_results_bd = future_bd.result()
                    # write_lock is expected to be defined from a previous cell (e.g., CELL 11)
                    with write_lock: 
                        all_results_body.extend(row_results_bd)
                except Exception as e_bd:
                    row_idx_bd = future_to_row_body[future_bd]
                    logger.error(f"Failed to process row {row_idx_bd} for body extraction in main loop: {str(e_bd)}")
        
        logger.info(f"Creating new DataFrame with {len(all_results_body)} records from body extraction")
        new_df_body = pd.DataFrame(all_results_body)
        
        # Generate output filename for body extraction results
        output_path_body = current_csv_path.replace('.csv', '_with_extracted_issues_from_body.csv')
        
        logger.info(f"Saving body extraction results to: {output_path_body}")
        new_df_body.to_csv(output_path_body, index=False)
        
        # Log statistics for body extraction
        total_original_rows_bd = len(df)
        total_new_rows_bd = len(new_df_body)
        rows_with_issues_in_body = len(new_df_body[new_df_body['found_in_body'] == True])
        unique_issues_found_in_body = 0
        if 'extracted_issue_number_body' in new_df_body.columns:
             unique_issues_found_in_body = len(new_df_body[new_df_body['extracted_issue_number_body'].notna()]['extracted_issue_number_body'].unique())
        
        logger.info("="*50)
        logger.info("PR BODY EXTRACTION PROCESSING SUMMARY")
        logger.info("="*50)
        logger.info(f"Original rows processed: {total_original_rows_bd}")
        logger.info(f"New rows generated (from body): {total_new_rows_bd}")
        logger.info(f"Rows with issues found in body: {rows_with_issues_in_body}")
        logger.info(f"Unique issues extracted from body: {unique_issues_found_in_body}")
        if total_original_rows_bd > 0:
            logger.info(f"Expansion ratio (body): {total_new_rows_bd/total_original_rows_bd:.2f}x")
        logger.info(f"Output file (body extraction): {output_path_body}")
        logger.info("="*50)
        
        print(f"\n✅ PR Body issue extraction completed successfully!")
        print(f"📊 Original rows: {total_original_rows_bd}")
        print(f"📊 New rows (from body): {total_new_rows_bd}")
        print(f"📊 Rows with issues found in body: {rows_with_issues_in_body}")
        print(f"📊 Unique issues found in body: {unique_issues_found_in_body}")
        print(f"💾 Output saved to: {output_path_body}")
        
        return new_df_body
        
    except FileNotFoundError:
        logger.error(f"Error: The CSV file was not found at {current_csv_path}.")
        print(f"❌ Error: The CSV file was not found at {current_csv_path}.")
    except Exception as e:
        logger.error(f"Fatal error in PR body extraction process: {str(e)}")
        print(f"❌ Fatal error in PR body extraction process: {str(e)}")
        raise

# Execute the body extraction process
# This will use csv_path, generate_issue_link, and write_lock from the previous cells' scope.
result_df_body = run_body_extraction()
# Out:
# 2025-06-05 16:29:41.757 | INFO     | __main__:run_body_extraction:127 - Starting issue number extraction from PR BODY content
# 2025-06-05 16:29:41.759 | INFO     | __main__:run_body_extraction:134 - Loading CSV file: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary.csv
# 2025-06-05 16:29:42.119 | INFO     | __main__:run_body_extraction:136 - Loaded 25042 records from CSV for body extraction
# 2025-06-05 16:29:43.551 | INFO     | __main__:run_body_extraction:143 - Starting parallel processing for PR bodies...
# 2025-06-05 16:29:43.567 | INFO     | __main__:process_row_for_body:96 - Row 16: Found 1 issues in body: ['6892']
# 2025-06-05 16:29:43.582 | INFO     | __main__:process_row_for_body:96 - Row 31: Found 1 issues in body: ['29017']
# 2025-06-05 16:29:43.584 | INFO     | __main__:process_row_for_body:96 - Row 32: Found 1 issues in body: ['25709']
# 2025-06-05 16:29:43.834 | INFO     | __main__:process_row_for_body:96 - Row 37: Found 1 issues in body: ['17740']
# 2025-06-05 16:29:43.834 | INFO     | __main__:process_row_for_body:96 - Row 41: Found 1 issues in body: ['12492']
# 2025-06-05 16:29:43.834 | INFO     | __main__:process_row_for_body:96 - Row 42: Found 1 issues in body: ['29643']
# 2025-06-05 16:29:43.850 | INFO     | __main__:process_row_for_body:96 - Row 44: Found 1 issues in body: ['17806']
# 2025-06-05 16:29:43.850 | INFO     | __main__:process_row_for_body:96 - Row 46: Found 2 issues in body: ['32020', '32658']
# 2025-06-05 16:29:43.850 | INFO     | __main__:process_row_for_body:96 - Row 48: Found 2 issues in body: ['32848', '26284']
# 2025-06-05 16:29:43.850 | INFO     | __main__:process_row_for_body:96 - Row 49: Found 2 issues in body: ['24903', '12804']
# 2025-06-05 16:29:43.858 | INFO     | __main__:process_row_for_body:96 - Row 50: Found 1 issues in body: ['11085']
# 2025-06-05 16:29:43.860 | INFO     | __main__:process_row_for_body:96 - Row 53: Found 1 issues in body: ['29366']
# 2025-06-05 16:29:43.861 | INFO     | __main__:process_row_for_body:96 - Row 54: Found 2 issues in body: ['17862', '17811']
# 2025-06-05 16:29:43.861 | INFO     | __main__:process_row_for_body:96 - Row 55: Found 1 issues in body: ['31783']
# 2025-06-05 16:29:43.861 | INFO     | __main__:process_row_for_body:96 - Row 57: Found 1 issues in body: ['10825']
# 2025-06-05 16:29:43.871 | INFO     | __main__:process_row_for_body:96 - Row 59: Found 3 issues in body: ['10000', '12308', '12495']
# 2025-06-05 16:29:43.872 | INFO     | __main__:process_row_for_body:96 - Row 60: Found 1 issues in body: ['17296']
# 2025-06-05 16:29:43.872 | INFO     | __main__:process_row_for_body:96 - Row 61: Found 2 issues in body: ['18949', '28176']
# 2025-06-05 16:29:43.872 | INFO     | __main__:process_row_for_body:96 - Row 62: Found 1 issues in body: ['32092']
# 2025-06-05 16:29:43.872 | INFO     | __main__:process_row_for_body:96 - Row 64: Found 1 issues in body: ['27918']
# 2025-06-05 16:29:43.872 | INFO     | __main__:process_row_for_body:96 - Row 66: Found 5 issues in body: ['28521', '28424', '29089', '28077', '24944']
# Processing PR Bodies:   0%|          | 0/25042 [00:00<?, ?it/s]2025-06-05 16:29:43.872 | INFO     | __main__:process_row_for_body:96 - Row 68: Found 1 issues in body: ['17809']
# 2025-06-05 16:29:43.883 | INFO     | __main__:process_row_for_body:96 - Row 69: Found 3 issues in body: ['10434', '32608', '32171']
# 2025-06-05 16:29:43.923 | INFO     | __main__:process_row_for_body:96 - Row 71: Found 2 issues in body: ['29573', '29428']
# 2025-06-05 16:29:44.022 | INFO     | __main__:process_row_for_body:96 - Row 73: Found 1 issues in body: ['31601']
# 2025-06-05 16:29:44.085 | INFO     | __main__:process_row_for_body:96 - Row 77: Found 1 issues in body: ['17795']
# 2025-06-05 16:29:44.453 | INFO     | __main__:process_row_for_body:96 - Row 78: Found 1 issues in body: ['31159']
# 2025-06-05 16:29:44.569 | INFO     | __main__:process_row_for_body:96 - Row 79: Found 1 issues in body: ['29633']
# 2025-06-05 16:29:44.589 | INFO     | __main__:process_row_for_body:96 - Row 80: Found 1 issues in body: ['10825']
# 2025-06-05 16:29:44.648 | INFO     | __main__:process_row_for_body:96 - Row 81: Found 1 issues in body: ['11052']
# 2025-06-05 16:29:44.651 | INFO     | __main__:process_row_for_body:96 - Row 83: Found 1 issues in body: ['17727']
# 2025-06-05 16:29:44.653 | INFO     | __main__:process_row_for_body:96 - Row 85: Found 2 issues in body: ['420', '32612']
# 2025-06-05 16:29:44.654 | INFO     | __main__:process_row_for_body:96 - Row 87: Found 1 issues in body: ['14724']
# 2025-06-05 16:29:44.656 | INFO     | __main__:process_row_for_body:96 - Row 88: Found 1 issues in body: ['105']
# 2025-06-05 16:29:44.657 | INFO     | __main__:process_row_for_body:96 - Row 89: Found 1 issues in body: ['12492']
# 2025-06-05 16:29:44.662 | INFO     | __main__:process_row_for_body:96 - Row 94: Found 1 issues in body: ['17693']
# 2025-06-05 16:29:44.664 | INFO     | __main__:process_row_for_body:96 - Row 95: Found 1 issues in body: ['32575']
# 2025-06-05 16:29:44.670 | INFO     | __main__:process_row_for_body:96 - Row 102: Found 1 issues in body: ['17724']
# 2025-06-05 16:29:44.671 | INFO     | __main__:process_row_for_body:96 - Row 103: Found 1 issues in body: ['32558']
# 2025-06-05 16:29:44.672 | INFO     | __main__:process_row_for_body:96 - Row 104: Found 1 issues in body: ['14809']
# 2025-06-05 16:29:44.674 | INFO     | __main__:process_row_for_body:96 - Row 105: Found 1 issues in body: ['28634']
# 2025-06-05 16:29:44.675 | INFO     | __main__:process_row_for_body:96 - Row 107: Found 1 issues in body: ['12771']
# 2025-06-05 16:29:44.677 | INFO     | __main__:process_row_for_body:96 - Row 109: Found 1 issues in body: ['17746']
# Processing PR Bodies:   0%|          | 119/25042 [00:00<00:21, 1179.89it/s]2025-06-05 16:29:44.679 | INFO     | __main__:process_row_for_body:96 - Row 111: Found 1 issues in body: ['32641']
# 2025-06-05 16:29:44.680 | INFO     | __main__:process_row_for_body:96 - Row 113: Found 2 issues in body: ['31698', '31537']
# 2025-06-05 16:29:44.681 | INFO     | __main__:process_row_for_body:96 - Row 114: Found 1 issues in body: ['7285']
# 2025-06-05 16:29:44.685 | INFO     | __main__:process_row_for_body:96 - Row 120: Found 2 issues in body: ['32136', '32580']
# 2025-06-05 16:29:44.686 | INFO     | __main__:process_row_for_body:96 - Row 123: Found 1 issues in body: ['12251']
# 2025-06-05 16:29:44.688 | INFO     | __main__:process_row_for_body:96 - Row 125: Found 2 issues in body: ['17680', '17607']
# 2025-06-05 16:29:44.690 | INFO     | __main__:process_row_for_body:96 - Row 126: Found 2 issues in body: ['32402', '30980']
# 2025-06-05 16:29:44.691 | INFO     | __main__:process_row_for_body:96 - Row 128: Found 3 issues in body: ['31338', '29292', '31386']
# 2025-06-05 16:29:44.693 | INFO     | __main__:process_row_for_body:96 - Row 129: Found 1 issues in body: ['27799']
# 2025-06-05 16:29:44.695 | INFO     | __main__:process_row_for_body:96 - Row 130: Found 3 issues in body: ['29749', '28678', '28888']
# 2025-06-05 16:29:44.696 | INFO     | __main__:process_row_for_body:96 - Row 131: Found 1 issues in body: ['12584']
# 2025-06-05 16:29:44.698 | INFO     | __main__:process_row_for_body:96 - Row 133: Found 1 issues in body: ['28847']
# 2025-06-05 16:29:44.700 | INFO     | __main__:process_row_for_body:96 - Row 135: Found 1 issues in body: ['30982']
# 2025-06-05 16:29:44.702 | INFO     | __main__:process_row_for_body:96 - Row 137: Found 1 issues in body: ['12775']
# 2025-06-05 16:29:44.703 | INFO     | __main__:process_row_for_body:96 - Row 138: Found 1 issues in body: ['29449']
# 2025-06-05 16:29:44.705 | INFO     | __main__:process_row_for_body:96 - Row 142: Found 2 issues in body: ['17782', '17991']
# 2025-06-05 16:29:44.707 | INFO     | __main__:process_row_for_body:96 - Row 143: Found 3 issues in body: ['32660', '29628', '32159']
# 2025-06-05 16:29:44.709 | INFO     | __main__:process_row_for_body:96 - Row 148: Found 1 issues in body: ['17950']
# 2025-06-05 16:29:44.709 | INFO     | __main__:process_row_for_body:96 - Row 151: Found 1 issues in body: ['29076']
# 2025-06-05 16:29:44.716 | INFO     | __main__:process_row_for_body:96 - Row 152: Found 1 issues in body: ['1466']
# 2025-06-05 16:29:44.718 | INFO     | __main__:process_row_for_body:96 - Row 153: Found 1 issues in body: ['10499']
# 2025-06-05 16:29:44.719 | INFO     | __main__:process_row_for_body:96 - Row 157: Found 1 issues in body: ['17788']
# 2025-06-05 16:29:44.720 | INFO     | __main__:process_row_for_body:96 - Row 159: Found 1 issues in body: ['32417']
# 2025-06-05 16:29:44.722 | INFO     | __main__:process_row_for_body:96 - Row 160: Found 1 issues in body: ['28406']
# 2025-06-05 16:29:44.723 | INFO     | __main__:process_row_for_body:96 - Row 161: Found 2 issues in body: ['34990', '35178']
# 2025-06-05 16:29:44.726 | INFO     | __main__:process_row_for_body:96 - Row 164: Found 2 issues in body: ['37669', '37751']
# 2025-06-05 16:29:44.727 | INFO     | __main__:process_row_for_body:96 - Row 165: Found 1 issues in body: ['25983']
# 2025-06-05 16:29:44.729 | INFO     | __main__:process_row_for_body:96 - Row 166: Found 1 issues in body: ['40226']
# 2025-06-05 16:29:44.730 | INFO     | __main__:process_row_for_body:96 - Row 168: Found 3 issues in body: ['25970', '26541', '25978']
# 2025-06-05 16:29:44.732 | INFO     | __main__:process_row_for_body:96 - Row 169: Found 1 issues in body: ['22048']
# 2025-06-05 16:29:44.733 | INFO     | __main__:process_row_for_body:96 - Row 170: Found 1 issues in body: ['24643']
# 2025-06-05 16:29:44.737 | INFO     | __main__:process_row_for_body:96 - Row 171: Found 1 issues in body: ['25441']
# 2025-06-05 16:29:44.740 | INFO     | __main__:process_row_for_body:96 - Row 172: Found 1 issues in body: ['22002']
# 2025-06-05 16:29:44.741 | INFO     | __main__:process_row_for_body:96 - Row 173: Found 1 issues in body: ['40127']
# 2025-06-05 16:29:44.741 | INFO     | __main__:process_row_for_body:96 - Row 174: Found 2 issues in body: ['35057', '34919']
# 2025-06-05 16:29:44.741 | INFO     | __main__:process_row_for_body:96 - Row 175: Found 1 issues in body: ['26346']
# 2025-06-05 16:29:44.741 | INFO     | __main__:process_row_for_body:96 - Row 176: Found 2 issues in body: ['23000', '22025']
# 2025-06-05 16:29:44.751 | INFO     | __main__:process_row_for_body:96 - Row 177: Found 3 issues in body: ['41174', '39324', '19804']
# 2025-06-05 16:29:44.753 | INFO     | __main__:process_row_for_body:96 - Row 179: Found 1 issues in body: ['39892']
# 2025-06-05 16:29:44.756 | INFO     | __main__:process_row_for_body:96 - Row 182: Found 1 issues in body: ['20884']
# 2025-06-05 16:29:44.756 | INFO     | __main__:process_row_for_body:96 - Row 184: Found 2 issues in body: ['26584', '26430']
# 2025-06-05 16:29:44.756 | INFO     | __main__:process_row_for_body:96 - Row 185: Found 1 issues in body: ['24158']
# 2025-06-05 16:29:44.756 | INFO     | __main__:process_row_for_body:96 - Row 186: Found 1 issues in body: ['40127']
# 2025-06-05 16:29:44.756 | INFO     | __main__:process_row_for_body:96 - Row 187: Found 1 issues in body: ['35578']
# 2025-06-05 16:29:44.756 | INFO     | __main__:process_row_for_body:96 - Row 188: Found 3 issues in body: ['25955', '517', '22927']
# 2025-06-05 16:29:44.756 | INFO     | __main__:process_row_for_body:96 - Row 190: Found 1 issues in body: ['37666']
# 2025-06-05 16:29:44.768 | INFO     | __main__:process_row_for_body:96 - Row 192: Found 1 issues in body: ['24959']
# 2025-06-05 16:29:44.770 | INFO     | __main__:process_row_for_body:96 - Row 193: Found 1 issues in body: ['40289']
# 2025-06-05 16:29:44.771 | INFO     | __main__:process_row_for_body:96 - Row 196: Found 1 issues in body: ['29183']
# 2025-06-05 16:29:44.771 | INFO     | __main__:process_row_for_body:96 - Row 197: Found 2 issues in body: ['37734', '37199']
# 2025-06-05 16:29:44.771 | INFO     | __main__:process_row_for_body:96 - Row 198: Found 1 issues in body: ['25395']
# 2025-06-05 16:29:44.771 | INFO     | __main__:process_row_for_body:96 - Row 199: Found 1 issues in body: ['22037']
# 2025-06-05 16:29:44.771 | INFO     | __main__:process_row_for_body:96 - Row 200: Found 1 issues in body: ['40292']
# 2025-06-05 16:29:44.771 | INFO     | __main__:process_row_for_body:96 - Row 206: Found 1 issues in body: ['40045']
# 2025-06-05 16:29:44.771 | INFO     | __main__:process_row_for_body:96 - Row 207: Found 1 issues in body: ['173']
# 2025-06-05 16:29:44.785 | INFO     | __main__:process_row_for_body:96 - Row 209: Found 2 issues in body: ['24412', '12804']
# 2025-06-05 16:29:44.787 | INFO     | __main__:process_row_for_body:96 - Row 210: Found 1 issues in body: ['40313']
# 2025-06-05 16:29:44.788 | INFO     | __main__:process_row_for_body:96 - Row 211: Found 3 issues in body: ['26265', '26251', '26071']
# 2025-06-05 16:29:44.791 | INFO     | __main__:process_row_for_body:96 - Row 213: Found 1 issues in body: ['36652']
# 2025-06-05 16:29:44.791 | INFO     | __main__:process_row_for_body:96 - Row 214: Found 2 issues in body: ['25326', '25592']
# 2025-06-05 16:29:44.793 | INFO     | __main__:process_row_for_body:96 - Row 215: Found 1 issues in body: ['1394']
# 2025-06-05 16:29:44.793 | INFO     | __main__:process_row_for_body:96 - Row 219: Found 1 issues in body: ['5106']
# 2025-06-05 16:29:44.793 | INFO     | __main__:process_row_for_body:96 - Row 220: Found 3 issues in body: ['4386', '2637', '3334']
# Processing PR Bodies:   1%|          | 237/25042 [00:00<00:23, 1064.83it/s]2025-06-05 16:29:44.793 | INFO     | __main__:process_row_for_body:96 - Row 225: Found 1 issues in body: ['4950']
# 2025-06-05 16:29:44.800 | INFO     | __main__:process_row_for_body:96 - Row 227: Found 2 issues in body: ['2774', '3655']
# 2025-06-05 16:29:44.802 | INFO     | __main__:process_row_for_body:96 - Row 228: Found 1 issues in body: ['4589']
# 2025-06-05 16:29:44.804 | INFO     | __main__:process_row_for_body:96 - Row 229: Found 1 issues in body: ['4575']
# 2025-06-05 16:29:44.808 | INFO     | __main__:process_row_for_body:96 - Row 240: Found 1 issues in body: ['4950']
# 2025-06-05 16:29:44.808 | INFO     | __main__:process_row_for_body:96 - Row 243: Found 1 issues in body: ['4509']
# 2025-06-05 16:29:44.808 | INFO     | __main__:process_row_for_body:96 - Row 244: Found 1 issues in body: ['3601']
# 2025-06-05 16:29:44.808 | INFO     | __main__:process_row_for_body:96 - Row 246: Found 1 issues in body: ['4504']
# 2025-06-05 16:29:44.808 | INFO     | __main__:process_row_for_body:96 - Row 250: Found 1 issues in body: ['4716']
# 2025-06-05 16:29:44.818 | INFO     | __main__:process_row_for_body:96 - Row 254: Found 1 issues in body: ['3997']
# 2025-06-05 16:29:44.820 | INFO     | __main__:process_row_for_body:96 - Row 256: Found 1 issues in body: ['161']
# 2025-06-05 16:29:44.821 | INFO     | __main__:process_row_for_body:96 - Row 261: Found 1 issues in body: ['4567']
# 2025-06-05 16:29:44.821 | INFO     | __main__:process_row_for_body:96 - Row 263: Found 2 issues in body: ['5262', '5263']
# 2025-06-05 16:29:44.825 | INFO     | __main__:process_row_for_body:96 - Row 270: Found 1 issues in body: ['32']
# 2025-06-05 16:29:44.827 | INFO     | __main__:process_row_for_body:96 - Row 271: Found 1 issues in body: ['12926']
# 2025-06-05 16:29:44.827 | INFO     | __main__:process_row_for_body:96 - Row 273: Found 1 issues in body: ['22214']
# 2025-06-05 16:29:44.829 | INFO     | __main__:process_row_for_body:96 - Row 275: Found 1 issues in body: ['24534']
# 2025-06-05 16:29:44.831 | INFO     | __main__:process_row_for_body:96 - Row 276: Found 1 issues in body: ['10959']
# 2025-06-05 16:29:44.834 | INFO     | __main__:process_row_for_body:96 - Row 277: Found 1 issues in body: ['24599']
# 2025-06-05 16:29:44.834 | INFO     | __main__:process_row_for_body:96 - Row 279: Found 1 issues in body: ['20829']
# 2025-06-05 16:29:44.834 | INFO     | __main__:process_row_for_body:96 - Row 281: Found 1 issues in body: ['22199']
# 2025-06-05 16:29:44.834 | INFO     | __main__:process_row_for_body:96 - Row 285: Found 2 issues in body: ['21801', '22230']
# 2025-06-05 16:29:44.834 | INFO     | __main__:process_row_for_body:96 - Row 288: Found 1 issues in body: ['24584']
# 2025-06-05 16:29:44.834 | INFO     | __main__:process_row_for_body:96 - Row 289: Found 1 issues in body: ['22227']
# 2025-06-05 16:29:44.872 | INFO     | __main__:process_row_for_body:96 - Row 302: Found 1 issues in body: ['19877']
# 2025-06-05 16:29:44.885 | INFO     | __main__:process_row_for_body:96 - Row 303: Found 2 issues in body: ['20150', '19871']
# 2025-06-05 16:29:44.834 | INFO     | __main__:process_row_for_body:96 - Row 291: Found 1 issues in body: ['24541']
# 2025-06-05 16:29:44.902 | INFO     | __main__:process_row_for_body:96 - Row 306: Found 1 issues in body: ['19075']
# 2025-06-05 16:29:44.906 | INFO     | __main__:process_row_for_body:96 - Row 309: Found 1 issues in body: ['18791']
# 2025-06-05 16:29:44.859 | INFO     | __main__:process_row_for_body:96 - Row 299: Found 1 issues in body: ['19981']
# 2025-06-05 16:29:44.912 | INFO     | __main__:process_row_for_body:96 - Row 311: Found 5 issues in body: ['20069', '19842', '20101', '20103', '20063']
# 2025-06-05 16:29:44.888 | INFO     | __main__:process_row_for_body:96 - Row 305: Found 1 issues in body: ['19981']
# 2025-06-05 16:29:44.834 | INFO     | __main__:process_row_for_body:96 - Row 292: Found 1 issues in body: ['21923']
# 2025-06-05 16:29:44.834 | INFO     | __main__:process_row_for_body:96 - Row 293: Found 1 issues in body: ['20829']
# 2025-06-05 16:29:44.852 | INFO     | __main__:process_row_for_body:96 - Row 297: Found 3 issues in body: ['21850', '22209', '22201']
# 2025-06-05 16:29:44.856 | INFO     | __main__:process_row_for_body:96 - Row 298: Found 1 issues in body: ['24631']
# 2025-06-05 16:29:44.910 | INFO     | __main__:process_row_for_body:96 - Row 310: Found 1 issues in body: ['20056']
# 2025-06-05 16:29:44.865 | INFO     | __main__:process_row_for_body:96 - Row 301: Found 1 issues in body: ['19300']
# 2025-06-05 16:29:44.916 | INFO     | __main__:process_row_for_body:96 - Row 313: Found 3 issues in body: ['20081', '20126', '19939']
# 2025-06-05 16:29:44.940 | INFO     | __main__:process_row_for_body:96 - Row 322: Found 1 issues in body: ['20117']
# 2025-06-05 16:29:44.923 | INFO     | __main__:process_row_for_body:96 - Row 315: Found 1 issues in body: ['19994']
# 2025-06-05 16:29:44.923 | INFO     | __main__:process_row_for_body:96 - Row 316: Found 1 issues in body: ['19299']
# 2025-06-05 16:29:44.923 | INFO     | __main__:process_row_for_body:96 - Row 317: Found 1 issues in body: ['18907']
# 2025-06-05 16:29:44.931 | INFO     | __main__:process_row_for_body:96 - Row 319: Found 1 issues in body: ['19456']
# 2025-06-05 16:29:44.933 | INFO     | __main__:process_row_for_body:96 - Row 320: Found 1 issues in body: ['20119']
# 2025-06-05 16:29:44.934 | INFO     | __main__:process_row_for_body:96 - Row 321: Found 1 issues in body: ['18427']
# 2025-06-05 16:29:44.923 | INFO     | __main__:process_row_for_body:96 - Row 314: Found 1 issues in body: ['10050']
# 2025-06-05 16:29:44.949 | INFO     | __main__:process_row_for_body:96 - Row 324: Found 1 issues in body: ['19858']
# 2025-06-05 16:29:44.954 | INFO     | __main__:process_row_for_body:96 - Row 328: Found 1 issues in body: ['29077']
# 2025-06-05 16:29:44.956 | INFO     | __main__:process_row_for_body:96 - Row 332: Found 1 issues in body: ['29627']
# 2025-06-05 16:29:44.959 | INFO     | __main__:process_row_for_body:96 - Row 333: Found 2 issues in body: ['29160', '28352']
# 2025-06-05 16:29:44.959 | INFO     | __main__:process_row_for_body:96 - Row 334: Found 2 issues in body: ['29368', '29219']
# 2025-06-05 16:29:44.959 | INFO     | __main__:process_row_for_body:96 - Row 336: Found 1 issues in body: ['29086']
# 2025-06-05 16:29:44.966 | INFO     | __main__:process_row_for_body:96 - Row 339: Found 1 issues in body: ['29385']
# 2025-06-05 16:29:44.968 | INFO     | __main__:process_row_for_body:96 - Row 340: Found 1 issues in body: ['29066']
# Processing PR Bodies:   1%|▏         | 345/25042 [00:00<00:29, 840.29it/s] 2025-06-05 16:29:44.971 | INFO     | __main__:process_row_for_body:96 - Row 342: Found 2 issues in body: ['28711', '28018']
# 2025-06-05 16:29:44.972 | INFO     | __main__:process_row_for_body:96 - Row 344: Found 1 issues in body: ['29071']
# 2025-06-05 16:29:44.972 | INFO     | __main__:process_row_for_body:96 - Row 345: Found 1 issues in body: ['29572']
# 2025-06-05 16:29:44.972 | INFO     | __main__:process_row_for_body:96 - Row 346: Found 1 issues in body: ['28998']
# 2025-06-05 16:29:44.972 | INFO     | __main__:process_row_for_body:96 - Row 347: Found 1 issues in body: ['28998']
# 2025-06-05 16:29:44.972 | INFO     | __main__:process_row_for_body:96 - Row 350: Found 2 issues in body: ['32477', '28883']
# 2025-06-05 16:29:44.972 | INFO     | __main__:process_row_for_body:96 - Row 352: Found 1 issues in body: ['27765']
# 2025-06-05 16:29:44.985 | INFO     | __main__:process_row_for_body:96 - Row 355: Found 1 issues in body: ['32648']
# 2025-06-05 16:29:44.987 | INFO     | __main__:process_row_for_body:96 - Row 358: Found 1 issues in body: ['26915']
# 2025-06-05 16:29:44.987 | INFO     | __main__:process_row_for_body:96 - Row 363: Found 1 issues in body: ['32531']
# 2025-06-05 16:29:44.987 | INFO     | __main__:process_row_for_body:96 - Row 366: Found 2 issues in body: ['28064', '31385']
# 2025-06-05 16:29:44.987 | INFO     | __main__:process_row_for_body:96 - Row 371: Found 1 issues in body: ['7869']
# 2025-06-05 16:29:44.987 | INFO     | __main__:process_row_for_body:96 - Row 385: Found 1 issues in body: ['22052']
# 2025-06-05 16:29:45.005 | INFO     | __main__:process_row_for_body:96 - Row 391: Found 2 issues in body: ['32369', '32230']
# 2025-06-05 16:29:45.005 | INFO     | __main__:process_row_for_body:96 - Row 393: Found 1 issues in body: ['24697']
# 2025-06-05 16:29:45.005 | INFO     | __main__:process_row_for_body:96 - Row 396: Found 1 issues in body: ['32589']
# 2025-06-05 16:29:45.005 | INFO     | __main__:process_row_for_body:96 - Row 402: Found 3 issues in body: ['31707', '31822', '13158']
# 2025-06-05 16:29:45.005 | INFO     | __main__:process_row_for_body:96 - Row 406: Found 2 issues in body: ['28439', '9144']
# 2025-06-05 16:29:45.016 | INFO     | __main__:process_row_for_body:96 - Row 409: Found 1 issues in body: ['6049']
# 2025-06-05 16:29:45.018 | INFO     | __main__:process_row_for_body:96 - Row 411: Found 1 issues in body: ['7346']
# 2025-06-05 16:29:45.020 | INFO     | __main__:process_row_for_body:96 - Row 412: Found 1 issues in body: ['32437']
# 2025-06-05 16:29:45.022 | INFO     | __main__:process_row_for_body:96 - Row 418: Found 1 issues in body: ['32683']
# 2025-06-05 16:29:45.024 | INFO     | __main__:process_row_for_body:96 - Row 424: Found 1 issues in body: ['32493']
# 2025-06-05 16:29:45.026 | INFO     | __main__:process_row_for_body:96 - Row 429: Found 3 issues in body: ['31717', '31444', '31713']
# 2025-06-05 16:29:45.028 | INFO     | __main__:process_row_for_body:96 - Row 432: Found 1 issues in body: ['32663']
# 2025-06-05 16:29:45.030 | INFO     | __main__:process_row_for_body:96 - Row 435: Found 1 issues in body: ['22141']
# 2025-06-05 16:29:45.031 | INFO     | __main__:process_row_for_body:96 - Row 436: Found 1 issues in body: ['40131']
# 2025-06-05 16:29:45.034 | INFO     | __main__:process_row_for_body:96 - Row 437: Found 1 issues in body: ['37379']
# 2025-06-05 16:29:45.036 | INFO     | __main__:process_row_for_body:96 - Row 438: Found 1 issues in body: ['26707']
# 2025-06-05 16:29:45.037 | INFO     | __main__:process_row_for_body:96 - Row 439: Found 2 issues in body: ['12667', '12661']
# 2025-06-05 16:29:45.038 | INFO     | __main__:process_row_for_body:96 - Row 442: Found 1 issues in body: ['38510']
# 2025-06-05 16:29:45.039 | INFO     | __main__:process_row_for_body:96 - Row 443: Found 1 issues in body: ['26707']
# 2025-06-05 16:29:45.041 | INFO     | __main__:process_row_for_body:96 - Row 445: Found 1 issues in body: ['38065']
# 2025-06-05 16:29:45.043 | INFO     | __main__:process_row_for_body:96 - Row 446: Found 1 issues in body: ['12497']
# 2025-06-05 16:29:45.044 | INFO     | __main__:process_row_for_body:96 - Row 447: Found 1 issues in body: ['26678']
# 2025-06-05 16:29:45.045 | INFO     | __main__:process_row_for_body:96 - Row 448: Found 1 issues in body: ['25041']
# 2025-06-05 16:29:45.045 | INFO     | __main__:process_row_for_body:96 - Row 449: Found 1 issues in body: ['12785']
# 2025-06-05 16:29:45.045 | INFO     | __main__:process_row_for_body:96 - Row 450: Found 1 issues in body: ['39717']
# 2025-06-05 16:29:45.051 | INFO     | __main__:process_row_for_body:96 - Row 452: Found 2 issues in body: ['26362', '17208']
# 2025-06-05 16:29:45.052 | INFO     | __main__:process_row_for_body:96 - Row 454: Found 1 issues in body: ['36811']
# 2025-06-05 16:29:45.056 | INFO     | __main__:process_row_for_body:96 - Row 457: Found 1 issues in body: ['26204']
# 2025-06-05 16:29:45.056 | INFO     | __main__:process_row_for_body:96 - Row 459: Found 1 issues in body: ['40220']
# 2025-06-05 16:29:45.056 | INFO     | __main__:process_row_for_body:96 - Row 460: Found 1 issues in body: ['37688']
# Processing PR Bodies:   2%|▏         | 461/25042 [00:00<00:26, 942.63it/s]2025-06-05 16:29:45.056 | INFO     | __main__:process_row_for_body:96 - Row 461: Found 1 issues in body: ['26716']
# 2025-06-05 16:29:45.056 | INFO     | __main__:process_row_for_body:96 - Row 462: Found 1 issues in body: ['12781']
# 2025-06-05 16:29:45.056 | INFO     | __main__:process_row_for_body:96 - Row 463: Found 1 issues in body: ['25185']
# 2025-06-05 16:29:45.056 | INFO     | __main__:process_row_for_body:96 - Row 464: Found 1 issues in body: ['39905']
# 2025-06-05 16:29:45.067 | INFO     | __main__:process_row_for_body:96 - Row 466: Found 1 issues in body: ['25971']
# 2025-06-05 16:29:45.069 | INFO     | __main__:process_row_for_body:96 - Row 467: Found 1 issues in body: ['12747']
# 2025-06-05 16:29:45.071 | INFO     | __main__:process_row_for_body:96 - Row 468: Found 1 issues in body: ['40280']
# 2025-06-05 16:29:45.074 | INFO     | __main__:process_row_for_body:96 - Row 472: Found 2 issues in body: ['22757', '24984']
# 2025-06-05 16:29:45.074 | INFO     | __main__:process_row_for_body:96 - Row 473: Found 1 issues in body: ['12791']
# 2025-06-05 16:29:45.074 | INFO     | __main__:process_row_for_body:96 - Row 477: Found 1 issues in body: ['12789']
# 2025-06-05 16:29:45.082 | INFO     | __main__:process_row_for_body:96 - Row 480: Found 1 issues in body: ['32398']
# 2025-06-05 16:29:45.098 | INFO     | __main__:process_row_for_body:96 - Row 481: Found 2 issues in body: ['26054', '24443']
# 2025-06-05 16:29:45.099 | INFO     | __main__:process_row_for_body:96 - Row 482: Found 1 issues in body: ['20884']
# 2025-06-05 16:29:45.101 | INFO     | __main__:process_row_for_body:96 - Row 483: Found 1 issues in body: ['12795']
# 2025-06-05 16:29:45.104 | INFO     | __main__:process_row_for_body:96 - Row 484: Found 1 issues in body: ['40309']
# 2025-06-05 16:29:45.105 | INFO     | __main__:process_row_for_body:96 - Row 485: Found 1 issues in body: ['26701']
# 2025-06-05 16:29:45.105 | INFO     | __main__:process_row_for_body:96 - Row 486: Found 1 issues in body: ['12700']
# 2025-06-05 16:29:45.105 | INFO     | __main__:process_row_for_body:96 - Row 487: Found 1 issues in body: ['24995']
# 2025-06-05 16:29:45.105 | INFO     | __main__:process_row_for_body:96 - Row 488: Found 1 issues in body: ['40309']
# 2025-06-05 16:29:45.105 | INFO     | __main__:process_row_for_body:96 - Row 492: Found 1 issues in body: ['21791']
# 2025-06-05 16:29:45.105 | INFO     | __main__:process_row_for_body:96 - Row 494: Found 1 issues in body: ['1212']
# 2025-06-05 16:29:45.120 | INFO     | __main__:process_row_for_body:96 - Row 497: Found 1 issues in body: ['35543']
# 2025-06-05 16:29:45.124 | INFO     | __main__:process_row_for_body:96 - Row 499: Found 1 issues in body: ['24956']
# 2025-06-05 16:29:45.126 | INFO     | __main__:process_row_for_body:96 - Row 500: Found 1 issues in body: ['10818']
# 2025-06-05 16:29:45.126 | INFO     | __main__:process_row_for_body:96 - Row 501: Found 1 issues in body: ['40278']
# 2025-06-05 16:29:45.126 | INFO     | __main__:process_row_for_body:96 - Row 503: Found 1 issues in body: ['12754']
# 2025-06-05 16:29:45.126 | INFO     | __main__:process_row_for_body:96 - Row 504: Found 2 issues in body: ['40296', '40308']
# 2025-06-05 16:29:45.134 | INFO     | __main__:process_row_for_body:96 - Row 508: Found 1 issues in body: ['91']
# 2025-06-05 16:29:45.136 | INFO     | __main__:process_row_for_body:96 - Row 511: Found 1 issues in body: ['40318']
# 2025-06-05 16:29:45.137 | INFO     | __main__:process_row_for_body:96 - Row 513: Found 1 issues in body: ['25598']
# 2025-06-05 16:29:45.138 | INFO     | __main__:process_row_for_body:96 - Row 515: Found 1 issues in body: ['25164']
# 2025-06-05 16:29:45.139 | INFO     | __main__:process_row_for_body:96 - Row 516: Found 1 issues in body: ['40302']
# 2025-06-05 16:29:45.141 | INFO     | __main__:process_row_for_body:96 - Row 518: Found 1 issues in body: ['26740']
# 2025-06-05 16:29:45.144 | INFO     | __main__:process_row_for_body:96 - Row 525: Found 8 issues in body: ['13756', '13577', '13735', '13537', '12998', '13739', '13752', '12968']
# 2025-06-05 16:29:45.146 | INFO     | __main__:process_row_for_body:96 - Row 528: Found 1 issues in body: ['42523']
# 2025-06-05 16:29:45.147 | INFO     | __main__:process_row_for_body:96 - Row 530: Found 1 issues in body: ['40264']
# 2025-06-05 16:29:45.149 | INFO     | __main__:process_row_for_body:96 - Row 532: Found 1 issues in body: ['4582']
# 2025-06-05 16:29:45.151 | INFO     | __main__:process_row_for_body:96 - Row 534: Found 1 issues in body: ['42555']
# 2025-06-05 16:29:45.152 | INFO     | __main__:process_row_for_body:96 - Row 536: Found 2 issues in body: ['17774', '17353']
# 2025-06-05 16:29:45.153 | INFO     | __main__:process_row_for_body:96 - Row 538: Found 1 issues in body: ['4578']
# 2025-06-05 16:29:45.155 | INFO     | __main__:process_row_for_body:96 - Row 540: Found 1 issues in body: ['41451']
# 2025-06-05 16:29:45.156 | INFO     | __main__:process_row_for_body:96 - Row 541: Found 2 issues in body: ['17781', '17786']
# Processing PR Bodies:   2%|▏         | 570/25042 [00:00<00:24, 987.95it/s]2025-06-05 16:29:45.158 | INFO     | __main__:process_row_for_body:96 - Row 547: Found 1 issues in body: ['39814']
# 2025-06-05 16:29:45.160 | INFO     | __main__:process_row_for_body:96 - Row 549: Found 1 issues in body: ['40472']
# 2025-06-05 16:29:45.163 | INFO     | __main__:process_row_for_body:96 - Row 558: Found 1 issues in body: ['14003']
# 2025-06-05 16:29:45.166 | INFO     | __main__:process_row_for_body:96 - Row 569: Found 1 issues in body: ['40264']
# 2025-06-05 16:29:45.168 | INFO     | __main__:process_row_for_body:96 - Row 574: Found 1 issues in body: ['42504']
# 2025-06-05 16:29:45.171 | INFO     | __main__:process_row_for_body:96 - Row 576: Found 1 issues in body: ['5106']
# 2025-06-05 16:29:45.172 | INFO     | __main__:process_row_for_body:96 - Row 580: Found 1 issues in body: ['42482']
# 2025-06-05 16:29:45.175 | INFO     | __main__:process_row_for_body:96 - Row 581: Found 2 issues in body: ['17825', '17928']
# 2025-06-05 16:29:45.176 | INFO     | __main__:process_row_for_body:96 - Row 582: Found 2 issues in body: ['41227', '41226']
# 2025-06-05 16:29:45.178 | INFO     | __main__:process_row_for_body:96 - Row 587: Found 1 issues in body: ['14381']
# 2025-06-05 16:29:45.181 | INFO     | __main__:process_row_for_body:96 - Row 591: Found 1 issues in body: ['42566']
# 2025-06-05 16:29:45.182 | INFO     | __main__:process_row_for_body:96 - Row 592: Found 1 issues in body: ['17933']
# 2025-06-05 16:29:45.184 | INFO     | __main__:process_row_for_body:96 - Row 593: Found 1 issues in body: ['35517']
# 2025-06-05 16:29:45.185 | INFO     | __main__:process_row_for_body:96 - Row 594: Found 2 issues in body: ['5283', '5282']
# 2025-06-05 16:29:45.187 | INFO     | __main__:process_row_for_body:96 - Row 598: Found 1 issues in body: ['42566']
# 2025-06-05 16:29:45.190 | INFO     | __main__:process_row_for_body:96 - Row 600: Found 2 issues in body: ['40717', '40604']
# 2025-06-05 16:29:45.192 | INFO     | __main__:process_row_for_body:96 - Row 604: Found 1 issues in body: ['5013']
# 2025-06-05 16:29:45.192 | INFO     | __main__:process_row_for_body:96 - Row 606: Found 1 issues in body: ['17779']
# 2025-06-05 16:29:45.196 | INFO     | __main__:process_row_for_body:96 - Row 614: Found 2 issues in body: ['17914', '17948']
# 2025-06-05 16:29:45.196 | INFO     | __main__:process_row_for_body:96 - Row 615: Found 1 issues in body: ['5272']
# 2025-06-05 16:29:45.201 | INFO     | __main__:process_row_for_body:96 - Row 616: Found 2 issues in body: ['33066', '32976']
# 2025-06-05 16:29:45.203 | INFO     | __main__:process_row_for_body:96 - Row 617: Found 1 issues in body: ['4534']
# 2025-06-05 16:29:45.204 | INFO     | __main__:process_row_for_body:96 - Row 618: Found 1 issues in body: ['40264']
# 2025-06-05 16:29:45.206 | INFO     | __main__:process_row_for_body:96 - Row 621: Found 1 issues in body: ['5279']
# 2025-06-05 16:29:45.208 | INFO     | __main__:process_row_for_body:96 - Row 622: Found 1 issues in body: ['4558']
# 2025-06-05 16:29:45.209 | INFO     | __main__:process_row_for_body:96 - Row 625: Found 1 issues in body: ['17934']
# 2025-06-05 16:29:45.211 | INFO     | __main__:process_row_for_body:96 - Row 628: Found 1 issues in body: ['42933']
# 2025-06-05 16:29:45.212 | INFO     | __main__:process_row_for_body:96 - Row 629: Found 1 issues in body: ['44117']
# 2025-06-05 16:29:45.214 | INFO     | __main__:process_row_for_body:96 - Row 630: Found 1 issues in body: ['18931']
# 2025-06-05 16:29:45.216 | INFO     | __main__:process_row_for_body:96 - Row 631: Found 1 issues in body: ['18902']
# 2025-06-05 16:29:45.219 | INFO     | __main__:process_row_for_body:96 - Row 633: Found 1 issues in body: ['19914']
# 2025-06-05 16:29:45.221 | INFO     | __main__:process_row_for_body:96 - Row 634: Found 2 issues in body: ['29682', '29691']
# 2025-06-05 16:29:45.222 | INFO     | __main__:process_row_for_body:96 - Row 635: Found 1 issues in body: ['20139']
# 2025-06-05 16:29:45.224 | INFO     | __main__:process_row_for_body:96 - Row 636: Found 1 issues in body: ['18751']
# 2025-06-05 16:29:45.241 | INFO     | __main__:process_row_for_body:96 - Row 645: Found 1 issues in body: ['28893']
# 2025-06-05 16:29:45.251 | INFO     | __main__:process_row_for_body:96 - Row 646: Found 1 issues in body: ['19662']
# 2025-06-05 16:29:45.227 | INFO     | __main__:process_row_for_body:96 - Row 639: Found 1 issues in body: ['20128']
# 2025-06-05 16:29:45.229 | INFO     | __main__:process_row_for_body:96 - Row 640: Found 2 issues in body: ['28665', '29070']
# 2025-06-05 16:29:45.230 | INFO     | __main__:process_row_for_body:96 - Row 642: Found 2 issues in body: ['29682', '29691']
# 2025-06-05 16:29:45.232 | INFO     | __main__:process_row_for_body:96 - Row 643: Found 1 issues in body: ['20007']
# 2025-06-05 16:29:45.233 | INFO     | __main__:process_row_for_body:96 - Row 644: Found 1 issues in body: ['18955']
# 2025-06-05 16:29:45.225 | INFO     | __main__:process_row_for_body:96 - Row 637: Found 1 issues in body: ['28714']
# 2025-06-05 16:29:45.226 | INFO     | __main__:process_row_for_body:96 - Row 638: Found 1 issues in body: ['28879']
# 2025-06-05 16:29:45.255 | INFO     | __main__:process_row_for_body:96 - Row 647: Found 3 issues in body: ['29273', '28714', '29367']
# 2025-06-05 16:29:45.257 | INFO     | __main__:process_row_for_body:96 - Row 648: Found 1 issues in body: ['19981']
# 2025-06-05 16:29:45.259 | INFO     | __main__:process_row_for_body:96 - Row 649: Found 1 issues in body: ['28285']
# 2025-06-05 16:29:45.261 | INFO     | __main__:process_row_for_body:96 - Row 651: Found 1 issues in body: ['19954']
# 2025-06-05 16:29:45.263 | INFO     | __main__:process_row_for_body:96 - Row 652: Found 5 issues in body: ['29561', '29450', '29455', '29392', '26044']
# 2025-06-05 16:29:45.264 | INFO     | __main__:process_row_for_body:96 - Row 653: Found 1 issues in body: ['19216']
# 2025-06-05 16:29:45.267 | INFO     | __main__:process_row_for_body:96 - Row 654: Found 2 issues in body: ['29133', '26856']
# 2025-06-05 16:29:45.269 | INFO     | __main__:process_row_for_body:96 - Row 656: Found 1 issues in body: ['20129']
# 2025-06-05 16:29:45.270 | INFO     | __main__:process_row_for_body:96 - Row 657: Found 1 issues in body: ['29435']
# 2025-06-05 16:29:45.271 | INFO     | __main__:process_row_for_body:96 - Row 659: Found 3 issues in body: ['18449', '19224', '18505']
# 2025-06-05 16:29:45.273 | INFO     | __main__:process_row_for_body:96 - Row 660: Found 1 issues in body: ['19188']
# 2025-06-05 16:29:45.274 | INFO     | __main__:process_row_for_body:96 - Row 661: Found 1 issues in body: ['29703']
# 2025-06-05 16:29:45.276 | INFO     | __main__:process_row_for_body:96 - Row 663: Found 1 issues in body: ['29703']
# 2025-06-05 16:29:45.278 | INFO     | __main__:process_row_for_body:96 - Row 664: Found 1 issues in body: ['20153']
# 2025-06-05 16:29:45.279 | INFO     | __main__:process_row_for_body:96 - Row 665: Found 1 issues in body: ['15800']
# 2025-06-05 16:29:45.281 | INFO     | __main__:process_row_for_body:96 - Row 667: Found 1 issues in body: ['20153']
# 2025-06-05 16:29:45.282 | INFO     | __main__:process_row_for_body:96 - Row 668: Found 1 issues in body: ['29703']
# 2025-06-05 16:29:45.284 | INFO     | __main__:process_row_for_body:96 - Row 670: Found 2 issues in body: ['28855', '29100']
# Processing PR Bodies:   3%|▎         | 673/25042 [00:00<00:26, 927.64it/s]2025-06-05 16:29:45.286 | INFO     | __main__:process_row_for_body:96 - Row 671: Found 1 issues in body: ['14214']
# 2025-06-05 16:29:45.288 | INFO     | __main__:process_row_for_body:96 - Row 673: Found 8 issues in body: ['28194', '25154', '28297', '25153', '28979', '29022', '28207', '28970']
# 2025-06-05 16:29:45.290 | INFO     | __main__:process_row_for_body:96 - Row 674: Found 1 issues in body: ['19104']
# 2025-06-05 16:29:45.291 | INFO     | __main__:process_row_for_body:96 - Row 675: Found 1 issues in body: ['19105']
# 2025-06-05 16:29:45.294 | INFO     | __main__:process_row_for_body:96 - Row 676: Found 4 issues in body: ['8203', '15120', '14816', '15100']
# 2025-06-05 16:29:45.296 | INFO     | __main__:process_row_for_body:96 - Row 678: Found 1 issues in body: ['20159']
# 2025-06-05 16:29:45.298 | INFO     | __main__:process_row_for_body:96 - Row 681: Found 1 issues in body: ['20160']
# 2025-06-05 16:29:45.299 | INFO     | __main__:process_row_for_body:96 - Row 682: Found 1 issues in body: ['20832']
# 2025-06-05 16:29:45.301 | INFO     | __main__:process_row_for_body:96 - Row 684: Found 1 issues in body: ['22213']
# 2025-06-05 16:29:45.303 | INFO     | __main__:process_row_for_body:96 - Row 685: Found 1 issues in body: ['24534']
# 2025-06-05 16:29:45.304 | INFO     | __main__:process_row_for_body:96 - Row 686: Found 2 issues in body: ['23577', '23532']
# 2025-06-05 16:29:45.305 | INFO     | __main__:process_row_for_body:96 - Row 688: Found 2 issues in body: ['23816', '24564']
# 2025-06-05 16:29:45.308 | INFO     | __main__:process_row_for_body:96 - Row 693: Found 1 issues in body: ['24393']
# 2025-06-05 16:29:45.309 | INFO     | __main__:process_row_for_body:96 - Row 694: Found 2 issues in body: ['24388', '24293']
# 2025-06-05 16:29:45.312 | INFO     | __main__:process_row_for_body:96 - Row 695: Found 1 issues in body: ['20832']
# 2025-06-05 16:29:45.314 | INFO     | __main__:process_row_for_body:96 - Row 696: Found 1 issues in body: ['24606']
# 2025-06-05 16:29:45.315 | INFO     | __main__:process_row_for_body:96 - Row 698: Found 1 issues in body: ['24566']
# 2025-06-05 16:29:45.317 | INFO     | __main__:process_row_for_body:96 - Row 700: Found 2 issues in body: ['21676', '21652']
# 2025-06-05 16:29:45.319 | INFO     | __main__:process_row_for_body:96 - Row 702: Found 1 issues in body: ['24421']
# 2025-06-05 16:29:45.320 | INFO     | __main__:process_row_for_body:96 - Row 703: Found 1 issues in body: ['20832']
# 2025-06-05 16:29:45.323 | INFO     | __main__:process_row_for_body:96 - Row 708: Found 1 issues in body: ['20825']
# 2025-06-05 16:29:45.326 | INFO     | __main__:process_row_for_body:96 - Row 711: Found 1 issues in body: ['11178']
# 2025-06-05 16:29:45.333 | INFO     | __main__:process_row_for_body:96 - Row 717: Found 1 issues in body: ['11046']
# 2025-06-05 16:29:45.335 | INFO     | __main__:process_row_for_body:96 - Row 718: Found 1 issues in body: ['11152']
# 2025-06-05 16:29:45.337 | INFO     | __main__:process_row_for_body:96 - Row 720: Found 1 issues in body: ['12703']
# 2025-06-05 16:29:45.341 | INFO     | __main__:process_row_for_body:96 - Row 726: Found 1 issues in body: ['10909']
# 2025-06-05 16:29:45.343 | INFO     | __main__:process_row_for_body:96 - Row 731: Found 1 issues in body: ['10723']
# 2025-06-05 16:29:45.346 | INFO     | __main__:process_row_for_body:96 - Row 736: Found 1 issues in body: ['11165']
# 2025-06-05 16:29:45.348 | INFO     | __main__:process_row_for_body:96 - Row 747: Found 3 issues in body: ['12256', '12387', '12369']
# 2025-06-05 16:29:45.353 | INFO     | __main__:process_row_for_body:96 - Row 752: Found 1 issues in body: ['5210']
# 2025-06-05 16:29:45.354 | INFO     | __main__:process_row_for_body:96 - Row 753: Found 1 issues in body: ['9983']
# 2025-06-05 16:29:45.357 | INFO     | __main__:process_row_for_body:96 - Row 758: Found 1 issues in body: ['12755']
# 2025-06-05 16:29:45.359 | INFO     | __main__:process_row_for_body:96 - Row 761: Found 1 issues in body: ['12220']
# 2025-06-05 16:29:45.361 | INFO     | __main__:process_row_for_body:96 - Row 773: Found 1 issues in body: ['11014']
# 2025-06-05 16:29:45.363 | INFO     | __main__:process_row_for_body:96 - Row 775: Found 1 issues in body: ['8398']
# 2025-06-05 16:29:45.365 | INFO     | __main__:process_row_for_body:96 - Row 779: Found 1 issues in body: ['6890']
# 2025-06-05 16:29:45.369 | INFO     | __main__:process_row_for_body:96 - Row 787: Found 1 issues in body: ['11186']
# 2025-06-05 16:29:45.372 | INFO     | __main__:process_row_for_body:96 - Row 794: Found 1 issues in body: ['9902']
# 2025-06-05 16:29:45.374 | INFO     | __main__:process_row_for_body:96 - Row 796: Found 1 issues in body: ['32673']
# 2025-06-05 16:29:45.376 | INFO     | __main__:process_row_for_body:96 - Row 798: Found 1 issues in body: ['40343']
# 2025-06-05 16:29:45.378 | INFO     | __main__:process_row_for_body:96 - Row 799: Found 1 issues in body: ['32676']
# 2025-06-05 16:29:45.381 | INFO     | __main__:process_row_for_body:96 - Row 801: Found 1 issues in body: ['40277']
# 2025-06-05 16:29:45.382 | INFO     | __main__:process_row_for_body:96 - Row 802: Found 1 issues in body: ['32676']
# 2025-06-05 16:29:45.385 | INFO     | __main__:process_row_for_body:96 - Row 805: Found 1 issues in body: ['40315']
# 2025-06-05 16:29:45.387 | INFO     | __main__:process_row_for_body:96 - Row 807: Found 1 issues in body: ['32214']
# Processing PR Bodies:   3%|▎         | 807/25042 [00:00<00:23, 1047.27it/s]2025-06-05 16:29:45.389 | INFO     | __main__:process_row_for_body:96 - Row 808: Found 1 issues in body: ['35488']
# 2025-06-05 16:29:45.392 | INFO     | __main__:process_row_for_body:96 - Row 809: Found 1 issues in body: ['31791']
# 2025-06-05 16:29:45.393 | INFO     | __main__:process_row_for_body:96 - Row 810: Found 3 issues in body: ['38968', '38826', '38072']
# 2025-06-05 16:29:45.394 | INFO     | __main__:process_row_for_body:96 - Row 811: Found 1 issues in body: ['32653']
# 2025-06-05 16:29:45.396 | INFO     | __main__:process_row_for_body:96 - Row 812: Found 1 issues in body: ['40120']
# 2025-06-05 16:29:45.398 | INFO     | __main__:process_row_for_body:96 - Row 813: Found 1 issues in body: ['32567']
# 2025-06-05 16:29:45.399 | INFO     | __main__:process_row_for_body:96 - Row 814: Found 1 issues in body: ['34034']
# 2025-06-05 16:29:45.401 | INFO     | __main__:process_row_for_body:96 - Row 817: Found 1 issues in body: ['36559']
# 2025-06-05 16:29:45.403 | INFO     | __main__:process_row_for_body:96 - Row 818: Found 1 issues in body: ['31719']
# 2025-06-05 16:29:45.405 | INFO     | __main__:process_row_for_body:96 - Row 822: Found 1 issues in body: ['32653']
# 2025-06-05 16:29:45.407 | INFO     | __main__:process_row_for_body:96 - Row 824: Found 1 issues in body: ['31449']
# 2025-06-05 16:29:45.410 | INFO     | __main__:process_row_for_body:96 - Row 826: Found 1 issues in body: ['32098']
# 2025-06-05 16:29:45.412 | INFO     | __main__:process_row_for_body:96 - Row 828: Found 2 issues in body: ['32730', '32133']
# 2025-06-05 16:29:45.413 | INFO     | __main__:process_row_for_body:96 - Row 831: Found 1 issues in body: ['36543']
# 2025-06-05 16:29:45.415 | INFO     | __main__:process_row_for_body:96 - Row 832: Found 3 issues in body: ['32555', '30378', '32753']
# 2025-06-05 16:29:45.433 | INFO     | __main__:process_row_for_body:96 - Row 833: Found 12 issues in body: ['13117', '13188', '8704', '13203', '13240', '13181', '13179', '13190', '13217', '13', '13242', '13177']
# 2025-06-05 16:29:45.434 | INFO     | __main__:process_row_for_body:96 - Row 834: Found 1 issues in body: ['31197']
# 2025-06-05 16:29:45.435 | INFO     | __main__:process_row_for_body:96 - Row 835: Found 1 issues in body: ['40299']
# 2025-06-05 16:29:45.436 | INFO     | __main__:process_row_for_body:96 - Row 836: Found 1 issues in body: ['32652']
# 2025-06-05 16:29:45.439 | INFO     | __main__:process_row_for_body:96 - Row 837: Found 1 issues in body: ['40291']
# 2025-06-05 16:29:45.440 | INFO     | __main__:process_row_for_body:96 - Row 839: Found 1 issues in body: ['32675']
# 2025-06-05 16:29:45.442 | INFO     | __main__:process_row_for_body:96 - Row 840: Found 2 issues in body: ['35179', '32940']
# 2025-06-05 16:29:45.443 | INFO     | __main__:process_row_for_body:96 - Row 842: Found 1 issues in body: ['40324']
# 2025-06-05 16:29:45.445 | INFO     | __main__:process_row_for_body:96 - Row 843: Found 1 issues in body: ['31960']
# 2025-06-05 16:29:45.446 | INFO     | __main__:process_row_for_body:96 - Row 844: Found 1 issues in body: ['40154']
# 2025-06-05 16:29:45.448 | INFO     | __main__:process_row_for_body:96 - Row 845: Found 1 issues in body: ['32524']
# 2025-06-05 16:29:45.450 | INFO     | __main__:process_row_for_body:96 - Row 846: Found 1 issues in body: ['34615']
# 2025-06-05 16:29:45.469 | INFO     | __main__:process_row_for_body:96 - Row 859: Found 1 issues in body: ['17846']
# 2025-06-05 16:29:45.452 | INFO     | __main__:process_row_for_body:96 - Row 848: Found 1 issues in body: ['4433']
# 2025-06-05 16:29:45.486 | INFO     | __main__:process_row_for_body:96 - Row 868: Found 1 issues in body: ['17812']
# 2025-06-05 16:29:45.452 | INFO     | __main__:process_row_for_body:96 - Row 853: Found 2 issues in body: ['41288', '41285']
# 2025-06-05 16:29:45.452 | INFO     | __main__:process_row_for_body:96 - Row 854: Found 2 issues in body: ['17753', '17799']
# 2025-06-05 16:29:45.452 | INFO     | __main__:process_row_for_body:96 - Row 855: Found 4 issues in body: ['312', '313', '528', '530']
# 2025-06-05 16:29:45.464 | INFO     | __main__:process_row_for_body:96 - Row 857: Found 1 issues in body: ['42327']
# 2025-06-05 16:29:45.451 | INFO     | __main__:process_row_for_body:96 - Row 847: Found 1 issues in body: ['29262']
# 2025-06-05 16:29:45.484 | INFO     | __main__:process_row_for_body:96 - Row 867: Found 2 issues in body: ['41402', '42427']
# 2025-06-05 16:29:45.452 | INFO     | __main__:process_row_for_body:96 - Row 849: Found 2 issues in body: ['32369', '32230']
# 2025-06-05 16:29:45.489 | INFO     | __main__:process_row_for_body:96 - Row 869: Found 1 issues in body: ['679']
# 2025-06-05 16:29:45.490 | INFO     | __main__:process_row_for_body:96 - Row 872: Found 1 issues in body: ['33087']
# 2025-06-05 16:29:45.492 | INFO     | __main__:process_row_for_body:96 - Row 873: Found 2 issues in body: ['17816', '17751']
# 2025-06-05 16:29:45.493 | INFO     | __main__:process_row_for_body:96 - Row 874: Found 1 issues in body: ['42972']
# 2025-06-05 16:29:45.497 | INFO     | __main__:process_row_for_body:96 - Row 877: Found 1 issues in body: ['3632']
# 2025-06-05 16:29:45.500 | INFO     | __main__:process_row_for_body:96 - Row 878: Found 1 issues in body: ['17932']
# 2025-06-05 16:29:45.501 | INFO     | __main__:process_row_for_body:96 - Row 879: Found 1 issues in body: ['42976']
# 2025-06-05 16:29:45.503 | INFO     | __main__:process_row_for_body:96 - Row 881: Found 1 issues in body: ['37831']
# ...
# 2025-06-05 16:30:55.246 | INFO     | __main__:process_row_for_body:96 - Row 24784: Found 1 issues in body: ['38453']
# 2025-06-05 16:30:55.250 | INFO     | __main__:process_row_for_body:96 - Row 24785: Found 1 issues in body: ['26490']
# 2025-06-05 16:30:55.256 | INFO     | __main__:process_row_for_body:96 - Row 24788: Found 1 issues in body: ['21074']
# 2025-06-05 16:30:55.260 | INFO     | __main__:process_row_for_body:96 - Row 24790: Found 1 issues in body: ['25417']
# 2025-06-05 16:30:55.264 | INFO     | __main__:process_row_for_body:96 - Row 24791: Found 1 issues in body: ['29444']
# 2025-06-05 16:30:55.269 | INFO     | __main__:process_row_for_body:96 - Row 24792: Found 1 issues in body: ['8946']
# 2025-06-05 16:30:55.273 | INFO     | __main__:process_row_for_body:96 - Row 24793: Found 2 issues in body: ['25010', '25128']
# 2025-06-05 16:30:55.282 | INFO     | __main__:process_row_for_body:96 - Row 24797: Found 2 issues in body: ['29287', '27804']
# 2025-06-05 16:30:55.288 | INFO     | __main__:process_row_for_body:96 - Row 24800: Found 1 issues in body: ['40']
# 2025-06-05 16:30:55.291 | INFO     | __main__:process_row_for_body:96 - Row 24801: Found 1 issues in body: ['12363']
# 2025-06-05 16:30:55.294 | INFO     | __main__:process_row_for_body:96 - Row 24802: Found 1 issues in body: ['167']
# 2025-06-05 16:30:55.297 | INFO     | __main__:process_row_for_body:96 - Row 24804: Found 1 issues in body: ['25139']
# 2025-06-05 16:30:55.303 | INFO     | __main__:process_row_for_body:96 - Row 24806: Found 1 issues in body: ['29274']
# 2025-06-05 16:30:55.307 | INFO     | __main__:process_row_for_body:96 - Row 24807: Found 1 issues in body: ['39893']
# 2025-06-05 16:30:55.312 | INFO     | __main__:process_row_for_body:96 - Row 24809: Found 1 issues in body: ['35347']
# 2025-06-05 16:30:55.316 | INFO     | __main__:process_row_for_body:96 - Row 24810: Found 2 issues in body: ['20644', '20164']
# 2025-06-05 16:30:55.320 | INFO     | __main__:process_row_for_body:96 - Row 24812: Found 1 issues in body: ['40262']
# 2025-06-05 16:30:55.324 | INFO     | __main__:process_row_for_body:96 - Row 24814: Found 1 issues in body: ['29309']
# 2025-06-05 16:30:55.327 | INFO     | __main__:process_row_for_body:96 - Row 24817: Found 1 issues in body: ['25441']
# 2025-06-05 16:30:55.330 | INFO     | __main__:process_row_for_body:96 - Row 24818: Found 1 issues in body: ['29113']
# Processing PR Bodies:  99%|█████████▉| 24822/25042 [01:10<00:00, 353.92it/s]2025-06-05 16:30:55.333 | INFO     | __main__:process_row_for_body:96 - Row 24819: Found 1 issues in body: ['11239']
# 2025-06-05 16:30:55.341 | INFO     | __main__:process_row_for_body:96 - Row 24820: Found 2 issues in body: ['17749', '21303']
# 2025-06-05 16:30:55.346 | INFO     | __main__:process_row_for_body:96 - Row 24822: Found 2 issues in body: ['35546', '35548']
# 2025-06-05 16:30:55.356 | INFO     | __main__:process_row_for_body:96 - Row 24826: Found 1 issues in body: ['24922']
# 2025-06-05 16:30:55.359 | INFO     | __main__:process_row_for_body:96 - Row 24827: Found 1 issues in body: ['4366']
# 2025-06-05 16:30:55.363 | INFO     | __main__:process_row_for_body:96 - Row 24828: Found 2 issues in body: ['36984', '36559']
# 2025-06-05 16:30:55.367 | INFO     | __main__:process_row_for_body:96 - Row 24829: Found 1 issues in body: ['26659']
# 2025-06-05 16:30:55.372 | INFO     | __main__:process_row_for_body:96 - Row 24830: Found 1 issues in body: ['29325']
# 2025-06-05 16:30:55.376 | INFO     | __main__:process_row_for_body:96 - Row 24831: Found 1 issues in body: ['19347']
# 2025-06-05 16:30:55.379 | INFO     | __main__:process_row_for_body:96 - Row 24833: Found 1 issues in body: ['40264']
# 2025-06-05 16:30:55.382 | INFO     | __main__:process_row_for_body:96 - Row 24834: Found 1 issues in body: ['28959']
# 2025-06-05 16:30:55.393 | INFO     | __main__:process_row_for_body:96 - Row 24837: Found 1 issues in body: ['26601']
# 2025-06-05 16:30:55.397 | INFO     | __main__:process_row_for_body:96 - Row 24838: Found 1 issues in body: ['24259']
# 2025-06-05 16:30:55.401 | INFO     | __main__:process_row_for_body:96 - Row 24839: Found 1 issues in body: ['29239']
# 2025-06-05 16:30:55.404 | INFO     | __main__:process_row_for_body:96 - Row 24840: Found 1 issues in body: ['11312']
# 2025-06-05 16:30:55.407 | INFO     | __main__:process_row_for_body:96 - Row 24841: Found 1 issues in body: ['4367']
# 2025-06-05 16:30:55.411 | INFO     | __main__:process_row_for_body:96 - Row 24845: Found 1 issues in body: ['28172']
# 2025-06-05 16:30:55.415 | INFO     | __main__:process_row_for_body:96 - Row 24846: Found 1 issues in body: ['26621']
# 2025-06-05 16:30:55.423 | INFO     | __main__:process_row_for_body:96 - Row 24848: Found 1 issues in body: ['23691']
# 2025-06-05 16:30:55.432 | INFO     | __main__:process_row_for_body:96 - Row 24849: Found 1 issues in body: ['40163']
# 2025-06-05 16:30:55.438 | INFO     | __main__:process_row_for_body:96 - Row 24851: Found 1 issues in body: ['26636']
# 2025-06-05 16:30:55.440 | INFO     | __main__:process_row_for_body:96 - Row 24852: Found 1 issues in body: ['10584']
# 2025-06-05 16:30:55.444 | INFO     | __main__:process_row_for_body:96 - Row 24853: Found 1 issues in body: ['40262']
# Processing PR Bodies:  99%|█████████▉| 24859/25042 [01:10<00:00, 339.99it/s]2025-06-05 16:30:55.450 | INFO     | __main__:process_row_for_body:96 - Row 24854: Found 1 issues in body: ['28128']
# 2025-06-05 16:30:55.458 | INFO     | __main__:process_row_for_body:96 - Row 24856: Found 1 issues in body: ['29073']
# 2025-06-05 16:30:55.462 | INFO     | __main__:process_row_for_body:96 - Row 24858: Found 1 issues in body: ['25196']
# 2025-06-05 16:30:55.466 | INFO     | __main__:process_row_for_body:96 - Row 24859: Found 1 issues in body: ['40012']
# 2025-06-05 16:30:55.470 | INFO     | __main__:process_row_for_body:96 - Row 24860: Found 1 issues in body: ['37541']
# 2025-06-05 16:30:55.475 | INFO     | __main__:process_row_for_body:96 - Row 24862: Found 1 issues in body: ['1163']
# 2025-06-05 16:30:55.487 | INFO     | __main__:process_row_for_body:96 - Row 24869: Found 2 issues in body: ['29161', '29426']
# 2025-06-05 16:30:55.491 | INFO     | __main__:process_row_for_body:96 - Row 24871: Found 1 issues in body: ['12748']
# 2025-06-05 16:30:55.495 | INFO     | __main__:process_row_for_body:96 - Row 24873: Found 2 issues in body: ['40215', '40119']
# 2025-06-05 16:30:55.505 | INFO     | __main__:process_row_for_body:96 - Row 24882: Found 1 issues in body: ['7700']
# 2025-06-05 16:30:55.509 | INFO     | __main__:process_row_for_body:96 - Row 24884: Found 2 issues in body: ['13171', '14480']
# 2025-06-05 16:30:55.514 | INFO     | __main__:process_row_for_body:96 - Row 24885: Found 1 issues in body: ['5024']
# Processing PR Bodies:  99%|█████████▉| 24907/25042 [01:11<00:00, 370.22it/s]2025-06-05 16:30:55.528 | INFO     | __main__:process_row_for_body:96 - Row 24892: Found 8 issues in body: ['6297', '6222', '6441', '6301', '6281', '6480', '6263', '6385']
# 2025-06-05 16:30:55.539 | INFO     | __main__:process_row_for_body:96 - Row 24897: Found 3 issues in body: ['17645', '13950', '16922']
# 2025-06-05 16:30:55.545 | INFO     | __main__:process_row_for_body:96 - Row 24902: Found 2 issues in body: ['17780', '17743']
# 2025-06-05 16:30:55.553 | INFO     | __main__:process_row_for_body:96 - Row 24906: Found 3 issues in body: ['13769', '13758', '14673']
# 2025-06-05 16:30:55.558 | INFO     | __main__:process_row_for_body:96 - Row 24908: Found 1 issues in body: ['17929']
# 2025-06-05 16:30:55.563 | INFO     | __main__:process_row_for_body:96 - Row 24911: Found 1 issues in body: ['4338']
# 2025-06-05 16:30:55.582 | INFO     | __main__:process_row_for_body:96 - Row 24913: Found 16 issues in body: ['6238', '6245', '6297', '6124', '6441', '6301', '6281', '6480', '6236', '6263', '6385', '6180', '5998', '6193', '6203', '6159']
# 2025-06-05 16:30:55.595 | INFO     | __main__:process_row_for_body:96 - Row 24919: Found 1 issues in body: ['4275']
# 2025-06-05 16:30:55.599 | INFO     | __main__:process_row_for_body:96 - Row 24921: Found 1 issues in body: ['17669']
# 2025-06-05 16:30:55.613 | INFO     | __main__:process_row_for_body:96 - Row 24925: Found 1 issues in body: ['4086']
# 2025-06-05 16:30:55.627 | INFO     | __main__:process_row_for_body:96 - Row 24926: Found 3 issues in body: ['815', '818', '803']
# 2025-06-05 16:30:55.632 | INFO     | __main__:process_row_for_body:96 - Row 24927: Found 1 issues in body: ['3333']
# Processing PR Bodies: 100%|█████████▉| 24955/25042 [01:11<00:00, 399.57it/s]2025-06-05 16:30:55.647 | INFO     | __main__:process_row_for_body:96 - Row 24936: Found 1 issues in body: ['14003']
# 2025-06-05 16:30:55.657 | INFO     | __main__:process_row_for_body:96 - Row 24941: Found 1 issues in body: ['17262']
# 2025-06-05 16:30:55.660 | INFO     | __main__:process_row_for_body:96 - Row 24942: Found 1 issues in body: ['6851']
# 2025-06-05 16:30:55.670 | INFO     | __main__:process_row_for_body:96 - Row 24951: Found 3 issues in body: ['12035', '15818', '4569']
# 2025-06-05 16:30:55.674 | INFO     | __main__:process_row_for_body:96 - Row 24952: Found 1 issues in body: ['4530']
# 2025-06-05 16:30:55.686 | INFO     | __main__:process_row_for_body:96 - Row 24958: Found 3 issues in body: ['15035', '4878', '15031']
# 2025-06-05 16:30:55.692 | INFO     | __main__:process_row_for_body:96 - Row 24961: Found 1 issues in body: ['10721']
# 2025-06-05 16:30:55.696 | INFO     | __main__:process_row_for_body:96 - Row 24962: Found 1 issues in body: ['12949']
# 2025-06-05 16:30:55.706 | INFO     | __main__:process_row_for_body:96 - Row 24967: Found 1 issues in body: ['17763']
# 2025-06-05 16:30:55.710 | INFO     | __main__:process_row_for_body:96 - Row 24969: Found 1 issues in body: ['4556']
# 2025-06-05 16:30:55.722 | INFO     | __main__:process_row_for_body:96 - Row 24970: Found 1 issues in body: ['14479']
# 2025-06-05 16:30:55.729 | INFO     | __main__:process_row_for_body:96 - Row 24975: Found 1 issues in body: ['14352']
# 2025-06-05 16:30:55.745 | INFO     | __main__:process_row_for_body:96 - Row 24981: Found 1 issues in body: ['17794']
# 2025-06-05 16:30:55.752 | INFO     | __main__:process_row_for_body:96 - Row 24986: Found 1 issues in body: ['18995']
# 2025-06-05 16:30:55.756 | INFO     | __main__:process_row_for_body:96 - Row 24988: Found 1 issues in body: ['18881']
# 2025-06-05 16:30:55.760 | INFO     | __main__:process_row_for_body:96 - Row 24992: Found 1 issues in body: ['22236']
# 2025-06-05 16:30:55.763 | INFO     | __main__:process_row_for_body:96 - Row 24993: Found 1 issues in body: ['20499']
# Processing PR Bodies: 100%|█████████▉| 24997/25042 [01:11<00:00, 404.17it/s]2025-06-05 16:30:55.766 | INFO     | __main__:process_row_for_body:96 - Row 24995: Found 1 issues in body: ['23233']
# 2025-06-05 16:30:55.772 | INFO     | __main__:process_row_for_body:96 - Row 24997: Found 1 issues in body: ['22543']
# 2025-06-05 16:30:55.775 | INFO     | __main__:process_row_for_body:96 - Row 24998: Found 1 issues in body: ['22248']
# 2025-06-05 16:30:55.781 | INFO     | __main__:process_row_for_body:96 - Row 25000: Found 1 issues in body: ['3751']
# 2025-06-05 16:30:55.787 | INFO     | __main__:process_row_for_body:96 - Row 25002: Found 3 issues in body: ['21850', '22209', '22201']
# 2025-06-05 16:30:55.793 | INFO     | __main__:process_row_for_body:96 - Row 25003: Found 1 issues in body: ['23621']
# 2025-06-05 16:30:55.795 | INFO     | __main__:process_row_for_body:96 - Row 25004: Found 1 issues in body: ['24542']
# 2025-06-05 16:30:55.803 | INFO     | __main__:process_row_for_body:96 - Row 25005: Found 1 issues in body: ['24585']
# 2025-06-05 16:30:55.807 | INFO     | __main__:process_row_for_body:96 - Row 25006: Found 1 issues in body: ['21862']
# 2025-06-05 16:30:55.815 | INFO     | __main__:process_row_for_body:96 - Row 25010: Found 1 issues in body: ['24540']
# 2025-06-05 16:30:55.822 | INFO     | __main__:process_row_for_body:96 - Row 25011: Found 1 issues in body: ['24879']
# 2025-06-05 16:30:55.827 | INFO     | __main__:process_row_for_body:96 - Row 25012: Found 1 issues in body: ['19229']
# 2025-06-05 16:30:55.831 | INFO     | __main__:process_row_for_body:96 - Row 25014: Found 1 issues in body: ['16030']
# 2025-06-05 16:30:55.840 | INFO     | __main__:process_row_for_body:96 - Row 25017: Found 1 issues in body: ['19898']
# 2025-06-05 16:30:55.844 | INFO     | __main__:process_row_for_body:96 - Row 25019: Found 1 issues in body: ['19896']
# 2025-06-05 16:30:55.851 | INFO     | __main__:process_row_for_body:96 - Row 25020: Found 1 issues in body: ['19169']
# 2025-06-05 16:30:55.858 | INFO     | __main__:process_row_for_body:96 - Row 25021: Found 1 issues in body: ['19690']
# 2025-06-05 16:30:55.861 | INFO     | __main__:process_row_for_body:96 - Row 25022: Found 1 issues in body: ['19883']
# 2025-06-05 16:30:55.866 | INFO     | __main__:process_row_for_body:96 - Row 25023: Found 1 issues in body: ['19883']
# 2025-06-05 16:30:55.876 | INFO     | __main__:process_row_for_body:96 - Row 25024: Found 1 issues in body: ['19291']
# 2025-06-05 16:30:55.889 | INFO     | __main__:process_row_for_body:96 - Row 25026: Found 1 issues in body: ['19895']
# 2025-06-05 16:30:55.909 | INFO     | __main__:process_row_for_body:96 - Row 25032: Found 1 issues in body: ['18789']
# 2025-06-05 16:30:55.914 | INFO     | __main__:process_row_for_body:96 - Row 25033: Found 1 issues in body: ['19699']
# 2025-06-05 16:30:55.924 | INFO     | __main__:process_row_for_body:96 - Row 25036: Found 1 issues in body: ['19304']
# 2025-06-05 16:30:55.929 | INFO     | __main__:process_row_for_body:96 - Row 25037: Found 1 issues in body: ['19939']
# 2025-06-05 16:30:55.933 | INFO     | __main__:process_row_for_body:96 - Row 25038: Found 2 issues in body: ['17892', '19262']
# Processing PR Bodies: 100%|█████████▉| 25039/25042 [01:11<00:00, 334.93it/s]2025-06-05 16:30:55.936 | INFO     | __main__:process_row_for_body:96 - Row 25039: Found 1 issues in body: ['13811']
# 2025-06-05 16:30:55.944 | INFO     | __main__:process_row_for_body:96 - Row 25040: Found 2 issues in body: ['20023', '19799']
# 2025-06-05 16:30:55.955 | INFO     | __main__:process_row_for_body:96 - Row 25041: Found 1 issues in body: ['18956']
# Processing PR Bodies: 100%|██████████| 25042/25042 [01:11<00:00, 350.72it/s]
# 2025-06-05 16:30:55.995 | INFO     | __main__:run_body_extraction:158 - Creating new DataFrame with 29081 records from body extraction
# 2025-06-05 16:30:56.350 | INFO     | __main__:run_body_extraction:164 - Saving body extraction results to: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues_from_body.csv
# 2025-06-05 16:31:02.119 | INFO     | __main__:run_body_extraction:175 - ==================================================
# 2025-06-05 16:31:02.129 | INFO     | __main__:run_body_extraction:176 - PR BODY EXTRACTION PROCESSING SUMMARY
# 2025-06-05 16:31:02.131 | INFO     | __main__:run_body_extraction:177 - ==================================================
# 2025-06-05 16:31:02.132 | INFO     | __main__:run_body_extraction:178 - Original rows processed: 25042
# 2025-06-05 16:31:02.139 | INFO     | __main__:run_body_extraction:179 - New rows generated (from body): 29081
# 2025-06-05 16:31:02.148 | INFO     | __main__:run_body_extraction:180 - Rows with issues found in body: 14104
# 2025-06-05 16:31:02.163 | INFO     | __main__:run_body_extraction:181 - Unique issues extracted from body: 10375
# 2025-06-05 16:31:02.171 | INFO     | __main__:run_body_extraction:183 - Expansion ratio (body): 1.16x
# 2025-06-05 16:31:02.176 | INFO     | __main__:run_body_extraction:184 - Output file (body extraction): ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues_from_body.csv
# 2025-06-05 16:31:02.188 | INFO     | __main__:run_body_extraction:185 - ==================================================
# ✅ PR Body issue extraction completed successfully!
# 📊 Original rows: 25042
# 📊 New rows (from body): 29081
# 📊 Rows with issues found in body: 14104
# 📊 Unique issues found in body: 10375
# 💾 Output saved to: ../data/keyword-linking/pullrequestToIssue/closed_prs_summary_with_extracted_issues_from_body.csv
