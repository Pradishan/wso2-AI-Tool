# %%
from dotenv import load_dotenv
import os
import sys

# Load environment variables from .env file
load_dotenv()

import re
import pandas as pd
from tqdm import tqdm
from loguru import logger
from pymongo import MongoClient
import requests 
import time 

# GitHub Personal Access Token (optional, but recommended for higher rate limits)
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")
if not GITHUB_TOKEN:
    logger.warning("GitHub token not found. Rate limits may apply.")

BATCH_SIZE = 500 # Number of records to process before writing to CSV

# Logger config
logger.add("logs/issue-pr-keyworld.log")
# Out:
# 1

# %%
# Mongo connection
client = MongoClient("mongodb://localhost:27017/")
db = client.github_data
issues_col = db.issues

logger.info("🔌 MongoDB connected.")
# Out:
# 2025-05-23 11:02:01.635 | INFO     | __main__:<module>:6 - 🔌 MongoDB connected.

# %%
def find_keyword_pr(issue, comments):
    pattern_priority = {
        r"(?i)Closed\s+with\s+#(\d+)": 1,
        r"(?i)Fixed\s+in\s+#(\d+)": 2,
        r"(?i)Fix\s+Issue\s+#(\d+)": 3,
        r"(?i)(?:close|closes|closed|fix|fixes|fixed|resolve|resolves|resolved)\s+#(\d+)": 4,
        r"(?i)#(\d+)\s+(?:has\s+been\s+)?(?:closed|fixed|resolved)": 5,
        r"(?i)(?:related\s+to|references)\s+#(\d+)": 6
    }

    found_prs = []

    # Check issue title
    issue_title = issue.get("title", "")
    if issue_title:
        for pattern, priority in pattern_priority.items():
            for match in re.finditer(pattern, issue_title, re.IGNORECASE):
                if match.group(1): 
                    found_prs.append((int(match.group(1)), "title_match", priority))

    # Check issue body
    issue_body = issue.get("body", "")
    if issue_body:
        for pattern, priority in pattern_priority.items():
            for match in re.finditer(pattern, issue_body, re.IGNORECASE):
                if match.group(1):
                    found_prs.append((int(match.group(1)), "body_match", priority))

    # Check comments
    for c in comments:
        comment_body = c.get("body", "")
        if comment_body:
            for pattern, priority in pattern_priority.items():
                for match in re.finditer(pattern, comment_body, re.IGNORECASE):
                    if match.group(1):
                        found_prs.append((int(match.group(1)), "comment_match", priority))
                        
    # Deduplicate and Sort by Priority
    found_prs = list(dict.fromkeys(found_prs))  # Remove duplicates while preserving order
    found_prs.sort(key=lambda x: x[2])  # Sort by priority (third element)

    return [(pr_number, strategy) for pr_number, strategy, priority in found_prs]  # Remove priority from final output

# %%
def fetch_pr_details_from_github(repo_api_url, pr_number, token=None):
    """
    Fetches PR details (title, body, html_url) from the GitHub API.
    repo_api_url is the API URL for the repository (e.g., https://api.github.com/repos/owner/repo)
    """
    if not repo_api_url:
        logger.warning(f"Repository API URL is missing. Cannot fetch PR #{pr_number}.")
        return None

    # Construct the API URL for the pull request
    # Example repo_api_url: "https://api.github.com/repos/wso2/product-is"
    # We need to ensure it's the base repo API URL for pulls.
    pr_api_url = f"{repo_api_url}/pulls/{pr_number}"
    
    headers = {
        "Accept": "application/vnd.github.v3+json"
    }
    if token:
        headers["Authorization"] = f"token {token}"

    try:
        response = requests.get(pr_api_url, headers=headers)
        
        if response.status_code == 403:
            logger.warning(f"Rate limit hit or forbidden access for PR #{pr_number} at {pr_api_url}. Checking headers...")
            if 'X-RateLimit-Remaining' in response.headers and int(response.headers['X-RateLimit-Remaining']) == 0:
                reset_time = int(response.headers.get('X-RateLimit-Reset', time.time() + 60))
                sleep_duration = max(0, reset_time - time.time()) + 5 # Add a small buffer
                logger.info(f"Rate limit exceeded. Sleeping for {sleep_duration:.2f} seconds.")
                time.sleep(sleep_duration)
                # Retry the request once after sleeping
                response = requests.get(pr_api_url, headers=headers)
        
        response.raise_for_status()  # Raises an HTTPError for bad responses (4XX or 5XX) after retry attempt
        
        pr_data = response.json()
        return {
            "title": pr_data.get("title", "N/A"),
            "body": pr_data.get("body", "N/A"),
            "html_url": pr_data.get("html_url", "N/A")
        }
    except requests.exceptions.HTTPError as e:
        if e.response.status_code == 404:
            logger.warning(f"PR #{pr_number} not found at {pr_api_url}. Status: {e.response.status_code}")
        elif e.response.status_code == 403: # If still 403 after retry
             logger.error(f"Persistent 403 error for PR #{pr_number} at {pr_api_url} after retry. Token issue or access denied.")
        else:
            logger.error(f"HTTP error fetching PR #{pr_number} from {pr_api_url}: {e}")
        return None
    except requests.exceptions.RequestException as e:
        logger.error(f"Error fetching PR #{pr_number} from {pr_api_url}: {e}")
        return None
    except Exception as e:
        logger.error(f"An unexpected error occurred while fetching PR #{pr_number} from {pr_api_url}: {e}")
        return None

# %%
results_issue_only = []
# This list will store data needed for the next cell to fetch full PR details.
# Each item will be a dictionary like:
# { 'issue_number': ..., 'issue_link': ..., ..., 'linked_pr_number': ..., 'strategy': ..., 'repository_api_url': ... }
issues_for_full_pr_details = []


csv_issue_only_path = "../data/keyword-linking/issue-pr/kelinked_issues_prs_issue_only.csv"

headers_issue_only = [
    "issue_number", "issue_link", "issue_title", "issue_body",
    "linked_pr_number", "strategy"
]

# Write headers to csv_issue_only_path
pd.DataFrame(columns=headers_issue_only).to_csv(csv_issue_only_path, index=False, mode='w')
logger.info(f"Initialized {csv_issue_only_path} with headers.")

processed_issue_count = 0
total_issues = issues_col.count_documents({ "issue.state": "closed" })
cursor = issues_col.find({ "issue.state": "closed" })

logger.info("🔎 Starting initial issue-PR linking and data collection (for issue_only.csv)...")
for record in tqdm(cursor, total=total_issues, desc="🔗 Linking Issues (Pass 1)"):
    issue_data = record.get("issue", {})
    comments = record.get("comments", [])

    issue_number_val = issue_data.get("number")
    issue_html_url_val = issue_data.get("html_url", "N/A")
    issue_title_val = issue_data.get("title", "N/A")
    issue_body_val = issue_data.get("body", "N/A")
    repository_api_url_val = issue_data.get("repository_url", None)

    linked_prs_info = find_keyword_pr(issue_data, comments)

    if linked_prs_info:
        for pr_number_val, strategy_val in linked_prs_info:
            issue_only_entry = {
                "issue_number": issue_number_val,
                "issue_link": issue_html_url_val,
                "issue_title": issue_title_val,
                "issue_body": issue_body_val,
                "linked_pr_number": pr_number_val,
                "strategy": strategy_val
            }
            results_issue_only.append(issue_only_entry)

            # Prepare data for the next cell (full PR details fetching)
            data_for_next_cell = {
                **issue_only_entry, # Includes all issue details, pr_number, strategy
                "repository_api_url": repository_api_url_val
            }
            issues_for_full_pr_details.append(data_for_next_cell)
            
            logger.success(f"Issue #{issue_number_val} ➡️ PR #{pr_number_val} via {strategy_val}. Logged for issue_only.csv.")
    else:
        logger.warning(f"Issue #{issue_number_val} ➡️ No PR linked.")
        # If you want to include issues with no PRs in issue_only.csv, add them here.
        # For example:
        # results_issue_only.append({
        #     "issue_number": issue_number_val, "issue_link": issue_html_url_val, 
        #     "issue_title": issue_title_val, "issue_body": issue_body_val,
        #     "linked_pr_number": "N/A", "strategy": "no_link_found"
        # })

    processed_issue_count += 1

    if processed_issue_count % BATCH_SIZE == 0:
        if results_issue_only:
            df_issue = pd.DataFrame(results_issue_only)
            df_issue.to_csv(csv_issue_only_path, mode='a', header=False, index=False)
            logger.info(f"Appended batch of {len(results_issue_only)} records to {csv_issue_only_path}")
            results_issue_only.clear()

# Write any remaining records for issue_only.csv
if results_issue_only:
    df_issue = pd.DataFrame(results_issue_only)
    df_issue.to_csv(csv_issue_only_path, mode='a', header=False, index=False)
    logger.info(f"Appended final batch of {len(results_issue_only)} records to {csv_issue_only_path}")
    results_issue_only.clear()

logger.info(f"✅ Initial linking complete. Output in '{csv_issue_only_path}'.")
logger.info(f"{len(issues_for_full_pr_details)} PRs identified for full detail fetching in the next step.")
# Out:
# 2025-05-23 11:02:14.107 | INFO     | __main__:<module>:17 - Initialized data/linked_issues_prs_issue_only.csv with headers.
# 2025-05-23 11:02:14.335 | INFO     | __main__:<module>:23 - 🔎 Starting initial issue-PR linking and data collection (for issue_only.csv)...
# 🔗 Linking Issues (Pass 1):   0%|          | 0/16788 [00:00<?, ?it/s]2025-05-23 11:02:14.466 | WARNING  | __main__:<module>:57 - Issue #44106 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   0%|          | 1/16788 [00:00<33:41,  8.30it/s]2025-05-23 11:02:14.472 | WARNING  | __main__:<module>:57 - Issue #44078 ➡️ No PR linked.
# 2025-05-23 11:02:14.473 | WARNING  | __main__:<module>:57 - Issue #44075 ➡️ No PR linked.
# 2025-05-23 11:02:14.473 | WARNING  | __main__:<module>:57 - Issue #44043 ➡️ No PR linked.
# 2025-05-23 11:02:14.475 | WARNING  | __main__:<module>:57 - Issue #44028 ➡️ No PR linked.
# 2025-05-23 11:02:14.477 | WARNING  | __main__:<module>:57 - Issue #43999 ➡️ No PR linked.
# 2025-05-23 11:02:14.478 | WARNING  | __main__:<module>:57 - Issue #43997 ➡️ No PR linked.
# 2025-05-23 11:02:14.480 | WARNING  | __main__:<module>:57 - Issue #43985 ➡️ No PR linked.
# 2025-05-23 11:02:14.483 | WARNING  | __main__:<module>:57 - Issue #43984 ➡️ No PR linked.
# 2025-05-23 11:02:14.484 | WARNING  | __main__:<module>:57 - Issue #43965 ➡️ No PR linked.
# 2025-05-23 11:02:14.485 | WARNING  | __main__:<module>:57 - Issue #43957 ➡️ No PR linked.
# 2025-05-23 11:02:14.485 | WARNING  | __main__:<module>:57 - Issue #43956 ➡️ No PR linked.
# 2025-05-23 11:02:14.485 | WARNING  | __main__:<module>:57 - Issue #43949 ➡️ No PR linked.
# 2025-05-23 11:02:14.490 | WARNING  | __main__:<module>:57 - Issue #43945 ➡️ No PR linked.
# 2025-05-23 11:02:14.493 | WARNING  | __main__:<module>:57 - Issue #43943 ➡️ No PR linked.
# 2025-05-23 11:02:14.496 | WARNING  | __main__:<module>:57 - Issue #43940 ➡️ No PR linked.
# 2025-05-23 11:02:14.498 | WARNING  | __main__:<module>:57 - Issue #43938 ➡️ No PR linked.
# 2025-05-23 11:02:14.499 | WARNING  | __main__:<module>:57 - Issue #43936 ➡️ No PR linked.
# 2025-05-23 11:02:14.500 | WARNING  | __main__:<module>:57 - Issue #43919 ➡️ No PR linked.
# 2025-05-23 11:02:14.501 | WARNING  | __main__:<module>:57 - Issue #43914 ➡️ No PR linked.
# 2025-05-23 11:02:14.502 | WARNING  | __main__:<module>:57 - Issue #43912 ➡️ No PR linked.
# 2025-05-23 11:02:14.504 | WARNING  | __main__:<module>:57 - Issue #43906 ➡️ No PR linked.
# 2025-05-23 11:02:14.506 | WARNING  | __main__:<module>:57 - Issue #43905 ➡️ No PR linked.
# 2025-05-23 11:02:14.509 | WARNING  | __main__:<module>:57 - Issue #43902 ➡️ No PR linked.
# 2025-05-23 11:02:14.513 | WARNING  | __main__:<module>:57 - Issue #43880 ➡️ No PR linked.
# 2025-05-23 11:02:14.514 | WARNING  | __main__:<module>:57 - Issue #43874 ➡️ No PR linked.
# 2025-05-23 11:02:14.516 | WARNING  | __main__:<module>:57 - Issue #43865 ➡️ No PR linked.
# 2025-05-23 11:02:14.517 | WARNING  | __main__:<module>:57 - Issue #43855 ➡️ No PR linked.
# 2025-05-23 11:02:14.517 | WARNING  | __main__:<module>:57 - Issue #43853 ➡️ No PR linked.
# 2025-05-23 11:02:14.517 | WARNING  | __main__:<module>:57 - Issue #43843 ➡️ No PR linked.
# 2025-05-23 11:02:14.524 | WARNING  | __main__:<module>:57 - Issue #43823 ➡️ No PR linked.
# 2025-05-23 11:02:14.525 | WARNING  | __main__:<module>:57 - Issue #43822 ➡️ No PR linked.
# 2025-05-23 11:02:14.527 | WARNING  | __main__:<module>:57 - Issue #43819 ➡️ No PR linked.
# 2025-05-23 11:02:14.529 | WARNING  | __main__:<module>:57 - Issue #43816 ➡️ No PR linked.
# 2025-05-23 11:02:14.536 | WARNING  | __main__:<module>:57 - Issue #43808 ➡️ No PR linked.
# 2025-05-23 11:02:14.543 | WARNING  | __main__:<module>:57 - Issue #43806 ➡️ No PR linked.
# 2025-05-23 11:02:14.545 | WARNING  | __main__:<module>:57 - Issue #43800 ➡️ No PR linked.
# 2025-05-23 11:02:14.546 | WARNING  | __main__:<module>:57 - Issue #43797 ➡️ No PR linked.
# 2025-05-23 11:02:14.546 | WARNING  | __main__:<module>:57 - Issue #43794 ➡️ No PR linked.
# 2025-05-23 11:02:14.546 | WARNING  | __main__:<module>:57 - Issue #43793 ➡️ No PR linked.
# 2025-05-23 11:02:14.546 | WARNING  | __main__:<module>:57 - Issue #43792 ➡️ No PR linked.
# 2025-05-23 11:02:14.553 | SUCCESS  | __main__:<module>:55 - Issue #43789 ➡️ PR #43820 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:14.556 | WARNING  | __main__:<module>:57 - Issue #43788 ➡️ No PR linked.
# 2025-05-23 11:02:14.559 | WARNING  | __main__:<module>:57 - Issue #43787 ➡️ No PR linked.
# 2025-05-23 11:02:14.561 | WARNING  | __main__:<module>:57 - Issue #43785 ➡️ No PR linked.
# 2025-05-23 11:02:14.562 | WARNING  | __main__:<module>:57 - Issue #43784 ➡️ No PR linked.
# 2025-05-23 11:02:14.564 | WARNING  | __main__:<module>:57 - Issue #43781 ➡️ No PR linked.
# 2025-05-23 11:02:14.571 | WARNING  | __main__:<module>:57 - Issue #43779 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   0%|          | 48/16788 [00:00<01:06, 253.11it/s]2025-05-23 11:02:14.575 | WARNING  | __main__:<module>:57 - Issue #43775 ➡️ No PR linked.
# 2025-05-23 11:02:14.577 | WARNING  | __main__:<module>:57 - Issue #43772 ➡️ No PR linked.
# 2025-05-23 11:02:14.588 | WARNING  | __main__:<module>:57 - Issue #43771 ➡️ No PR linked.
# 2025-05-23 11:02:14.590 | WARNING  | __main__:<module>:57 - Issue #43769 ➡️ No PR linked.
# 2025-05-23 11:02:14.593 | WARNING  | __main__:<module>:57 - Issue #43774 ➡️ No PR linked.
# 2025-05-23 11:02:14.595 | WARNING  | __main__:<module>:57 - Issue #43764 ➡️ No PR linked.
# 2025-05-23 11:02:14.596 | WARNING  | __main__:<module>:57 - Issue #43761 ➡️ No PR linked.
# 2025-05-23 11:02:14.597 | WARNING  | __main__:<module>:57 - Issue #43748 ➡️ No PR linked.
# 2025-05-23 11:02:14.599 | WARNING  | __main__:<module>:57 - Issue #43738 ➡️ No PR linked.
# 2025-05-23 11:02:14.603 | WARNING  | __main__:<module>:57 - Issue #43734 ➡️ No PR linked.
# 2025-05-23 11:02:14.607 | WARNING  | __main__:<module>:57 - Issue #43730 ➡️ No PR linked.
# 2025-05-23 11:02:14.611 | WARNING  | __main__:<module>:57 - Issue #43710 ➡️ No PR linked.
# 2025-05-23 11:02:14.613 | WARNING  | __main__:<module>:57 - Issue #43702 ➡️ No PR linked.
# 2025-05-23 11:02:14.614 | WARNING  | __main__:<module>:57 - Issue #43700 ➡️ No PR linked.
# 2025-05-23 11:02:14.615 | WARNING  | __main__:<module>:57 - Issue #43694 ➡️ No PR linked.
# 2025-05-23 11:02:14.616 | WARNING  | __main__:<module>:57 - Issue #43691 ➡️ No PR linked.
# 2025-05-23 11:02:14.620 | WARNING  | __main__:<module>:57 - Issue #43688 ➡️ No PR linked.
# 2025-05-23 11:02:14.622 | WARNING  | __main__:<module>:57 - Issue #43682 ➡️ No PR linked.
# 2025-05-23 11:02:14.625 | WARNING  | __main__:<module>:57 - Issue #43679 ➡️ No PR linked.
# 2025-05-23 11:02:14.628 | WARNING  | __main__:<module>:57 - Issue #43675 ➡️ No PR linked.
# 2025-05-23 11:02:14.630 | WARNING  | __main__:<module>:57 - Issue #43673 ➡️ No PR linked.
# 2025-05-23 11:02:14.631 | WARNING  | __main__:<module>:57 - Issue #43664 ➡️ No PR linked.
# 2025-05-23 11:02:14.633 | WARNING  | __main__:<module>:57 - Issue #43657 ➡️ No PR linked.
# 2025-05-23 11:02:14.633 | WARNING  | __main__:<module>:57 - Issue #43654 ➡️ No PR linked.
# 2025-05-23 11:02:14.633 | WARNING  | __main__:<module>:57 - Issue #43648 ➡️ No PR linked.
# 2025-05-23 11:02:14.639 | WARNING  | __main__:<module>:57 - Issue #43644 ➡️ No PR linked.
# 2025-05-23 11:02:14.640 | WARNING  | __main__:<module>:57 - Issue #43635 ➡️ No PR linked.
# 2025-05-23 11:02:14.641 | WARNING  | __main__:<module>:57 - Issue #43631 ➡️ No PR linked.
# 2025-05-23 11:02:14.643 | WARNING  | __main__:<module>:57 - Issue #43626 ➡️ No PR linked.
# 2025-05-23 11:02:14.643 | WARNING  | __main__:<module>:57 - Issue #43620 ➡️ No PR linked.
# 2025-05-23 11:02:14.643 | WARNING  | __main__:<module>:57 - Issue #43614 ➡️ No PR linked.
# 2025-05-23 11:02:14.643 | WARNING  | __main__:<module>:57 - Issue #43591 ➡️ No PR linked.
# 2025-05-23 11:02:14.653 | WARNING  | __main__:<module>:57 - Issue #43581 ➡️ No PR linked.
# 2025-05-23 11:02:14.659 | WARNING  | __main__:<module>:57 - Issue #43579 ➡️ No PR linked.
# 2025-05-23 11:02:14.661 | WARNING  | __main__:<module>:57 - Issue #43574 ➡️ No PR linked.
# 2025-05-23 11:02:14.663 | WARNING  | __main__:<module>:57 - Issue #43570 ➡️ No PR linked.
# 2025-05-23 11:02:14.666 | WARNING  | __main__:<module>:57 - Issue #43564 ➡️ No PR linked.
# 2025-05-23 11:02:14.672 | WARNING  | __main__:<module>:57 - Issue #43554 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   1%|          | 86/16788 [00:00<00:55, 303.22it/s]2025-05-23 11:02:14.676 | WARNING  | __main__:<module>:57 - Issue #43552 ➡️ No PR linked.
# 2025-05-23 11:02:14.678 | WARNING  | __main__:<module>:57 - Issue #43541 ➡️ No PR linked.
# 2025-05-23 11:02:14.681 | WARNING  | __main__:<module>:57 - Issue #43539 ➡️ No PR linked.
# 2025-05-23 11:02:14.683 | WARNING  | __main__:<module>:57 - Issue #43538 ➡️ No PR linked.
# 2025-05-23 11:02:14.686 | WARNING  | __main__:<module>:57 - Issue #43531 ➡️ No PR linked.
# 2025-05-23 11:02:14.688 | WARNING  | __main__:<module>:57 - Issue #43528 ➡️ No PR linked.
# 2025-05-23 11:02:14.691 | WARNING  | __main__:<module>:57 - Issue #43527 ➡️ No PR linked.
# 2025-05-23 11:02:14.693 | WARNING  | __main__:<module>:57 - Issue #43518 ➡️ No PR linked.
# 2025-05-23 11:02:14.695 | WARNING  | __main__:<module>:57 - Issue #43516 ➡️ No PR linked.
# 2025-05-23 11:02:14.697 | WARNING  | __main__:<module>:57 - Issue #43492 ➡️ No PR linked.
# 2025-05-23 11:02:14.699 | WARNING  | __main__:<module>:57 - Issue #43490 ➡️ No PR linked.
# 2025-05-23 11:02:14.700 | WARNING  | __main__:<module>:57 - Issue #43488 ➡️ No PR linked.
# 2025-05-23 11:02:14.701 | WARNING  | __main__:<module>:57 - Issue #43486 ➡️ No PR linked.
# 2025-05-23 11:02:14.704 | WARNING  | __main__:<module>:57 - Issue #43480 ➡️ No PR linked.
# 2025-05-23 11:02:14.721 | WARNING  | __main__:<module>:57 - Issue #43478 ➡️ No PR linked.
# 2025-05-23 11:02:14.998 | WARNING  | __main__:<module>:57 - Issue #43466 ➡️ No PR linked.
# 2025-05-23 11:02:14.998 | WARNING  | __main__:<module>:57 - Issue #43464 ➡️ No PR linked.
# 2025-05-23 11:02:14.998 | WARNING  | __main__:<module>:57 - Issue #43463 ➡️ No PR linked.
# 2025-05-23 11:02:15.003 | WARNING  | __main__:<module>:57 - Issue #43462 ➡️ No PR linked.
# 2025-05-23 11:02:15.003 | WARNING  | __main__:<module>:57 - Issue #43455 ➡️ No PR linked.
# 2025-05-23 11:02:15.005 | WARNING  | __main__:<module>:57 - Issue #43452 ➡️ No PR linked.
# 2025-05-23 11:02:15.006 | WARNING  | __main__:<module>:57 - Issue #43433 ➡️ No PR linked.
# 2025-05-23 11:02:15.008 | WARNING  | __main__:<module>:57 - Issue #43432 ➡️ No PR linked.
# 2025-05-23 11:02:15.009 | WARNING  | __main__:<module>:57 - Issue #43431 ➡️ No PR linked.
# 2025-05-23 11:02:15.011 | WARNING  | __main__:<module>:57 - Issue #43430 ➡️ No PR linked.
# 2025-05-23 11:02:15.013 | WARNING  | __main__:<module>:57 - Issue #43428 ➡️ No PR linked.
# 2025-05-23 11:02:15.016 | WARNING  | __main__:<module>:57 - Issue #43423 ➡️ No PR linked.
# 2025-05-23 11:02:15.018 | WARNING  | __main__:<module>:57 - Issue #43422 ➡️ No PR linked.
# 2025-05-23 11:02:15.021 | WARNING  | __main__:<module>:57 - Issue #43418 ➡️ No PR linked.
# 2025-05-23 11:02:15.024 | WARNING  | __main__:<module>:57 - Issue #43414 ➡️ No PR linked.
# 2025-05-23 11:02:15.026 | WARNING  | __main__:<module>:57 - Issue #43409 ➡️ No PR linked.
# 2025-05-23 11:02:15.026 | WARNING  | __main__:<module>:57 - Issue #43374 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   1%|          | 118/16788 [00:00<01:45, 158.67it/s]2025-05-23 11:02:15.026 | WARNING  | __main__:<module>:57 - Issue #43359 ➡️ No PR linked.
# 2025-05-23 11:02:15.033 | WARNING  | __main__:<module>:57 - Issue #43358 ➡️ No PR linked.
# 2025-05-23 11:02:15.033 | WARNING  | __main__:<module>:57 - Issue #43356 ➡️ No PR linked.
# 2025-05-23 11:02:15.033 | WARNING  | __main__:<module>:57 - Issue #43352 ➡️ No PR linked.
# 2025-05-23 11:02:15.033 | WARNING  | __main__:<module>:57 - Issue #43351 ➡️ No PR linked.
# 2025-05-23 11:02:15.039 | WARNING  | __main__:<module>:57 - Issue #43350 ➡️ No PR linked.
# 2025-05-23 11:02:15.041 | WARNING  | __main__:<module>:57 - Issue #43349 ➡️ No PR linked.
# 2025-05-23 11:02:15.044 | SUCCESS  | __main__:<module>:55 - Issue #43348 ➡️ PR #43303 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:15.044 | WARNING  | __main__:<module>:57 - Issue #43345 ➡️ No PR linked.
# 2025-05-23 11:02:15.052 | WARNING  | __main__:<module>:57 - Issue #43344 ➡️ No PR linked.
# 2025-05-23 11:02:15.056 | WARNING  | __main__:<module>:57 - Issue #43343 ➡️ No PR linked.
# 2025-05-23 11:02:15.059 | WARNING  | __main__:<module>:57 - Issue #43342 ➡️ No PR linked.
# 2025-05-23 11:02:15.060 | WARNING  | __main__:<module>:57 - Issue #43337 ➡️ No PR linked.
# 2025-05-23 11:02:15.063 | WARNING  | __main__:<module>:57 - Issue #43336 ➡️ No PR linked.
# 2025-05-23 11:02:15.063 | WARNING  | __main__:<module>:57 - Issue #43323 ➡️ No PR linked.
# 2025-05-23 11:02:15.063 | WARNING  | __main__:<module>:57 - Issue #43307 ➡️ No PR linked.
# 2025-05-23 11:02:15.063 | WARNING  | __main__:<module>:57 - Issue #43299 ➡️ No PR linked.
# 2025-05-23 11:02:15.063 | WARNING  | __main__:<module>:57 - Issue #43294 ➡️ No PR linked.
# 2025-05-23 11:02:15.073 | SUCCESS  | __main__:<module>:55 - Issue #43293 ➡️ PR #43295 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:15.075 | WARNING  | __main__:<module>:57 - Issue #43292 ➡️ No PR linked.
# 2025-05-23 11:02:15.077 | WARNING  | __main__:<module>:57 - Issue #43288 ➡️ No PR linked.
# 2025-05-23 11:02:15.078 | WARNING  | __main__:<module>:57 - Issue #43287 ➡️ No PR linked.
# 2025-05-23 11:02:15.082 | WARNING  | __main__:<module>:57 - Issue #43286 ➡️ No PR linked.
# 2025-05-23 11:02:15.083 | WARNING  | __main__:<module>:57 - Issue #43285 ➡️ No PR linked.
# 2025-05-23 11:02:15.083 | WARNING  | __main__:<module>:57 - Issue #43284 ➡️ No PR linked.
# 2025-05-23 11:02:15.083 | WARNING  | __main__:<module>:57 - Issue #43277 ➡️ No PR linked.
# 2025-05-23 11:02:15.089 | WARNING  | __main__:<module>:57 - Issue #43267 ➡️ No PR linked.
# 2025-05-23 11:02:15.091 | WARNING  | __main__:<module>:57 - Issue #43254 ➡️ No PR linked.
# 2025-05-23 11:02:15.093 | WARNING  | __main__:<module>:57 - Issue #43248 ➡️ No PR linked.
# 2025-05-23 11:02:15.095 | WARNING  | __main__:<module>:57 - Issue #43242 ➡️ No PR linked.
# 2025-05-23 11:02:15.098 | WARNING  | __main__:<module>:57 - Issue #43241 ➡️ No PR linked.
# 2025-05-23 11:02:15.100 | WARNING  | __main__:<module>:57 - Issue #43238 ➡️ No PR linked.
# 2025-05-23 11:02:15.100 | WARNING  | __main__:<module>:57 - Issue #43237 ➡️ No PR linked.
# 2025-05-23 11:02:15.100 | WARNING  | __main__:<module>:57 - Issue #43236 ➡️ No PR linked.
# 2025-05-23 11:02:15.103 | WARNING  | __main__:<module>:57 - Issue #43235 ➡️ No PR linked.
# 2025-05-23 11:02:15.106 | WARNING  | __main__:<module>:57 - Issue #43233 ➡️ No PR linked.
# 2025-05-23 11:02:15.108 | WARNING  | __main__:<module>:57 - Issue #43226 ➡️ No PR linked.
# 2025-05-23 11:02:15.110 | WARNING  | __main__:<module>:57 - Issue #43224 ➡️ No PR linked.
# 2025-05-23 11:02:15.111 | WARNING  | __main__:<module>:57 - Issue #43223 ➡️ No PR linked.
# 2025-05-23 11:02:15.114 | WARNING  | __main__:<module>:57 - Issue #43222 ➡️ No PR linked.
# 2025-05-23 11:02:15.115 | WARNING  | __main__:<module>:57 - Issue #43206 ➡️ No PR linked.
# 2025-05-23 11:02:15.115 | SUCCESS  | __main__:<module>:55 - Issue #43205 ➡️ PR #43279 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:15.115 | SUCCESS  | __main__:<module>:55 - Issue #43204 ➡️ PR #43279 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:15.122 | SUCCESS  | __main__:<module>:55 - Issue #43204 ➡️ PR #43224 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:15.124 | WARNING  | __main__:<module>:57 - Issue #43200 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   1%|          | 162/16788 [00:00<01:15, 219.53it/s]2025-05-23 11:02:15.128 | WARNING  | __main__:<module>:57 - Issue #43199 ➡️ No PR linked.
# 2025-05-23 11:02:15.131 | WARNING  | __main__:<module>:57 - Issue #43198 ➡️ No PR linked.
# 2025-05-23 11:02:15.133 | SUCCESS  | __main__:<module>:55 - Issue #43192 ➡️ PR #42956 via body_match. Logged for issue_only.csv.
# 2025-05-23 11:02:15.133 | WARNING  | __main__:<module>:57 - Issue #43191 ➡️ No PR linked.
# 2025-05-23 11:02:15.143 | WARNING  | __main__:<module>:57 - Issue #43188 ➡️ No PR linked.
# 2025-05-23 11:02:15.146 | WARNING  | __main__:<module>:57 - Issue #43177 ➡️ No PR linked.
# 2025-05-23 11:02:15.149 | WARNING  | __main__:<module>:57 - Issue #43172 ➡️ No PR linked.
# 2025-05-23 11:02:15.168 | WARNING  | __main__:<module>:57 - Issue #43171 ➡️ No PR linked.
# 2025-05-23 11:02:15.171 | WARNING  | __main__:<module>:57 - Issue #43162 ➡️ No PR linked.
# 2025-05-23 11:02:15.175 | WARNING  | __main__:<module>:57 - Issue #43161 ➡️ No PR linked.
# 2025-05-23 11:02:15.175 | WARNING  | __main__:<module>:57 - Issue #43156 ➡️ No PR linked.
# 2025-05-23 11:02:15.175 | WARNING  | __main__:<module>:57 - Issue #43154 ➡️ No PR linked.
# 2025-05-23 11:02:15.183 | WARNING  | __main__:<module>:57 - Issue #43146 ➡️ No PR linked.
# 2025-05-23 11:02:15.183 | WARNING  | __main__:<module>:57 - Issue #43144 ➡️ No PR linked.
# 2025-05-23 11:02:15.183 | WARNING  | __main__:<module>:57 - Issue #43143 ➡️ No PR linked.
# 2025-05-23 11:02:15.190 | WARNING  | __main__:<module>:57 - Issue #43142 ➡️ No PR linked.
# 2025-05-23 11:02:15.193 | WARNING  | __main__:<module>:57 - Issue #43138 ➡️ No PR linked.
# 2025-05-23 11:02:15.195 | WARNING  | __main__:<module>:57 - Issue #43130 ➡️ No PR linked.
# 2025-05-23 11:02:15.198 | SUCCESS  | __main__:<module>:55 - Issue #43129 ➡️ PR #43010 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:15.200 | WARNING  | __main__:<module>:57 - Issue #43128 ➡️ No PR linked.
# 2025-05-23 11:02:15.202 | WARNING  | __main__:<module>:57 - Issue #43127 ➡️ No PR linked.
# 2025-05-23 11:02:15.206 | WARNING  | __main__:<module>:57 - Issue #43126 ➡️ No PR linked.
# 2025-05-23 11:02:15.209 | WARNING  | __main__:<module>:57 - Issue #43125 ➡️ No PR linked.
# 2025-05-23 11:02:15.211 | WARNING  | __main__:<module>:57 - Issue #43124 ➡️ No PR linked.
# 2025-05-23 11:02:15.213 | WARNING  | __main__:<module>:57 - Issue #43123 ➡️ No PR linked.
# 2025-05-23 11:02:15.218 | WARNING  | __main__:<module>:57 - Issue #43122 ➡️ No PR linked.
# 2025-05-23 11:02:15.218 | WARNING  | __main__:<module>:57 - Issue #43119 ➡️ No PR linked.
# 2025-05-23 11:02:15.224 | WARNING  | __main__:<module>:57 - Issue #43117 ➡️ No PR linked.
# 2025-05-23 11:02:15.226 | WARNING  | __main__:<module>:57 - Issue #43116 ➡️ No PR linked.
# 2025-05-23 11:02:15.227 | WARNING  | __main__:<module>:57 - Issue #43113 ➡️ No PR linked.
# 2025-05-23 11:02:15.229 | WARNING  | __main__:<module>:57 - Issue #43107 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   1%|          | 193/16788 [00:00<01:09, 238.08it/s]2025-05-23 11:02:15.234 | WARNING  | __main__:<module>:57 - Issue #43098 ➡️ No PR linked.
# 2025-05-23 11:02:15.234 | WARNING  | __main__:<module>:57 - Issue #43094 ➡️ No PR linked.
# 2025-05-23 11:02:15.234 | WARNING  | __main__:<module>:57 - Issue #43091 ➡️ No PR linked.
# 2025-05-23 11:02:15.241 | WARNING  | __main__:<module>:57 - Issue #43066 ➡️ No PR linked.
# 2025-05-23 11:02:15.243 | WARNING  | __main__:<module>:57 - Issue #43060 ➡️ No PR linked.
# 2025-05-23 11:02:15.246 | WARNING  | __main__:<module>:57 - Issue #43055 ➡️ No PR linked.
# 2025-05-23 11:02:15.248 | WARNING  | __main__:<module>:57 - Issue #43043 ➡️ No PR linked.
# 2025-05-23 11:02:15.250 | WARNING  | __main__:<module>:57 - Issue #43041 ➡️ No PR linked.
# 2025-05-23 11:02:15.252 | WARNING  | __main__:<module>:57 - Issue #43038 ➡️ No PR linked.
# 2025-05-23 11:02:15.257 | WARNING  | __main__:<module>:57 - Issue #43034 ➡️ No PR linked.
# 2025-05-23 11:02:15.259 | WARNING  | __main__:<module>:57 - Issue #43030 ➡️ No PR linked.
# 2025-05-23 11:02:15.261 | WARNING  | __main__:<module>:57 - Issue #43029 ➡️ No PR linked.
# 2025-05-23 11:02:15.263 | WARNING  | __main__:<module>:57 - Issue #43016 ➡️ No PR linked.
# 2025-05-23 11:02:15.265 | WARNING  | __main__:<module>:57 - Issue #43012 ➡️ No PR linked.
# 2025-05-23 11:02:15.266 | WARNING  | __main__:<module>:57 - Issue #43008 ➡️ No PR linked.
# 2025-05-23 11:02:15.266 | WARNING  | __main__:<module>:57 - Issue #43007 ➡️ No PR linked.
# 2025-05-23 11:02:15.273 | WARNING  | __main__:<module>:57 - Issue #43001 ➡️ No PR linked.
# 2025-05-23 11:02:15.275 | WARNING  | __main__:<module>:57 - Issue #42994 ➡️ No PR linked.
# 2025-05-23 11:02:15.277 | WARNING  | __main__:<module>:57 - Issue #42988 ➡️ No PR linked.
# 2025-05-23 11:02:15.279 | WARNING  | __main__:<module>:57 - Issue #42987 ➡️ No PR linked.
# 2025-05-23 11:02:15.284 | WARNING  | __main__:<module>:57 - Issue #42985 ➡️ No PR linked.
# 2025-05-23 11:02:15.284 | WARNING  | __main__:<module>:57 - Issue #42984 ➡️ No PR linked.
# 2025-05-23 11:02:15.290 | WARNING  | __main__:<module>:57 - Issue #42981 ➡️ No PR linked.
# 2025-05-23 11:02:15.293 | WARNING  | __main__:<module>:57 - Issue #42979 ➡️ No PR linked.
# 2025-05-23 11:02:15.296 | WARNING  | __main__:<module>:57 - Issue #42976 ➡️ No PR linked.
# 2025-05-23 11:02:15.297 | WARNING  | __main__:<module>:57 - Issue #42974 ➡️ No PR linked.
# 2025-05-23 11:02:15.299 | WARNING  | __main__:<module>:57 - Issue #42973 ➡️ No PR linked.
# 2025-05-23 11:02:15.302 | WARNING  | __main__:<module>:57 - Issue #42972 ➡️ No PR linked.
# 2025-05-23 11:02:15.304 | WARNING  | __main__:<module>:57 - Issue #42967 ➡️ No PR linked.
# 2025-05-23 11:02:15.307 | WARNING  | __main__:<module>:57 - Issue #42961 ➡️ No PR linked.
# 2025-05-23 11:02:15.309 | WARNING  | __main__:<module>:57 - Issue #42959 ➡️ No PR linked.
# 2025-05-23 11:02:15.311 | WARNING  | __main__:<module>:57 - Issue #42958 ➡️ No PR linked.
# 2025-05-23 11:02:15.314 | WARNING  | __main__:<module>:57 - Issue #42957 ➡️ No PR linked.
# 2025-05-23 11:02:15.316 | WARNING  | __main__:<module>:57 - Issue #42954 ➡️ No PR linked.
# 2025-05-23 11:02:15.319 | WARNING  | __main__:<module>:57 - Issue #42942 ➡️ No PR linked.
# 2025-05-23 11:02:15.322 | WARNING  | __main__:<module>:57 - Issue #42935 ➡️ No PR linked.
# 2025-05-23 11:02:15.327 | WARNING  | __main__:<module>:57 - Issue #42934 ➡️ No PR linked.
# 2025-05-23 11:02:15.330 | WARNING  | __main__:<module>:57 - Issue #42933 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   1%|▏         | 231/16788 [00:00<01:00, 273.39it/s]2025-05-23 11:02:15.336 | WARNING  | __main__:<module>:57 - Issue #42924 ➡️ No PR linked.
# 2025-05-23 11:02:15.341 | WARNING  | __main__:<module>:57 - Issue #42922 ➡️ No PR linked.
# 2025-05-23 11:02:15.345 | WARNING  | __main__:<module>:57 - Issue #42910 ➡️ No PR linked.
# 2025-05-23 11:02:15.351 | WARNING  | __main__:<module>:57 - Issue #42906 ➡️ No PR linked.
# 2025-05-23 11:02:15.353 | WARNING  | __main__:<module>:57 - Issue #42902 ➡️ No PR linked.
# 2025-05-23 11:02:15.360 | WARNING  | __main__:<module>:57 - Issue #42892 ➡️ No PR linked.
# 2025-05-23 11:02:15.376 | WARNING  | __main__:<module>:57 - Issue #42880 ➡️ No PR linked.
# 2025-05-23 11:02:15.380 | WARNING  | __main__:<module>:57 - Issue #42879 ➡️ No PR linked.
# 2025-05-23 11:02:15.383 | WARNING  | __main__:<module>:57 - Issue #42872 ➡️ No PR linked.
# 2025-05-23 11:02:15.386 | WARNING  | __main__:<module>:57 - Issue #42871 ➡️ No PR linked.
# 2025-05-23 11:02:15.407 | WARNING  | __main__:<module>:57 - Issue #42869 ➡️ No PR linked.
# 2025-05-23 11:02:15.413 | WARNING  | __main__:<module>:57 - Issue #42868 ➡️ No PR linked.
# 2025-05-23 11:02:15.416 | WARNING  | __main__:<module>:57 - Issue #42867 ➡️ No PR linked.
# 2025-05-23 11:02:15.419 | WARNING  | __main__:<module>:57 - Issue #42865 ➡️ No PR linked.
# 2025-05-23 11:02:15.425 | WARNING  | __main__:<module>:57 - Issue #42861 ➡️ No PR linked.
# 2025-05-23 11:02:15.435 | WARNING  | __main__:<module>:57 - Issue #42860 ➡️ No PR linked.
# 2025-05-23 11:02:15.457 | WARNING  | __main__:<module>:57 - Issue #42859 ➡️ No PR linked.
# 2025-05-23 11:02:15.483 | WARNING  | __main__:<module>:57 - Issue #42858 ➡️ No PR linked.
# 2025-05-23 11:02:15.483 | WARNING  | __main__:<module>:57 - Issue #42848 ➡️ No PR linked.
# 2025-05-23 11:02:15.495 | WARNING  | __main__:<module>:57 - Issue #42844 ➡️ No PR linked.
# 2025-05-23 11:02:15.547 | WARNING  | __main__:<module>:57 - Issue #42836 ➡️ No PR linked.
# 2025-05-23 11:02:15.556 | WARNING  | __main__:<module>:57 - Issue #42835 ➡️ No PR linked.
# 2025-05-23 11:02:15.560 | WARNING  | __main__:<module>:57 - Issue #42833 ➡️ No PR linked.
# 2025-05-23 11:02:15.567 | WARNING  | __main__:<module>:57 - Issue #42830 ➡️ No PR linked.
# 2025-05-23 11:02:15.608 | WARNING  | __main__:<module>:57 - Issue #42829 ➡️ No PR linked.
# 2025-05-23 11:02:15.611 | WARNING  | __main__:<module>:57 - Issue #42823 ➡️ No PR linked.
# 2025-05-23 11:02:15.614 | WARNING  | __main__:<module>:57 - Issue #42822 ➡️ No PR linked.
# 2025-05-23 11:02:15.617 | WARNING  | __main__:<module>:57 - Issue #42820 ➡️ No PR linked.
# 2025-05-23 11:02:15.621 | WARNING  | __main__:<module>:57 - Issue #42818 ➡️ No PR linked.
# 2025-05-23 11:02:15.623 | WARNING  | __main__:<module>:57 - Issue #42817 ➡️ No PR linked.
# 2025-05-23 11:02:15.628 | WARNING  | __main__:<module>:57 - Issue #42816 ➡️ No PR linked.
# 2025-05-23 11:02:15.628 | WARNING  | __main__:<module>:57 - Issue #42814 ➡️ No PR linked.
# 2025-05-23 11:02:15.647 | WARNING  | __main__:<module>:57 - Issue #42811 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   2%|▏         | 264/16788 [00:01<01:30, 183.52it/s]2025-05-23 11:02:15.651 | WARNING  | __main__:<module>:57 - Issue #42808 ➡️ No PR linked.
# 2025-05-23 11:02:15.654 | WARNING  | __main__:<module>:57 - Issue #42807 ➡️ No PR linked.
# 2025-05-23 11:02:15.659 | WARNING  | __main__:<module>:57 - Issue #42806 ➡️ No PR linked.
# 2025-05-23 11:02:15.662 | WARNING  | __main__:<module>:57 - Issue #42805 ➡️ No PR linked.
# 2025-05-23 11:02:15.694 | WARNING  | __main__:<module>:57 - Issue #42803 ➡️ No PR linked.
# 2025-05-23 11:02:15.697 | WARNING  | __main__:<module>:57 - Issue #42802 ➡️ No PR linked.
# 2025-05-23 11:02:15.699 | SUCCESS  | __main__:<module>:55 - Issue #42801 ➡️ PR #42843 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:15.701 | WARNING  | __main__:<module>:57 - Issue #42798 ➡️ No PR linked.
# 2025-05-23 11:02:15.703 | WARNING  | __main__:<module>:57 - Issue #42789 ➡️ No PR linked.
# 2025-05-23 11:02:15.708 | WARNING  | __main__:<module>:57 - Issue #42787 ➡️ No PR linked.
# 2025-05-23 11:02:15.711 | WARNING  | __main__:<module>:57 - Issue #42786 ➡️ No PR linked.
# 2025-05-23 11:02:15.713 | WARNING  | __main__:<module>:57 - Issue #42782 ➡️ No PR linked.
# 2025-05-23 11:02:15.715 | WARNING  | __main__:<module>:57 - Issue #42780 ➡️ No PR linked.
# 2025-05-23 11:02:15.717 | WARNING  | __main__:<module>:57 - Issue #42773 ➡️ No PR linked.
# 2025-05-23 11:02:15.720 | WARNING  | __main__:<module>:57 - Issue #42771 ➡️ No PR linked.
# 2025-05-23 11:02:15.724 | WARNING  | __main__:<module>:57 - Issue #42760 ➡️ No PR linked.
# 2025-05-23 11:02:15.726 | WARNING  | __main__:<module>:57 - Issue #42754 ➡️ No PR linked.
# 2025-05-23 11:02:15.728 | WARNING  | __main__:<module>:57 - Issue #42751 ➡️ No PR linked.
# 2025-05-23 11:02:15.729 | WARNING  | __main__:<module>:57 - Issue #42749 ➡️ No PR linked.
# 2025-05-23 11:02:15.730 | WARNING  | __main__:<module>:57 - Issue #42735 ➡️ No PR linked.
# 2025-05-23 11:02:15.736 | WARNING  | __main__:<module>:57 - Issue #42728 ➡️ No PR linked.
# 2025-05-23 11:02:15.739 | WARNING  | __main__:<module>:57 - Issue #42725 ➡️ No PR linked.
# 2025-05-23 11:02:15.741 | WARNING  | __main__:<module>:57 - Issue #42718 ➡️ No PR linked.
# 2025-05-23 11:02:15.743 | WARNING  | __main__:<module>:57 - Issue #42712 ➡️ No PR linked.
# 2025-05-23 11:02:15.745 | WARNING  | __main__:<module>:57 - Issue #42711 ➡️ No PR linked.
# 2025-05-23 11:02:15.747 | WARNING  | __main__:<module>:57 - Issue #42704 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   2%|▏         | 290/16788 [00:01<01:23, 198.20it/s]2025-05-23 11:02:15.750 | WARNING  | __main__:<module>:57 - Issue #42703 ➡️ No PR linked.
# 2025-05-23 11:02:15.753 | WARNING  | __main__:<module>:57 - Issue #42698 ➡️ No PR linked.
# 2025-05-23 11:02:15.756 | WARNING  | __main__:<module>:57 - Issue #42693 ➡️ No PR linked.
# 2025-05-23 11:02:15.758 | WARNING  | __main__:<module>:57 - Issue #42685 ➡️ No PR linked.
# 2025-05-23 11:02:15.760 | WARNING  | __main__:<module>:57 - Issue #42684 ➡️ No PR linked.
# 2025-05-23 11:02:15.765 | WARNING  | __main__:<module>:57 - Issue #42681 ➡️ No PR linked.
# 2025-05-23 11:02:15.768 | WARNING  | __main__:<module>:57 - Issue #42678 ➡️ No PR linked.
# 2025-05-23 11:02:15.771 | WARNING  | __main__:<module>:57 - Issue #42667 ➡️ No PR linked.
# 2025-05-23 11:02:15.777 | SUCCESS  | __main__:<module>:55 - Issue #42662 ➡️ PR #42679 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:15.781 | WARNING  | __main__:<module>:57 - Issue #42657 ➡️ No PR linked.
# 2025-05-23 11:02:15.785 | WARNING  | __main__:<module>:57 - Issue #42655 ➡️ No PR linked.
# 2025-05-23 11:02:15.786 | WARNING  | __main__:<module>:57 - Issue #42654 ➡️ No PR linked.
# 2025-05-23 11:02:15.791 | WARNING  | __main__:<module>:57 - Issue #42653 ➡️ No PR linked.
# 2025-05-23 11:02:15.796 | WARNING  | __main__:<module>:57 - Issue #42652 ➡️ No PR linked.
# 2025-05-23 11:02:15.799 | SUCCESS  | __main__:<module>:55 - Issue #42648 ➡️ PR #42650 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:15.830 | WARNING  | __main__:<module>:57 - Issue #42640 ➡️ No PR linked.
# 2025-05-23 11:02:15.834 | WARNING  | __main__:<module>:57 - Issue #42636 ➡️ No PR linked.
# 2025-05-23 11:02:15.838 | WARNING  | __main__:<module>:57 - Issue #42624 ➡️ No PR linked.
# 2025-05-23 11:02:15.841 | WARNING  | __main__:<module>:57 - Issue #42617 ➡️ No PR linked.
# 2025-05-23 11:02:15.844 | WARNING  | __main__:<module>:57 - Issue #42615 ➡️ No PR linked.
# 2025-05-23 11:02:15.848 | WARNING  | __main__:<module>:57 - Issue #42628 ➡️ No PR linked.
# 2025-05-23 11:02:15.851 | WARNING  | __main__:<module>:57 - Issue #42610 ➡️ No PR linked.
# 2025-05-23 11:02:15.857 | WARNING  | __main__:<module>:57 - Issue #42606 ➡️ No PR linked.
# 2025-05-23 11:02:15.862 | WARNING  | __main__:<module>:57 - Issue #42605 ➡️ No PR linked.
# 2025-05-23 11:02:15.880 | WARNING  | __main__:<module>:57 - Issue #42604 ➡️ No PR linked.
# 2025-05-23 11:02:15.883 | WARNING  | __main__:<module>:57 - Issue #42600 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   2%|▏         | 316/16788 [00:01<01:23, 196.80it/s]2025-05-23 11:02:15.887 | WARNING  | __main__:<module>:57 - Issue #42595 ➡️ No PR linked.
# 2025-05-23 11:02:15.891 | WARNING  | __main__:<module>:57 - Issue #42592 ➡️ No PR linked.
# 2025-05-23 11:02:15.895 | WARNING  | __main__:<module>:57 - Issue #42591 ➡️ No PR linked.
# 2025-05-23 11:02:15.895 | WARNING  | __main__:<module>:57 - Issue #42593 ➡️ No PR linked.
# 2025-05-23 11:02:15.895 | WARNING  | __main__:<module>:57 - Issue #42590 ➡️ No PR linked.
# 2025-05-23 11:02:15.902 | WARNING  | __main__:<module>:57 - Issue #42583 ➡️ No PR linked.
# 2025-05-23 11:02:15.908 | WARNING  | __main__:<module>:57 - Issue #42566 ➡️ No PR linked.
# 2025-05-23 11:02:15.914 | WARNING  | __main__:<module>:57 - Issue #42562 ➡️ No PR linked.
# 2025-05-23 11:02:15.915 | WARNING  | __main__:<module>:57 - Issue #42561 ➡️ No PR linked.
# 2025-05-23 11:02:15.915 | WARNING  | __main__:<module>:57 - Issue #42556 ➡️ No PR linked.
# 2025-05-23 11:02:15.925 | WARNING  | __main__:<module>:57 - Issue #42555 ➡️ No PR linked.
# 2025-05-23 11:02:15.928 | WARNING  | __main__:<module>:57 - Issue #42553 ➡️ No PR linked.
# 2025-05-23 11:02:15.930 | WARNING  | __main__:<module>:57 - Issue #42549 ➡️ No PR linked.
# 2025-05-23 11:02:15.935 | WARNING  | __main__:<module>:57 - Issue #42543 ➡️ No PR linked.
# 2025-05-23 11:02:15.938 | WARNING  | __main__:<module>:57 - Issue #42541 ➡️ No PR linked.
# 2025-05-23 11:02:15.942 | WARNING  | __main__:<module>:57 - Issue #42540 ➡️ No PR linked.
# 2025-05-23 11:02:15.943 | WARNING  | __main__:<module>:57 - Issue #42536 ➡️ No PR linked.
# 2025-05-23 11:02:15.945 | WARNING  | __main__:<module>:57 - Issue #42523 ➡️ No PR linked.
# 2025-05-23 11:02:15.949 | WARNING  | __main__:<module>:57 - Issue #42520 ➡️ No PR linked.
# 2025-05-23 11:02:15.951 | WARNING  | __main__:<module>:57 - Issue #42515 ➡️ No PR linked.
# 2025-05-23 11:02:15.954 | WARNING  | __main__:<module>:57 - Issue #42512 ➡️ No PR linked.
# 2025-05-23 11:02:15.957 | WARNING  | __main__:<module>:57 - Issue #42507 ➡️ No PR linked.
# 2025-05-23 11:02:15.959 | WARNING  | __main__:<module>:57 - Issue #42506 ➡️ No PR linked.
# 2025-05-23 11:02:15.961 | WARNING  | __main__:<module>:57 - Issue #42504 ➡️ No PR linked.
# 2025-05-23 11:02:15.964 | WARNING  | __main__:<module>:57 - Issue #42499 ➡️ No PR linked.
# 2025-05-23 11:02:15.966 | WARNING  | __main__:<module>:57 - Issue #42497 ➡️ No PR linked.
# 2025-05-23 11:02:15.967 | WARNING  | __main__:<module>:57 - Issue #42487 ➡️ No PR linked.
# 2025-05-23 11:02:15.969 | WARNING  | __main__:<module>:57 - Issue #42483 ➡️ No PR linked.
# 2025-05-23 11:02:15.971 | WARNING  | __main__:<module>:57 - Issue #42482 ➡️ No PR linked.
# 2025-05-23 11:02:15.973 | WARNING  | __main__:<module>:57 - Issue #42476 ➡️ No PR linked.
# 2025-05-23 11:02:15.976 | WARNING  | __main__:<module>:57 - Issue #42475 ➡️ No PR linked.
# 2025-05-23 11:02:15.980 | WARNING  | __main__:<module>:57 - Issue #42472 ➡️ No PR linked.
# 2025-05-23 11:02:15.983 | WARNING  | __main__:<module>:57 - Issue #42466 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   2%|▏         | 349/16788 [00:01<01:15, 218.69it/s]2025-05-23 11:02:16.002 | WARNING  | __main__:<module>:57 - Issue #42465 ➡️ No PR linked.
# 2025-05-23 11:02:16.004 | WARNING  | __main__:<module>:57 - Issue #42463 ➡️ No PR linked.
# 2025-05-23 11:02:16.007 | WARNING  | __main__:<module>:57 - Issue #42459 ➡️ No PR linked.
# 2025-05-23 11:02:16.009 | WARNING  | __main__:<module>:57 - Issue #42454 ➡️ No PR linked.
# 2025-05-23 11:02:16.011 | WARNING  | __main__:<module>:57 - Issue #42453 ➡️ No PR linked.
# 2025-05-23 11:02:16.014 | WARNING  | __main__:<module>:57 - Issue #42450 ➡️ No PR linked.
# 2025-05-23 11:02:16.016 | WARNING  | __main__:<module>:57 - Issue #42449 ➡️ No PR linked.
# 2025-05-23 11:02:16.016 | WARNING  | __main__:<module>:57 - Issue #42439 ➡️ No PR linked.
# 2025-05-23 11:02:16.022 | WARNING  | __main__:<module>:57 - Issue #42437 ➡️ No PR linked.
# 2025-05-23 11:02:16.024 | WARNING  | __main__:<module>:57 - Issue #42435 ➡️ No PR linked.
# 2025-05-23 11:02:16.026 | WARNING  | __main__:<module>:57 - Issue #42432 ➡️ No PR linked.
# 2025-05-23 11:02:16.028 | WARNING  | __main__:<module>:57 - Issue #42431 ➡️ No PR linked.
# 2025-05-23 11:02:16.030 | WARNING  | __main__:<module>:57 - Issue #42427 ➡️ No PR linked.
# 2025-05-23 11:02:16.035 | WARNING  | __main__:<module>:57 - Issue #42425 ➡️ No PR linked.
# 2025-05-23 11:02:16.038 | WARNING  | __main__:<module>:57 - Issue #42424 ➡️ No PR linked.
# 2025-05-23 11:02:16.042 | WARNING  | __main__:<module>:57 - Issue #42423 ➡️ No PR linked.
# 2025-05-23 11:02:16.046 | WARNING  | __main__:<module>:57 - Issue #42418 ➡️ No PR linked.
# 2025-05-23 11:02:16.049 | WARNING  | __main__:<module>:57 - Issue #42416 ➡️ No PR linked.
# 2025-05-23 11:02:16.051 | WARNING  | __main__:<module>:57 - Issue #42410 ➡️ No PR linked.
# 2025-05-23 11:02:16.054 | WARNING  | __main__:<module>:57 - Issue #42408 ➡️ No PR linked.
# 2025-05-23 11:02:16.057 | WARNING  | __main__:<module>:57 - Issue #42406 ➡️ No PR linked.
# 2025-05-23 11:02:16.059 | WARNING  | __main__:<module>:57 - Issue #42404 ➡️ No PR linked.
# 2025-05-23 11:02:16.061 | WARNING  | __main__:<module>:57 - Issue #42402 ➡️ No PR linked.
# 2025-05-23 11:02:16.063 | WARNING  | __main__:<module>:57 - Issue #42400 ➡️ No PR linked.
# 2025-05-23 11:02:16.065 | WARNING  | __main__:<module>:57 - Issue #42385 ➡️ No PR linked.
# 2025-05-23 11:02:16.067 | WARNING  | __main__:<module>:57 - Issue #42367 ➡️ No PR linked.
# 2025-05-23 11:02:16.069 | WARNING  | __main__:<module>:57 - Issue #42365 ➡️ No PR linked.
# 2025-05-23 11:02:16.071 | WARNING  | __main__:<module>:57 - Issue #42359 ➡️ No PR linked.
# 2025-05-23 11:02:16.074 | WARNING  | __main__:<module>:57 - Issue #42358 ➡️ No PR linked.
# 2025-05-23 11:02:16.078 | WARNING  | __main__:<module>:57 - Issue #42356 ➡️ No PR linked.
# 2025-05-23 11:02:16.080 | WARNING  | __main__:<module>:57 - Issue #42352 ➡️ No PR linked.
# 2025-05-23 11:02:16.081 | WARNING  | __main__:<module>:57 - Issue #42348 ➡️ No PR linked.
# 2025-05-23 11:02:16.082 | WARNING  | __main__:<module>:57 - Issue #42347 ➡️ No PR linked.
# 2025-05-23 11:02:16.084 | WARNING  | __main__:<module>:57 - Issue #42345 ➡️ No PR linked.
# 2025-05-23 11:02:16.087 | WARNING  | __main__:<module>:57 - Issue #42344 ➡️ No PR linked.
# 2025-05-23 11:02:16.091 | WARNING  | __main__:<module>:57 - Issue #42343 ➡️ No PR linked.
# 2025-05-23 11:02:16.095 | WARNING  | __main__:<module>:57 - Issue #42338 ➡️ No PR linked.
# 2025-05-23 11:02:16.095 | WARNING  | __main__:<module>:57 - Issue #42335 ➡️ No PR linked.
# 2025-05-23 11:02:16.095 | WARNING  | __main__:<module>:57 - Issue #42333 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   2%|▏         | 388/16788 [00:01<01:03, 257.26it/s]2025-05-23 11:02:16.102 | WARNING  | __main__:<module>:57 - Issue #42331 ➡️ No PR linked.
# 2025-05-23 11:02:16.106 | WARNING  | __main__:<module>:57 - Issue #42330 ➡️ No PR linked.
# 2025-05-23 11:02:16.109 | WARNING  | __main__:<module>:57 - Issue #42327 ➡️ No PR linked.
# 2025-05-23 11:02:16.112 | WARNING  | __main__:<module>:57 - Issue #42326 ➡️ No PR linked.
# 2025-05-23 11:02:16.114 | WARNING  | __main__:<module>:57 - Issue #42324 ➡️ No PR linked.
# 2025-05-23 11:02:16.116 | WARNING  | __main__:<module>:57 - Issue #42323 ➡️ No PR linked.
# 2025-05-23 11:02:16.117 | WARNING  | __main__:<module>:57 - Issue #42320 ➡️ No PR linked.
# 2025-05-23 11:02:16.118 | WARNING  | __main__:<module>:57 - Issue #42319 ➡️ No PR linked.
# 2025-05-23 11:02:16.122 | WARNING  | __main__:<module>:57 - Issue #42318 ➡️ No PR linked.
# 2025-05-23 11:02:16.124 | WARNING  | __main__:<module>:57 - Issue #42317 ➡️ No PR linked.
# 2025-05-23 11:02:16.137 | WARNING  | __main__:<module>:57 - Issue #42314 ➡️ No PR linked.
# 2025-05-23 11:02:16.143 | WARNING  | __main__:<module>:57 - Issue #42312 ➡️ No PR linked.
# 2025-05-23 11:02:16.145 | WARNING  | __main__:<module>:57 - Issue #42309 ➡️ No PR linked.
# 2025-05-23 11:02:16.150 | WARNING  | __main__:<module>:57 - Issue #42305 ➡️ No PR linked.
# 2025-05-23 11:02:16.152 | WARNING  | __main__:<module>:57 - Issue #42304 ➡️ No PR linked.
# 2025-05-23 11:02:16.154 | WARNING  | __main__:<module>:57 - Issue #42295 ➡️ No PR linked.
# 2025-05-23 11:02:16.159 | WARNING  | __main__:<module>:57 - Issue #42301 ➡️ No PR linked.
# 2025-05-23 11:02:16.161 | WARNING  | __main__:<module>:57 - Issue #42289 ➡️ No PR linked.
# 2025-05-23 11:02:16.164 | WARNING  | __main__:<module>:57 - Issue #42288 ➡️ No PR linked.
# 2025-05-23 11:02:16.166 | WARNING  | __main__:<module>:57 - Issue #42286 ➡️ No PR linked.
# 2025-05-23 11:02:16.171 | WARNING  | __main__:<module>:57 - Issue #42281 ➡️ No PR linked.
# 2025-05-23 11:02:16.173 | WARNING  | __main__:<module>:57 - Issue #42275 ➡️ No PR linked.
# 2025-05-23 11:02:16.177 | WARNING  | __main__:<module>:57 - Issue #42269 ➡️ No PR linked.
# 2025-05-23 11:02:16.181 | WARNING  | __main__:<module>:57 - Issue #42268 ➡️ No PR linked.
# 2025-05-23 11:02:16.184 | WARNING  | __main__:<module>:57 - Issue #42262 ➡️ No PR linked.
# 2025-05-23 11:02:16.184 | WARNING  | __main__:<module>:57 - Issue #42261 ➡️ No PR linked.
# 2025-05-23 11:02:16.189 | WARNING  | __main__:<module>:57 - Issue #42259 ➡️ No PR linked.
# 2025-05-23 11:02:16.191 | SUCCESS  | __main__:<module>:55 - Issue #42258 ➡️ PR #43279 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:16.194 | WARNING  | __main__:<module>:57 - Issue #42248 ➡️ No PR linked.
# 2025-05-23 11:02:16.196 | WARNING  | __main__:<module>:57 - Issue #42244 ➡️ No PR linked.
# 2025-05-23 11:02:16.199 | WARNING  | __main__:<module>:57 - Issue #42243 ➡️ No PR linked.
# 2025-05-23 11:02:16.203 | WARNING  | __main__:<module>:57 - Issue #42241 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   3%|▎         | 420/16788 [00:01<01:00, 270.41it/s]2025-05-23 11:02:16.209 | WARNING  | __main__:<module>:57 - Issue #42237 ➡️ No PR linked.
# 2025-05-23 11:02:16.214 | WARNING  | __main__:<module>:57 - Issue #42235 ➡️ No PR linked.
# 2025-05-23 11:02:16.217 | WARNING  | __main__:<module>:57 - Issue #42220 ➡️ No PR linked.
# 2025-05-23 11:02:16.220 | WARNING  | __main__:<module>:57 - Issue #42219 ➡️ No PR linked.
# 2025-05-23 11:02:16.223 | WARNING  | __main__:<module>:57 - Issue #42216 ➡️ No PR linked.
# 2025-05-23 11:02:16.226 | WARNING  | __main__:<module>:57 - Issue #42211 ➡️ No PR linked.
# 2025-05-23 11:02:16.227 | WARNING  | __main__:<module>:57 - Issue #42208 ➡️ No PR linked.
# 2025-05-23 11:02:16.230 | WARNING  | __main__:<module>:57 - Issue #42205 ➡️ No PR linked.
# 2025-05-23 11:02:16.232 | WARNING  | __main__:<module>:57 - Issue #42204 ➡️ No PR linked.
# 2025-05-23 11:02:16.234 | WARNING  | __main__:<module>:57 - Issue #42200 ➡️ No PR linked.
# 2025-05-23 11:02:16.236 | WARNING  | __main__:<module>:57 - Issue #42199 ➡️ No PR linked.
# 2025-05-23 11:02:16.239 | WARNING  | __main__:<module>:57 - Issue #42193 ➡️ No PR linked.
# 2025-05-23 11:02:16.243 | WARNING  | __main__:<module>:57 - Issue #42192 ➡️ No PR linked.
# 2025-05-23 11:02:16.246 | WARNING  | __main__:<module>:57 - Issue #42185 ➡️ No PR linked.
# 2025-05-23 11:02:16.249 | WARNING  | __main__:<module>:57 - Issue #42182 ➡️ No PR linked.
# 2025-05-23 11:02:16.251 | WARNING  | __main__:<module>:57 - Issue #42180 ➡️ No PR linked.
# 2025-05-23 11:02:16.253 | WARNING  | __main__:<module>:57 - Issue #42178 ➡️ No PR linked.
# 2025-05-23 11:02:16.255 | WARNING  | __main__:<module>:57 - Issue #42170 ➡️ No PR linked.
# 2025-05-23 11:02:16.257 | WARNING  | __main__:<module>:57 - Issue #42167 ➡️ No PR linked.
# 2025-05-23 11:02:16.261 | WARNING  | __main__:<module>:57 - Issue #42159 ➡️ No PR linked.
# 2025-05-23 11:02:16.264 | WARNING  | __main__:<module>:57 - Issue #42155 ➡️ No PR linked.
# 2025-05-23 11:02:16.266 | WARNING  | __main__:<module>:57 - Issue #42151 ➡️ No PR linked.
# 2025-05-23 11:02:16.268 | WARNING  | __main__:<module>:57 - Issue #42148 ➡️ No PR linked.
# 2025-05-23 11:02:16.271 | WARNING  | __main__:<module>:57 - Issue #42146 ➡️ No PR linked.
# 2025-05-23 11:02:16.274 | WARNING  | __main__:<module>:57 - Issue #42144 ➡️ No PR linked.
# 2025-05-23 11:02:16.277 | WARNING  | __main__:<module>:57 - Issue #42141 ➡️ No PR linked.
# 2025-05-23 11:02:16.279 | WARNING  | __main__:<module>:57 - Issue #42138 ➡️ No PR linked.
# 2025-05-23 11:02:16.281 | WARNING  | __main__:<module>:57 - Issue #42134 ➡️ No PR linked.
# 2025-05-23 11:02:16.284 | WARNING  | __main__:<module>:57 - Issue #42128 ➡️ No PR linked.
# 2025-05-23 11:02:16.287 | WARNING  | __main__:<module>:57 - Issue #42127 ➡️ No PR linked.
# 2025-05-23 11:02:16.289 | WARNING  | __main__:<module>:57 - Issue #42123 ➡️ No PR linked.
# 2025-05-23 11:02:16.292 | WARNING  | __main__:<module>:57 - Issue #42122 ➡️ No PR linked.
# 2025-05-23 11:02:16.295 | WARNING  | __main__:<module>:57 - Issue #42121 ➡️ No PR linked.
# 2025-05-23 11:02:16.297 | WARNING  | __main__:<module>:57 - Issue #42120 ➡️ No PR linked.
# 2025-05-23 11:02:16.299 | WARNING  | __main__:<module>:57 - Issue #42114 ➡️ No PR linked.
# 2025-05-23 11:02:16.301 | WARNING  | __main__:<module>:57 - Issue #42113 ➡️ No PR linked.
# 2025-05-23 11:02:16.303 | WARNING  | __main__:<module>:57 - Issue #42107 ➡️ No PR linked.
# 2025-05-23 11:02:16.305 | WARNING  | __main__:<module>:57 - Issue #42106 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   3%|▎         | 458/16788 [00:01<00:54, 298.41it/s]2025-05-23 11:02:16.308 | WARNING  | __main__:<module>:57 - Issue #42105 ➡️ No PR linked.
# 2025-05-23 11:02:16.310 | WARNING  | __main__:<module>:57 - Issue #42104 ➡️ No PR linked.
# 2025-05-23 11:02:16.318 | WARNING  | __main__:<module>:57 - Issue #42094 ➡️ No PR linked.
# 2025-05-23 11:02:16.323 | WARNING  | __main__:<module>:57 - Issue #42088 ➡️ No PR linked.
# 2025-05-23 11:02:16.327 | WARNING  | __main__:<module>:57 - Issue #42086 ➡️ No PR linked.
# 2025-05-23 11:02:16.329 | WARNING  | __main__:<module>:57 - Issue #42083 ➡️ No PR linked.
# 2025-05-23 11:02:16.332 | WARNING  | __main__:<module>:57 - Issue #42077 ➡️ No PR linked.
# 2025-05-23 11:02:16.335 | WARNING  | __main__:<module>:57 - Issue #42075 ➡️ No PR linked.
# 2025-05-23 11:02:16.337 | WARNING  | __main__:<module>:57 - Issue #42064 ➡️ No PR linked.
# 2025-05-23 11:02:16.341 | WARNING  | __main__:<module>:57 - Issue #42041 ➡️ No PR linked.
# 2025-05-23 11:02:16.343 | WARNING  | __main__:<module>:57 - Issue #42039 ➡️ No PR linked.
# 2025-05-23 11:02:16.348 | WARNING  | __main__:<module>:57 - Issue #42037 ➡️ No PR linked.
# 2025-05-23 11:02:16.350 | WARNING  | __main__:<module>:57 - Issue #42035 ➡️ No PR linked.
# 2025-05-23 11:02:16.355 | WARNING  | __main__:<module>:57 - Issue #42034 ➡️ No PR linked.
# 2025-05-23 11:02:16.359 | WARNING  | __main__:<module>:57 - Issue #42032 ➡️ No PR linked.
# 2025-05-23 11:02:16.361 | WARNING  | __main__:<module>:57 - Issue #42028 ➡️ No PR linked.
# 2025-05-23 11:02:16.364 | WARNING  | __main__:<module>:57 - Issue #42027 ➡️ No PR linked.
# 2025-05-23 11:02:16.367 | WARNING  | __main__:<module>:57 - Issue #42023 ➡️ No PR linked.
# 2025-05-23 11:02:16.369 | WARNING  | __main__:<module>:57 - Issue #42019 ➡️ No PR linked.
# 2025-05-23 11:02:16.373 | WARNING  | __main__:<module>:57 - Issue #42017 ➡️ No PR linked.
# 2025-05-23 11:02:16.375 | WARNING  | __main__:<module>:57 - Issue #42013 ➡️ No PR linked.
# 2025-05-23 11:02:16.377 | WARNING  | __main__:<module>:57 - Issue #42009 ➡️ No PR linked.
# 2025-05-23 11:02:16.381 | WARNING  | __main__:<module>:57 - Issue #42005 ➡️ No PR linked.
# 2025-05-23 11:02:16.383 | SUCCESS  | __main__:<module>:55 - Issue #42004 ➡️ PR #42084 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:16.384 | WARNING  | __main__:<module>:57 - Issue #42001 ➡️ No PR linked.
# 2025-05-23 11:02:16.386 | WARNING  | __main__:<module>:57 - Issue #41995 ➡️ No PR linked.
# 2025-05-23 11:02:16.387 | WARNING  | __main__:<module>:57 - Issue #41993 ➡️ No PR linked.
# 2025-05-23 11:02:16.389 | WARNING  | __main__:<module>:57 - Issue #41990 ➡️ No PR linked.
# 2025-05-23 11:02:16.391 | WARNING  | __main__:<module>:57 - Issue #41981 ➡️ No PR linked.
# 2025-05-23 11:02:16.395 | WARNING  | __main__:<module>:57 - Issue #41976 ➡️ No PR linked.
# 2025-05-23 11:02:16.397 | WARNING  | __main__:<module>:57 - Issue #41975 ➡️ No PR linked.
# 2025-05-23 11:02:16.399 | WARNING  | __main__:<module>:57 - Issue #41969 ➡️ No PR linked.
# 2025-05-23 11:02:16.401 | SUCCESS  | __main__:<module>:55 - Issue #41968 ➡️ PR #42050 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:16.403 | WARNING  | __main__:<module>:57 - Issue #41966 ➡️ No PR linked.
# 2025-05-23 11:02:16.405 | WARNING  | __main__:<module>:57 - Issue #41965 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):   3%|▎         | 493/16788 [00:02<00:52, 312.31it/s]2025-05-23 11:02:16.409 | WARNING  | __main__:<module>:57 - Issue #41962 ➡️ No PR linked.
# 2025-05-23 11:02:16.410 | WARNING  | __main__:<module>:57 - Issue #41961 ➡️ No PR linked.
# 2025-05-23 11:02:16.413 | WARNING  | __main__:<module>:57 - Issue #41957 ➡️ No PR linked.
# 2025-05-23 11:02:16.415 | SUCCESS  | __main__:<module>:55 - Issue #41953 ➡️ PR #41999 via comment_match. Logged for issue_only.csv.
# 2025-05-23 11:02:16.418 | WARNING  | __main__:<module>:57 - Issue #41952 ➡️ No PR linked.
# 2025-05-23 11:02:16.420 | WARNING  | __main__:<module>:57 - Issue #41948 ➡️ No PR linked.
# 2025-05-23 11:02:16.422 | WARNING  | __main__:<module>:57 - Issue #41941 ➡️ No PR linked.
# 2025-05-23 11:02:16.433 | INFO     | __main__:<module>:72 - Appended batch of 15 records to data/linked_issues_prs_issue_only.csv
# 2025-05-23 11:02:16.435 | WARNING  | __main__:<module>:57 - Issue #41940 ➡️ No PR linked.
# 2025-05-23 11:02:16.438 | WARNING  | __main__:<module>:57 - Issue #41930 ➡️ No PR linked.
# 2025-05-23 11:02:16.440 | WARNING  | __main__:<module>:57 - Issue #41929 ➡️ No PR linked.
# 2025-05-23 11:02:16.441 | WARNING  | __main__:<module>:57 - Issue #41928 ➡️ No PR linked.
# 2025-05-23 11:02:16.445 | WARNING  | __main__:<module>:57 - Issue #41927 ➡️ No PR linked.
# 2025-05-23 11:02:16.447 | WARNING  | __main__:<module>:57 - Issue #41923 ➡️ No PR linked.
# 2025-05-23 11:02:16.449 | WARNING  | __main__:<module>:57 - Issue #41921 ➡️ No PR linked.
# ...
# 2025-05-23 11:03:26.424 | WARNING  | __main__:<module>:57 - Issue #694 ➡️ No PR linked.
# 2025-05-23 11:03:26.432 | WARNING  | __main__:<module>:57 - Issue #691 ➡️ No PR linked.
# 2025-05-23 11:03:26.432 | WARNING  | __main__:<module>:57 - Issue #690 ➡️ No PR linked.
# 2025-05-23 11:03:26.437 | WARNING  | __main__:<module>:57 - Issue #682 ➡️ No PR linked.
# 2025-05-23 11:03:26.440 | WARNING  | __main__:<module>:57 - Issue #679 ➡️ No PR linked.
# 2025-05-23 11:03:26.443 | WARNING  | __main__:<module>:57 - Issue #678 ➡️ No PR linked.
# 2025-05-23 11:03:26.443 | WARNING  | __main__:<module>:57 - Issue #677 ➡️ No PR linked.
# 2025-05-23 11:03:26.443 | WARNING  | __main__:<module>:57 - Issue #675 ➡️ No PR linked.
# 2025-05-23 11:03:26.448 | WARNING  | __main__:<module>:57 - Issue #674 ➡️ No PR linked.
# 2025-05-23 11:03:26.448 | WARNING  | __main__:<module>:57 - Issue #673 ➡️ No PR linked.
# 2025-05-23 11:03:26.448 | WARNING  | __main__:<module>:57 - Issue #671 ➡️ No PR linked.
# 2025-05-23 11:03:26.452 | WARNING  | __main__:<module>:57 - Issue #670 ➡️ No PR linked.
# 2025-05-23 11:03:26.452 | WARNING  | __main__:<module>:57 - Issue #669 ➡️ No PR linked.
# 2025-05-23 11:03:26.457 | WARNING  | __main__:<module>:57 - Issue #668 ➡️ No PR linked.
# 2025-05-23 11:03:26.458 | WARNING  | __main__:<module>:57 - Issue #667 ➡️ No PR linked.
# 2025-05-23 11:03:26.460 | WARNING  | __main__:<module>:57 - Issue #666 ➡️ No PR linked.
# 2025-05-23 11:03:26.462 | WARNING  | __main__:<module>:57 - Issue #665 ➡️ No PR linked.
# 2025-05-23 11:03:26.465 | WARNING  | __main__:<module>:57 - Issue #664 ➡️ No PR linked.
# 2025-05-23 11:03:26.468 | WARNING  | __main__:<module>:57 - Issue #661 ➡️ No PR linked.
# 2025-05-23 11:03:26.471 | WARNING  | __main__:<module>:57 - Issue #660 ➡️ No PR linked.
# 2025-05-23 11:03:26.474 | WARNING  | __main__:<module>:57 - Issue #659 ➡️ No PR linked.
# 2025-05-23 11:03:26.474 | WARNING  | __main__:<module>:57 - Issue #658 ➡️ No PR linked.
# 2025-05-23 11:03:26.474 | WARNING  | __main__:<module>:57 - Issue #657 ➡️ No PR linked.
# 2025-05-23 11:03:26.474 | WARNING  | __main__:<module>:57 - Issue #656 ➡️ No PR linked.
# 2025-05-23 11:03:26.474 | WARNING  | __main__:<module>:57 - Issue #655 ➡️ No PR linked.
# 2025-05-23 11:03:26.482 | WARNING  | __main__:<module>:57 - Issue #654 ➡️ No PR linked.
# 2025-05-23 11:03:26.482 | WARNING  | __main__:<module>:57 - Issue #653 ➡️ No PR linked.
# 2025-05-23 11:03:26.482 | WARNING  | __main__:<module>:57 - Issue #652 ➡️ No PR linked.
# 2025-05-23 11:03:26.482 | WARNING  | __main__:<module>:57 - Issue #651 ➡️ No PR linked.
# 2025-05-23 11:03:26.482 | WARNING  | __main__:<module>:57 - Issue #650 ➡️ No PR linked.
# 2025-05-23 11:03:26.493 | WARNING  | __main__:<module>:57 - Issue #649 ➡️ No PR linked.
# 2025-05-23 11:03:26.497 | WARNING  | __main__:<module>:57 - Issue #648 ➡️ No PR linked.
# 2025-05-23 11:03:26.497 | WARNING  | __main__:<module>:57 - Issue #647 ➡️ No PR linked.
# 2025-05-23 11:03:26.497 | WARNING  | __main__:<module>:57 - Issue #646 ➡️ No PR linked.
# 2025-05-23 11:03:26.502 | WARNING  | __main__:<module>:57 - Issue #644 ➡️ No PR linked.
# 2025-05-23 11:03:26.502 | WARNING  | __main__:<module>:57 - Issue #641 ➡️ No PR linked.
# 2025-05-23 11:03:26.508 | WARNING  | __main__:<module>:57 - Issue #629 ➡️ No PR linked.
# 2025-05-23 11:03:26.508 | WARNING  | __main__:<module>:57 - Issue #610 ➡️ No PR linked.
# 2025-05-23 11:03:26.513 | WARNING  | __main__:<module>:57 - Issue #603 ➡️ No PR linked.
# 2025-05-23 11:03:26.513 | WARNING  | __main__:<module>:57 - Issue #583 ➡️ No PR linked.
# 2025-05-23 11:03:26.513 | WARNING  | __main__:<module>:57 - Issue #578 ➡️ No PR linked.
# 2025-05-23 11:03:26.513 | WARNING  | __main__:<module>:57 - Issue #553 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):  99%|█████████▉| 16657/16788 [01:12<00:00, 361.35it/s]2025-05-23 11:03:26.524 | WARNING  | __main__:<module>:57 - Issue #551 ➡️ No PR linked.
# 2025-05-23 11:03:26.543 | WARNING  | __main__:<module>:57 - Issue #529 ➡️ No PR linked.
# 2025-05-23 11:03:26.543 | WARNING  | __main__:<module>:57 - Issue #506 ➡️ No PR linked.
# 2025-05-23 11:03:26.548 | WARNING  | __main__:<module>:57 - Issue #500 ➡️ No PR linked.
# 2025-05-23 11:03:26.548 | WARNING  | __main__:<module>:57 - Issue #481 ➡️ No PR linked.
# 2025-05-23 11:03:26.553 | WARNING  | __main__:<module>:57 - Issue #475 ➡️ No PR linked.
# 2025-05-23 11:03:26.553 | WARNING  | __main__:<module>:57 - Issue #468 ➡️ No PR linked.
# 2025-05-23 11:03:26.553 | WARNING  | __main__:<module>:57 - Issue #464 ➡️ No PR linked.
# 2025-05-23 11:03:26.559 | WARNING  | __main__:<module>:57 - Issue #456 ➡️ No PR linked.
# 2025-05-23 11:03:26.561 | WARNING  | __main__:<module>:57 - Issue #453 ➡️ No PR linked.
# 2025-05-23 11:03:26.562 | WARNING  | __main__:<module>:57 - Issue #450 ➡️ No PR linked.
# 2025-05-23 11:03:26.565 | WARNING  | __main__:<module>:57 - Issue #448 ➡️ No PR linked.
# 2025-05-23 11:03:26.567 | WARNING  | __main__:<module>:57 - Issue #442 ➡️ No PR linked.
# 2025-05-23 11:03:26.569 | WARNING  | __main__:<module>:57 - Issue #438 ➡️ No PR linked.
# 2025-05-23 11:03:26.571 | WARNING  | __main__:<module>:57 - Issue #431 ➡️ No PR linked.
# 2025-05-23 11:03:26.574 | WARNING  | __main__:<module>:57 - Issue #422 ➡️ No PR linked.
# 2025-05-23 11:03:26.574 | WARNING  | __main__:<module>:57 - Issue #421 ➡️ No PR linked.
# 2025-05-23 11:03:26.574 | WARNING  | __main__:<module>:57 - Issue #420 ➡️ No PR linked.
# 2025-05-23 11:03:26.582 | WARNING  | __main__:<module>:57 - Issue #413 ➡️ No PR linked.
# 2025-05-23 11:03:26.582 | WARNING  | __main__:<module>:57 - Issue #411 ➡️ No PR linked.
# 2025-05-23 11:03:26.582 | WARNING  | __main__:<module>:57 - Issue #410 ➡️ No PR linked.
# 2025-05-23 11:03:26.590 | WARNING  | __main__:<module>:57 - Issue #395 ➡️ No PR linked.
# 2025-05-23 11:03:26.592 | WARNING  | __main__:<module>:57 - Issue #394 ➡️ No PR linked.
# 2025-05-23 11:03:26.592 | WARNING  | __main__:<module>:57 - Issue #393 ➡️ No PR linked.
# 2025-05-23 11:03:26.592 | WARNING  | __main__:<module>:57 - Issue #392 ➡️ No PR linked.
# 2025-05-23 11:03:26.592 | WARNING  | __main__:<module>:57 - Issue #391 ➡️ No PR linked.
# 2025-05-23 11:03:26.602 | WARNING  | __main__:<module>:57 - Issue #389 ➡️ No PR linked.
# 2025-05-23 11:03:26.602 | WARNING  | __main__:<module>:57 - Issue #384 ➡️ No PR linked.
# 2025-05-23 11:03:26.608 | WARNING  | __main__:<module>:57 - Issue #374 ➡️ No PR linked.
# 2025-05-23 11:03:26.608 | WARNING  | __main__:<module>:57 - Issue #354 ➡️ No PR linked.
# 2025-05-23 11:03:26.612 | WARNING  | __main__:<module>:57 - Issue #347 ➡️ No PR linked.
# 2025-05-23 11:03:26.612 | WARNING  | __main__:<module>:57 - Issue #341 ➡️ No PR linked.
# 2025-05-23 11:03:26.612 | WARNING  | __main__:<module>:57 - Issue #339 ➡️ No PR linked.
# 2025-05-23 11:03:26.612 | WARNING  | __main__:<module>:57 - Issue #338 ➡️ No PR linked.
# 2025-05-23 11:03:26.612 | WARNING  | __main__:<module>:57 - Issue #337 ➡️ No PR linked.
# 2025-05-23 11:03:26.622 | WARNING  | __main__:<module>:57 - Issue #336 ➡️ No PR linked.
# 2025-05-23 11:03:26.624 | WARNING  | __main__:<module>:57 - Issue #335 ➡️ No PR linked.
# 2025-05-23 11:03:26.624 | WARNING  | __main__:<module>:57 - Issue #334 ➡️ No PR linked.
# 2025-05-23 11:03:26.624 | WARNING  | __main__:<module>:57 - Issue #333 ➡️ No PR linked.
# 2025-05-23 11:03:26.624 | WARNING  | __main__:<module>:57 - Issue #332 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1):  99%|█████████▉| 16697/16788 [01:12<00:00, 364.11it/s]2025-05-23 11:03:26.632 | WARNING  | __main__:<module>:57 - Issue #331 ➡️ No PR linked.
# 2025-05-23 11:03:26.632 | WARNING  | __main__:<module>:57 - Issue #330 ➡️ No PR linked.
# 2025-05-23 11:03:26.632 | WARNING  | __main__:<module>:57 - Issue #328 ➡️ No PR linked.
# 2025-05-23 11:03:26.639 | WARNING  | __main__:<module>:57 - Issue #320 ➡️ No PR linked.
# 2025-05-23 11:03:26.643 | WARNING  | __main__:<module>:57 - Issue #308 ➡️ No PR linked.
# 2025-05-23 11:03:26.643 | WARNING  | __main__:<module>:57 - Issue #306 ➡️ No PR linked.
# 2025-05-23 11:03:26.643 | WARNING  | __main__:<module>:57 - Issue #304 ➡️ No PR linked.
# 2025-05-23 11:03:26.648 | WARNING  | __main__:<module>:57 - Issue #303 ➡️ No PR linked.
# 2025-05-23 11:03:26.648 | WARNING  | __main__:<module>:57 - Issue #297 ➡️ No PR linked.
# 2025-05-23 11:03:26.652 | WARNING  | __main__:<module>:57 - Issue #290 ➡️ No PR linked.
# 2025-05-23 11:03:26.652 | WARNING  | __main__:<module>:57 - Issue #285 ➡️ No PR linked.
# 2025-05-23 11:03:26.656 | WARNING  | __main__:<module>:57 - Issue #278 ➡️ No PR linked.
# 2025-05-23 11:03:26.658 | WARNING  | __main__:<module>:57 - Issue #260 ➡️ No PR linked.
# 2025-05-23 11:03:26.660 | WARNING  | __main__:<module>:57 - Issue #254 ➡️ No PR linked.
# 2025-05-23 11:03:26.663 | WARNING  | __main__:<module>:57 - Issue #213 ➡️ No PR linked.
# 2025-05-23 11:03:26.667 | WARNING  | __main__:<module>:57 - Issue #193 ➡️ No PR linked.
# 2025-05-23 11:03:26.670 | WARNING  | __main__:<module>:57 - Issue #192 ➡️ No PR linked.
# 2025-05-23 11:03:26.671 | WARNING  | __main__:<module>:57 - Issue #190 ➡️ No PR linked.
# 2025-05-23 11:03:26.674 | WARNING  | __main__:<module>:57 - Issue #187 ➡️ No PR linked.
# 2025-05-23 11:03:26.676 | WARNING  | __main__:<module>:57 - Issue #186 ➡️ No PR linked.
# 2025-05-23 11:03:26.680 | WARNING  | __main__:<module>:57 - Issue #185 ➡️ No PR linked.
# 2025-05-23 11:03:26.681 | WARNING  | __main__:<module>:57 - Issue #184 ➡️ No PR linked.
# 2025-05-23 11:03:26.684 | WARNING  | __main__:<module>:57 - Issue #183 ➡️ No PR linked.
# 2025-05-23 11:03:26.687 | WARNING  | __main__:<module>:57 - Issue #182 ➡️ No PR linked.
# 2025-05-23 11:03:26.687 | WARNING  | __main__:<module>:57 - Issue #181 ➡️ No PR linked.
# 2025-05-23 11:03:26.691 | WARNING  | __main__:<module>:57 - Issue #180 ➡️ No PR linked.
# 2025-05-23 11:03:26.692 | WARNING  | __main__:<module>:57 - Issue #179 ➡️ No PR linked.
# 2025-05-23 11:03:26.692 | WARNING  | __main__:<module>:57 - Issue #178 ➡️ No PR linked.
# 2025-05-23 11:03:26.697 | WARNING  | __main__:<module>:57 - Issue #172 ➡️ No PR linked.
# 2025-05-23 11:03:26.697 | WARNING  | __main__:<module>:57 - Issue #171 ➡️ No PR linked.
# 2025-05-23 11:03:26.697 | WARNING  | __main__:<module>:57 - Issue #170 ➡️ No PR linked.
# 2025-05-23 11:03:26.702 | WARNING  | __main__:<module>:57 - Issue #168 ➡️ No PR linked.
# 2025-05-23 11:03:26.702 | WARNING  | __main__:<module>:57 - Issue #166 ➡️ No PR linked.
# 2025-05-23 11:03:26.707 | WARNING  | __main__:<module>:57 - Issue #165 ➡️ No PR linked.
# 2025-05-23 11:03:26.708 | WARNING  | __main__:<module>:57 - Issue #164 ➡️ No PR linked.
# 2025-05-23 11:03:26.712 | WARNING  | __main__:<module>:57 - Issue #163 ➡️ No PR linked.
# 2025-05-23 11:03:26.712 | WARNING  | __main__:<module>:57 - Issue #161 ➡️ No PR linked.
# 2025-05-23 11:03:26.712 | WARNING  | __main__:<module>:57 - Issue #160 ➡️ No PR linked.
# 2025-05-23 11:03:26.712 | WARNING  | __main__:<module>:57 - Issue #153 ➡️ No PR linked.
# 2025-05-23 11:03:26.712 | WARNING  | __main__:<module>:57 - Issue #149 ➡️ No PR linked.
# 2025-05-23 11:03:26.712 | WARNING  | __main__:<module>:57 - Issue #137 ➡️ No PR linked.
# 2025-05-23 11:03:26.723 | WARNING  | __main__:<module>:57 - Issue #136 ➡️ No PR linked.
# 2025-05-23 11:03:26.724 | WARNING  | __main__:<module>:57 - Issue #135 ➡️ No PR linked.
# 2025-05-23 11:03:26.724 | WARNING  | __main__:<module>:57 - Issue #132 ➡️ No PR linked.
# 2025-05-23 11:03:26.724 | WARNING  | __main__:<module>:57 - Issue #121 ➡️ No PR linked.
# 2025-05-23 11:03:26.724 | WARNING  | __main__:<module>:57 - Issue #120 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1): 100%|█████████▉| 16743/16788 [01:12<00:00, 390.19it/s]2025-05-23 11:03:26.732 | WARNING  | __main__:<module>:57 - Issue #117 ➡️ No PR linked.
# 2025-05-23 11:03:26.732 | WARNING  | __main__:<module>:57 - Issue #114 ➡️ No PR linked.
# 2025-05-23 11:03:26.732 | WARNING  | __main__:<module>:57 - Issue #110 ➡️ No PR linked.
# 2025-05-23 11:03:26.741 | WARNING  | __main__:<module>:57 - Issue #109 ➡️ No PR linked.
# 2025-05-23 11:03:26.743 | WARNING  | __main__:<module>:57 - Issue #108 ➡️ No PR linked.
# 2025-05-23 11:03:26.746 | WARNING  | __main__:<module>:57 - Issue #107 ➡️ No PR linked.
# 2025-05-23 11:03:26.749 | WARNING  | __main__:<module>:57 - Issue #106 ➡️ No PR linked.
# 2025-05-23 11:03:26.753 | WARNING  | __main__:<module>:57 - Issue #101 ➡️ No PR linked.
# 2025-05-23 11:03:26.755 | WARNING  | __main__:<module>:57 - Issue #100 ➡️ No PR linked.
# 2025-05-23 11:03:26.757 | WARNING  | __main__:<module>:57 - Issue #97 ➡️ No PR linked.
# 2025-05-23 11:03:26.758 | WARNING  | __main__:<module>:57 - Issue #96 ➡️ No PR linked.
# 2025-05-23 11:03:26.760 | WARNING  | __main__:<module>:57 - Issue #95 ➡️ No PR linked.
# 2025-05-23 11:03:26.762 | WARNING  | __main__:<module>:57 - Issue #92 ➡️ No PR linked.
# 2025-05-23 11:03:26.765 | WARNING  | __main__:<module>:57 - Issue #91 ➡️ No PR linked.
# 2025-05-23 11:03:26.767 | WARNING  | __main__:<module>:57 - Issue #90 ➡️ No PR linked.
# 2025-05-23 11:03:26.769 | WARNING  | __main__:<module>:57 - Issue #88 ➡️ No PR linked.
# 2025-05-23 11:03:26.771 | WARNING  | __main__:<module>:57 - Issue #83 ➡️ No PR linked.
# 2025-05-23 11:03:26.773 | WARNING  | __main__:<module>:57 - Issue #72 ➡️ No PR linked.
# 2025-05-23 11:03:26.774 | WARNING  | __main__:<module>:57 - Issue #54 ➡️ No PR linked.
# 2025-05-23 11:03:26.774 | WARNING  | __main__:<module>:57 - Issue #46 ➡️ No PR linked.
# 2025-05-23 11:03:26.774 | WARNING  | __main__:<module>:57 - Issue #45 ➡️ No PR linked.
# 2025-05-23 11:03:26.782 | WARNING  | __main__:<module>:57 - Issue #44 ➡️ No PR linked.
# 2025-05-23 11:03:26.782 | WARNING  | __main__:<module>:57 - Issue #42 ➡️ No PR linked.
# 2025-05-23 11:03:26.782 | WARNING  | __main__:<module>:57 - Issue #41 ➡️ No PR linked.
# 2025-05-23 11:03:26.789 | WARNING  | __main__:<module>:57 - Issue #39 ➡️ No PR linked.
# 2025-05-23 11:03:26.791 | WARNING  | __main__:<module>:57 - Issue #36 ➡️ No PR linked.
# 2025-05-23 11:03:26.792 | WARNING  | __main__:<module>:57 - Issue #35 ➡️ No PR linked.
# 2025-05-23 11:03:26.792 | WARNING  | __main__:<module>:57 - Issue #33 ➡️ No PR linked.
# 2025-05-23 11:03:26.792 | WARNING  | __main__:<module>:57 - Issue #32 ➡️ No PR linked.
# 2025-05-23 11:03:26.792 | WARNING  | __main__:<module>:57 - Issue #31 ➡️ No PR linked.
# 2025-05-23 11:03:26.802 | WARNING  | __main__:<module>:57 - Issue #23 ➡️ No PR linked.
# 2025-05-23 11:03:26.802 | WARNING  | __main__:<module>:57 - Issue #18 ➡️ No PR linked.
# 2025-05-23 11:03:26.802 | WARNING  | __main__:<module>:57 - Issue #16 ➡️ No PR linked.
# 2025-05-23 11:03:26.808 | WARNING  | __main__:<module>:57 - Issue #15 ➡️ No PR linked.
# 2025-05-23 11:03:26.808 | WARNING  | __main__:<module>:57 - Issue #12 ➡️ No PR linked.
# 2025-05-23 11:03:26.808 | WARNING  | __main__:<module>:57 - Issue #10 ➡️ No PR linked.
# 2025-05-23 11:03:26.813 | WARNING  | __main__:<module>:57 - Issue #9 ➡️ No PR linked.
# 2025-05-23 11:03:26.813 | WARNING  | __main__:<module>:57 - Issue #8 ➡️ No PR linked.
# 2025-05-23 11:03:26.817 | WARNING  | __main__:<module>:57 - Issue #7 ➡️ No PR linked.
# 2025-05-23 11:03:26.817 | WARNING  | __main__:<module>:57 - Issue #6 ➡️ No PR linked.
# 2025-05-23 11:03:26.823 | WARNING  | __main__:<module>:57 - Issue #5 ➡️ No PR linked.
# 2025-05-23 11:03:26.824 | WARNING  | __main__:<module>:57 - Issue #4 ➡️ No PR linked.
# 2025-05-23 11:03:26.824 | WARNING  | __main__:<module>:57 - Issue #3 ➡️ No PR linked.
# 2025-05-23 11:03:26.824 | WARNING  | __main__:<module>:57 - Issue #2 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1): 100%|█████████▉| 16787/16788 [01:12<00:00, 404.14it/s]2025-05-23 11:03:26.832 | WARNING  | __main__:<module>:57 - Issue #1 ➡️ No PR linked.
# 🔗 Linking Issues (Pass 1): 100%|██████████| 16788/16788 [01:12<00:00, 231.60it/s]
# 2025-05-23 11:03:26.843 | INFO     | __main__:<module>:79 - Appended final batch of 2 records to data/linked_issues_prs_issue_only.csv
# 2025-05-23 11:03:26.843 | INFO     | __main__:<module>:82 - ✅ Initial linking complete. Output in 'data/linked_issues_prs_issue_only.csv'.
# 2025-05-23 11:03:26.843 | INFO     | __main__:<module>:83 - 296 PRs identified for full detail fetching in the next step.

# %%
# This cell generates csv_full_details_path using data from the previous cell.

results_full_details = []
csv_full_details_path = "../data/keyword-linking/ssue-pr/linked_issues_prs_full_details.csv"

headers_full = [
    "issue_number", "issue_link", "issue_title", "issue_body",
    "linked_pr_number", "pr_title", "pr_body", "pr_link", "strategy"
]

# Write headers to csv_full_details_path
pd.DataFrame(columns=headers_full).to_csv(csv_full_details_path, index=False, mode='w')
logger.info(f"Initialized {csv_full_details_path} with headers.")

processed_pr_count_git = 0

if not 'issues_for_full_pr_details' in locals() or not issues_for_full_pr_details:
    logger.warning("No data ('issues_for_full_pr_details') found from the previous cell to process for full PR details.")
else:
    logger.info(f"🔎 Starting full PR detail fetching for {len(issues_for_full_pr_details)} identified PRs...")
    for item_data in tqdm(issues_for_full_pr_details, desc="🔗 Fetching PR Details (Pass 2)"):
        repository_api_url = item_data.get("repository_api_url")
        pr_number = item_data.get("linked_pr_number")
        
        pr_details_fetched = None
        if repository_api_url and pr_number != "N/A": # Ensure pr_number is valid
            pr_details_fetched = fetch_pr_details_from_github(repository_api_url, pr_number, GITHUB_TOKEN)
        else:
            logger.warning(f"Issue #{item_data.get('issue_number')} - PR #{pr_number}: Missing repo URL or PR number. Skipping PR detail fetch.")

        pr_title_val = pr_details_fetched.get("title", "N/A") if pr_details_fetched else "N/A"
        
        pr_body_temp = pr_details_fetched.get("body", "N/A") if pr_details_fetched else "N/A"
        if isinstance(pr_body_temp, str) and pr_body_temp != "N/A":
            # Replace all types of newlines with a single space
            pr_body_val = pr_body_temp.replace("\r\n", " ").replace("\n", " ").replace("\r", " ")
        else:
            pr_body_val = pr_body_temp # Assigns "N/A" or empty string if that was the case

        pr_link_val = pr_details_fetched.get("html_url", "N/A") if pr_details_fetched else "N/A"

        full_detail_entry = {
            "issue_number": item_data.get("issue_number"),
            "issue_link": item_data.get("issue_link"),
            "issue_title": item_data.get("issue_title"),
            "issue_body": item_data.get("issue_body"),
            "linked_pr_number": pr_number,
            "pr_title": pr_title_val,
            "pr_body": pr_body_val, # Consider summarizing/truncating
            "pr_link": pr_link_val,
            "strategy": item_data.get("strategy")
        }
        results_full_details.append(full_detail_entry)
        # logger.debug(f"Fetched details for PR #{pr_number} linked to Issue #{item_data.get('issue_number')}")

        processed_pr_count_git += 1

        if processed_pr_count_git % BATCH_SIZE == 0:
            if results_full_details:
                df_full = pd.DataFrame(results_full_details)
                df_full.to_csv(csv_full_details_path, mode='a', header=False, index=False)
                logger.info(f"Appended batch of {len(results_full_details)} records to {csv_full_details_path}")
                results_full_details.clear()

    # Write any remaining records for full_details.csv
    if results_full_details:
        df_full = pd.DataFrame(results_full_details)
        df_full.to_csv(csv_full_details_path, mode='a', header=False, index=False)
        logger.info(f"Appended final batch of {len(results_full_details)} records to {csv_full_details_path}")
        results_full_details.clear()

    logger.info(f"✅ Full PR detail fetching complete. Output in '{csv_full_details_path}'.")

# %%
# This cell is now redundant as CSV saving is handled in the main processing loop.
# df = pd.DataFrame(results)
# df.to_csv("data/linked_issues_prs_keyword.csv", index=False)
# logger.success("📄 CSV saved as 'linked_issues_prs_keyword.csv'")
logger.info("Previous CSV saving cell is now integrated into the main processing loop.")
