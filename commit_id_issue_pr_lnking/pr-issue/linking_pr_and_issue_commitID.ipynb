# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

import re
import pandas as pd
from tqdm import tqdm
from loguru import logger
from pymongo import MongoClient
import requests 
import time 
import concurrent.futures

# GitHub Personal Access Token (optional, but recommended for higher rate limits)
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")
if not GITHUB_TOKEN:
    logger.warning("GitHub token not found. Rate limits may apply.")

BATCH_SIZE = 500 # Number of records to process before writing to CSV

# Logger config
logger.add("logs/prs-linking-commite.log")
# Out:
# 1

# %% [markdown]
#  mongoDB configuration

# %%
# Mongo connection
client = MongoClient("mongodb://localhost:27017/")
db = client.github_data
pull_request_col = db.pull_requests

logger.info("🔌 MongoDB connected.")
# Out:
# 2025-06-02 10:41:21.178 | INFO     | __main__:<module>:6 - 🔌 MongoDB connected.

# %%
# we are interested in isspull_requestues that are closed and referenced in commits
qurey = {
    "pull_request.state": "closed",
    "timeline.event": "referenced"
}

# %% [markdown]
# github APIs

# %%
def get_commit_data(url):
    """
    Fetch commit data for a given pull_request number from GitHub API.
    """
    headers = {
        "Authorization": f"token {GITHUB_TOKEN}" if GITHUB_TOKEN else None
    }
    
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        html_url = data.get("html_url")
        message = data.get("commit").get("message")
        if not message:
            logger.error(f"Missing commit message in response: {data}")   
        logger.success(f"✅ Successfully fetched commit data from {url}")
        return html_url, message
    else:
        # The variable 'issue_number' is not in the scope of this function.
        # Logging the URL that caused the error instead.
        # Also, providing more error details from response.text
        logger.error(f"Error fetching commit data from {url}: {response.status_code} - {response.text}")
        # Ensure two values are returned as expected by the calling code
        return None, None

# %% [markdown]
# csv initialization

# %%
results_commite_id = []

csv_path = "../../data/commit_id-linking/pr-issue/linked_pull_request_commite_id.csv"

headers_pull_request_commite_id = [
    "pull_request_number", "pull_request_link", "pull_request_title", "pull_request_body",
    "linked_commit_id", "linked_commit_url", "linked_commit_message",
]

pd.DataFrame(columns=headers_pull_request_commite_id).to_csv(csv_path, index=False)
logger.info(f"Initialized CSV file at {csv_path}.")
# Out:
# 2025-06-02 10:40:34.626 | INFO     | __main__:<module>:11 - Initialized CSV file at ../../data/commit_id-linking/pr-issue/linked_pull_request_commite_id.csv.

# %% [markdown]
# fetching the data from mongoDB

# %%
# Fetch all records into a list to prevent cursor timeout during processing
logger.info("Fetching all records from MongoDB...")
all_records_list = list(pull_request_col.find(qurey))
toal_pull_request_count = len(all_records_list) # Actual number of records fetched
logger.info(f"Successfully fetched {toal_pull_request_count} records. Starting processing.")
# Out:
# 2025-06-02 10:43:01.285 | INFO     | __main__:<module>:2 - Fetching all records from MongoDB...
# 2025-06-02 10:43:04.530 | INFO     | __main__:<module>:5 - Successfully fetched 998 records. Starting processing.

# %% [markdown]
# Commit data fetching

# %%
logger.info("Starting to process pull_requests and fetch initial commit data concurrently...")

# Temporary list to hold data before converting to DataFrame rows
processed_event_data = []
MAX_WORKERS_COMMIT_DATA = 10  # Number of threads to use for fetching commit data
with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS_COMMIT_DATA) as executor:
    future_to_event = {}
    for record_idx, record in enumerate(tqdm(all_records_list, total=toal_pull_request_count, desc="Submitting commit data tasks")):
        pull_request_data = record["pull_request"]
        for event_idx, event in enumerate(record.get("timeline", [])):
            if event.get("event") == "referenced":
                linked_commit_url_api = event.get("commit_url") # This is the API URL for the commit
                if linked_commit_url_api:
                    # Store record_idx and event_idx to link back results
                    future = executor.submit(get_commit_data, linked_commit_url_api)
                    future_to_event[future] = (record_idx, event_idx, pull_request_data, event)

    logger.info(f"Submitted {len(future_to_event)} tasks to fetch commit data. Waiting for completion...")
    for future in tqdm(concurrent.futures.as_completed(future_to_event), total=len(future_to_event), desc="Processing commit data results"):
        record_idx, event_idx, pull_request_data, event = future_to_event[future]
        try:
            linked_commit_html_url, linked_commit_message = future.result()
            linked_commit_id = event.get("commit_id")
            
            if linked_commit_id and linked_commit_html_url: # Ensure we have the essential data
                processed_event_data.append({
                    "pull_request_number": pull_request_data["number"],
                    "pull_request_link": pull_request_data.get("html_url"),
                    "pull_request_title": pull_request_data.get("title"),
                    "pull_request_body": pull_request_data.get("body"),
                    "linked_commit_id": linked_commit_id,
                    "linked_commit_url": linked_commit_html_url, 
                    "linked_commit_message": linked_commit_message,
                })
            elif linked_commit_id:
                 logger.warning(f"Commit data fetched for commit ID {linked_commit_id} but HTML URL was missing. API URL was {event.get('commit_url')}")

        except Exception as exc:
            original_commit_url = event.get("commit_url")
            logger.error(f"Fetching commit data for {original_commit_url} (event in pull_request {pull_request_data.get('number')}) generated an exception: {exc}")

logger.info(f"Finished fetching commit data. {len(processed_event_data)} events processed into commit details.")

# Convert processed_event_data to DataFrame and save to CSV
if processed_event_data:
    df_commits = pd.DataFrame(processed_event_data)
    df_commits.to_csv(csv_path, mode='w', header=headers_pull_request_commite_id, index=False) # Write header once with all data
    logger.info(f"Saved {len(df_commits)} records with commit data to {csv_path}.")
else:
    logger.info("No commit data was successfully processed to save.")

logger.info("✅ Initial commit data processing complete.")
# Out:
# 2025-06-02 10:43:10.118 | INFO     | __main__:<module>:1 - Starting to process pull_requests and fetch initial commit data concurrently...
# Submitting commit data tasks: 100%|██████████| 998/998 [00:00<00:00, 3911.45it/s]
# 2025-06-02 10:43:10.404 | INFO     | __main__:<module>:18 - Submitted 2308 tasks to fetch commit data. Waiting for completion...
# Processing commit data results:   0%|          | 0/2308 [00:00<?, ?it/s]2025-06-02 10:43:11.145 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/chiranSachintha/ballerina-lang/commits/ce793f94a38df5a844d84519473e8b04317e60bd
# Processing commit data results:   0%|          | 1/2308 [00:00<28:56,  1.33it/s]2025-06-02 10:43:11.163 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/HindujaB/ballerina-lang/commits/92d3b7d3abdd1aa25b508e0e121939ba1873cf36
# 2025-06-02 10:43:11.185 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/chiranSachintha/ballerina-lang/commits/9b1b66778270ad96f070a40ecd13f1664b590b3f
# 2025-06-02 10:43:11.195 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/dulajdilshan/ballerina-lang/commits/6d426c39abebe37af8892710cdf2d9b1235a688a
# 2025-06-02 10:43:11.212 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/4e800422f10a07515fbf1eaedd9005411e0d2a0f
# 2025-06-02 10:43:11.230 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/Shadow-Devil/ballerina-lang/commits/e26c61edbb0b53de3ef0d365800f9508ddb89cf1
# 2025-06-02 10:43:11.251 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/lochana-chathura/ballerina-lang/commits/c14cd0fd297af2515b980c68a2d7353aec989d06
# 2025-06-02 10:43:11.255 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/4e800422f10a07515fbf1eaedd9005411e0d2a0f
# 2025-06-02 10:43:11.256 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/Shadow-Devil/ballerina-lang/commits/1622a6f8dadc587e809c8d7932b0288d9e57665a
# Processing commit data results:   0%|          | 8/2308 [00:00<03:12, 11.95it/s]2025-06-02 10:43:11.312 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/e7c4a286fb50fbe95f4f96974002fb20e298c8eb
# 2025-06-02 10:43:12.068 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/34f51ac014c8f741a6ccde07c8d857d74280e8d7
# 2025-06-02 10:43:12.094 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/lochana-chathura/ballerina-lang/commits/122e109de00a40ed24eb1886e996cfcf284720ad
# Processing commit data results:   1%|          | 12/2308 [00:01<05:09,  7.43it/s]2025-06-02 10:43:12.128 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/4fb98152f78784ef2120116ee0e97da7dd6a6830
# 2025-06-02 10:43:12.179 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/253516ce0fed92fbe4322e517ca0f55fb4f8077f
# 2025-06-02 10:43:12.186 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/ec8e4834a36bd34109ef5bd7ff1300050b38581f
# Processing commit data results:   1%|          | 15/2308 [00:01<03:57,  9.65it/s]2025-06-02 10:43:12.213 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/9318f342bff49fe4b774a7522ce237268ca49016
# 2025-06-02 10:43:12.216 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/6522707bb2ee90a87fc54e51ac34a607c3fcab6c
# 2025-06-02 10:43:12.228 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/80cabf7ea867d8c3980712b49de48fc08db03d7d
# 2025-06-02 10:43:12.251 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/f2052f9bfb266b04952fed8eec96a352e3097dd8
# 2025-06-02 10:43:12.652 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aneeshafedo/ballerina-lang/commits/16f50449288d523db821c08206489daf6346e3e4
# Processing commit data results:   1%|          | 20/2308 [00:02<03:44, 10.21it/s]2025-06-02 10:43:13.027 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/67322573d4b424f9491a8f98c423ae0c45c5d134
# 2025-06-02 10:43:13.051 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/f0ba832d0c97dda8e0f96013f34d632a6163af88
# Processing commit data results:   1%|          | 22/2308 [00:02<04:32,  8.40it/s]2025-06-02 10:43:13.070 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/41ec917310592e71d65c2439bb41b613f6dc1044
# 2025-06-02 10:43:13.081 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/0fa52db4553681d73ce46b0e3d64ac9a36d4b61d
# 2025-06-02 10:43:13.129 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/3c1202c72bacd3ad73990686bd814928bf1f7847
# 2025-06-02 10:43:13.130 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/65b2686335a3a9227f250e37ae14f3f1676f3bcf
# 2025-06-02 10:43:13.132 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/551965be2094b247b5b19592e382245477bc16ad
# 2025-06-02 10:43:13.169 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/e5a5605da03bb314e7eeb14d819d4724d6fb21b7
# Processing commit data results:   1%|          | 28/2308 [00:02<02:47, 13.61it/s]2025-06-02 10:43:13.179 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/ba62ac5c6df1d4887d6fd82b3c70a059eeab3cdc
# 2025-06-02 10:43:13.609 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/981af68f109459e21f14b4f2b790d9c6f065a7f8
# 2025-06-02 10:43:13.994 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/172fb8541d82fcd14d5bbc0d6e09d9fcf324f561
# 2025-06-02 10:43:13.994 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/79e0dd31f56df779f2f5a1f34530efa5d2a5869a
# Processing commit data results:   1%|▏         | 31/2308 [00:03<04:38,  8.18it/s]2025-06-02 10:43:14.011 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/a5e8bd9dad9ea7a77a61ab4b07e9ce7445b3e0e1
# 2025-06-02 10:43:14.011 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/18d356a0515fc372314b21bc6a88042b31917a1f
# 2025-06-02 10:43:14.079 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/6055ad46aadf9d78432fe38252b99da7e80a75bb
# 2025-06-02 10:43:14.079 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/40b635d8aa7be1d09f1d8ca6abc009b00fed8966
# 2025-06-02 10:43:14.094 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/b270dd23b9fb34bac574c72f74e84110f409e749
# Processing commit data results:   2%|▏         | 36/2308 [00:03<03:11, 11.84it/s]2025-06-02 10:43:14.094 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/ccc78c149eb11dfbcfed69ad2845151b6620f896
# 2025-06-02 10:43:14.094 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/6353e8db25d70383a4de3a5be7090a02e3647387
# 2025-06-02 10:43:14.529 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/f68e2613488c7dc2677ee3d6d8a8359baea5e8fc
# Processing commit data results:   2%|▏         | 40/2308 [00:04<03:28, 10.87it/s]2025-06-02 10:43:14.927 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/6618da27324df0809a6c788f814ad3b1cc76adbc
# 2025-06-02 10:43:14.927 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/af5e640d9aaaf6f89d679c1e7574abd5053ef0c9
# 2025-06-02 10:43:14.944 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/261212458b913b45382a107c6340443c4b0c7308
# 2025-06-02 10:43:14.944 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/60de3676e45f79afb35d8a183aa4fc5253d790df
# Processing commit data results:   2%|▏         | 43/2308 [00:04<03:56,  9.59it/s]2025-06-02 10:43:14.977 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/0dbbffbd1f29aa357fe435f476f40d26fbb272db
# 2025-06-02 10:43:15.016 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/22238867f5e5c044824e1d7b9fddba6a1ccc6791
# 2025-06-02 10:43:15.034 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/e1a58682a8fd8bc46df0350946d8d0e798caf0ce
# 2025-06-02 10:43:15.047 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/e93021369c2bc43966b8a627efb8c863f48cd37e
# 2025-06-02 10:43:15.065 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/70947f39e2b5b84894d9be98902cc2759d0cd649
# Processing commit data results:   2%|▏         | 49/2308 [00:04<02:35, 14.51it/s]2025-06-02 10:43:15.468 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/d58e1cd3872ddf5871ef60da5f463210714b6287
# 2025-06-02 10:43:15.911 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/malinthar/ballerina-lang/commits/d2567b00fa5ca948ac75cd0162d4a470c20d0a04
# 2025-06-02 10:43:15.911 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aneeshafedo/ballerina-lang/commits/96bea255f210a6e53bbc89b55a0f1f8e17b07a0a
# 2025-06-02 10:43:15.911 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aneeshafedo/ballerina-lang/commits/62ed601fe7f889f0dfdf54206f4ddb91e1d3c00e
# Processing commit data results:   2%|▏         | 52/2308 [00:05<04:26,  8.46it/s]2025-06-02 10:43:15.911 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/DamithaSenevirathne/ballerina-lang/commits/a751519c748ae22ee99b2b0a2f6dc4978a8f4dbc
# 2025-06-02 10:43:15.929 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/gimantha/ballerina-lang/commits/e5f80b8a9365fc43f7462323d85270d972431316
# 2025-06-02 10:43:15.945 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/29965678df926972272695a77738530b2aee67a9
# 2025-06-02 10:43:15.981 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/gimantha/ballerina-lang/commits/b9a2c8dc3bdca543fda295d701c378e6ceaf9ebf
# 2025-06-02 10:43:16.191 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/e1082d4fa95f6c42e9fe3d40bab2a99c758b9a8c
# Processing commit data results:   3%|▎         | 58/2308 [00:05<03:20, 11.20it/s]2025-06-02 10:43:16.580 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/8eaa0c6f7bf96a655ad9303ecea029c5fcea06a8
# 2025-06-02 10:43:16.713 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/579e66be061a184f19c3e15ad3fdd6f1ea27d1df
# 2025-06-02 10:43:16.941 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/5c1541e20fb2885a0da2c63ac6de8c11f75e09ab
# Processing commit data results:   3%|▎         | 61/2308 [00:06<04:39,  8.05it/s]2025-06-02 10:43:16.970 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/7bd07b3294cc8ed4c9791bf623bc0e760c71d7fa
# 2025-06-02 10:43:16.971 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/1a7acc03ead2c06bb3a67fe920c9863dc1e964e6
# 2025-06-02 10:43:16.973 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/79771f7ffacc44a984f6b165ff0557709c6d819f
# 2025-06-02 10:43:16.977 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/07c9394e12975310d4f1fc646d88c4052c87cf87
# 2025-06-02 10:43:17.018 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/01bbb2e5d72079b2c33b69ca75b228ac85214c6f
# 2025-06-02 10:43:17.049 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/61d982ee4b3f9764beee1fe84ff25b72f69a5665
# Processing commit data results:   3%|▎         | 67/2308 [00:06<03:08, 11.90it/s]2025-06-02 10:43:17.122 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/c5d7b3d62282dc443ccf655ea9fb831d02cba431
# 2025-06-02 10:43:17.506 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/c6625ece5d0619ff40377fa78e53dcbb2397cf42
# 2025-06-02 10:43:17.625 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/07fad95c103ad1bd7f16210a475e35405835bbe2
# Processing commit data results:   3%|▎         | 70/2308 [00:07<03:59,  9.34it/s]2025-06-02 10:43:17.869 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/faf5f697ce2bc36cd761cb78cbc383e59603c591
# 2025-06-02 10:43:17.886 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/5923afaa0a8d6fcd195f79b1890ef4c4a8c2ae2b
# 2025-06-02 10:43:17.926 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/module-ballerina-protobuf/commits/219226a28213a27d7ae0d939a7d1e1697231f7d7
# 2025-06-02 10:43:17.926 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/204c7fddbc3f68e39c864ccf99f8f678b00d3c6b
# Processing commit data results:   3%|▎         | 73/2308 [00:07<03:54,  9.55it/s]2025-06-02 10:43:17.946 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/04a7608b8f4fcc340fa9524955d5b0182cb99a56
# 2025-06-02 10:43:18.008 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/a4efc128028bea46c0a98223ed10e70c590ac97e
# 2025-06-02 10:43:18.017 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/dedc1c067b4cf035156b765b1912c6eefd3086b7
# 2025-06-02 10:43:18.062 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/9e72044f2c46468281e75f44a3b11b15f7fabe87
# Processing commit data results:   3%|▎         | 78/2308 [00:07<02:51, 12.98it/s]2025-06-02 10:43:18.428 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/pcnfernando/ballerina-lang/commits/c346c7b426cbd564429ca4dd812ace6e21d1772e
# 2025-06-02 10:43:18.613 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/54e7cf44d048b5eb3f8946cd247eabd3c25ffd10
# 2025-06-02 10:43:18.811 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/pramodya1994/ballerina-lang/commits/c30a199c3f79d484a302105a35f92725073ce27c
# Processing commit data results:   4%|▎         | 81/2308 [00:08<04:21,  8.50it/s]2025-06-02 10:43:18.816 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/rdulmina/ballerina-lang/commits/5358e33984ce47ec1eef5f9b4ea7b5597e2d8d62
# 2025-06-02 10:43:18.843 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/nadeeshaan/ballerina/commits/dedd263369c58c174b4b0236dc6e1158cb656a1a
# 2025-06-02 10:43:18.885 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/nadeeshaan/ballerina/commits/dedd263369c58c174b4b0236dc6e1158cb656a1a
# 2025-06-02 10:43:18.926 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/af3208953aab11e06227d3a56ae7a5149075bf5a
# Processing commit data results:   4%|▎         | 85/2308 [00:08<03:20, 11.09it/s]2025-06-02 10:43:18.985 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/Ibaqu/ballerina-lang/commits/3a1a8deb8bfe6454b0a8ed1bbed95a88f35f8886
# 2025-06-02 10:43:19.056 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/73acf45368dde4a2612875c206c86bcdef3fe2ed
# 2025-06-02 10:43:19.127 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/80ac3ceba0cc941eab65a3a7229e14af08ca0804
# Processing commit data results:   4%|▍         | 88/2308 [00:08<03:06, 11.88it/s]2025-06-02 10:43:19.378 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/nadeeshaan/ballerina/commits/dedd263369c58c174b4b0236dc6e1158cb656a1a
# 2025-06-02 10:43:19.926 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/de46c04697d0c89afb82fcb3a99214caa214e53e
# 2025-06-02 10:43:19.944 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/865850e24ff2882178085c7b0ed3948248e5df8c
# 2025-06-02 10:43:19.949 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/e579188782723e7abaa6ce622e4d2fe536150146
# Processing commit data results:   4%|▍         | 91/2308 [00:09<04:57,  7.44it/s]2025-06-02 10:43:19.949 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/Ibaqu/ballerina-lang/commits/783d35ad1a3650be519024e441b052e11851817e
# 2025-06-02 10:43:19.951 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/193dec94d620ed79c00f7091e9df3e334c994ba2
# 2025-06-02 10:43:19.953 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/38f08a3aab39eec395d5e3d90fb6a2d92cbb94c2
# 2025-06-02 10:43:19.953 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/29c5af9c478d0188b012a4ffb4095ebc7c83862d
# 2025-06-02 10:43:20.032 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/2331ee332dd2e43f05a94f2028c9e067047079a1
# 2025-06-02 10:43:20.495 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/9632ed9ad9af98fc1596d75a05a2e19cae8d98f2
# Processing commit data results:   4%|▍         | 98/2308 [00:10<03:58,  9.28it/s]2025-06-02 10:43:20.779 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/370335339026651ad227f84ca26cb8568749670c
# 2025-06-02 10:43:20.881 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/370335339026651ad227f84ca26cb8568749670c
# Processing commit data results:   4%|▍         | 100/2308 [00:10<04:28,  8.24it/s]2025-06-02 10:43:20.881 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/c9f3b8fd6b27ce5c335137c6a08e28622bd07161
# 2025-06-02 10:43:20.910 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/4fce97f123f71d84f87ca06f4685d28f27dc0845
# 2025-06-02 10:43:20.917 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/395ae7273c6deda46bcce72ff31dae2e2311df9b
# 2025-06-02 10:43:20.941 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/75047dc3fe73b0df5fbf0d54f28814171da0a331
# 2025-06-02 10:43:20.943 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/636e761c4106c2369f4fcd83a2f9c37ad375cd72
# 2025-06-02 10:43:20.961 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/IMS94/ballerina-lang/commits/94bb0bb0346307be88adf2e582f61ae9fea71473
# 2025-06-02 10:43:21.045 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/7bc60703d122aa3cb52841e11ff650a37a85300a
# Processing commit data results:   5%|▍         | 107/2308 [00:10<02:51, 12.85it/s]2025-06-02 10:43:21.399 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/54766108100dcc90bcbfe84ccb821de258c31770
# 2025-06-02 10:43:21.677 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/2621054a9adda164c7212cdaf06c878c27737f39
# 2025-06-02 10:43:21.805 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/6d1436122aa44e6305f293d1f6329d2b61b03a66
# Processing commit data results:   5%|▍         | 110/2308 [00:11<04:14,  8.63it/s]2025-06-02 10:43:21.814 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/6c56a04d1f29c704c6b3943b4251e9f1eb23207e
# 2025-06-02 10:43:21.861 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/sanjana/ballerina-lang/commits/7291512df6b188e938eaa08423e5a4d1494b10fd
# 2025-06-02 10:43:21.862 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/azinneera/ballerina-lang/commits/cc934102941d48a01d63b1ca62ae53b0cc8dbe82
# 2025-06-02 10:43:21.879 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/azinneera/ballerina-lang/commits/97a504dc45c986cac8741956cfbb01e83e293f8c
# 2025-06-02 10:43:21.928 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/azinneera/ballerina-lang/commits/1faf35865aaabdb8f3083a33012e43aaadcfcd6d
# Processing commit data results:   5%|▍         | 115/2308 [00:11<03:05, 11.80it/s]2025-06-02 10:43:21.961 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/lasinicl/ballerina-lang/commits/a70cef952313319d250d7880a7c38ca5670cfa24
# 2025-06-02 10:43:22.042 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/rdhananjaya/ballerina-lang/commits/eb45cd6f787917bc1f3949e0fe7df3349ed92d7d
# 2025-06-02 10:43:22.410 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/68704df54ad1b63eca9a8f3447ebe81ceffe1b0f
# Processing commit data results:   5%|▌         | 118/2308 [00:12<03:42,  9.84it/s]2025-06-02 10:43:22.658 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/a21287826f56b01dcaa220043782ac3615f1cbd6
# 2025-06-02 10:43:22.697 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/nadundesilva/module-ballerina-http/commits/3b48daba750ad484e1efcbd8e526ddf05af452b7
# Processing commit data results:   5%|▌         | 120/2308 [00:12<03:59,  9.13it/s]2025-06-02 10:43:22.721 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/nadundesilva/module-ballerina-http/commits/8ad3725658a5580b4b4ed09cfa7a5a6411619110
# 2025-06-02 10:43:22.757 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/nadundesilva/module-ballerina-grpc/commits/a6bf1b23b5513953275a79708b7d613cfe53d959
# 2025-06-02 10:43:22.893 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/11dc08c819671d1986139a54852de7da3d6c26bf
# Processing commit data results:   5%|▌         | 123/2308 [00:12<03:31, 10.32it/s]2025-06-02 10:43:23.023 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/0d52d1213005830f47a154547aa4f4b0509731c8
# 2025-06-02 10:43:23.069 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/module-ballerina-config/commits/61c336e060673f417d0d27f692f4534683ca5d63
# Processing commit data results:   5%|▌         | 125/2308 [00:12<03:28, 10.48it/s]2025-06-02 10:43:23.073 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/374ef12d7652234aecf44c0b0d9c97b10351d45d
# 2025-06-02 10:43:23.130 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/1e3870ba54f2dcb67d8e54f7ae7de374b3dc4531
# 2025-06-02 10:43:23.359 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/0acd42bd2bfed74d3eb78657978b317dbf8f681f
# Processing commit data results:   6%|▌         | 128/2308 [00:12<03:28, 10.48it/s]2025-06-02 10:43:23.580 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/d964ea09c55bf5ba00be1408e81d2ee9ab222a92
# 2025-06-02 10:43:23.642 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/hemikak/ballerina-lang/commits/d492f7197b3688aaf71ad35b787ca3091a1d553b
# Processing commit data results:   6%|▌         | 130/2308 [00:13<03:51,  9.43it/s]2025-06-02 10:43:23.678 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ldclakmal/ballerina-lang/commits/d4e83ab1866cc81aaba1603a2befbf695e4438e8
# 2025-06-02 10:43:23.698 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ldclakmal/ballerina-lang/commits/b839e7b690b7c9203dbe4821e1660100b729b0f7
# 2025-06-02 10:43:23.864 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/b1626eb13d6bd9062c02d1c1b541d2d7216f0bc4
# Processing commit data results:   6%|▌         | 133/2308 [00:13<03:27, 10.47it/s]2025-06-02 10:43:23.960 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ldclakmal/ballerina-lang/commits/5aeeab873561d2bb0e54ee6d8caa2f5198599785
# 2025-06-02 10:43:24.008 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/lnash94/ballerina-lang/commits/20a1bd806b5aa8467fba721713c6ae8edc42b758
# Processing commit data results:   6%|▌         | 135/2308 [00:13<03:16, 11.06it/s]2025-06-02 10:43:24.070 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/lnash94/ballerina-lang/commits/b010447f13b090936b5db4cd9e17c72fd225f30a
# 2025-06-02 10:43:24.111 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/lnash94/ballerina-lang/commits/a60ad768665da0cde274b933f6aef153e4293dcb
# Processing commit data results:   6%|▌         | 137/2308 [00:13<02:54, 12.46it/s]2025-06-02 10:43:24.578 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/Kishanthan/ballerina/commits/802106ddc9666f3d236924402dc5d828a7cec972
# 2025-06-02 10:43:24.578 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ldclakmal/ballerina-lang/commits/44b8fb36e622deacbeedd30252b5464424266570
# Processing commit data results:   6%|▌         | 139/2308 [00:14<04:21,  8.29it/s]2025-06-02 10:43:24.615 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/6f564427acd454203ad8aaf72a19a95d8828facc
# 2025-06-02 10:43:24.644 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ldclakmal/ballerina-lang/commits/d974c632bc0674622c417d206be1f5f388496562
# 2025-06-02 10:43:24.732 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/warunalakshitha/ballerina-lang/commits/b157441134c1e0919823628aa744e49703c667e9
# Processing commit data results:   6%|▌         | 142/2308 [00:14<03:27, 10.46it/s]2025-06-02 10:43:24.756 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/1768bdcae7aea01705b21918d7690b7bacc72978
# 2025-06-02 10:43:24.876 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/pcnfernando/ballerina-lang/commits/658e9c9101a683cd4aa3b1370415656e83d301f8
# Processing commit data results:   6%|▌         | 144/2308 [00:14<03:13, 11.18it/s]2025-06-02 10:43:25.065 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/737374319acaee03d53cfbf0883b5523ba946456
# 2025-06-02 10:43:25.101 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/94fddae642d111000dfe10880653f3c0e95729e0
# Processing commit data results:   6%|▋         | 146/2308 [00:14<03:27, 10.41it/s]2025-06-02 10:43:25.196 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/f9fba880cf0365ceec922e48af46ff1528fa8836
# 2025-06-02 10:43:25.513 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/2bd9eb8ffe1597be8dbcaa3c116d1569b85438bb
# Processing commit data results:   6%|▋         | 148/2308 [00:15<04:36,  7.80it/s]2025-06-02 10:43:25.528 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/module-ballerina-http/commits/618945f3f3d987cea91039edc444e1a252aa9b54
# 2025-06-02 10:43:25.577 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/Kishanthan/ballerina/commits/5f1d4511eeb1be6559198d4118aa055f5224eff4
# 2025-06-02 10:43:25.652 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/pcnfernando/ballerina-lang/commits/5dc2913459f0bff7bdef8498cc5466da32ba6bed
# Processing commit data results:   7%|▋         | 151/2308 [00:15<03:27, 10.39it/s]2025-06-02 10:43:25.692 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/231bbe9f542968db4280635aa0f520febac6b775
# 2025-06-02 10:43:25.722 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/vinok88/ballerina/commits/e8c27a829eb59a1921843ef5dd242d6fd06d14f2
# 2025-06-02 10:43:25.795 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/vinok88/ballerina/commits/adeae965ee1d462627db6626806ee52178c8adcc
# Processing commit data results:   7%|▋         | 154/2308 [00:15<02:50, 12.62it/s]2025-06-02 10:43:25.959 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/vinok88/ballerina/commits/a4f0686992c4732108634993a74d66d3d1e9aa2d
# 2025-06-02 10:43:26.083 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/8f83a417717509b4316c4dd8790b63bfb03dc262
# Processing commit data results:   7%|▋         | 156/2308 [00:15<03:28, 10.32it/s]2025-06-02 10:43:26.156 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/c46c05c45b5657cfe3f5680769f4ca5de9ddf1ec
# 2025-06-02 10:43:26.489 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/vinok88/ballerina/commits/120cdddec167750a229ccb9b003df101f56b4080
# Processing commit data results:   7%|▋         | 158/2308 [00:16<04:25,  8.11it/s]2025-06-02 10:43:26.568 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/grainier/ballerina/commits/76dbe7f2d70fb6c03eecb853346d0724cb86eec7
# 2025-06-02 10:43:26.652 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/vinok88/ballerina/commits/5419ca73ab7379ef3b47f38fed9b8134f3e01ec2
# Processing commit data results:   7%|▋         | 160/2308 [00:16<03:59,  8.97it/s]2025-06-02 10:43:26.704 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/vinok88/ballerina/commits/d74ee3552bf4ce74737402e34e9601d3899f950f
# 2025-06-02 10:43:26.814 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/vinok88/ballerina/commits/d4c460f787d03b8400f12ff49e41dc9fba39acda
# Processing commit data results:   7%|▋         | 162/2308 [00:16<03:41,  9.69it/s]2025-06-02 10:43:26.872 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/vinok88/ballerina/commits/aeb2ff381b31f39cc621b64cc333bf54a19ce944
# 2025-06-02 10:43:26.959 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/82c73675a56592fa42af974a5f9ffba564aa79da
# Processing commit data results:   7%|▋         | 164/2308 [00:16<03:22, 10.58it/s]2025-06-02 10:43:27.037 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/vinok88/ballerina/commits/40aae99340fdba4ce1c60756790e79192390d08a
# 2025-06-02 10:43:27.079 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/53d7f6b44737362057055f3ba60f18836e6b2bf3
# Processing commit data results:   7%|▋         | 166/2308 [00:16<03:00, 11.88it/s]2025-06-02 10:43:27.199 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/5f607a26eec4def45af2aa11d1d414540dc5734e
# 2025-06-02 10:43:27.394 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/1e2dd2b00482182fe566f39e3faa03d061fc0d1c
# Processing commit data results:   7%|▋         | 168/2308 [00:16<03:46,  9.44it/s]2025-06-02 10:43:27.610 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/f2cba48aa8728837e69462010e877a698b3130ae
# 2025-06-02 10:43:27.662 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/rdhananjaya/ballerina-lang/commits/e064834f82ecaf1855dee1b0718db3ce1f64a313
# Processing commit data results:   7%|▋         | 170/2308 [00:17<04:04,  8.76it/s]2025-06-02 10:43:27.816 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/fac37a7fdcb40a720fface1a97b5e8cab4909772
# 2025-06-02 10:43:27.868 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/KosalaHerath/ballerina-lang/commits/741c138bcd2df9d307665e0109d9cd86e163bf0a
# Processing commit data results:   7%|▋         | 172/2308 [00:17<03:56,  9.03it/s]2025-06-02 10:43:27.907 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/88a967aed5df844e1c8b642e78f1c455f06f1e22
# 2025-06-02 10:43:27.946 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/fd42645876b3d7cb8233a7d44c98ac92fbe7fa34
# 2025-06-02 10:43:28.078 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/f626b0e5a40fff96f83170c2a898c8fd57a5ee52
# Processing commit data results:   8%|▊         | 175/2308 [00:17<03:22, 10.52it/s]2025-06-02 10:43:28.116 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/ballerina-lang/commits/b5dd7dda3840950847dbe63383a1d9953eb8ed41
# 2025-06-02 10:43:28.331 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/ballerina-lang/commits/fc7e4ba9f1c58fc57b68e4bc56155a637fa72fc2
# Processing commit data results:   8%|▊         | 177/2308 [00:17<03:40,  9.68it/s]2025-06-02 10:43:28.470 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/TharushiJay/ballerina-lang/commits/6fe955d95cf955d9bc399a9624461823255a0fb0
# 2025-06-02 10:43:28.598 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/c6de6389407ce6e189fab4df1ebeee1adf4e6088
# Processing commit data results:   8%|▊         | 179/2308 [00:18<04:01,  8.83it/s]2025-06-02 10:43:28.690 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/ballerina-lang/commits/9a8efd1a106f08ef3045846bd68cd3b14a93e5b7
# 2025-06-02 10:43:28.753 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/ballerina-lang/commits/546b3c40b16ff4b2ab10f47a6904d78853018ae8
# Processing commit data results:   8%|▊         | 181/2308 [00:18<03:35,  9.88it/s]2025-06-02 10:43:28.813 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/kaviththiranga/ballerina-1/commits/42bd1f7d03a8d2e15a74ff3656489328c1c33caf
# 2025-06-02 10:43:28.861 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/prabushi/plugin-vscode/commits/e91717b7f512ae9262ccbb292b4cb7d394d5d71f
# Processing commit data results:   8%|▊         | 183/2308 [00:18<03:07, 11.34it/s]2025-06-02 10:43:28.870 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/ballerina-lang/commits/eec050af065fe31994624b1f00979d432e393f5e
# 2025-06-02 10:43:29.004 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/ballerina-lang/commits/358757b663eff6f23d3a94f1b8935ba33b595592
# Processing commit data results:   8%|▊         | 185/2308 [00:18<02:56, 12.01it/s]2025-06-02 10:43:29.067 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/a7b8297621b9703c75ccf756f5f55bed85a4ad25
# 2025-06-02 10:43:29.228 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/ballerina-lang/commits/e7f06fb2ac6f99f67148742c60fc317de62c9df8
# Processing commit data results:   8%|▊         | 187/2308 [00:18<03:18, 10.69it/s]2025-06-02 10:43:29.374 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/ballerina-lang/commits/d7e4b918639020e77c6f37cd6d0af6715d23db8a
# 2025-06-02 10:43:29.494 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/ballerina-lang/commits/6762953bcce25ba499e81d91b3367f2a2cdddf25
# Processing commit data results:   8%|▊         | 189/2308 [00:19<03:43,  9.50it/s]2025-06-02 10:43:29.578 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/aashikam/ballerina-lang/commits/d4e9dbdad111d794156a332d970b05519752f4fb
# 2025-06-02 10:43:29.698 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/64ccf0b21fb2cae9991feca053be0f4561e728db
# Processing commit data results:   8%|▊         | 191/2308 [00:19<03:36,  9.76it/s]2025-06-02 10:43:29.723 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/d1801381dbd28dbea706a31770af5672e250636e
# 2025-06-02 10:43:29.759 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/802e1265b8a9750047618ba21ecd5a79bc1c31b7
# 2025-06-02 10:43:29.775 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/riyafa/ballerina/commits/9668eb2c0222e4ce29a86630a02015164a254d65
# 2025-06-02 10:43:29.915 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/dd8711d10ec72cf15160433fee1d8db03375f3a9
# Processing commit data results:   8%|▊         | 195/2308 [00:19<02:49, 12.45it/s]2025-06-02 10:43:29.990 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/5d2fe43589f4e9d6d8dea32d20ff5a33f36331c3
# 2025-06-02 10:43:30.165 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/38831f1d1061f5f003b6bd49e8409e677dc74b12
# Processing commit data results:   9%|▊         | 197/2308 [00:19<03:11, 11.00it/s]2025-06-02 10:43:30.360 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/cb4d1145f815cbba6c3c027e266239392988c628
# 2025-06-02 10:43:30.378 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/2e2b172b7cdbe526f197b02e8c865037c36805a7
# Processing commit data results:   9%|▊         | 199/2308 [00:19<03:21, 10.48it/s]2025-06-02 10:43:30.561 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/e8408a985d9230eec97bde775b0cfdaaa2212a87
# ...
# 2025-06-02 10:46:54.844 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/djkevincr/ballerina/commits/cbf310133148e88da0e0523b68427becd02305e6
# Processing commit data results:  97%|█████████▋| 2249/2308 [03:44<00:06,  8.70it/s]2025-06-02 10:46:55.013 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/b11ec4bed43a105e0e0662b1ffdf63b4f59360f0
# 2025-06-02 10:46:55.196 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/Anoukh/ballerina-lang/commits/e5f4b99852d088329074968cf6c99e654e452413
# Processing commit data results:  98%|█████████▊| 2251/2308 [03:44<00:07,  7.63it/s]2025-06-02 10:46:55.253 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/375e7b5c1405a5e3e095803a4de2d9ce54c16b20
# 2025-06-02 10:46:55.363 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/9115bf81d9979f567279795e58ba4b390d69f23d
# Processing commit data results:  98%|█████████▊| 2253/2308 [03:44<00:06,  8.50it/s]2025-06-02 10:46:55.463 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/1d76822b0919623cea40ccc48704776129cb6af7
# 2025-06-02 10:46:55.597 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/35f569e8d040ee39a60b8cbf2681fdd6530e1f8c
# Processing commit data results:  98%|█████████▊| 2255/2308 [03:45<00:06,  8.35it/s]2025-06-02 10:46:55.680 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/a9c0de3c74ad99538ca972d66560270d3290e9e6
# 2025-06-02 10:46:55.696 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/ecaa6ffcbdb36135945754d8a7cd2f8a9357c952
# 2025-06-02 10:46:55.830 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/9fa7a7c369e554b0e2ead3c5825d668171b212bd
# Processing commit data results:  98%|█████████▊| 2258/2308 [03:45<00:05,  9.61it/s]2025-06-02 10:46:55.996 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/fc5d0cb4010f964e89b5e25c5864d74db40e3a29
# 2025-06-02 10:46:56.145 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/chamil321/ballerina/commits/6ee2987619760279860d1e4ebb81038783494e52
# Processing commit data results:  98%|█████████▊| 2260/2308 [03:45<00:05,  8.56it/s]2025-06-02 10:46:56.249 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/irunika/ballerina/commits/7fd763a9296464293be68abc42079cf84c26a1ec
# Processing commit data results:  98%|█████████▊| 2261/2308 [03:45<00:05,  8.74it/s]2025-06-02 10:46:56.366 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/roonyh/ballerina/commits/7dc43e94cc88cf41c7a275ed09a8d4e731d087ac
# Processing commit data results:  98%|█████████▊| 2262/2308 [03:45<00:05,  8.78it/s]2025-06-02 10:46:56.497 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/djkevincr/ballerina/commits/3164d335f668b915306fcb099ebe137bd6003693
# Processing commit data results:  98%|█████████▊| 2263/2308 [03:46<00:05,  8.51it/s]2025-06-02 10:46:56.597 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/d03540f8cda0c40fdb99203d2ddc36822705ce72
# Processing commit data results:  98%|█████████▊| 2264/2308 [03:46<00:04,  8.80it/s]2025-06-02 10:46:56.731 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/ba18d5fd5e1a3aef35033a70a3a5441775d79d09
# Processing commit data results:  98%|█████████▊| 2265/2308 [03:46<00:05,  8.14it/s]2025-06-02 10:46:56.816 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/srsharon/ballerina-lang/commits/26a93cd81b13fc14c22bdd2185bf99377d2fb3f2
# 2025-06-02 10:46:56.985 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/5c642ca4cc632ae9df512aebb8fdf66f8a088e7a
# Processing commit data results:  98%|█████████▊| 2267/2308 [03:46<00:04,  8.22it/s]2025-06-02 10:46:57.280 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/96d920f636ec066693e6657888c32f54d7274f78
# Processing commit data results:  98%|█████████▊| 2268/2308 [03:46<00:06,  6.23it/s]2025-06-02 10:46:57.413 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/2c46bf9322cc67146e9049b073d92a567a710338
# Processing commit data results:  98%|█████████▊| 2269/2308 [03:47<00:05,  6.50it/s]2025-06-02 10:46:57.497 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/CharukaK/ballerina/commits/0aeaf9cdaed975a963ca7e346b94ecc652e16562
# 2025-06-02 10:46:57.513 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/179b66eec1cb27586a3803929a7ca69b733efccd
# 2025-06-02 10:46:57.763 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/malinthar/ballerina-lang/commits/b124b6890295a0913d346319fe1b9e5f73b0fc45
# Processing commit data results:  98%|█████████▊| 2272/2308 [03:47<00:04,  7.42it/s]2025-06-02 10:46:57.813 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/e0850785082b9b6dacc2560162385a08bb696c46
# 2025-06-02 10:46:57.855 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/pcnfernando/ballerina-lang/commits/2852e8a326c19689ee54f30716fbeac3bf70a0aa
# 2025-06-02 10:46:58.080 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/chamil321/ballerina/commits/86cc4ee4504b5efb1ca3baf835de7848b78046ae
# Processing commit data results:  99%|█████████▊| 2275/2308 [03:47<00:04,  8.17it/s]2025-06-02 10:46:58.080 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/djkevincr/ballerina/commits/9e0f11196435336a2a7816a01c0729c40ac8f40b
# 2025-06-02 10:46:58.380 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/b950836873bec28d159d755ddf0116f5eed5265e
# Processing commit data results:  99%|█████████▊| 2277/2308 [03:47<00:04,  7.67it/s]2025-06-02 10:46:58.396 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/chamil321/ballerina/commits/8a700a006de671f46e73c792242e0c818902bc9d
# 2025-06-02 10:46:58.478 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/Anoukh/ballerina-lang/commits/d2dbcef0baf83be90b38c27817422fcd3c4b9bc6
# Processing commit data results:  99%|█████████▊| 2279/2308 [03:48<00:03,  9.34it/s]2025-06-02 10:46:58.564 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/d4bf88d22a7ea1a94a3bad528645539c83510056
# 2025-06-02 10:46:58.762 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/61d0d5090c6b26e098b04d94f0762cb3c106cd7e
# Processing commit data results:  99%|█████████▉| 2281/2308 [03:48<00:03,  8.54it/s]2025-06-02 10:46:58.813 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/srsharon/ballerina-lang/commits/3f4f2eecde6d59f7f7667402edb1a0c5d033a6c8
# 2025-06-02 10:46:58.965 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/Anoukh/ballerina-lang/commits/39c4ec99330cccce21072454b97d7c61ff84a1a7
# Processing commit data results:  99%|█████████▉| 2283/2308 [03:48<00:02,  8.73it/s]2025-06-02 10:46:59.098 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/8035f88708d799964620722b9a83796991109fa4
# Processing commit data results:  99%|█████████▉| 2284/2308 [03:48<00:02,  8.49it/s]2025-06-02 10:46:59.380 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/32ad39f582cc844cd51f41fb46e1516bcc9b581f
# Processing commit data results:  99%|█████████▉| 2285/2308 [03:48<00:03,  6.77it/s]2025-06-02 10:46:59.413 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/b3bb50b919bac60e267dda878b7ecc91e82f4446
# 2025-06-02 10:46:59.430 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/CharukaK/ballerina/commits/739ceba4569ddf1f716dae752ca4dbec6ec21344
# 2025-06-02 10:46:59.530 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/611daa5d828d2fa81e6df7cda4043e668aa584b8
# Processing commit data results:  99%|█████████▉| 2288/2308 [03:49<00:02,  9.48it/s]2025-06-02 10:46:59.740 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/malinthar/ballerina-lang/commits/ce9b7097aac96063e819831f1742cbed4c2d6995
# 2025-06-02 10:46:59.875 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/74492009fac1ea9910cd462e49a67e6b7c23b6d7
# Processing commit data results:  99%|█████████▉| 2290/2308 [03:49<00:02,  8.13it/s]2025-06-02 10:46:59.891 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/irunika/ballerina/commits/8fc924289ecd16c8a53783a7d5a54f99fe2fd2c6
# 2025-06-02 10:46:59.906 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/6d76b038fcdcdfb907acbba640f0e2be01eea490
# 2025-06-02 10:47:00.000 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/286236a12784182bdece1ac2872f1d8cba6708a7
# Processing commit data results:  99%|█████████▉| 2293/2308 [03:49<00:01, 10.75it/s]2025-06-02 10:47:00.298 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/djkevincr/ballerina/commits/687f502157cf5dd719bb01b5001c70ca9e78bf64
# 2025-06-02 10:47:00.424 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/manuranga/ballerina/commits/86efb69f33c6914aa430f450ee84e990e8ffd1d3
# 2025-06-02 10:47:00.424 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/Anoukh/ballerina-lang/commits/f6ae3f6d0a60c0770ae5031e16d5b5835bca5adb
# Processing commit data results:  99%|█████████▉| 2295/2308 [03:50<00:01,  7.97it/s]2025-06-02 10:47:00.487 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/7b6170d794a8b037d51182ab66e99ac0fa3f014e
# 2025-06-02 10:47:00.565 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/f1995fa4393c64b3a80c87fdf7e5231bb6f0d64b
# Processing commit data results: 100%|█████████▉| 2298/2308 [03:50<00:00, 10.36it/s]2025-06-02 10:47:00.863 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/9dd1c7d7469ea629c5169134561c26ba3a16bf01
# 2025-06-02 10:47:00.895 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/a016a2292fe438605fc436fdd0e7d673c68b153e
# Processing commit data results: 100%|█████████▉| 2300/2308 [03:50<00:00,  8.91it/s]2025-06-02 10:47:01.067 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/mohanvive/ballerina-lang/commits/fcd2805a9773e5cbb1e1617e33568bdd8384b157
# 2025-06-02 10:47:01.209 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/7e3825d226ffd4fc02c44c19fc3fe40f876b106d
# Processing commit data results: 100%|█████████▉| 2302/2308 [03:50<00:00,  8.04it/s]2025-06-02 10:47:01.236 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/MaryamZi/ballerina/commits/1e2d729c368f6311cee3789d05244cc98d09c37e
# 2025-06-02 10:47:01.413 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/9092281904a9f9146870449f16a3d8b5798ad497
# Processing commit data results: 100%|█████████▉| 2304/2308 [03:51<00:00,  8.46it/s]2025-06-02 10:47:01.468 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/ac8ba523d8b0491a226b3e00064378c8bb7c6c52
# 2025-06-02 10:47:01.538 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/4a8f3a320b2313d4e2f06ec1772e0517c7571b40
# Processing commit data results: 100%|█████████▉| 2306/2308 [03:51<00:00,  9.78it/s]2025-06-02 10:47:01.550 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/gayalkuruppu/ballerina-lang/commits/24f2a06e0423abbea877541807d4dbf9c03093f2
# 2025-06-02 10:47:01.660 | SUCCESS  | __main__:get_commit_data:17 - ✅ Successfully fetched commit data from https://api.github.com/repos/ballerina-platform/ballerina-lang/commits/9c5d6e892bf5214201cce00f5742fa9502c0a681
# Processing commit data results: 100%|██████████| 2308/2308 [03:51<00:00,  9.98it/s]
# 2025-06-02 10:47:01.664 | INFO     | __main__:<module>:42 - Finished fetching commit data. 2308 events processed into commit details.
# 2025-06-02 10:47:01.760 | INFO     | __main__:<module>:48 - Saved 2308 records with commit data to ../../data/commit_id-linking/pr-issue/linked_pull_request_commite_id.csv.
# 2025-06-02 10:47:01.760 | INFO     | __main__:<module>:52 - ✅ Initial commit data processing complete.

# %% [markdown]
# getting commit url

# %%
# Function to parse owner and repo from a GitHub commit URL
def parse_commit_url(commit_url):
    if pd.isna(commit_url) or not isinstance(commit_url, str):
        logger.warning(f"Invalid commit_url for parsing: {commit_url}")
        return None, None
    # Regex for HTML URLs like https://github.com/owner/repo/commit/sha
    match = re.search(r"https://github.com/([^/]+)/([^/]+)/commit/.*", commit_url)
    if match:
        return match.group(1), match.group(2)
    
    # Regex for API URLs like https://api.github.com/repos/owner/repo/commits/sha
    # This is a fallback, as current 'linked_commit_url' seems to be HTML URLs
    match_api = re.search(r"https://api.github.com/repos/([^/]+)/([^/]+)/commits/.*", commit_url)
    if match_api:
        return match_api.group(1), match_api.group(2)
        
    logger.warning(f"Could not parse owner/repo from URL: {commit_url}")
    return None, None

# %% [markdown]
# search for issue refference

# %%
# csv_path = "../../data/commit_id-linking/pr-issue/linked_pull_request_commite_id.csv"

# Load the CSV file into a DataFrame
df = pd.read_csv(csv_path)

def extract_issue_details_from_commit(row: pd.Series) -> pd.Series:
    """
    Extracts an issue number from a commit message and constructs a full GitHub issue link.
    """
    commit_message = str(row.get('linked_commit_message', ''))
    if pd.isna(commit_message) or not commit_message.strip():
        return pd.Series([None, None], index=['extracted_issue_number', 'extracted_issue_link'])

    # Covers: fix(es/ed/ing), clos(e/es/ed), resolv(e/es/ed), issue(s)
    keyword_pattern = r'\b(?:fix(?:es|ed|ing)?|clos(?:e|es|ed)|resolv(?:e|es|ed)|issue(?:s)?)\b'

    # Optimized patterns to find issue numbers, ordered by specificity.
    issue_patterns = [
        # Priority 1: Keywords followed by a full GitHub issue or pull request URL.
        rf'{keyword_pattern}\s+https?://github\.com/[^/]+/[^/]+/(?:issues|pull)/(\d+)',

        # Priority 2: Keywords followed by #number.
        rf'{keyword_pattern}\s+#(\d+)\b',

        # Priority 3: Keywords followed by a plain number (no #).
        rf'{keyword_pattern}\s+(\d+)\b',

        # Priority 4: Keywords followed by "Fix <something> (from #number)".
        rf'{keyword_pattern}.*\(from\s+#(\d+)\)',

        # Priority 5: Keywords followed by "Fix <something> #number".
        rf'{keyword_pattern}.*#(\d+)\b',

        # Priority 6: Keywords followed by "part of #number" or "part of issue #number".
        rf'{keyword_pattern}.*(?:#(\d+)\b|part of\s+(?:issue\s+)?#(\d+)\b)',

        # Priority 7: Keywords followed by "/fix-#number" or "/fix-number".
        rf'{keyword_pattern}.*(?:/fix-#(\d+)\b|/fix-(\d+)\b)',

        # Priority 8: Specific pattern to extract issue numbers from "Fixes" URL.
        rf'Fixes:\s+https?://github\.com/[^/]+/[^/]+/issues/(\d+)'

    ]

    
    extracted_issue_number = None
    for pattern in issue_patterns:
        match = re.search(pattern, commit_message, re.IGNORECASE)
        if match:
            # The issue number is in the first captured group for these patterns.
            if match.groups(): 
                 extracted_issue_number = match.group(1)
                 if extracted_issue_number:
                    break  # Found a qualifying issue number, stop searching
    
    if not extracted_issue_number:
        return pd.Series([None, None], index=['extracted_issue_number', 'extracted_issue_link'])

    extracted_issue_link = None
    owner, repo = None, None
    
    commit_url_val = row.get('linked_commit_url')
    if pd.notna(commit_url_val):
        try:
            parsed_info = parse_commit_url(str(commit_url_val))
            if isinstance(parsed_info, tuple) and len(parsed_info) == 2:
                owner_candidate, repo_candidate = parsed_info
                # Ensure owner and repo are strings and not None before assignment
                if isinstance(owner_candidate, str) and isinstance(repo_candidate, str):
                    owner, repo = owner_candidate, repo_candidate
                else:
                    logger.warning(
                        f"parse_commit_url returned non-string owner/repo for URL: {commit_url_val}. "
                        f"Owner type: {type(owner_candidate)}, Repo type: {type(repo_candidate)}. "
                        f"PR: {row.get('pull_request_number', 'N/A')}."
                    )
                    # owner, repo remain None
            elif parsed_info is not None: # If it's None, it means parsing failed gracefully.
                logger.warning(
                    f"parse_commit_url did not return expected owner/repo tuple for URL: {commit_url_val}. "
                    f"Got: {type(parsed_info)}. PR: {row.get('pull_request_number', 'N/A')}."
                )
                # owner, repo remain None
        except Exception as e:
            logger.error(
                f"Exception during parse_commit_url for URL: {commit_url_val}. Error: {e}. "
                f"PR: {row.get('pull_request_number', 'N/A')}."
            )
            # owner, repo remain None
    
    if owner and repo and extracted_issue_number: # Check if owner and repo are valid strings
        extracted_issue_link = f"https://github.com/{owner}/{repo}/issues/{extracted_issue_number}"
    elif extracted_issue_number: 
        # This warning logs if issue number was found but link couldn't be formed
        # (e.g. owner/repo determination failed).
        current_owner_repo_state = f"owner: '{owner}', repo: '{repo}'"
        logger.warning(
            f"Could not determine valid owner/repo ({current_owner_repo_state}) from commit URL: {commit_url_val} "
            f"to form issue link for extracted issue #{extracted_issue_number} "
            f"from PR: {row.get('pull_request_number', 'N/A')}."
        )

    return pd.Series([extracted_issue_number, extracted_issue_link], index=['extracted_issue_number', 'extracted_issue_link'])

# Apply the function to the DataFrame to create new columns
# Ensure that 'linked_commit_message' and 'linked_commit_url' columns exist in df
logger.info("Extracting issue details from commit messages...")
df[['extracted_issue_number', 'extracted_issue_link']] = df.apply(
    extract_issue_details_from_commit, axis=1
)

df_referenced_issues = df.copy()
logger.info(f"Found {len(df_referenced_issues)} commits with extracted issue references.")

# Define the path for the new CSV file
output_csv_path_extracted_issues = "../../data/commit_id-linking/pr-issue/commits_with_extracted_issue_references.csv"

# Save the filtered DataFrame to the new CSV file
if not df_referenced_issues.empty:
    df_referenced_issues.to_csv(output_csv_path_extracted_issues, index=False)
    logger.info(f"Saved DataFrame with extracted issue references to {output_csv_path_extracted_issues}")
else:
    logger.info("No issue references were extracted, so no new CSV file was saved.")
# Out:
# 2025-06-02 12:33:37.279 | INFO     | __main__:<module>:107 - Extracting issue details from commit messages...
# 2025-06-02 12:33:38.113 | INFO     | __main__:<module>:113 - Found 2308 commits with extracted issue references.
# 2025-06-02 12:33:38.197 | INFO     | __main__:<module>:121 - Saved DataFrame with extracted issue references to ../../data/commit_id-linking/pr-issue/commits_with_extracted_issue_references.csv

# %%
output_csv_path_extracted_issues = "../../data/commit_id-linking/pr-issue/commits_with_extracted_issue_references.csv"
# Load the dataset
df_loaded = pd.read_csv(output_csv_path_extracted_issues)
logger.info(f"Loaded dataset from {output_csv_path_extracted_issues}. Shape: {df_loaded.shape}")

# Remove rows where 'issue_number' or 'pr_number' is missing
df_cleaned = df_loaded.dropna(subset=['extracted_issue_number', 'pull_request_number'])
logger.info(f"Shape after dropping rows with missing 'extracted_issue_number' or 'pull_request_number': {df_cleaned.shape}")

# Drop duplicate 'issue_number' and 'pr_number' pairs
# Keep the first occurrence by default
df_cleaned = df_cleaned.drop_duplicates(subset=['extracted_issue_number', 'pull_request_number'], keep='first')
logger.info(f"Shape after dropping duplicate 'extracted_issue_number'-'pull_request_number' pairs: {df_cleaned.shape}")

# Display the first few rows of the cleaned DataFrame and its info
print("Cleaned DataFrame head:")
print(df_cleaned.head())
print("\nCleaned DataFrame info:")
df_cleaned.info()

# Optionally, save the cleaned DataFrame to a new CSV file
cleaned_csv_path = "../../data/commit_id-linking/pr-issue/linked_pr_commit_issue_data_cleaned.csv"
df_cleaned.to_csv(cleaned_csv_path, index=False)
logger.info(f"💾 Cleaned DataFrame saved to {cleaned_csv_path}")
# Out:
# 2025-06-02 15:07:19.471 | INFO     | __main__:<module>:4 - Loaded dataset from ../../data/commit_id-linking/pr-issue/commits_with_extracted_issue_references.csv. Shape: (2308, 9)
# 2025-06-02 15:07:19.471 | INFO     | __main__:<module>:8 - Shape after dropping rows with missing 'extracted_issue_number' or 'pull_request_number': (515, 9)
# 2025-06-02 15:07:19.485 | INFO     | __main__:<module>:13 - Shape after dropping duplicate 'extracted_issue_number'-'pull_request_number' pairs: (426, 9)
# 2025-06-02 15:07:19.527 | INFO     | __main__:<module>:24 - 💾 Cleaned DataFrame saved to ../../data/commit_id-linking/pr-issue/linked_pr_commit_issue_data_cleaned.csv
# Cleaned DataFrame head:
#     pull_request_number                                  pull_request_link  \
# 5                 42717  https://github.com/ballerina-platform/ballerin...
# 8                 43067  https://github.com/ballerina-platform/ballerin...
# 14                38624  https://github.com/ballerina-platform/ballerin...
# 22                38590  https://github.com/ballerina-platform/ballerin...
# 31                38563  https://github.com/ballerina-platform/ballerin...
#
#                                    pull_request_title  \
# 5         Warn about corruption in Dependencies.toml.
# 8            Improve the caching of lang gradle build
# 14  Fix completions in the field access expression...
# 22  Fix missing Fill required fields code action w...
# 31  Fix completions for quote identifier given wit...
#
#                                     pull_request_body  \
# 5   ## Purpose\r\n> Describe the problems, issues,...
# 8   ## Purpose\r\n> Fix the up-to-date checking of...
# 14  ## Purpose\r\n> $Title\r\n\r\nFixes #38457\r\n...
# 22  ## Purpose\r\n> $Title\r\n\r\nFixes #38463\r\n...
# 31  ## Purpose\r\n$subject\r\n\r\nFixes #38485\r\n...
#
#                             linked_commit_id  \
# 5   e26c61edbb0b53de3ef0d365800f9508ddb89cf1
# 8   1622a6f8dadc587e809c8d7932b0288d9e57665a
# 14  ec8e4834a36bd34109ef5bd7ff1300050b38581f
# 22  41ec917310592e71d65c2439bb41b613f6dc1044
# 31  79e0dd31f56df779f2f5a1f34530efa5d2a5869a
#
#                                     linked_commit_url  \
# 5   https://github.com/Shadow-Devil/ballerina-lang...
# 8   https://github.com/Shadow-Devil/ballerina-lang...
# 14  https://github.com/IMS94/ballerina-lang/commit...
# 22  https://github.com/IMS94/ballerina-lang/commit...
# 31  https://github.com/IMS94/ballerina-lang/commit...
#
#                                 linked_commit_message  extracted_issue_number  \
# 5   Fix testcase for new warning about corrupted D...                 42717.0
# 8              Fix caching issue introduced in #43067                 43067.0
# 14  Fix field access comps after type narrowing in...                 38624.0
# 22  Fix FillRecordFieldsCodeAction for rem-method-...                 38590.0
# 31  Fix completions for quote identifier given wit...                 38563.0
#
#                                  extracted_issue_link
# 5   https://github.com/Shadow-Devil/ballerina-lang...
# 8   https://github.com/Shadow-Devil/ballerina-lang...
# 14  https://github.com/IMS94/ballerina-lang/issues...
# 22  https://github.com/IMS94/ballerina-lang/issues...
# 31  https://github.com/IMS94/ballerina-lang/issues...
#
# Cleaned DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 426 entries, 5 to 2232
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pull_request_number     426 non-null    int64
#  1   pull_request_link       426 non-null    object
#  2   pull_request_title      426 non-null    object
#  3   pull_request_body       104 non-null    object
#  4   linked_commit_id        426 non-null    object
#  5   linked_commit_url       426 non-null    object
#  6   linked_commit_message   426 non-null    object
#  7   extracted_issue_number  426 non-null    float64
#  8   extracted_issue_link    426 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 33.3+ KB
